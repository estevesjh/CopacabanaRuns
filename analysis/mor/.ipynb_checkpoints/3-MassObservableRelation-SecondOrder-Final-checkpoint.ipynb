# %% [markdown]
# # Second Order Mass-Observable Relation Fit
#
# Here we try to fit a second order mu-m200 mass observable relation. We disscuss the evolution of the slope.

# %% [markdown]
# ## Packages

# %%
import matplotlib.pyplot as plt
import matplotlib
plt.rcParams.update({'font.size': 16})
#Plotting parameters
import matplotlib as mpl

mpl.rcParams['xtick.direction'], mpl.rcParams['ytick.direction'] = 'in', 'in'
mpl.rcParams['xtick.major.size'], mpl.rcParams['xtick.minor.size'] = 14, 8
mpl.rcParams['xtick.major.width'], mpl.rcParams['xtick.minor.width'] = 1.2, 0.8
mpl.rcParams['xtick.major.pad'], mpl.rcParams['xtick.minor.pad'] = 10, 10
mpl.rcParams['ytick.major.size'], mpl.rcParams['ytick.minor.size'] = 14, 8
mpl.rcParams['ytick.major.width'], mpl.rcParams['ytick.minor.width'] = 1.2, 0.8
mpl.rcParams['xtick.labelsize'], mpl.rcParams['ytick.labelsize'] = 20, 20

# Parameters used in this module
# One dictionary to store default values
# Another that user can view/change as necessary
Default_Params = {'default_cmap'   : plt.cm.coolwarm,
                  'title_fontsize' : 25,
                  'legend_fontsize': 22,
                  'xlabel_fontsize': 30,
                  'ylabel_fontsize': 30,
                  'scatter_factor' : 1.0}

Params = Default_Params.copy()

import seaborn as sns; sns.set(color_codes=True)
sns.set_style("whitegrid")

import numpy as np
from scipy.interpolate import interp1d
import scipy

from astropy.table import Table, vstack
from astropy.io.fits import getdata
import pandas as pd

# %%
import sys
sys.path.append("/home/s1/jesteves/git/ccopa/python/")
from main import copacabana
# Out:
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Load Data

# %%
root = '/home/s1/jesteves/git/buzzardAnalysis/mainAnalysis/'
cfg  = root+'config_buzzard_v2.yaml'

copa = copacabana(cfg,dataset='buzzard_v2')
# Out:
# master file:
#  /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00017.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00018.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00019.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00020.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00022.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00032.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00033.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00034.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00035.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00038.hdf5
# ...

# %%
run_name = u'gauss003_r200_02Lstar_nfw'
cat = copa.load_copa_out('cluster',run_name)

mask = (cat['redshift']<=0.65)&(cat['redshift']>=0.20)&(cat['MU']>0.)&(cat['Ngals_true']>=1.)

print('masked fraction: %.2f'%(1.*np.count_nonzero(mask)/len(cat)))
cat  = cat[mask] 

cat.rename_column('M200_true','M200')
# Out:
# masked fraction: 0.68
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/astropy/table/column.py:954: RuntimeWarning: invalid value encountered in greater
#   return getattr(self.data, op)(other)

# %%
## load uniform, lambda>5, lambda>20

outpath = '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/to_heidi/'
# fname   = outpath+'buzzard_v2_lambda_gt20_mu-star_rhod.fits'
fname   = outpath+'buzzard_v2_lambda_gt5_small_mu-star_r200.fits'

joined = Table(getdata(fname))

# %%
cols = ['MU','Ngals','MU_TRUE','Ngals_true','MU_ERR_JK','MU_TRUE_ERR_JK']
for col in cols:
    joined[col] = joined['%s_%s'%(col,run_name[:-4])]

mask = (joined['Ngals_true']>=1)&(joined['MU']>0.)

lbd5 = joined[(joined['LAMBDA_CHISQ']>=5.)&mask]
lbd20= joined[(joined['LAMBDA_CHISQ']>=20.)&mask]

# %%
print('uniform sample size: %i'%len(cat))
print('lbd>5   sample size: %i'%len(lbd5))
print('lbd>20  sample size: %i'%len(lbd20))
# Out:
# uniform sample size: 1803
# lbd>5   sample size: 61126
# lbd>20  sample size: 8624

# %%
#joined[joined['MU']<1.]

# %%
lbd5.w
# Out:
# <Table length=61126>
#  haloid         M200       ...     MU_ERR_JK        MU_TRUE_ERR_JK
#  int32        float32      ...      float64            float64
# -------- ----------------- ... ------------------ ------------------
#  7673687  96510000000000.0 ... 39.770577265841276  48.40154635509612
#  7674995  40720000000000.0 ... 11.892833257222746  32.60855376365977
#  7675586  19090000000000.0 ...   8.52793872448362 11.417414204118389
#  7676255  15670000000000.0 ... 12.262326054354933 16.408690564766356
#  7691957  14940000000000.0 ... 12.880403554757281  18.61820149477524
#  7692083 108900000000000.0 ...  24.02495895510334 32.787250429484736
#  7692096 170900000000000.0 ...   41.8224017482648  51.31831816585523
#  7692569 123100000000000.0 ...  9.398869417165157  57.23218574449017
#  7692660  90420000000000.0 ...  41.40742430533155 45.767929967480654
#  7692886  69920000000000.0 ...  25.69647703194448  27.69008831495554
# ...

# %%
def get_variables(data,Mp=1e14,Mup=1e12):
    x = np.array(data['M200'])
    y = np.array(data['MU_TRUE']*1e10)
    yt= np.array(data['MU_TRUE_ERR_JK']*1e10)
    return np.log10(x/Mp), np.log10(y/Mup), yt/Mup
#     return x, y, yt

# %%
datasets  = [cat,lbd5,lbd20]
dataLabels= ['Uniform','Lambda>5','Lambda>20']

# %%
varlist = dict()
Mp, Mup = 10.**15.5, 5.03e+11

for di,li in zip(datasets,dataLabels):
    x1, y1, y1err = get_variables(di , Mp, Mup)
    varlist[li] = [x1,y1,y1err]

# %% [markdown]
# ### Mass Distribution

# %%
units  = '\; [M_{\odot}]'
ylabel = r'$ \mu_{\star} %s$'%units
xlabel = r'$ M_{200} %s$'%units

# %%
massbins = np.logspace(13.,15.1,21)

for col in varlist.keys():
    x,y,_ = varlist[col]
    _ = plt.hist(10**x*Mp,bins=massbins,label=col,histtype='step',lw=3,density=False)

plt.xscale('log')
plt.legend(fontsize=12)
plt.yscale('log')
plt.xlabel(xlabel,fontsize=12)
# Out:
# Text(0.5,0,'$ M_{200} \\; [M_{\\odot}]$')

# %%
mubins = np.logspace(10.,13.5,21)

for col in varlist.keys():
    x,y,_ = varlist[col]
    _ = plt.hist(10**y*Mup,bins=mubins,label=col,histtype='step',lw=3,density=False)

plt.xscale('log')
# plt.legend(fontsize=12)
plt.yscale('log')
plt.xlabel(ylabel,fontsize=16)
# Out:
# Text(0.5,0,'$ \\mu_{\\star} \\; [M_{\\odot}]$')

# %% [markdown]
# ### mu-star distribution

# %%
fig = plt.figure(figsize=(12,4))

for i,col in enumerate(varlist.keys()):
    x,y,yerr = varlist[col]
    x,y,yerr = 10**x,10**y, 10**yerr
    ni = '13%i'%(i+1)
    ax = fig.add_subplot(int(ni))
    ax.loglog()
    # ax.scatter(x, y1,alpha=0.5)
    ax.errorbar(x[::5]*Mp, y[::5]*Mup, xerr=yerr[::5]*Mup, ls=' ',fmt='o', markersize=8, capsize=20, alpha=0.2)
    ax.set_title(col)
    ax.set_xlim(10**12.7,10**15.5)
    ax.set_ylim(10**10.,10**13.8)
    
    ax.set_xlabel(xlabel)
    if i==0:
        ax.set_ylabel(ylabel)

# %% [markdown]
# # Second Order Model

# %%
def qmodel(theta,x):
    a, b, c = theta
    return a*x**2 + b*x + c
    
def lnlike(theta, x, y, yerr):
    a, b, c, ln_sig = theta
    model = a*x**2 + b*x + c
    inv_sigma2 = 1.0/(yerr**2 + ln_sig**2)
    return -0.5*(np.sum((y-model)**2*inv_sigma2 - np.log(inv_sigma2)))

# %%
def lnprior(theta):
    a, b, c, ln_sig = theta
    if (0. < ln_sig < 0.5):
        return 0.
    return -np.inf

# %%
def lnprob(theta, x, y, yerr):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(theta, x, y, yerr)

# %%
from scipy import odr

quad_model = odr.Model(qmodel)
def fit_poly_2nd(x,y,yerr=None,guess=[0.3,0.7,1.]):
    # Create a RealData object
    data = odr.RealData(x, y, sy=yerr)

    # Set up ODR with the model and data.
    model = odr.ODR(data, quad_model, beta0=guess, maxit=100)

    # Run the regression.
    out  = model.run()
    
    #print fit parameters and 1-sigma estimates
    popt = out.beta
    perr = out.sd_beta
    
    dof  = len(y)-1
    sig2 = np.sqrt(np.sum((y - qmodel(popt,x))** 2) / dof)
    
    popt = np.append(popt,sig2)
    perr = np.append(perr,np.array([0.075]))
    print('fit parameter 1-sigma error')
    print('———————————–')
    for i in range(len(popt)):
        print('%i: %.5f \t %.5f'%(i, popt[i],perr[i]))
    return popt, perr

# %%
## Run Emcee

# %%
x0_prior_min = np.array([0.2,1.25,1.6,0.10])
x0_prior_max = np.array([0.4,1.75,2.5,0.25])

import emcee
def run_emcee(x,y,yerr,nsteps=1000,nwalkers=100,discard=100):
    guess,gerr = fit_poly_2nd(x,y,1/np.sqrt(10**y))

    ndim= 4
    pos = [guess + gerr*np.random.randn(ndim) for i in range(nwalkers)]
    print(pos[0])
    #pos = list(np.array([np.random.uniform(xmin,xmax, nwalkers) for xmin, xmax in zip(x0_prior_min,x0_prior_max)]).T)

    sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(x, y, yerr))
    sampler.run_mcmc(pos, nsteps)
    
    samples = sampler.chain[:, discard:, :].reshape((-1, ndim)).copy()
    sampler.reset()
    return samples

def get_emcee_results(samples,p=[2.5,97.5]):
    pars = list(map(lambda v: (v[1], v[2], v[0]), zip(*np.percentile(samples, [p[0], 50, p[1]],axis=0))))
    mydict  = dict()
    mypars  = ['beta2','beta1','alpha','scatter']
    for li, ppi in zip(mypars,pars):
        for mi,pi in zip(['','+','-'],ppi):
            mydict[li+mi] = pi
    return mydict

# %% [markdown]
# ## Perform Fit

# %%
from fit_mor_evolution import mass_observable_relation, save_mor_results, load_mor_results, makeBin

# %%
data=lbd5
Mp, Mup = 10.**15.5, 5.03e+11

x     = np.array(data['M200']/Mp)
y1    = np.array(data['MU']*1e10/Mup)
y1err = np.array(data['MU_ERR_JK']*1e10/Mup)
y2    = np.array(data['MU_TRUE']*1e10/Mup)
y2err = np.array(data['MU_TRUE_ERR_JK']*1e10/Mup)

zcls = np.array(data['redshift'])

# %%
zbins = np.percentile(zcls,np.linspace(0,100,13))
# zbins = np.array([0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])

zkeys, zmed = makeBin(zcls,zbins)
zlabel = [r'%.3f < z < %.3f'%(zl,zh) for zl,zh in zip(zbins[:-1],zbins[1:])]

# %%
outs = []

print('Evolution Fit')
for idx,zli in zip(zkeys,zlabel):
    mor = mass_observable_relation()
    print('zbin: %s'%zli)
    mor.add_dataset('observed',x[idx],y1[idx],y1err[idx],y_label='mu_obs')
    mor.fit_emcee('observed',is_log=True,percentile=[16,84], nsteps=500, nwalkers=80)
    
    mor.add_dataset('true',x[idx],y2[idx],y2err[idx],y_label='mu_tru')
    mor.fit_emcee('true',is_log=True,percentile=[16,84], nsteps=500, nwalkers=80)
    
    outs.append(mor)
    print('\n')
    
print('done')
# Out:
# Evolution Fit
# Welcome Mass-Observable Relation Fit
# zbin: 0.200 < z < 0.276
# fit parameter 1-sigma error
# 0: 0.20787 	 0.01308
# 1: 1.34232 	 0.04610
# 2: 1.85398 	 0.03919
# 3: 0.21935 	 0.07500
# [0.20877366 1.32472045 1.85965406 0.14283538]
# fit parameter 1-sigma error
# 0: 0.27237 	 0.01123
# 1: 1.51629 	 0.04010
# 2: 1.96709 	 0.03465
# 3: 0.18985 	 0.07500
# [0.26856493 1.50870161 1.95576584 0.26285267]
#
#
# Welcome Mass-Observable Relation Fit
# zbin: 0.276 < z < 0.330
# fit parameter 1-sigma error
# 0: 0.17231 	 0.01471
# 1: 1.23732 	 0.05224
# 2: 1.83688 	 0.04497
# 3: 0.22316 	 0.07500
# [0.1519619  1.21383476 1.83502913 0.24342223]
# fit parameter 1-sigma error
# 0: 0.22546 	 0.01212
# 1: 1.35961 	 0.04346
# 2: 1.90078 	 0.03784
# 3: 0.18789 	 0.07500
# [0.22227128 1.35344772 1.92578055 0.27911534]
#
#
# Welcome Mass-Observable Relation Fit
# zbin: 0.330 < z < 0.375
# fit parameter 1-sigma error
# 0: 0.14413 	 0.01489
# 1: 1.21666 	 0.05273
# 2: 1.96038 	 0.04546
# ...

# %%
import pickle
def save_mor_results(key,outs,root='/data/des61.a/data/johnny/toto'):
    fname = root+'/%s_mass-obsevable_evol.obj'%key
    file_pi = open(fname, 'w') 
    pickle.dump(outs, file_pi)
    file_pi.close()
    
def load_mor_results(key,root='/data/des61.a/data/johnny/toto'):
    fname = root+'/%s_mass-obsevable_evol.obj'%key
    filehandler = open(fname, 'r') 
    p2 = pickle.load(filehandler)
    filehandler.close()
    return p2

# %%
save_mor_results('lbd_gt5_nbins12',[outs,zmed])

# %%
out5, zmed   = load_mor_results('lbd_gt5_nbins12')

# %% [markdown]
# ## Lambda>20

# %%
data=lbd20

x     = np.array(data['M200']/Mp)
y1    = np.array(data['MU']*1e10/Mup)
y1err = np.array(data['MU_ERR_JK']*1e10/Mup)
y2    = np.array(data['MU_TRUE']*1e10/Mup)
y2err = np.array(data['MU_TRUE_ERR_JK']*1e10/Mup)

zcls = np.array(data['redshift'])

# %%
zbins = np.percentile(zcls,np.linspace(0,100,13))
# zbins = np.array([0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])

zkeys, zmed = makeBin(zcls,zbins)
zlabel = [r'%.3f < z < %.3f'%(zl,zh) for zl,zh in zip(zbins[:-1],zbins[1:])]

# %%
outs = []

print('Evolution Fit')
for idx,zli in zip(zkeys,zlabel):
    mor = mass_observable_relation()
    print('zbin: %s'%zli)
    mor.add_dataset('observed',x[idx],y1[idx],y1err[idx],y_label='mu_obs')
    mor.fit_emcee('observed',is_log=True,percentile=[16,84],nsteps=500, nwalkers=80)
    
    mor.add_dataset('true',x[idx],y2[idx],y2err[idx],y_label='mu_tru')
    mor.fit_emcee('true',is_log=True,percentile=[16,84],nsteps=500, nwalkers=80)
    
    outs.append(mor)
    print('\n')
    
print('done')
# Out:
# Evolution Fit
# Welcome Mass-Observable Relation Fit
# zbin: 0.200 < z < 0.291
# fit parameter 1-sigma error
# 0: 0.22965 	 0.02718
# 1: 1.24164 	 0.07773
# 2: 1.75340 	 0.05369
# 3: 0.15528 	 0.07500
# [0.27003592 1.26380428 1.70169738 0.14339289]
# fit parameter 1-sigma error
# 0: 0.29088 	 0.02898
# 1: 1.57975 	 0.08319
# 2: 2.03091 	 0.05755
# 3: 0.15635 	 0.07500
# [0.26867843 1.42242983 2.04137732 0.080496  ]
#
#
# Welcome Mass-Observable Relation Fit
# zbin: 0.291 < z < 0.347
# fit parameter 1-sigma error
# 0: 0.30393 	 0.03686
# 1: 1.52106 	 0.11092
# 2: 2.05504 	 0.08127
# 3: 0.17372 	 0.07500
# [0.33803506 1.54135058 2.05211751 0.18693909]
# fit parameter 1-sigma error
# 0: 0.30659 	 0.03562
# 1: 1.68226 	 0.10556
# 2: 2.22545 	 0.07603
# 3: 0.15954 	 0.07500
# [0.37115048 1.62823094 2.27720561 0.25580978]
#
#
# Welcome Mass-Observable Relation Fit
# zbin: 0.347 < z < 0.386
# fit parameter 1-sigma error
# 0: 0.29980 	 0.03935
# 1: 1.55713 	 0.11935
# 2: 2.15991 	 0.08803
# ...

# %%
save_mor_results('lbd_gt20_nbins12',[outs,zmed])

# %%
out20, zmed   = load_mor_results('lbd_gt20_nbins12')

# %% [markdown]
# ## Uniform

# %%
data=cat

x     = np.array(data['M200']/Mp)
y1    = np.array(data['MU']*1e10/Mup)
y1err = np.array(data['MU_ERR_JK']*1e10/Mup)
y2    = np.array(data['MU_TRUE']*1e10/Mup)
y2err = np.array(data['MU_TRUE_ERR_JK']*1e10/Mup)

zcls = np.array(data['redshift'])

# %%
zbins = np.percentile(zcls,np.linspace(0,100,13))
# zbins = np.array([0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])

zkeys, zmed = makeBin(zcls,zbins)
zlabel = [r'%.3f < z < %.3f'%(zl,zh) for zl,zh in zip(zbins[:-1],zbins[1:])]

# %%
outs = []

print('Evolution Fit')
for idx,zli in zip(zkeys,zlabel):
    mor = mass_observable_relation()
    print('zbin: %s'%zli)
    mor.add_dataset('observed',x[idx],y1[idx],y1err[idx],y_label='mu_obs')
    mor.fit_emcee('observed',is_log=True,percentile=[16,84],nsteps=500, nwalkers=80)
    
    mor.add_dataset('true',x[idx],y2[idx],y2err[idx],y_label='mu_tru')
    mor.fit_emcee('true',is_log=True,percentile=[16,84],nsteps=500, nwalkers=80)
    
    outs.append(mor)
    print('\n')
    
print('done')
# Out:
# Evolution Fit
# Welcome Mass-Observable Relation Fit
# zbin: 0.200 < z < 0.238
# fit parameter 1-sigma error
# 0: 0.14746 	 0.16819
# 1: 1.35886 	 0.40957
# 2: 1.79805 	 0.24148
# 3: 0.20075 	 0.07500
# [0.00942473 1.04299125 1.90812365 0.13429237]
# fit parameter 1-sigma error
# 0: 0.40756 	 0.12504
# 1: 1.92706 	 0.31462
# 2: 2.13914 	 0.19115
# 3: 0.14402 	 0.07500
# [0.28838979 1.7576225  2.20471924 0.01015078]
#
#
# Welcome Mass-Observable Relation Fit
# zbin: 0.238 < z < 0.273
# fit parameter 1-sigma error
# 0: 0.01291 	 0.13187
# 1: 1.03242 	 0.30043
# 2: 1.65763 	 0.16179
# 3: 0.19272 	 0.07500
# [-0.05625844  0.97836349  1.94069058  0.10751311]
# fit parameter 1-sigma error
# 0: 0.19246 	 0.10483
# 1: 1.37708 	 0.24731
# 2: 1.85812 	 0.13817
# 3: 0.14845 	 0.07500
# [0.31506265 0.89654932 1.96563363 0.27672962]
#
#
# Welcome Mass-Observable Relation Fit
# zbin: 0.273 < z < 0.307
# fit parameter 1-sigma error
# 0: 0.27722 	 0.14909
# 1: 1.66976 	 0.36422
# ...

# %%
save_mor_results('uniform_nbins12',[outs,zmed])

# %%
outu, zmed   = load_mor_results('uniform_nbins12')

# %% [markdown]
# ## Plot Results

# %%
from fit_mor_evolution import plot_par_evolution

# %%
mor_relation_label = r'$\langle log_{10} \mu_{\star} | M_{200} \rangle  = \alpha+\beta_1 \; log_{10} (M_{200}/M_p)+\beta_2 \; log_{10} (M_{200}/M_p)^2$'

# %%
#Generate figure if none provided
fig, ax = plt.subplots(3, 1, figsize=(12, 18), sharex = True) #gridspec_kw = {'height_ratios':[1.75, 1, 1]}
plt.subplots_adjust(hspace = 0.025)

name = 'observed'
plot_par_evolution(zmed,out5,'beta1'  , name, xlabel=r'$\beta_1$', ax=ax[0], color='b', color2='b',label='Observed')
plot_par_evolution(zmed,out5,'beta2'  , name, xlabel=r'$\beta_2$', ax=ax[1], color='b', color2='b')
plot_par_evolution(zmed,out5,'alpha'  , name, xlabel=r'$\alpha$', ax=ax[2], color='b', color2='b')

name = 'true'
plot_par_evolution(zmed+0.01,out5,'beta1', name,xlabel=r'$\beta_1$', ax=ax[0], color='r', color2='r',label='True')
plot_par_evolution(zmed+0.01,out5,'beta2', name,xlabel=r'$\beta_2$', ax=ax[1], color='r', color2='r')
plot_par_evolution(zmed+0.01,out5,'alpha', name,xlabel=r'$\alpha$' , ax=ax[2], color='r', color2='r')

ax[0].legend(loc=2)
ax[0].set_title(mor_relation_label,fontsize=24)
ax[2].set_xlabel('redshift')
fig.tight_layout()
fig.savefig('lbd_gt5_mor_parameters_evolution.png')

# %%
names = ['beta2','beta1','alpha']
def convert_emcee_pars(self,name):
    popt,perr = [],[]
    for var in names:
        lm = self.data[name]['emcee']            
        popt.append(np.mean(lm[var]))
        
        lower_quartile, upper_quartile = np.mean(lm[var+'-']),np.mean(lm[var+'+'])
        perr.append(0.5*(upper_quartile-lower_quartile))
    return np.array(popt), np.array(perr)

def plot_mcmc_linear(self, name, nstd=1,ax=None,label=None,show_data=True,color=None):
    x,y,yerr,_ = self.get_variable(name,is_log=True)
    popt, perr = convert_emcee_pars(self,name)
    
    if ax is None: ax = plt.axes()
    # prepare confidence level curves
    popt_up = popt + nstd * perr
    popt_dw = popt - nstd * perr

    x_fit  = np.linspace(min(x), max(x), 100)
    fit    = qmodel(popt, x_fit)
    fit_up = qmodel(popt_up, x_fit)
    fit_dw = qmodel(popt_dw, x_fit)
    
    if label is None:
        label = r'$ \beta_1 = %.3f$'%(popt[1])+'\n'+r'$\beta_2 = %.3f ; \alpha=%.3f$'%(popt[0], popt[2])
    if show_data:
        ax.scatter(x, y, color='lightgray', alpha=0.75, s=5)
    p = ax.plot(x_fit, fit, lw=2, label=label,color=color)
    color = p[0].get_color()
    ax.fill_between(x_fit, fit_up, fit_dw, alpha=.5,color=color)
    ax.legend(loc='lower right',fontsize=12)

# %%
xxlabel  = r'$ Log(\mu_{\star,true}/10^{12}/M_{\odot})$'
yylabel  = r'$ Log(M_{200}/10^{15.5}/M_{\odot})$'

# %%
fig, ax = plt.subplots(4, 3, figsize=(16, 18), sharex = True, sharey=True) #gridspec_kw = {'height_ratios':[1.75, 1, 1]}

ll=0
for i in range(4):
    for j in range(3):
        plot_mcmc_linear(out5[ll], 'true',ax=ax[i,j])
        ax[i,j].set_title(zlabel[ll],fontsize=18)
        ll+=1
        if j==0:
            ax[i,j].set_ylabel(xxlabel, size=16)
        if i==3:
            ax[i,j].set_xlabel(yylabel, size=16)
        if ll==len(out5):
            break

# ax.set_title('Quadratic Model: y=a+b1*x+b2*x^2',fontsize=16)

# %%
colori = np.array(sns.color_palette("RdBu",15))

# %%
fig, ax = plt.subplots(1, figsize=(12, 8))

for ll in range(len(out5)):
    plot_mcmc_linear(out5[ll], 'true',ax=ax, label=zlabel[ll], color=colori[ll])
    
ax.set_ylabel(xxlabel, size=20)
ax.set_xlabel(yylabel, size=20)
ax.set_title(mor_relation_label, fontsize=18)
# Out:
# Text(0.5,1,'$\\langle log_{10} \\mu_{\\star} | M_{200} \\rangle  = \\alpha+\\beta_1 \\; log_{10} (M_{200}/M_p)+\\beta_2 \\; log_{10} (M_{200}/M_p)^2$')

# %% [markdown]
# ### Compare Results

# %%
#Generate figure if none provided
fig, ax = plt.subplots(3, 1, figsize=(12, 18), sharex = True) #gridspec_kw = {'height_ratios':[1.75, 1, 1]}
plt.subplots_adjust(hspace = 0.025)

name = 'true'
plot_par_evolution(zmed,out5,'beta1'  , name, ax=ax[0], color='b', color2='b',label='Lambda>5')
plot_par_evolution(zmed,out5,'beta2'  , name, ax=ax[1], color='b', color2='b')
plot_par_evolution(zmed,out5,'alpha', name, ax=ax[2], color='b', color2='b')

# name = 'true'
# plot_par_evolution(zmed+0.005,outu,'beta1'  , name,ax=ax[0], color='g', color2='g',label='Uniform')
# plot_par_evolution(zmed+0.005,outu,'beta2'  , name,ax=ax[1], color='g', color2='g')
# plot_par_evolution(zmed+0.005,outu,'scatter', name,ax=ax[2], color='g', color2='g')

name = 'true'
plot_par_evolution(zmed+0.01,out20,'beta1'  , name,ax=ax[0], color='r', color2='r',label='Lambda>20')
plot_par_evolution(zmed+0.01,out20,'beta2'  , name,ax=ax[1], color='r', color2='r')
plot_par_evolution(zmed+0.01,out20,'alpha', name,ax=ax[2], color='r', color2='r')

ax[0].legend(loc=2,fontsize=16)
ax[0].set_title(mor_relation_label,fontsize=24)
ax[2].set_xlabel('redshift')
fig.tight_layout()
fig.savefig('selections_mor_parameters_evolution.png')
