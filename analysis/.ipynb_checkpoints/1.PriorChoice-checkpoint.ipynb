# %% [markdown]
# # Bayesian Inference Model
#
# In Bayesian inference approach, we associate a membership probability for each galaxy in the following manner: <br>
#
# $$
# P(\textit{member}\;| \;R,z,c,N_c,N_f) = \frac{P(R,z,c,N_c,N_f|\; \textit{member})P(\textit{member})}{P(R,z,c)}
# $$
#
# where $ P(R,z,c,N_c,N_f|\; \textit{membership}) $ is our likelihood model and $P(\textit{membership})$ is our prior. The marginal, $P(R,z,c)$, is the probability of measuring any galaxy in the field or the cluster.

# %% [markdown]
# ## Prior
#
# In this notebook, we quantify our prior precision. Basically, we have two models for the prior, one that is simply the sum of the galaxies and one that is based on a beta distribution.
#
# **A) Counting model**: George et al. 2011 defined the prior as:
#
# $$
# P(\textit{member}) = N_c/(N_c+N_f) = 1-P(\textit{field})
# $$
#
# which is based on the relative numbers of galaxies inside a cylinder of length $3\sigma$.
#
# **B) Beta Distribution:** since the $P(\textit{member})$ is a number between 0 and 1 and it's a reflection of $P(\textit{member})=1-P(\textit{field})$ we can write both variables as beta distribution, $Beta(x;\alpha,\beta)$.
#
# $$
# f(x,\alpha,\beta) = \frac{\Gamma(\alpha+\beta) x^{a-1} (1-x)^{\beta-1}}{\Gamma(\alpha)\Gamma(\beta)} \qquad \qquad \text{where} \quad \alpha=N_c \; ,\; \beta=N_{f} \; \text{and} \; x = N_c/(N_c+N_f)
# $$
#
# Where $x \in [0,1]$ and $\alpha$ and $\beta$ positive numbers. Notice that $x$ is simply the prior for the model **A**. The number of cluster and field galaxies are taken into account by the beta distribution. The diffence in this models  can be significant in the low counts since $x$ is biased due to the poissonian random fluctuations.
#
# This is an informative prior, to compute $P(\textit{member})$ you need to integrate the probabilities over your model.
#
# $$
# P(\textit{member}| \alpha, \beta) = {\rm E}\left[P(Model_{Radial}|member)(x) Beta(x| \alpha, \beta)\right]
# $$
#
# where $x$ is the probability of galaxy being a member. Basically, we use our prior knowledge of $N_c, N_f$ and the radial distribution of the members to estimate the probability.

# %% [markdown]
# # Copacabana
#
# In this lines, I'll load the copacabana output and investigate the addition of the Beta Distribution.

# %%
import matplotlib.pyplot as plt
import matplotlib

import seaborn as sns; sns.set(color_codes=True)
plt.rcParams.update({'font.size': 16})
sns.set_style("whitegrid")

import numpy as np
from scipy.interpolate import interp1d
import scipy

from collections import defaultdict

# %%
import sys
sys.path.append("/home/s1/jesteves/git/ccopa/python/")
from main import copacabana
# Out:
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
root = '/home/s1/jesteves/git/buzzardAnalysis/mainAnalysis/'
cfg  = root+'config_buzzard_v2.yaml'

copa = copacabana(cfg,dataset='buzzard_v2')
# Out:
# master file:
#  /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00017.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00018.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00019.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00020.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00022.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00032.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00033.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00034.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00035.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00038.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00044.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00045.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00046.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00047.hdf5
# outdir: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/
# tile path: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles

# %%
run_name = u'dnf_r200_02Lstar_nfw'
cat = copa.load_copa_out('cluster',run_name)
gal = copa.load_copa_out('members',run_name)

# %%
zmask = np.logical_not(gal['zmask'])
true  = gal['GID']>0.

print(100.*np.count_nonzero(zmask&true)/np.count_nonzero(true))
# Out:
# 46.7480889292

# %% [markdown]
# ## Loading $\alpha$ and $\beta$
#
# We're making a correction on the $n_c$ only for this purpose. In another notebook I'll investigate why $n_c$ is biased.

# %%
pz_factor=0.84

# %%
area = cat['Area']

Nc = cat['Norm']#/pz_factor
Nf = cat['Nbkg']*area

Nt = cat['Ngals_true']#/pz_factor
Nft= cat['Nbkg_true']*area

Ncf = Nc+Nf

# %%
## Correcting Nc 
## Only for test purposes

# Nc = 1.34*Nc

# %%
# alpha = np.array(Nc).copy()
# beta  = np.array(Nf).copy()

# %%
alpha = np.array(Nt).copy()
beta  = np.array(Nft).copy()

# %%
cat['Norm','Nbkg']
# Out:
# <Table length=2636>
#         Norm               Nbkg
#       float64            float64
# ------------------- ------------------
#   23.94764915454746  4.548684034874968
#    8.88652562911704  2.544449282528104
#  10.415434294862196 2.7047052975402095
#   22.49589407500629 2.7455494273649426
#  11.905351841299046 1.7279993265070768
#    4.63746817936175 1.5195752072539483
#   65.13545010959858 2.3054992522031377
#   6.904375157957564 2.4743999888437314
#   18.86014235161832  2.627200559802343
#   36.11799030391131 3.4196153523855903
#                 ...                ...
#   44.34083709304874  5.894016060966803
#  48.964068562522655  6.516440920532876
#   82.49504541871707  6.022538453325407
#  0.3832410366754347  6.730510158106272
# -0.7472935823691687  7.909679084352667
#   114.5767643070659  8.061122874901235
#    36.9434172031876  8.059415206700267
#   17.71797377271807  7.021178352696375
#  57.284005692613555  6.056211687375611
#  42.263493370674084  2.964250842705825

# %% [markdown]
# ## Bayesian Approach: Membership probabilities
#
# Let's compute the new membership probabilities.

# %%
def chunks(ids1, ids2):
    """Yield successive n-sized chunks from data"""
    for id in ids2:
        w, = np.where( ids1==id )
        yield w

# %%
def set_new_columns(table,columns,val=0.):
    for col in columns:
        table[col] = val
    return table

# %% [markdown]
# ### Prior Example
#
# For a given cluster, we show the prior distribution.

# %%
cids = np.array(cat['CID'])
gids = np.array(gal['CID'])
r200 = np.array(cat['R200'])
zcls = np.array(cat['redshift'])
keys = list(chunks(gids,cids))

# %%
#gal.rename_column('redshift_1','redshift')

# %%
i=32
b = BayesianProbability(alpha[i],beta[i],r2=r200[i])
b.assign_probabilities(gal[keys[i]])
# Out:
# ratio: 1.00
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:73: RuntimeWarning: invalid value encountered in divide

# %% [markdown]
# In the figure above we illustrate the prior choice. The Beta Distribution has its mean at the prior probability $\alpha/(\alpha+\beta)=N_c/(N_c+N_f)$ (blue dashed line), which corresponds to the choice of a non informative prior. In our informative prior approach we marginilize the membership probability over the likelihood (black curve) and our new prior prior probability is the mean of this distribution (red dashed line). We can see that our new $P(member)$ has a slightly higher value. We note that for this purposes, our likelihood only depends on the radial distance, this choice is eplained on a later section.

# %%
b.plot_prior_distribution()
plt.yscale('log')
plt.ylim(1e-2,7e1)
# Out:
# (0.01, 70.0)

# %%
np.sum(b.pdf)
# Out:
# 1.0

# %%
np.sum(b.prob['marginal']['pdf'])#/(alpha[i]+beta[i])
# Out:
# 0.9999999999999999

# %%
ncls    = len(cat)
columns = ['flat','beta','old']

## compute the new probabilities
cla,res = [],[]
for i in range(ncls):
    print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
    b = BayesianProbability(alpha[i],beta[i],r2=r200[i])
    b.assign_probabilities(gal[keys[i]])
    b.compute_ngals()
    
    res.append(b.prob)
    cla.append(b)
    del b
# Out:
# alpha,beta: 34.00 ,37.33
# ratio: 1.00
# alpha,beta: 18.00 ,2.88
# ratio: 1.00
# alpha,beta: 19.00 ,7.65
# ratio: 1.00
# alpha,beta: 13.00 ,14.60
# ratio: 1.00
# alpha,beta: 15.00 ,8.47
# ratio: 1.00
# alpha,beta: 7.00 ,2.94
# ratio: 1.00
# alpha,beta: 55.00 ,26.36
# ratio: 1.00
# alpha,beta: 9.00 ,6.71
# ratio: 1.00
# alpha,beta: 47.00 ,8.48
# ratio: 1.00
# alpha,beta: 43.00 ,18.45
# ratio: 1.00
# alpha,beta: 43.00 ,16.77
# ratio: 1.00
# alpha,beta: 13.00 ,2.72
# ratio: 1.00
# alpha,beta: 21.00 ,8.31
# ratio: 1.00
# alpha,beta: 40.00 ,29.35
# ratio: 1.00
# alpha,beta: 11.00 ,5.09
# ratio: 1.00
# alpha,beta: 7.00 ,3.48
# ratio: 1.00
# alpha,beta: 19.00 ,16.65
# ratio: 1.00
# alpha,beta: 17.00 ,6.92
# ratio: 1.00
# alpha,beta: 18.00 ,9.66
# ratio: 1.00
# alpha,beta: 10.00 ,8.17
# ratio: 1.00
# alpha,beta: 20.00 ,12.41
# ratio: 1.00
# alpha,beta: 36.00 ,24.21
# ratio: 1.00
# alpha,beta: 10.00 ,13.33
# ratio: 1.00
# alpha,beta: 7.00 ,11.56
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:73: RuntimeWarning: invalid value encountered in divide
# ratio: 1.00
# alpha,beta: 16.00 ,19.82
# ratio: 1.00
# alpha,beta: 6.00 ,9.05
# ratio: 1.00
# alpha,beta: 67.00 ,67.27
# ratio: 1.00
# alpha,beta: 22.00 ,21.67
# ratio: 1.00
# alpha,beta: 20.00 ,16.23
# ratio: 1.00
# alpha,beta: 10.00 ,11.93
# ratio: 1.00
# alpha,beta: 12.00 ,23.70
# ratio: 1.00
# alpha,beta: 34.00 ,20.81
# ratio: 1.00
# alpha,beta: 167.00 ,75.33
# ratio: 1.00
# alpha,beta: 42.00 ,21.25
# ratio: 1.00
# alpha,beta: 58.00 ,18.68
# ratio: 1.00
# alpha,beta: 46.00 ,8.12
# ratio: 1.00
# alpha,beta: 29.00 ,5.32
# ratio: 1.00
# alpha,beta: 22.00 ,6.10
# ratio: 1.00
# alpha,beta: 100.00 ,29.34
# ratio: 1.00
# alpha,beta: 37.00 ,11.98
# ratio: 1.00
# alpha,beta: 24.00 ,6.47
# ratio: 1.00
# alpha,beta: 5.00 ,5.75
# ratio: 1.00
# alpha,beta: 12.00 ,9.69
# ratio: 1.00
# alpha,beta: 18.00 ,3.04
# ratio: 1.00
# alpha,beta: 12.00 ,3.83
# ratio: 1.00
# alpha,beta: 32.00 ,20.29
# ratio: 1.00
# alpha,beta: 41.00 ,30.12
# ratio: 1.00
# alpha,beta: 34.00 ,12.29
# ratio: 1.00
# alpha,beta: 38.00 ,24.00
# ratio: 1.00
# alpha,beta: 23.00 ,18.19
# ratio: 1.00
# alpha,beta: 20.00 ,14.33
# ratio: 1.00
# alpha,beta: 96.00 ,30.79
# ratio: 1.00
# alpha,beta: 75.00 ,21.75
# ratio: 1.00
# alpha,beta: 42.00 ,9.81
# ratio: 1.00
# alpha,beta: 25.00 ,18.90
# ratio: 1.00
# alpha,beta: 11.00 ,3.89
# ratio: 1.00
# alpha,beta: 8.00 ,10.07
# ratio: 1.00
# alpha,beta: 6.00 ,3.29
# ratio: 1.00
# alpha,beta: 76.00 ,30.60
# ratio: 1.00
# alpha,beta: 19.00 ,15.09
# ratio: 1.00
# alpha,beta: 13.00 ,6.33
# ratio: 1.00
# alpha,beta: 42.00 ,23.64
# ratio: 1.00
# alpha,beta: 18.00 ,15.50
# ratio: 1.00
# alpha,beta: 17.00 ,20.07
# ratio: 1.00
# alpha,beta: 37.00 ,19.09
# ratio: 1.00
# alpha,beta: 34.00 ,28.23
# ratio: 1.00
# alpha,beta: 29.00 ,10.84
# ratio: 1.00
# alpha,beta: 12.00 ,13.40
# ratio: 1.00
# alpha,beta: 7.00 ,4.18
# ratio: 1.00
# alpha,beta: 9.00 ,12.06
# ratio: 1.00
# alpha,beta: 83.00 ,44.37
# ratio: 1.00
# alpha,beta: 56.00 ,41.80
# ratio: 1.00
# alpha,beta: 13.00 ,11.03
# ratio: 1.00
# alpha,beta: 10.00 ,4.07
# ratio: 1.00
# alpha,beta: 36.00 ,22.81
# ratio: 1.00
# alpha,beta: 25.00 ,49.17
# ratio: 1.00
# alpha,beta: 18.00 ,24.19
# ratio: 1.00
# alpha,beta: 45.00 ,10.85
# ratio: 1.00
# alpha,beta: 45.00 ,32.41
# ratio: 1.00
# alpha,beta: 60.00 ,43.06
# ratio: 1.00
# alpha,beta: 31.00 ,23.52
# ratio: 1.00
# alpha,beta: 12.00 ,7.17
# ratio: 1.00
# alpha,beta: 5.00 ,11.12
# ratio: 1.00
# alpha,beta: 32.00 ,29.69
# ratio: 1.00
# alpha,beta: 22.00 ,39.71
# ratio: 1.00
# alpha,beta: 17.00 ,17.97
# ratio: 1.00
# alpha,beta: 12.00 ,10.23
# ratio: 1.00
# alpha,beta: 35.00 ,26.95
# ratio: 1.00
# alpha,beta: 5.00 ,15.10
# ratio: 1.00
# alpha,beta: 8.00 ,11.31
# ratio: 1.00
# alpha,beta: 39.00 ,39.94
# ratio: 1.00
# alpha,beta: 72.00 ,89.21
# ratio: 1.00
# alpha,beta: 47.00 ,90.93
# ratio: 1.00
# alpha,beta: 76.00 ,77.86
# ratio: 1.00
# alpha,beta: 65.00 ,159.88
# ratio: 1.00
# alpha,beta: 36.00 ,39.76
# ratio: 1.00
# alpha,beta: 83.00 ,49.10
# ratio: 1.00
# alpha,beta: 84.00 ,77.19
# ratio: 1.00
# alpha,beta: 31.00 ,56.30
# ratio: 1.00
# alpha,beta: 36.00 ,47.65
# ratio: 1.00
# alpha,beta: 44.00 ,63.55
# ratio: 1.00
# alpha,beta: 48.00 ,47.04
# ratio: 1.00
# alpha,beta: 36.00 ,75.68
# ratio: 1.00
# alpha,beta: 23.00 ,65.44
# ratio: 1.00
# alpha,beta: 31.00 ,30.04
# ratio: 1.00
# alpha,beta: 12.00 ,15.45
# ratio: 1.00
# alpha,beta: 11.00 ,11.88
# ratio: 1.00
# alpha,beta: 16.00 ,20.52
# ratio: 1.00
# alpha,beta: 13.00 ,18.27
# ratio: 1.00
# alpha,beta: 10.00 ,26.29
# ratio: 1.00
# alpha,beta: 11.00 ,13.71
# ratio: 1.00
# alpha,beta: 8.00 ,26.45
# ratio: 1.00
# alpha,beta: 42.00 ,55.62
# ratio: 1.00
# alpha,beta: 52.00 ,50.88
# ratio: 1.00
# alpha,beta: 51.00 ,81.14
# ratio: 1.00
# alpha,beta: 18.00 ,51.58
# ratio: 1.00
# alpha,beta: 46.00 ,51.65
# ratio: 1.00
# alpha,beta: 18.00 ,21.19
# ratio: 1.00
# alpha,beta: 7.00 ,19.15
# ratio: 1.00
# alpha,beta: 18.00 ,44.04
# ratio: 1.00
# alpha,beta: 19.00 ,29.21
# ratio: 1.00
# alpha,beta: 116.00 ,147.76
# ratio: 1.00
# alpha,beta: 31.00 ,87.29
# ratio: 1.00
# alpha,beta: 85.00 ,131.55
# ratio: 1.00
# alpha,beta: 54.00 ,68.36
# ratio: 1.00
# alpha,beta: 43.00 ,49.20
# ratio: 1.00
# alpha,beta: 39.00 ,77.83
# ratio: 1.00
# alpha,beta: 28.00 ,23.24
# ratio: 1.00
# alpha,beta: 16.00 ,26.88
# ratio: 1.00
# alpha,beta: 8.00 ,34.39
# ratio: 1.00
# alpha,beta: 11.00 ,43.69
# ratio: 1.00
# alpha,beta: 6.00 ,33.30
# ratio: 1.00
# alpha,beta: 7.00 ,9.51
# ratio: 1.00
# alpha,beta: 9.00 ,23.19
# ratio: 1.00
# alpha,beta: 64.00 ,124.49
# ratio: 1.00
# alpha,beta: 45.00 ,41.31
# ratio: 1.00
# alpha,beta: 50.00 ,78.81
# ratio: 1.00
# alpha,beta: 33.00 ,44.84
# ratio: 1.00
# alpha,beta: 38.00 ,47.11
# ratio: 1.00
# alpha,beta: 26.00 ,26.40
# ratio: 1.00
# alpha,beta: 10.00 ,26.72
# ratio: 1.00
# alpha,beta: 17.00 ,36.47
# ratio: 1.00
# alpha,beta: 19.00 ,28.12
# ratio: 1.00
# alpha,beta: 14.00 ,22.96
# ratio: 1.00
# alpha,beta: 8.00 ,20.41
# ratio: 1.00
# alpha,beta: 6.00 ,19.62
# ratio: 1.00
# alpha,beta: 14.00 ,33.29
# ratio: 1.00
# alpha,beta: 140.00 ,102.37
# ratio: 1.00
# alpha,beta: 27.00 ,54.19
# ratio: 1.00
# alpha,beta: 21.00 ,56.37
# ratio: 1.00
# alpha,beta: 12.00 ,33.94
# ratio: 1.00
# alpha,beta: 15.00 ,30.65
# ratio: 1.00
# alpha,beta: 8.00 ,17.88
# ratio: 1.00
# alpha,beta: 67.00 ,103.60
# ratio: 1.00
# alpha,beta: 29.00 ,95.94
# ratio: 1.00
# alpha,beta: 45.00 ,93.80
# ratio: 1.00
# alpha,beta: 197.00 ,83.34
# ratio: 1.00
# alpha,beta: 27.00 ,33.23
# ratio: 1.00
# alpha,beta: 52.00 ,30.41
# ratio: 1.00
# alpha,beta: 16.00 ,19.62
# ratio: 1.00
# alpha,beta: 30.00 ,25.66
# ratio: 1.00
# alpha,beta: 15.00 ,16.01
# ratio: 1.00
# alpha,beta: 15.00 ,19.48
# ratio: 1.00
# alpha,beta: 17.00 ,21.07
# ratio: 1.00
# alpha,beta: 13.00 ,14.18
# ratio: 1.00
# alpha,beta: 8.00 ,9.84
# ratio: 1.00
# alpha,beta: 45.00 ,69.47
# ratio: 1.00
# alpha,beta: 49.00 ,39.66
# ratio: 1.00
# alpha,beta: 4.00 ,5.42
# ratio: 1.00
# alpha,beta: 40.00 ,49.76
# ratio: 1.00
# alpha,beta: 54.00 ,61.20
# ratio: 1.00
# alpha,beta: 38.00 ,25.63
# ratio: 1.00
# alpha,beta: 29.00 ,41.15
# ratio: 1.00
# alpha,beta: 4.00 ,15.82
# ratio: 1.00
# alpha,beta: 133.00 ,87.09
# ratio: 1.00
# alpha,beta: 10.00 ,37.57
# ratio: 1.00
# alpha,beta: 175.00 ,110.12
# ratio: 1.00
# alpha,beta: 72.00 ,79.81
# ratio: 1.00
# alpha,beta: 49.00 ,68.38
# ratio: 1.00
# alpha,beta: 27.00 ,93.09
# ratio: 1.00
# alpha,beta: 27.00 ,39.39
# ratio: 1.00
# alpha,beta: 48.00 ,100.60
# ratio: 1.00
# alpha,beta: 95.00 ,39.88
# ratio: 1.00
# alpha,beta: 36.00 ,71.83
# ratio: 1.00
# alpha,beta: 23.00 ,35.37
# ratio: 1.00
# alpha,beta: 35.00 ,27.16
# ratio: 1.00
# alpha,beta: 14.00 ,56.48
# ratio: 1.00
# alpha,beta: 37.00 ,39.00
# ratio: 1.00
# alpha,beta: 10.00 ,32.00
# ratio: 1.00
# alpha,beta: 35.00 ,40.10
# ratio: 1.00
# alpha,beta: 61.00 ,69.44
# ratio: 1.00
# alpha,beta: 30.00 ,30.01
# ratio: 1.00
# alpha,beta: 37.00 ,24.55
# ratio: 1.00
# alpha,beta: 12.00 ,50.09
# ratio: 1.00
# alpha,beta: 26.00 ,14.17
# ratio: 1.00
# alpha,beta: 20.00 ,31.51
# ratio: 1.00
# alpha,beta: 6.00 ,13.71
# ratio: 1.00
# alpha,beta: 9.00 ,20.56
# ratio: 1.00
# alpha,beta: 7.00 ,9.23
# ratio: 1.00
# alpha,beta: 12.00 ,35.62
# ratio: 1.00
# alpha,beta: 12.00 ,21.03
# ratio: 1.00
# alpha,beta: 8.00 ,26.67
# ratio: 1.00
# alpha,beta: 5.00 ,18.72
# ratio: 1.00
# alpha,beta: 143.00 ,181.49
# ratio: 1.00
# alpha,beta: 76.00 ,63.15
# ratio: 1.00
# alpha,beta: 40.00 ,54.25
# ratio: 1.00
# alpha,beta: 127.00 ,93.22
# ratio: 1.00
# alpha,beta: 81.00 ,66.25
# ratio: 1.00
# alpha,beta: 35.00 ,42.42
# ratio: 1.00
# alpha,beta: 53.00 ,60.97
# ratio: 1.00
# alpha,beta: 61.00 ,41.66
# ratio: 1.00
# alpha,beta: 25.00 ,29.60
# ratio: 1.00
# alpha,beta: 14.00 ,22.19
# ratio: 1.00
# alpha,beta: 24.00 ,54.61
# ratio: 1.00
# alpha,beta: 22.00 ,30.36
# ratio: 1.00
# alpha,beta: 16.00 ,22.49
# ratio: 1.00
# alpha,beta: 21.00 ,21.49
# ratio: 1.00
# alpha,beta: 20.00 ,18.73
# ratio: 1.00
# alpha,beta: 15.00 ,46.91
# ratio: 1.00
# alpha,beta: 17.00 ,16.43
# ratio: 1.00
# alpha,beta: 6.00 ,28.08
# ratio: 1.00
# alpha,beta: 17.00 ,17.36
# ratio: 1.00
# alpha,beta: 12.00 ,18.16
# ratio: 1.00
# alpha,beta: 7.00 ,4.64
# ratio: 1.00
# alpha,beta: 11.00 ,9.78
# ratio: 1.00
# alpha,beta: 13.00 ,18.49
# ratio: 1.00
# alpha,beta: 6.00 ,12.84
# ratio: 1.00
# alpha,beta: 12.00 ,83.50
# ratio: 1.00
# alpha,beta: 49.00 ,88.72
# ratio: 1.00
# alpha,beta: 35.00 ,31.81
# ratio: 1.00
# alpha,beta: 33.00 ,58.66
# ratio: 1.00
# alpha,beta: 18.00 ,33.33
# ratio: 1.00
# alpha,beta: 3.00 ,25.32
# ratio: 1.00
# alpha,beta: 12.00 ,18.18
# ratio: 1.00
# alpha,beta: 10.00 ,22.17
# ratio: 1.00
# alpha,beta: 11.00 ,17.06
# ratio: 1.00
# alpha,beta: 4.00 ,14.27
# ratio: 1.00
# alpha,beta: 10.00 ,31.07
# ratio: 1.00
# alpha,beta: 7.00 ,16.59
# ratio: 1.00
# alpha,beta: 5.00 ,19.76
# ratio: 1.00
# alpha,beta: 34.00 ,79.41
# ratio: 1.00
# alpha,beta: 38.00 ,59.68
# ratio: 1.00
# alpha,beta: 9.00 ,22.37
# ratio: 1.00
# alpha,beta: 31.00 ,44.91
# ratio: 1.00
# alpha,beta: 20.00 ,56.64
# ratio: 1.00
# alpha,beta: 25.00 ,29.36
# ratio: 1.00
# alpha,beta: 7.00 ,25.85
# ratio: 1.00
# alpha,beta: 19.00 ,26.74
# ratio: 1.00
# alpha,beta: 14.00 ,16.60
# ratio: 1.00
# alpha,beta: 17.00 ,53.56
# ratio: 1.00
# alpha,beta: 15.00 ,22.70
# ratio: 1.00
# alpha,beta: 10.00 ,30.42
# ratio: 1.00
# alpha,beta: 18.00 ,36.68
# ratio: 1.00
# alpha,beta: 18.00 ,26.72
# ratio: 1.00
# alpha,beta: 11.00 ,31.58
# ratio: 1.00
# alpha,beta: 167.00 ,73.18
# ratio: 1.00
# alpha,beta: 113.00 ,100.91
# ratio: 1.00
# alpha,beta: 51.00 ,85.18
# ratio: 1.00
# alpha,beta: 27.00 ,44.07
# ratio: 1.00
# alpha,beta: 52.00 ,43.14
# ratio: 1.00
# alpha,beta: 21.00 ,32.84
# ratio: 1.00
# alpha,beta: 19.00 ,48.08
# ratio: 1.00
# alpha,beta: 13.00 ,24.77
# ratio: 1.00
# alpha,beta: 52.00 ,80.08
# ratio: 1.00
# alpha,beta: 21.00 ,29.05
# ratio: 1.00
# alpha,beta: 17.00 ,50.88
# ratio: 1.00
# alpha,beta: 8.00 ,17.35
# ratio: 1.00
# alpha,beta: 13.00 ,23.94
# ratio: 1.00
# alpha,beta: 10.00 ,17.95
# ratio: 1.00
# alpha,beta: 7.00 ,20.73
# ratio: 1.00
# alpha,beta: 14.00 ,60.44
# ratio: 1.00
# alpha,beta: 28.00 ,73.43
# ratio: 1.00
# alpha,beta: 20.00 ,29.90
# ratio: 1.00
# alpha,beta: 11.00 ,44.49
# ratio: 1.00
# alpha,beta: 14.00 ,54.86
# ratio: 1.00
# alpha,beta: 102.00 ,107.49
# ratio: 1.00
# alpha,beta: 29.00 ,51.58
# ratio: 1.00
# alpha,beta: 15.00 ,29.46
# ratio: 1.00
# alpha,beta: 12.00 ,36.17
# ratio: 1.00
# alpha,beta: 43.00 ,83.17
# ratio: 1.00
# alpha,beta: 48.00 ,69.95
# ratio: 1.00
# alpha,beta: 9.00 ,38.37
# ratio: 1.00
# alpha,beta: 11.00 ,4.29
# ratio: 1.00
# alpha,beta: 65.00 ,36.93
# ratio: 1.00
# alpha,beta: 30.00 ,32.33
# ratio: 1.00
# alpha,beta: 95.00 ,77.77
# ratio: 1.00
# alpha,beta: 9.00 ,16.84
# ratio: 1.00
# alpha,beta: 46.00 ,23.82
# ratio: 1.00
# alpha,beta: 20.00 ,8.88
# ratio: 1.00
# alpha,beta: 15.00 ,16.02
# ratio: 1.00
# alpha,beta: 47.00 ,20.50
# ratio: 1.00
# alpha,beta: 48.00 ,48.47
# ratio: 1.00
# alpha,beta: 37.00 ,18.56
# ratio: 1.00
# alpha,beta: 58.00 ,10.34
# ratio: 1.00
# alpha,beta: 29.00 ,19.73
# ratio: 1.00
# alpha,beta: 26.00 ,13.56
# ratio: 1.00
# alpha,beta: 21.00 ,15.34
# ratio: 1.00
# alpha,beta: 27.00 ,10.15
# ratio: 1.00
# alpha,beta: 17.00 ,12.07
# ratio: 1.00
# alpha,beta: 38.00 ,78.02
# ratio: 1.00
# alpha,beta: 28.00 ,45.37
# ratio: 1.00
# alpha,beta: 58.00 ,18.04
# ratio: 1.00
# alpha,beta: 35.00 ,17.82
# ratio: 1.00
# alpha,beta: 17.00 ,4.94
# ratio: 1.00
# alpha,beta: 15.00 ,3.97
# ratio: 1.00
# alpha,beta: 75.00 ,25.02
# ratio: 1.00
# alpha,beta: 26.00 ,16.69
# ratio: 1.00
# alpha,beta: 90.00 ,24.20
# ratio: 1.00
# alpha,beta: 17.00 ,3.88
# ratio: 1.00
# alpha,beta: 36.00 ,21.61
# ratio: 1.00
# alpha,beta: 96.00 ,27.70
# ratio: 1.00
# alpha,beta: 22.00 ,13.84
# ratio: 1.00
# alpha,beta: 16.00 ,31.10
# ratio: 1.00
# alpha,beta: 15.00 ,7.49
# ratio: 1.00
# alpha,beta: 68.00 ,34.81
# ratio: 1.00
# alpha,beta: 49.00 ,22.31
# ratio: 1.00
# alpha,beta: 17.00 ,14.16
# ratio: 1.00
# alpha,beta: 32.00 ,36.98
# ratio: 1.00
# alpha,beta: 17.00 ,15.04
# ratio: 1.00
# alpha,beta: 29.00 ,56.81
# ratio: 1.00
# alpha,beta: 34.00 ,66.96
# ratio: 1.00
# alpha,beta: 27.00 ,19.78
# ratio: 1.00
# alpha,beta: 19.00 ,4.98
# ratio: 1.00
# alpha,beta: 21.00 ,5.72
# ratio: 1.00
# alpha,beta: 45.00 ,21.68
# ratio: 1.00
# alpha,beta: 13.00 ,25.92
# ratio: 1.00
# alpha,beta: 25.00 ,26.32
# ratio: 1.00
# alpha,beta: 75.00 ,66.75
# ratio: 1.00
# alpha,beta: 151.00 ,55.75
# ratio: 1.00
# alpha,beta: 15.00 ,48.16
# ratio: 1.00
# alpha,beta: 74.00 ,75.22
# ratio: 1.00
# alpha,beta: 72.00 ,110.11
# ratio: 1.00
# alpha,beta: 75.00 ,75.46
# ratio: 1.00
# alpha,beta: 21.00 ,82.22
# ratio: 1.00
# alpha,beta: 80.00 ,62.83
# ratio: 1.00
# alpha,beta: 35.00 ,50.53
# ratio: 1.00
# alpha,beta: 35.00 ,56.48
# ratio: 1.00
# alpha,beta: 39.00 ,38.55
# ratio: 1.00
# alpha,beta: 12.00 ,14.84
# ratio: 1.00
# alpha,beta: 28.00 ,51.06
# ratio: 1.00
# alpha,beta: 22.00 ,36.59
# ratio: 1.00
# alpha,beta: 17.00 ,25.81
# ratio: 1.00
# alpha,beta: 15.00 ,18.83
# ratio: 1.00
# alpha,beta: 12.00 ,35.53
# ratio: 1.00
# alpha,beta: 15.00 ,15.45
# ratio: 1.00
# alpha,beta: 11.00 ,6.56
# ratio: 1.00
# alpha,beta: 9.00 ,10.52
# ratio: 1.00
# alpha,beta: 10.00 ,27.82
# ratio: 1.00
# alpha,beta: 101.00 ,154.25
# ratio: 1.00
# alpha,beta: 24.00 ,97.78
# ratio: 1.00
# alpha,beta: 44.00 ,76.62
# ratio: 1.00
# alpha,beta: 33.00 ,41.99
# ratio: 1.00
# alpha,beta: 82.00 ,140.74
# ratio: 1.00
# alpha,beta: 40.00 ,59.96
# ratio: 1.00
# alpha,beta: 123.00 ,63.69
# ratio: 1.00
# alpha,beta: 85.00 ,53.29
# ratio: 1.00
# alpha,beta: 11.00 ,16.46
# ratio: 1.00
# alpha,beta: 40.00 ,74.89
# ratio: 1.00
# alpha,beta: 17.00 ,23.85
# ratio: 1.00
# alpha,beta: 25.00 ,48.44
# ratio: 1.00
# alpha,beta: 29.00 ,41.96
# ratio: 1.00
# alpha,beta: 12.00 ,28.19
# ratio: 1.00
# alpha,beta: 11.00 ,24.36
# ratio: 1.00
# alpha,beta: 5.00 ,21.78
# ratio: 1.00
# alpha,beta: 115.00 ,71.02
# ratio: 1.00
# alpha,beta: 56.00 ,80.24
# ratio: 1.00
# alpha,beta: 16.00 ,42.40
# ratio: 1.00
# alpha,beta: 13.00 ,25.58
# ratio: 1.00
# alpha,beta: 8.00 ,14.71
# ratio: 1.00
# alpha,beta: 27.00 ,70.02
# ratio: 1.00
# alpha,beta: 29.00 ,74.65
# ratio: 1.00
# alpha,beta: 52.00 ,54.44
# ratio: 1.00
# alpha,beta: 55.00 ,71.89
# ratio: 1.00
# alpha,beta: 41.00 ,36.07
# ratio: 1.00
# alpha,beta: 36.00 ,45.78
# ratio: 1.00
# alpha,beta: 26.00 ,34.61
# ratio: 1.00
# alpha,beta: 24.00 ,41.79
# ratio: 1.00
# alpha,beta: 15.00 ,31.77
# ratio: 1.00
# alpha,beta: 8.00 ,6.26
# ratio: 1.00
# alpha,beta: 9.00 ,26.82
# ratio: 1.00
# alpha,beta: 5.00 ,5.25
# ratio: 1.00
# alpha,beta: 34.00 ,77.46
# ratio: 1.00
# alpha,beta: 13.00 ,24.87
# ratio: 1.00
# alpha,beta: 33.00 ,57.28
# ratio: 1.00
# alpha,beta: 47.00 ,32.71
# ratio: 1.00
# alpha,beta: 15.00 ,11.69
# ratio: 1.00
# alpha,beta: 16.00 ,5.63
# ratio: 1.00
# alpha,beta: 17.00 ,0.00
# ratio: 1.00
# alpha,beta: 24.00 ,6.26
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:303: RuntimeWarning: invalid value encountered in greater
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:303: RuntimeWarning: invalid value encountered in less_equal
# ratio: 1.00
# alpha,beta: 31.00 ,13.81
# ratio: 1.00
# alpha,beta: 26.00 ,24.76
# ratio: 1.00
# alpha,beta: 40.00 ,45.31
# ratio: 1.00
# alpha,beta: 13.00 ,12.67
# ratio: 1.00
# alpha,beta: 8.00 ,2.82
# ratio: 1.00
# alpha,beta: 13.00 ,20.38
# ratio: 1.00
# alpha,beta: 13.00 ,3.32
# ratio: 1.00
# alpha,beta: 14.00 ,5.04
# ratio: 1.00
# alpha,beta: 29.00 ,19.84
# ratio: 1.00
# alpha,beta: 11.00 ,6.53
# ratio: 1.00
# alpha,beta: 16.00 ,4.59
# ratio: 1.00
# alpha,beta: 8.00 ,2.65
# ratio: 1.00
# alpha,beta: 61.00 ,15.94
# ratio: 1.00
# alpha,beta: 5.00 ,14.88
# ratio: 1.00
# alpha,beta: 6.00 ,3.72
# ratio: 1.00
# alpha,beta: 62.00 ,21.34
# ratio: 1.00
# alpha,beta: 59.00 ,32.98
# ratio: 1.00
# alpha,beta: 39.00 ,12.79
# ratio: 1.00
# alpha,beta: 24.00 ,8.66
# ratio: 1.00
# alpha,beta: 9.00 ,11.05
# ratio: 1.00
# alpha,beta: 91.00 ,14.57
# ratio: 1.00
# alpha,beta: 30.00 ,18.25
# ratio: 1.00
# alpha,beta: 13.00 ,8.00
# ratio: 1.00
# alpha,beta: 10.00 ,7.04
# ratio: 1.00
# alpha,beta: 15.00 ,14.43
# ratio: 1.00
# alpha,beta: 83.00 ,81.65
# ratio: 1.00
# alpha,beta: 33.00 ,29.99
# ratio: 1.00
# alpha,beta: 34.00 ,32.21
# ratio: 1.00
# alpha,beta: 28.00 ,15.35
# ratio: 1.00
# alpha,beta: 140.00 ,44.81
# ratio: 1.00
# alpha,beta: 74.00 ,60.84
# ratio: 1.00
# alpha,beta: 73.00 ,41.18
# ratio: 1.00
# alpha,beta: 60.00 ,45.95
# ratio: 1.00
# alpha,beta: 19.00 ,16.62
# ratio: 1.00
# alpha,beta: 57.00 ,29.18
# ratio: 1.00
# alpha,beta: 45.00 ,12.89
# ratio: 1.00
# alpha,beta: 25.00 ,16.03
# ratio: 1.00
# alpha,beta: 8.00 ,17.77
# ratio: 1.00
# alpha,beta: 12.00 ,8.57
# ratio: 1.00
# alpha,beta: 49.00 ,46.25
# ratio: 1.00
# alpha,beta: 9.00 ,10.82
# ratio: 1.00
# alpha,beta: 7.00 ,15.35
# ratio: 1.00
# alpha,beta: 8.00 ,10.21
# ratio: 1.00
# alpha,beta: 77.00 ,31.97
# ratio: 1.00
# alpha,beta: 15.00 ,8.08
# ratio: 1.00
# alpha,beta: 11.00 ,4.99
# ratio: 1.00
# alpha,beta: 35.00 ,20.40
# ratio: 1.00
# alpha,beta: 76.00 ,105.50
# ratio: 1.00
# alpha,beta: 21.00 ,63.28
# ratio: 1.00
# alpha,beta: 234.00 ,176.90
# ratio: 1.00
# alpha,beta: 166.00 ,148.60
# ratio: 1.00
# alpha,beta: 43.00 ,102.85
# ratio: 1.00
# alpha,beta: 109.00 ,54.74
# ratio: 1.00
# alpha,beta: 34.00 ,96.32
# ratio: 1.00
# alpha,beta: 34.00 ,41.62
# ratio: 1.00
# alpha,beta: 17.00 ,38.83
# ratio: 1.00
# alpha,beta: 20.00 ,11.10
# ratio: 1.00
# alpha,beta: 9.00 ,30.95
# ratio: 1.00
# alpha,beta: 16.00 ,8.34
# ratio: 1.00
# alpha,beta: 12.00 ,26.93
# ratio: 1.00
# alpha,beta: 80.00 ,140.36
# ratio: 1.00
# alpha,beta: 55.00 ,111.28
# ratio: 1.00
# alpha,beta: 67.00 ,85.78
# ratio: 1.00
# alpha,beta: 16.00 ,29.49
# ratio: 1.00
# alpha,beta: 39.00 ,119.51
# ratio: 1.00
# alpha,beta: 98.00 ,111.09
# ratio: 1.00
# alpha,beta: 63.00 ,84.11
# ratio: 1.00
# alpha,beta: 132.00 ,67.28
# ratio: 1.00
# alpha,beta: 64.00 ,74.02
# ratio: 1.00
# alpha,beta: 56.00 ,79.44
# ratio: 1.00
# alpha,beta: 27.00 ,50.83
# ratio: 1.00
# alpha,beta: 41.00 ,21.73
# ratio: 1.00
# alpha,beta: 26.00 ,41.07
# ratio: 1.00
# alpha,beta: 19.00 ,56.72
# ratio: 1.00
# alpha,beta: 7.00 ,13.50
# ratio: 1.00
# alpha,beta: 6.00 ,14.79
# ratio: 1.00
# alpha,beta: 10.00 ,17.02
# ratio: 1.00
# alpha,beta: 13.00 ,17.18
# ratio: 1.00
# alpha,beta: 12.00 ,14.43
# ratio: 1.00
# alpha,beta: 89.00 ,105.14
# ratio: 1.00
# alpha,beta: 65.00 ,106.83
# ratio: 1.00
# alpha,beta: 17.00 ,15.09
# ratio: 1.00
# alpha,beta: 43.00 ,77.63
# ratio: 1.00
# alpha,beta: 44.00 ,66.06
# ratio: 1.00
# alpha,beta: 18.00 ,44.81
# ratio: 1.00
# alpha,beta: 11.00 ,18.98
# ratio: 1.00
# alpha,beta: 43.00 ,38.86
# ratio: 1.00
# alpha,beta: 29.00 ,74.79
# ratio: 1.00
# alpha,beta: 24.00 ,48.05
# ratio: 1.00
# alpha,beta: 19.00 ,56.05
# ratio: 1.00
# alpha,beta: 14.00 ,37.02
# ratio: 1.00
# alpha,beta: 20.00 ,34.79
# ratio: 1.00
# alpha,beta: 15.00 ,42.69
# ratio: 1.00
# alpha,beta: 15.00 ,23.78
# ratio: 1.00
# alpha,beta: 9.00 ,25.61
# ratio: 1.00
# alpha,beta: 12.00 ,28.73
# ratio: 1.00
# alpha,beta: 8.00 ,19.13
# ratio: 1.00
# alpha,beta: 13.00 ,21.95
# ratio: 1.00
# alpha,beta: 88.00 ,86.76
# ratio: 1.00
# alpha,beta: 35.00 ,94.86
# ratio: 1.00
# alpha,beta: 34.00 ,90.78
# ratio: 1.00
# alpha,beta: 47.00 ,79.16
# ratio: 1.00
# alpha,beta: 26.00 ,56.72
# ratio: 1.00
# alpha,beta: 31.00 ,58.03
# ratio: 1.00
# alpha,beta: 29.00 ,53.66
# ratio: 1.00
# alpha,beta: 19.00 ,61.37
# ratio: 1.00
# alpha,beta: 14.00 ,42.84
# ratio: 1.00
# alpha,beta: 17.00 ,38.58
# ratio: 1.00
# alpha,beta: 15.00 ,32.28
# ratio: 1.00
# alpha,beta: 12.00 ,19.64
# ratio: 1.00
# alpha,beta: 11.00 ,17.56
# ratio: 1.00
# alpha,beta: 194.00 ,118.19
# ratio: 1.00
# alpha,beta: 147.00 ,116.49
# ratio: 1.00
# alpha,beta: 85.00 ,59.04
# ratio: 1.00
# alpha,beta: 23.00 ,84.28
# ratio: 1.00
# alpha,beta: 14.00 ,21.45
# ratio: 1.00
# alpha,beta: 9.00 ,28.24
# ratio: 1.00
# alpha,beta: 6.00 ,28.10
# ratio: 1.00
# alpha,beta: 33.00 ,61.18
# ratio: 1.00
# alpha,beta: 16.00 ,65.17
# ratio: 1.00
# alpha,beta: 21.00 ,54.03
# ratio: 1.00
# alpha,beta: 9.00 ,28.68
# ratio: 1.00
# alpha,beta: 9.00 ,31.14
# ratio: 1.00
# alpha,beta: 116.00 ,82.71
# ratio: 1.00
# alpha,beta: 59.00 ,63.73
# ratio: 1.00
# alpha,beta: 39.00 ,157.96
# ratio: 1.00
# alpha,beta: 17.00 ,47.16
# ratio: 1.00
# alpha,beta: 13.00 ,25.26
# ratio: 1.00
# alpha,beta: 29.00 ,112.74
# ratio: 1.00
# alpha,beta: 35.00 ,87.99
# ratio: 1.00
# alpha,beta: 6.00 ,20.91
# ratio: 1.00
# alpha,beta: 5.00 ,21.87
# ratio: 1.00
# alpha,beta: 7.00 ,15.60
# ratio: 1.00
# alpha,beta: 68.00 ,142.11
# ratio: 1.00
# alpha,beta: 9.00 ,26.56
# ratio: 1.00
# alpha,beta: 6.00 ,13.87
# ratio: 1.00
# alpha,beta: 143.00 ,165.42
# ratio: 1.00
# alpha,beta: 45.00 ,64.41
# ratio: 1.00
# alpha,beta: 12.00 ,31.70
# ratio: 1.00
# alpha,beta: 41.00 ,67.80
# ratio: 1.00
# alpha,beta: 33.00 ,15.15
# ratio: 1.00
# alpha,beta: 0.00 ,11.85
# ratio: 1.00
# alpha,beta: 0.00 ,4.51
# ratio: 1.00
# alpha,beta: 0.00 ,14.58
# ratio: 1.00
# alpha,beta: 0.00 ,27.68
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:281: RuntimeWarning: invalid value encountered in multiply
# ratio: 1.00
# alpha,beta: 0.00 ,27.89
# ratio: 1.00
# alpha,beta: 0.00 ,22.41
# ratio: 1.00
# alpha,beta: 0.00 ,11.84
# ratio: 1.00
# alpha,beta: 0.00 ,6.56
# ratio: 1.00
# alpha,beta: 0.00 ,9.66
# ratio: 1.00
# alpha,beta: 0.00 ,10.90
# ratio: 1.00
# alpha,beta: 0.00 ,6.70
# ratio: 1.00
# alpha,beta: 0.00 ,5.87
# ratio: 1.00
# alpha,beta: 0.00 ,3.70
# ratio: 1.00
# alpha,beta: 0.00 ,7.64
# ratio: 1.00
# alpha,beta: 0.00 ,7.45
# ratio: 1.00
# alpha,beta: 0.00 ,5.61
# ratio: 1.00
# alpha,beta: 0.00 ,9.66
# ratio: 1.00
# alpha,beta: 0.00 ,3.92
# ratio: 1.00
# alpha,beta: 0.00 ,9.81
# ratio: 1.00
# alpha,beta: 0.00 ,18.42
# ratio: 1.00
# alpha,beta: 0.00 ,9.51
# ratio: 1.00
# alpha,beta: 0.00 ,18.64
# ratio: 1.00
# alpha,beta: 0.00 ,12.14
# ratio: 1.00
# alpha,beta: 0.00 ,17.08
# ratio: 1.00
# alpha,beta: 0.00 ,11.23
# ratio: 1.00
# alpha,beta: 0.00 ,2.57
# ratio: 1.00
# alpha,beta: 2.00 ,5.18
# ratio: 1.00
# alpha,beta: 0.00 ,1.43
# ratio: 1.00
# alpha,beta: 0.00 ,26.66
# ratio: 1.00
# alpha,beta: 0.00 ,26.40
# ratio: 1.00
# alpha,beta: 0.00 ,15.51
# ratio: 1.00
# alpha,beta: 0.00 ,5.16
# ratio: 1.00
# alpha,beta: 0.00 ,4.24
# ratio: 1.00
# alpha,beta: 0.00 ,6.32
# ratio: 1.00
# alpha,beta: 0.00 ,7.85
# ratio: 1.00
# alpha,beta: 0.00 ,4.88
# ratio: 1.00
# alpha,beta: 0.00 ,3.62
# ratio: 1.00
# alpha,beta: 0.00 ,16.64
# ratio: 1.00
# alpha,beta: 0.00 ,30.35
# ratio: 1.00
# alpha,beta: 0.00 ,25.41
# ratio: 1.00
# alpha,beta: 0.00 ,16.15
# ratio: 1.00
# alpha,beta: 0.00 ,8.59
# ratio: 1.00
# alpha,beta: 0.00 ,3.43
# ratio: 1.00
# alpha,beta: 0.00 ,4.39
# ratio: 1.00
# alpha,beta: 0.00 ,9.05
# ratio: 1.00
# alpha,beta: 0.00 ,29.09
# ratio: 1.00
# alpha,beta: 0.00 ,24.08
# ratio: 1.00
# alpha,beta: 0.00 ,28.04
# ratio: 1.00
# alpha,beta: 0.00 ,6.36
# ratio: 1.00
# alpha,beta: 0.00 ,19.07
# ratio: 1.00
# alpha,beta: 0.00 ,8.09
# ratio: 1.00
# alpha,beta: 0.00 ,5.62
# ratio: 1.00
# alpha,beta: 0.00 ,17.57
# ratio: 1.00
# alpha,beta: 0.00 ,36.69
# ratio: 1.00
# alpha,beta: 0.00 ,13.52
# ratio: 1.00
# alpha,beta: 0.00 ,2.86
# ratio: 1.00
# alpha,beta: 0.00 ,18.75
# ratio: 1.00
# alpha,beta: 0.00 ,13.31
# ratio: 1.00
# alpha,beta: 0.00 ,11.24
# ratio: 1.00
# alpha,beta: 0.00 ,11.12
# ratio: 1.00
# alpha,beta: 0.00 ,14.48
# ratio: 1.00
# alpha,beta: 0.00 ,30.11
# ratio: 1.00
# alpha,beta: 0.00 ,18.27
# ratio: 1.00
# alpha,beta: 0.00 ,5.96
# ratio: 1.00
# alpha,beta: 0.00 ,19.06
# ratio: 1.00
# alpha,beta: 0.00 ,24.92
# ratio: 1.00
# alpha,beta: 0.00 ,17.97
# ratio: 1.00
# alpha,beta: 0.00 ,17.69
# ratio: 1.00
# alpha,beta: 0.00 ,15.93
# ratio: 1.00
# alpha,beta: 0.00 ,22.01
# ratio: 1.00
# alpha,beta: 0.00 ,5.39
# ratio: 1.00
# alpha,beta: 0.00 ,36.04
# ratio: 1.00
# alpha,beta: 0.00 ,13.15
# ratio: 1.00
# alpha,beta: 0.00 ,53.78
# ratio: 1.00
# alpha,beta: 0.00 ,35.25
# ratio: 1.00
# alpha,beta: 0.00 ,14.81
# ratio: 1.00
# alpha,beta: 0.00 ,20.17
# ratio: 1.00
# alpha,beta: 0.00 ,12.20
# ratio: 1.00
# alpha,beta: 0.00 ,12.13
# ratio: 1.00
# alpha,beta: 0.00 ,15.38
# ratio: 1.00
# alpha,beta: 0.00 ,11.91
# ratio: 1.00
# alpha,beta: 0.00 ,36.18
# ratio: 1.00
# alpha,beta: 0.00 ,91.99
# ratio: 1.00
# alpha,beta: 0.00 ,44.07
# ratio: 1.00
# alpha,beta: 0.00 ,22.36
# ratio: 1.00
# alpha,beta: 0.00 ,16.62
# ratio: 1.00
# alpha,beta: 0.00 ,44.00
# ratio: 1.00
# alpha,beta: 0.00 ,61.73
# ratio: 1.00
# alpha,beta: 0.00 ,48.73
# ratio: 1.00
# alpha,beta: 0.00 ,5.65
# ratio: 1.00
# alpha,beta: 0.00 ,18.51
# ratio: 1.00
# alpha,beta: 0.00 ,7.08
# ratio: 1.00
# alpha,beta: 0.00 ,29.27
# ratio: 1.00
# alpha,beta: 0.00 ,15.02
# ratio: 1.00
# alpha,beta: 0.00 ,54.86
# ratio: 1.00
# alpha,beta: 0.00 ,53.92
# ratio: 1.00
# alpha,beta: 0.00 ,28.41
# ratio: 1.00
# alpha,beta: 0.00 ,15.08
# ratio: 1.00
# alpha,beta: 0.00 ,14.35
# ratio: 1.00
# alpha,beta: 0.00 ,17.79
# ratio: 1.00
# alpha,beta: 0.00 ,67.24
# ratio: 1.00
# alpha,beta: 0.00 ,59.93
# ratio: 1.00
# alpha,beta: 0.00 ,20.95
# ratio: 1.00
# alpha,beta: 0.00 ,106.27
# ratio: 1.00
# alpha,beta: 0.00 ,48.54
# ratio: 1.00
# alpha,beta: 0.00 ,55.97
# ratio: 1.00
# alpha,beta: 0.00 ,47.99
# ratio: 1.00
# alpha,beta: 0.00 ,36.63
# ratio: 1.00
# alpha,beta: 0.00 ,35.62
# ratio: 1.00
# alpha,beta: 0.00 ,25.48
# ratio: 1.00
# alpha,beta: 0.00 ,38.62
# ratio: 1.00
# alpha,beta: 0.00 ,18.96
# ratio: 1.00
# alpha,beta: 0.00 ,32.19
# ratio: 1.00
# alpha,beta: 0.00 ,22.18
# ratio: 1.00
# alpha,beta: 0.00 ,8.36
# ratio: 1.00
# alpha,beta: 0.00 ,15.47
# ratio: 1.00
# alpha,beta: 0.00 ,121.36
# ratio: 1.00
# alpha,beta: 0.00 ,62.73
# ratio: 1.00
# alpha,beta: 0.00 ,51.85
# ratio: 1.00
# alpha,beta: 0.00 ,39.20
# ratio: 1.00
# alpha,beta: 0.00 ,107.78
# ratio: 1.00
# alpha,beta: 0.00 ,24.95
# ratio: 1.00
# alpha,beta: 0.00 ,121.41
# ratio: 1.00
# alpha,beta: 0.00 ,53.65
# ratio: 1.00
# alpha,beta: 0.00 ,40.99
# ratio: 1.00
# alpha,beta: 0.00 ,30.06
# ratio: 1.00
# alpha,beta: 0.00 ,73.97
# ratio: 1.00
# alpha,beta: 0.00 ,24.81
# ratio: 1.00
# alpha,beta: 0.00 ,76.76
# ratio: 1.00
# alpha,beta: 0.00 ,30.77
# ratio: 1.00
# alpha,beta: 0.00 ,41.51
# ratio: 1.00
# alpha,beta: 0.00 ,23.63
# ratio: 1.00
# alpha,beta: 0.00 ,38.64
# ratio: 1.00
# alpha,beta: 0.00 ,22.06
# ratio: 1.00
# alpha,beta: 0.00 ,28.97
# ratio: 1.00
# alpha,beta: 0.00 ,19.07
# ratio: 1.00
# alpha,beta: 0.00 ,17.72
# ratio: 1.00
# alpha,beta: 0.00 ,27.29
# ratio: 1.00
# alpha,beta: 0.00 ,139.80
# ratio: 1.00
# alpha,beta: 0.00 ,44.20
# ratio: 1.00
# alpha,beta: 0.00 ,30.31
# ratio: 1.00
# alpha,beta: 0.00 ,30.12
# ratio: 1.00
# alpha,beta: 0.00 ,50.20
# ratio: 1.00
# alpha,beta: 0.00 ,56.04
# ratio: 1.00
# alpha,beta: 0.00 ,26.03
# ratio: 1.00
# alpha,beta: 0.00 ,22.26
# ratio: 1.00
# alpha,beta: 0.00 ,48.02
# ratio: 1.00
# alpha,beta: 0.00 ,21.62
# ratio: 1.00
# alpha,beta: 0.00 ,91.93
# ratio: 1.00
# alpha,beta: 0.00 ,52.08
# ratio: 1.00
# alpha,beta: 0.00 ,147.53
# ratio: 1.00
# alpha,beta: 0.00 ,50.55
# ratio: 1.00
# alpha,beta: 0.00 ,35.96
# ratio: 1.00
# alpha,beta: 0.00 ,147.92
# ratio: 1.00
# alpha,beta: 0.00 ,47.32
# ratio: 1.00
# alpha,beta: 0.00 ,47.32
# ratio: 1.00
# alpha,beta: 0.00 ,31.66
# ratio: 1.00
# alpha,beta: 0.00 ,43.76
# ratio: 1.00
# alpha,beta: 0.00 ,93.94
# ratio: 1.00
# alpha,beta: 0.00 ,111.27
# ratio: 1.00
# alpha,beta: 0.00 ,41.44
# ratio: 1.00
# alpha,beta: 0.00 ,50.41
# ratio: 1.00
# alpha,beta: 0.00 ,26.90
# ratio: 1.00
# alpha,beta: 0.00 ,27.33
# ratio: 1.00
# alpha,beta: 0.00 ,20.51
# ratio: 1.00
# alpha,beta: 0.00 ,28.32
# ratio: 1.00
# alpha,beta: 0.00 ,33.18
# ratio: 1.00
# alpha,beta: 0.00 ,34.01
# ratio: 1.00
# alpha,beta: 0.00 ,44.25
# ratio: 1.00
# alpha,beta: 0.00 ,63.32
# ratio: 1.00
# alpha,beta: 0.00 ,52.32
# ratio: 1.00
# alpha,beta: 0.00 ,42.54
# ratio: 1.00
# alpha,beta: 0.00 ,57.17
# ratio: 1.00
# alpha,beta: 0.00 ,57.57
# ratio: 1.00
# alpha,beta: 0.00 ,43.95
# ratio: 1.00
# alpha,beta: 0.00 ,26.98
# ratio: 1.00
# alpha,beta: 0.00 ,48.46
# ratio: 1.00
# alpha,beta: 0.00 ,30.44
# ratio: 1.00
# alpha,beta: 0.00 ,28.39
# ratio: 1.00
# alpha,beta: 0.00 ,20.68
# ratio: 1.00
# alpha,beta: 0.00 ,97.54
# ratio: 1.00
# alpha,beta: 0.00 ,102.12
# ratio: 1.00
# alpha,beta: 0.00 ,93.30
# ratio: 1.00
# alpha,beta: 0.00 ,34.66
# ratio: 1.00
# alpha,beta: 0.00 ,77.33
# ratio: 1.00
# alpha,beta: 0.00 ,48.36
# ratio: 1.00
# alpha,beta: 0.00 ,32.10
# ratio: 1.00
# alpha,beta: 0.00 ,31.86
# ratio: 1.00
# alpha,beta: 0.00 ,27.39
# ratio: 1.00
# alpha,beta: 10.00 ,7.63
# ratio: 1.00
# alpha,beta: 16.00 ,6.45
# ratio: 1.00
# alpha,beta: 43.00 ,38.54
# ratio: 1.00
# alpha,beta: 24.00 ,10.60
# ratio: 1.00
# alpha,beta: 7.00 ,5.73
# ratio: 1.00
# alpha,beta: 13.00 ,15.83
# ratio: 1.00
# alpha,beta: 88.00 ,24.15
# ratio: 1.00
# alpha,beta: 7.00 ,2.40
# ratio: 1.00
# alpha,beta: 76.00 ,10.99
# ratio: 1.00
# alpha,beta: 27.00 ,12.43
# ratio: 1.00
# alpha,beta: 12.00 ,3.98
# ratio: 1.00
# alpha,beta: 74.00 ,27.56
# ratio: 1.00
# alpha,beta: 24.00 ,17.62
# ratio: 1.00
# alpha,beta: 25.00 ,8.46
# ratio: 1.00
# alpha,beta: 10.00 ,0.95
# ratio: 1.00
# alpha,beta: 49.00 ,50.93
# ratio: 1.00
# alpha,beta: 16.00 ,8.14
# ratio: 1.00
# alpha,beta: 54.00 ,32.76
# ratio: 1.00
# alpha,beta: 19.00 ,28.33
# ratio: 1.00
# alpha,beta: 24.00 ,11.17
# ratio: 1.00
# alpha,beta: 9.00 ,7.27
# ratio: 1.00
# alpha,beta: 18.00 ,5.05
# ratio: 1.00
# alpha,beta: 12.00 ,16.82
# ratio: 1.00
# alpha,beta: 10.00 ,5.01
# ratio: 1.00
# alpha,beta: 43.00 ,16.15
# ratio: 1.00
# alpha,beta: 51.00 ,44.67
# ratio: 1.00
# alpha,beta: 29.00 ,30.65
# ratio: 1.00
# alpha,beta: 17.00 ,10.20
# ratio: 1.00
# alpha,beta: 18.00 ,1.59
# ratio: 1.00
# alpha,beta: 84.00 ,36.14
# ratio: 1.00
# alpha,beta: 47.00 ,34.48
# ratio: 1.00
# alpha,beta: 24.00 ,10.78
# ratio: 1.00
# alpha,beta: 9.00 ,3.79
# ratio: 1.00
# alpha,beta: 6.00 ,9.92
# ratio: 1.00
# alpha,beta: 29.00 ,16.73
# ratio: 1.00
# alpha,beta: 36.00 ,9.77
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:283: RuntimeWarning: invalid value encountered in divide
# ratio: 1.00
# alpha,beta: 18.00 ,2.13
# ratio: 1.00
# alpha,beta: 43.00 ,18.21
# ratio: 1.00
# alpha,beta: 122.00 ,22.38
# ratio: 1.00
# alpha,beta: 22.00 ,14.12
# ratio: 1.00
# alpha,beta: 11.00 ,11.84
# ratio: 1.00
# alpha,beta: 26.00 ,15.05
# ratio: 1.00
# alpha,beta: 18.00 ,14.93
# ratio: 1.00
# alpha,beta: 14.00 ,14.05
# ratio: 1.00
# alpha,beta: 23.00 ,9.17
# ratio: 1.00
# alpha,beta: 89.00 ,52.23
# ratio: 1.00
# alpha,beta: 33.00 ,11.71
# ratio: 1.00
# alpha,beta: 35.00 ,5.77
# ratio: 1.00
# alpha,beta: 14.00 ,8.51
# ratio: 1.00
# alpha,beta: 30.00 ,7.27
# ratio: 1.00
# alpha,beta: 54.00 ,29.61
# ratio: 1.00
# alpha,beta: 112.00 ,51.08
# ratio: 1.00
# alpha,beta: 54.00 ,25.72
# ratio: 1.00
# alpha,beta: 29.00 ,15.83
# ratio: 1.00
# alpha,beta: 8.00 ,2.92
# ratio: 1.00
# alpha,beta: 8.00 ,6.92
# ratio: 1.00
# alpha,beta: 13.00 ,18.22
# ratio: 1.00
# alpha,beta: 13.00 ,6.08
# ratio: 1.00
# alpha,beta: 19.00 ,20.11
# ratio: 1.00
# alpha,beta: 9.00 ,5.45
# ratio: 1.00
# alpha,beta: 43.00 ,27.62
# ratio: 1.00
# alpha,beta: 96.00 ,14.99
# ratio: 1.00
# alpha,beta: 74.00 ,23.90
# ratio: 1.00
# alpha,beta: 64.00 ,24.27
# ratio: 1.00
# alpha,beta: 25.00 ,4.77
# ratio: 1.00
# alpha,beta: 17.00 ,8.63
# ratio: 1.00
# alpha,beta: 24.00 ,10.84
# ratio: 1.00
# alpha,beta: 103.00 ,37.04
# ratio: 1.00
# alpha,beta: 39.00 ,15.40
# ratio: 1.00
# alpha,beta: 19.00 ,17.78
# ratio: 1.00
# alpha,beta: 15.00 ,5.80
# ratio: 1.00
# alpha,beta: 7.00 ,1.85
# ratio: 1.00
# alpha,beta: 40.00 ,25.06
# ratio: 1.00
# alpha,beta: 25.00 ,28.94
# ratio: 1.00
# alpha,beta: 19.00 ,16.91
# ratio: 1.00
# alpha,beta: 9.00 ,15.38
# ratio: 1.00
# alpha,beta: 7.00 ,11.47
# ratio: 1.00
# alpha,beta: 123.00 ,75.10
# ratio: 1.00
# alpha,beta: 91.00 ,51.19
# ratio: 1.00
# alpha,beta: 65.00 ,31.50
# ratio: 1.00
# alpha,beta: 45.00 ,29.23
# ratio: 1.00
# alpha,beta: 28.00 ,21.17
# ratio: 1.00
# alpha,beta: 34.00 ,32.22
# ratio: 1.00
# alpha,beta: 13.00 ,10.97
# ratio: 1.00
# alpha,beta: 17.00 ,21.38
# ratio: 1.00
# alpha,beta: 11.00 ,13.98
# ratio: 1.00
# alpha,beta: 19.00 ,9.67
# ratio: 1.00
# alpha,beta: 15.00 ,11.55
# ratio: 1.00
# alpha,beta: 18.00 ,23.81
# ratio: 1.00
# alpha,beta: 15.00 ,15.81
# ratio: 1.00
# alpha,beta: 50.00 ,36.44
# ratio: 1.00
# alpha,beta: 12.00 ,25.56
# ratio: 1.00
# alpha,beta: 7.00 ,3.23
# ratio: 1.00
# alpha,beta: 6.00 ,9.10
# ratio: 1.00
# alpha,beta: 37.00 ,27.25
# ratio: 1.00
# alpha,beta: 19.00 ,5.24
# ratio: 1.00
# alpha,beta: 30.00 ,15.77
# ratio: 1.00
# alpha,beta: 23.00 ,19.16
# ratio: 1.00
# alpha,beta: 21.00 ,19.59
# ratio: 1.00
# alpha,beta: 62.00 ,45.35
# ratio: 1.00
# alpha,beta: 26.00 ,39.46
# ratio: 1.00
# alpha,beta: 16.00 ,18.55
# ratio: 1.00
# alpha,beta: 24.00 ,29.07
# ratio: 1.00
# alpha,beta: 15.00 ,29.31
# ratio: 1.00
# alpha,beta: 192.00 ,44.91
# ratio: 1.00
# alpha,beta: 128.00 ,48.18
# ratio: 1.00
# alpha,beta: 11.00 ,8.44
# ratio: 1.00
# alpha,beta: 38.00 ,48.66
# ratio: 1.00
# alpha,beta: 36.00 ,14.55
# ratio: 1.00
# alpha,beta: 24.00 ,10.77
# ratio: 1.00
# alpha,beta: 42.00 ,8.92
# ratio: 1.00
# alpha,beta: 44.00 ,18.97
# ratio: 1.00
# alpha,beta: 12.00 ,11.82
# ratio: 1.00
# alpha,beta: 210.00 ,47.69
# ratio: 1.00
# alpha,beta: 126.00 ,34.67
# ratio: 1.00
# alpha,beta: 52.00 ,37.22
# ratio: 1.00
# alpha,beta: 43.00 ,30.60
# ratio: 1.00
# alpha,beta: 18.00 ,11.28
# ratio: 1.00
# alpha,beta: 17.00 ,11.83
# ratio: 1.00
# alpha,beta: 82.00 ,69.41
# ratio: 1.00
# alpha,beta: 73.00 ,42.51
# ratio: 1.00
# alpha,beta: 59.00 ,77.40
# ratio: 1.00
# alpha,beta: 41.00 ,51.58
# ratio: 1.00
# alpha,beta: 25.00 ,19.24
# ratio: 1.00
# alpha,beta: 16.00 ,15.77
# ratio: 1.00
# alpha,beta: 6.00 ,19.92
# ratio: 1.00
# alpha,beta: 76.00 ,57.50
# ratio: 1.00
# alpha,beta: 7.00 ,5.31
# ratio: 1.00
# alpha,beta: 14.00 ,26.33
# ratio: 1.00
# alpha,beta: 7.00 ,20.89
# ratio: 1.00
# alpha,beta: 25.00 ,25.03
# ratio: 1.00
# alpha,beta: 77.00 ,36.43
# ratio: 1.00
# alpha,beta: 20.00 ,9.60
# ratio: 1.00
# alpha,beta: 10.00 ,8.36
# ratio: 1.00
# alpha,beta: 145.00 ,39.32
# ratio: 1.00
# alpha,beta: 121.00 ,46.56
# ratio: 1.00
# alpha,beta: 14.00 ,9.99
# ratio: 1.00
# alpha,beta: 65.00 ,40.77
# ratio: 1.00
# alpha,beta: 14.00 ,12.99
# ratio: 1.00
# alpha,beta: 15.00 ,23.18
# ratio: 1.00
# alpha,beta: 10.00 ,11.17
# ratio: 1.00
# alpha,beta: 5.00 ,1.01
# ratio: 1.00
# alpha,beta: 39.00 ,45.57
# ratio: 1.00
# alpha,beta: 13.00 ,6.93
# ratio: 1.00
# alpha,beta: 6.00 ,18.07
# ratio: 1.00
# alpha,beta: 19.00 ,26.83
# ratio: 1.00
# alpha,beta: 9.00 ,6.28
# ratio: 1.00
# alpha,beta: 13.00 ,17.44
# ratio: 1.00
# alpha,beta: 12.00 ,19.28
# ratio: 1.00
# alpha,beta: 63.00 ,34.05
# ratio: 1.00
# alpha,beta: 68.00 ,64.30
# ratio: 1.00
# alpha,beta: 106.00 ,71.09
# ratio: 1.00
# alpha,beta: 35.00 ,34.15
# ratio: 1.00
# alpha,beta: 49.00 ,41.63
# ratio: 1.00
# alpha,beta: 44.00 ,43.34
# ratio: 1.00
# alpha,beta: 11.00 ,18.41
# ratio: 1.00
# alpha,beta: 11.00 ,14.72
# ratio: 1.00
# alpha,beta: 13.00 ,20.02
# ratio: 1.00
# alpha,beta: 33.00 ,29.81
# ratio: 1.00
# alpha,beta: 26.00 ,32.52
# ratio: 1.00
# alpha,beta: 25.00 ,42.64
# ratio: 1.00
# alpha,beta: 26.00 ,64.30
# ratio: 1.00
# alpha,beta: 15.00 ,14.19
# ratio: 1.00
# alpha,beta: 61.00 ,33.36
# ratio: 1.00
# alpha,beta: 38.00 ,29.08
# ratio: 1.00
# alpha,beta: 43.00 ,40.93
# ratio: 1.00
# alpha,beta: 18.00 ,22.84
# ratio: 1.00
# alpha,beta: 49.00 ,68.23
# ratio: 1.00
# alpha,beta: 59.00 ,80.80
# ratio: 1.00
# alpha,beta: 120.00 ,93.97
# ratio: 1.00
# alpha,beta: 91.00 ,68.21
# ratio: 1.00
# alpha,beta: 76.00 ,40.60
# ratio: 1.00
# alpha,beta: 15.00 ,28.67
# ratio: 1.00
# alpha,beta: 35.00 ,60.04
# ratio: 1.00
# alpha,beta: 40.00 ,36.57
# ratio: 1.00
# alpha,beta: 42.00 ,62.86
# ratio: 1.00
# alpha,beta: 44.00 ,33.98
# ratio: 1.00
# alpha,beta: 22.00 ,19.97
# ratio: 1.00
# alpha,beta: 24.00 ,23.29
# ratio: 1.00
# alpha,beta: 19.00 ,49.74
# ratio: 1.00
# alpha,beta: 15.00 ,26.14
# ratio: 1.00
# alpha,beta: 8.00 ,5.57
# ratio: 1.00
# alpha,beta: 9.00 ,4.80
# ratio: 1.00
# alpha,beta: 10.00 ,12.75
# ratio: 1.00
# alpha,beta: 15.00 ,16.56
# ratio: 1.00
# alpha,beta: 6.00 ,27.61
# ratio: 1.00
# alpha,beta: 113.00 ,118.19
# ratio: 1.00
# alpha,beta: 80.00 ,122.34
# ratio: 1.00
# alpha,beta: 64.00 ,107.66
# ratio: 1.00
# alpha,beta: 58.00 ,38.17
# ratio: 1.00
# alpha,beta: 36.00 ,46.24
# ratio: 1.00
# alpha,beta: 9.00 ,41.83
# ratio: 1.00
# alpha,beta: 13.00 ,23.40
# ratio: 1.00
# alpha,beta: 18.00 ,65.54
# ratio: 1.00
# alpha,beta: 20.00 ,37.50
# ratio: 1.00
# alpha,beta: 53.00 ,82.41
# ratio: 1.00
# alpha,beta: 77.00 ,119.36
# ratio: 1.00
# alpha,beta: 38.00 ,65.81
# ratio: 1.00
# alpha,beta: 45.00 ,44.25
# ratio: 1.00
# alpha,beta: 33.00 ,31.55
# ratio: 1.00
# alpha,beta: 21.00 ,58.52
# ratio: 1.00
# alpha,beta: 12.00 ,29.29
# ratio: 1.00
# alpha,beta: 7.00 ,26.35
# ratio: 1.00
# alpha,beta: 9.00 ,20.70
# ratio: 1.00
# alpha,beta: 15.00 ,17.28
# ratio: 1.00
# alpha,beta: 10.00 ,16.56
# ratio: 1.00
# alpha,beta: 13.00 ,13.72
# ratio: 1.00
# alpha,beta: 41.00 ,146.53
# ratio: 1.00
# alpha,beta: 120.00 ,78.28
# ratio: 1.00
# alpha,beta: 18.00 ,38.07
# ratio: 1.00
# alpha,beta: 16.00 ,15.85
# ratio: 1.00
# alpha,beta: 24.00 ,81.93
# ratio: 1.00
# alpha,beta: 15.00 ,49.37
# ratio: 1.00
# alpha,beta: 51.00 ,56.01
# ratio: 1.00
# alpha,beta: 41.00 ,67.05
# ratio: 1.00
# alpha,beta: 35.00 ,46.26
# ratio: 1.00
# alpha,beta: 41.00 ,43.09
# ratio: 1.00
# alpha,beta: 21.00 ,51.02
# ratio: 1.00
# alpha,beta: 19.00 ,35.05
# ratio: 1.00
# alpha,beta: 9.00 ,17.56
# ratio: 1.00
# alpha,beta: 33.00 ,27.62
# ratio: 1.00
# alpha,beta: 6.00 ,21.73
# ratio: 1.00
# alpha,beta: 41.00 ,44.28
# ratio: 1.00
# alpha,beta: 28.00 ,25.66
# ratio: 1.00
# alpha,beta: 12.00 ,19.65
# ratio: 1.00
# alpha,beta: 36.00 ,52.64
# ratio: 1.00
# alpha,beta: 38.00 ,77.27
# ratio: 1.00
# alpha,beta: 48.00 ,73.57
# ratio: 1.00
# alpha,beta: 20.00 ,31.33
# ratio: 1.00
# alpha,beta: 14.00 ,26.95
# ratio: 1.00
# alpha,beta: 13.00 ,29.22
# ratio: 1.00
# alpha,beta: 14.00 ,26.53
# ratio: 1.00
# alpha,beta: 11.00 ,30.34
# ratio: 1.00
# alpha,beta: 56.00 ,54.06
# ratio: 1.00
# alpha,beta: 22.00 ,18.53
# ratio: 1.00
# alpha,beta: 41.00 ,41.22
# ratio: 1.00
# alpha,beta: 7.00 ,35.06
# ratio: 1.00
# alpha,beta: 93.00 ,97.40
# ratio: 1.00
# alpha,beta: 43.00 ,64.93
# ratio: 1.00
# alpha,beta: 28.00 ,35.97
# ratio: 1.00
# alpha,beta: 27.00 ,25.87
# ratio: 1.00
# alpha,beta: 15.00 ,39.06
# ratio: 1.00
# alpha,beta: 11.00 ,16.21
# ratio: 1.00
# alpha,beta: 46.00 ,97.33
# ratio: 1.00
# alpha,beta: 41.00 ,40.44
# ratio: 1.00
# alpha,beta: 10.00 ,22.28
# ratio: 1.00
# alpha,beta: 42.00 ,54.42
# ratio: 1.00
# alpha,beta: 10.00 ,25.26
# ratio: 1.00
# alpha,beta: 10.00 ,14.54
# ratio: 1.00
# alpha,beta: 32.00 ,63.15
# ratio: 1.00
# alpha,beta: 3.00 ,14.78
# ratio: 1.00
# alpha,beta: 9.00 ,30.43
# ratio: 1.00
# alpha,beta: 8.00 ,24.40
# ratio: 1.00
# alpha,beta: 10.00 ,23.48
# ratio: 1.00
# alpha,beta: 23.00 ,39.56
# ratio: 1.00
# alpha,beta: 16.00 ,53.63
# ratio: 1.00
# alpha,beta: 18.00 ,34.27
# ratio: 1.00
# alpha,beta: 20.00 ,48.84
# ratio: 1.00
# alpha,beta: 5.00 ,24.16
# ratio: 1.00
# alpha,beta: 8.00 ,11.07
# ratio: 1.00
# alpha,beta: 30.00 ,37.58
# ratio: 1.00
# alpha,beta: 27.00 ,50.34
# ratio: 1.00
# alpha,beta: 14.00 ,29.25
# ratio: 1.00
# alpha,beta: 124.00 ,122.09
# ratio: 1.00
# alpha,beta: 104.00 ,126.61
# ratio: 1.00
# alpha,beta: 50.00 ,100.70
# ratio: 1.00
# alpha,beta: 46.00 ,114.74
# ratio: 1.00
# alpha,beta: 35.00 ,87.36
# ratio: 1.00
# alpha,beta: 39.00 ,104.76
# ratio: 1.00
# alpha,beta: 40.00 ,53.59
# ratio: 1.00
# alpha,beta: 18.00 ,70.51
# ratio: 1.00
# alpha,beta: 23.00 ,80.14
# ratio: 1.00
# alpha,beta: 14.00 ,32.90
# ratio: 1.00
# alpha,beta: 17.00 ,34.65
# ratio: 1.00
# alpha,beta: 8.00 ,26.36
# ratio: 1.00
# alpha,beta: 13.00 ,34.23
# ratio: 1.00
# alpha,beta: 35.00 ,117.34
# ratio: 1.00
# alpha,beta: 23.00 ,42.24
# ratio: 1.00
# alpha,beta: 11.00 ,53.75
# ratio: 1.00
# alpha,beta: 28.00 ,74.70
# ratio: 1.00
# alpha,beta: 10.00 ,27.44
# ratio: 1.00
# alpha,beta: 7.00 ,18.37
# ratio: 1.00
# alpha,beta: 20.00 ,31.77
# ratio: 1.00
# alpha,beta: 2.00 ,36.36
# ratio: 1.00
# alpha,beta: 39.00 ,75.14
# ratio: 1.00
# alpha,beta: 28.00 ,72.77
# ratio: 1.00
# alpha,beta: 39.00 ,67.72
# ratio: 1.00
# alpha,beta: 29.00 ,106.73
# ratio: 1.00
# alpha,beta: 31.00 ,61.89
# ratio: 1.00
# alpha,beta: 25.00 ,54.48
# ratio: 1.00
# alpha,beta: 26.00 ,73.80
# ratio: 1.00
# alpha,beta: 19.00 ,59.61
# ratio: 1.00
# alpha,beta: 7.00 ,23.63
# ratio: 1.00
# alpha,beta: 5.00 ,15.93
# ratio: 1.00
# alpha,beta: 6.00 ,21.14
# ratio: 1.00
# alpha,beta: 8.00 ,21.56
# ratio: 1.00
# alpha,beta: 9.00 ,21.05
# ratio: 1.00
# alpha,beta: 4.00 ,15.29
# ratio: 1.00
# alpha,beta: 43.00 ,87.49
# ratio: 1.00
# alpha,beta: 11.00 ,13.99
# ratio: 1.00
# alpha,beta: 21.00 ,42.81
# ratio: 1.00
# alpha,beta: 63.00 ,66.08
# ratio: 1.00
# alpha,beta: 29.00 ,49.92
# ratio: 1.00
# alpha,beta: 6.00 ,24.36
# ratio: 1.00
# alpha,beta: 28.00 ,60.29
# ratio: 1.00
# alpha,beta: 32.00 ,46.36
# ratio: 1.00
# alpha,beta: 13.00 ,27.59
# ratio: 1.00
# alpha,beta: 19.00 ,53.77
# ratio: 1.00
# alpha,beta: 8.00 ,15.63
# ratio: 1.00
# alpha,beta: 11.00 ,27.52
# ratio: 1.00
# alpha,beta: 7.00 ,29.92
# ratio: 1.00
# alpha,beta: 4.00 ,22.62
# ratio: 1.00
# alpha,beta: 15.00 ,101.96
# ratio: 1.00
# alpha,beta: 29.00 ,72.28
# ratio: 1.00
# alpha,beta: 44.00 ,50.62
# ratio: 1.00
# alpha,beta: 30.00 ,52.79
# ratio: 1.00
# alpha,beta: 17.00 ,69.77
# ratio: 1.00
# alpha,beta: 19.00 ,65.11
# ratio: 1.00
# alpha,beta: 11.00 ,18.96
# ratio: 1.00
# alpha,beta: 12.00 ,39.98
# ratio: 1.00
# alpha,beta: 22.00 ,56.43
# ratio: 1.00
# alpha,beta: 6.00 ,13.47
# ratio: 1.00
# alpha,beta: 143.00 ,66.79
# ratio: 1.00
# alpha,beta: 96.00 ,79.83
# ratio: 1.00
# alpha,beta: 36.00 ,48.75
# ratio: 1.00
# alpha,beta: 35.00 ,50.02
# ratio: 1.00
# alpha,beta: 38.00 ,50.59
# ratio: 1.00
# alpha,beta: 18.00 ,22.77
# ratio: 1.00
# alpha,beta: 29.00 ,40.13
# ratio: 1.00
# alpha,beta: 12.00 ,27.16
# ratio: 1.00
# alpha,beta: 22.00 ,45.92
# ratio: 1.00
# alpha,beta: 19.00 ,29.38
# ratio: 1.00
# alpha,beta: 9.00 ,30.05
# ratio: 1.00
# alpha,beta: 29.00 ,37.32
# ratio: 1.00
# alpha,beta: 14.00 ,5.84
# ratio: 1.00
# alpha,beta: 13.00 ,42.47
# ratio: 1.00
# alpha,beta: 9.00 ,19.12
# ratio: 1.00
# alpha,beta: 7.00 ,24.94
# ratio: 1.00
# alpha,beta: 13.00 ,13.76
# ratio: 1.00
# alpha,beta: 9.00 ,19.00
# ratio: 1.00
# alpha,beta: 8.00 ,10.22
# ratio: 1.00
# alpha,beta: 167.00 ,94.79
# ratio: 1.00
# alpha,beta: 46.00 ,45.71
# ratio: 1.00
# alpha,beta: 68.00 ,98.17
# ratio: 1.00
# alpha,beta: 58.00 ,48.61
# ratio: 1.00
# alpha,beta: 57.00 ,47.87
# ratio: 1.00
# alpha,beta: 37.00 ,62.82
# ratio: 1.00
# alpha,beta: 51.00 ,50.04
# ratio: 1.00
# alpha,beta: 40.00 ,38.43
# ratio: 1.00
# alpha,beta: 29.00 ,37.57
# ratio: 1.00
# alpha,beta: 38.00 ,50.84
# ratio: 1.00
# alpha,beta: 18.00 ,32.48
# ratio: 1.00
# alpha,beta: 15.00 ,65.16
# ratio: 1.00
# alpha,beta: 25.00 ,44.23
# ratio: 1.00
# alpha,beta: 10.00 ,33.03
# ratio: 1.00
# alpha,beta: 12.00 ,21.58
# ratio: 1.00
# alpha,beta: 95.00 ,112.64
# ratio: 1.00
# alpha,beta: 118.00 ,92.00
# ratio: 1.00
# alpha,beta: 50.00 ,52.16
# ratio: 1.00
# alpha,beta: 40.00 ,68.55
# ratio: 1.00
# alpha,beta: 52.00 ,114.32
# ratio: 1.00
# alpha,beta: 29.00 ,33.76
# ratio: 1.00
# alpha,beta: 25.00 ,40.24
# ratio: 1.00
# alpha,beta: 21.00 ,33.54
# ratio: 1.00
# alpha,beta: 17.00 ,18.57
# ratio: 1.00
# alpha,beta: 8.00 ,16.62
# ratio: 1.00
# alpha,beta: 8.00 ,21.88
# ratio: 1.00
# alpha,beta: 19.00 ,19.45
# ratio: 1.00
# alpha,beta: 13.00 ,16.09
# ratio: 1.00
# alpha,beta: 7.00 ,22.58
# ratio: 1.00
# alpha,beta: 7.00 ,7.52
# ratio: 1.00
# alpha,beta: 67.00 ,150.88
# ratio: 1.00
# alpha,beta: 65.00 ,112.07
# ratio: 1.00
# alpha,beta: 59.00 ,54.59
# ratio: 1.00
# alpha,beta: 31.00 ,63.18
# ratio: 1.00
# alpha,beta: 41.00 ,67.15
# ratio: 1.00
# alpha,beta: 26.00 ,68.38
# ratio: 1.00
# alpha,beta: 34.00 ,47.86
# ratio: 1.00
# alpha,beta: 17.00 ,49.97
# ratio: 1.00
# alpha,beta: 27.00 ,38.47
# ratio: 1.00
# alpha,beta: 19.00 ,29.63
# ratio: 1.00
# alpha,beta: 18.00 ,51.23
# ratio: 1.00
# alpha,beta: 12.00 ,57.93
# ratio: 1.00
# alpha,beta: 17.00 ,36.12
# ratio: 1.00
# alpha,beta: 13.00 ,18.02
# ratio: 1.00
# alpha,beta: 12.00 ,21.08
# ratio: 1.00
# alpha,beta: 6.00 ,21.49
# ratio: 1.00
# alpha,beta: 13.00 ,13.11
# ratio: 1.00
# alpha,beta: 9.00 ,17.79
# ratio: 1.00
# alpha,beta: 76.00 ,99.09
# ratio: 1.00
# alpha,beta: 97.00 ,162.63
# ratio: 1.00
# alpha,beta: 25.00 ,28.32
# ratio: 1.00
# alpha,beta: 18.00 ,36.81
# ratio: 1.00
# alpha,beta: 22.00 ,33.49
# ratio: 1.00
# alpha,beta: 18.00 ,33.40
# ratio: 1.00
# alpha,beta: 12.00 ,7.37
# ratio: 1.00
# alpha,beta: 160.00 ,110.87
# ratio: 1.00
# alpha,beta: 143.00 ,121.71
# ratio: 1.00
# alpha,beta: 157.00 ,94.43
# ratio: 1.00
# alpha,beta: 60.00 ,114.01
# ratio: 1.00
# alpha,beta: 120.00 ,83.07
# ratio: 1.00
# alpha,beta: 22.00 ,58.95
# ratio: 1.00
# alpha,beta: 45.00 ,61.52
# ratio: 1.00
# alpha,beta: 29.00 ,39.56
# ratio: 1.00
# alpha,beta: 36.00 ,67.67
# ratio: 1.00
# alpha,beta: 21.00 ,52.10
# ratio: 1.00
# alpha,beta: 21.00 ,52.30
# ratio: 1.00
# alpha,beta: 21.00 ,56.04
# ratio: 1.00
# alpha,beta: 11.00 ,28.38
# ratio: 1.00
# alpha,beta: 20.00 ,33.31
# ratio: 1.00
# alpha,beta: 21.00 ,56.64
# ratio: 1.00
# alpha,beta: 14.00 ,34.53
# ratio: 1.00
# alpha,beta: 16.00 ,18.95
# ratio: 1.00
# alpha,beta: 16.00 ,32.90
# ratio: 1.00
# alpha,beta: 9.00 ,12.70
# ratio: 1.00
# alpha,beta: 15.00 ,34.13
# ratio: 1.00
# alpha,beta: 6.00 ,18.86
# ratio: 1.00
# alpha,beta: 9.00 ,15.71
# ratio: 1.00
# alpha,beta: 6.00 ,17.11
# ratio: 1.00
# alpha,beta: 40.00 ,35.84
# ratio: 1.00
# alpha,beta: 11.00 ,29.45
# ratio: 1.00
# alpha,beta: 30.00 ,45.53
# ratio: 1.00
# alpha,beta: 18.00 ,50.76
# ratio: 1.00
# alpha,beta: 19.00 ,35.81
# ratio: 1.00
# alpha,beta: 92.00 ,23.93
# ratio: 1.00
# alpha,beta: 54.00 ,12.23
# ratio: 1.00
# alpha,beta: 17.00 ,1.02
# ratio: 1.00
# alpha,beta: 86.00 ,21.59
# ratio: 1.00
# alpha,beta: 40.00 ,12.35
# ratio: 1.00
# alpha,beta: 16.00 ,8.24
# ratio: 1.00
# alpha,beta: 36.00 ,19.84
# ratio: 1.00
# alpha,beta: 24.00 ,21.33
# ratio: 1.00
# alpha,beta: 21.00 ,7.67
# ratio: 1.00
# alpha,beta: 6.00 ,11.93
# ratio: 1.00
# alpha,beta: 14.00 ,15.90
# ratio: 1.00
# alpha,beta: 19.00 ,12.10
# ratio: 1.00
# alpha,beta: 21.00 ,6.76
# ratio: 1.00
# alpha,beta: 16.00 ,9.65
# ratio: 1.00
# alpha,beta: 55.00 ,11.52
# ratio: 1.00
# alpha,beta: 41.00 ,14.91
# ratio: 1.00
# alpha,beta: 52.00 ,25.31
# ratio: 1.00
# alpha,beta: 62.00 ,14.50
# ratio: 1.00
# alpha,beta: 45.00 ,14.38
# ratio: 1.00
# alpha,beta: 23.00 ,5.30
# ratio: 1.00
# alpha,beta: 12.00 ,3.49
# ratio: 1.00
# alpha,beta: 41.00 ,21.62
# ratio: 1.00
# alpha,beta: 7.00 ,1.53
# ratio: 1.00
# alpha,beta: 10.00 ,9.07
# ratio: 1.00
# alpha,beta: 78.00 ,11.81
# ratio: 1.00
# alpha,beta: 57.00 ,24.24
# ratio: 1.00
# alpha,beta: 35.00 ,28.34
# ratio: 1.00
# alpha,beta: 13.00 ,7.46
# ratio: 1.00
# alpha,beta: 14.00 ,11.19
# ratio: 1.00
# alpha,beta: 147.00 ,24.67
# ratio: 1.00
# alpha,beta: 107.00 ,58.06
# ratio: 1.00
# alpha,beta: 64.00 ,8.10
# ratio: 1.00
# alpha,beta: 56.00 ,19.43
# ratio: 1.00
# alpha,beta: 92.00 ,23.29
# ratio: 1.00
# alpha,beta: 11.00 ,3.45
# ratio: 1.00
# alpha,beta: 18.00 ,9.26
# ratio: 1.00
# alpha,beta: 21.00 ,15.61
# ratio: 1.00
# alpha,beta: 10.00 ,9.76
# ratio: 1.00
# alpha,beta: 78.00 ,71.51
# ratio: 1.00
# alpha,beta: 88.00 ,44.19
# ratio: 1.00
# alpha,beta: 61.00 ,37.96
# ratio: 1.00
# alpha,beta: 42.00 ,31.69
# ratio: 1.00
# alpha,beta: 48.00 ,20.96
# ratio: 1.00
# alpha,beta: 25.00 ,19.54
# ratio: 1.00
# alpha,beta: 111.00 ,44.50
# ratio: 1.00
# alpha,beta: 30.00 ,29.94
# ratio: 1.00
# alpha,beta: 8.00 ,13.68
# ratio: 1.00
# alpha,beta: 47.00 ,19.19
# ratio: 1.00
# alpha,beta: 12.00 ,18.29
# ratio: 1.00
# alpha,beta: 26.00 ,14.04
# ratio: 1.00
# alpha,beta: 19.00 ,4.47
# ratio: 1.00
# alpha,beta: 35.00 ,20.69
# ratio: 1.00
# alpha,beta: 26.00 ,8.04
# ratio: 1.00
# alpha,beta: 31.00 ,7.05
# ratio: 1.00
# alpha,beta: 44.00 ,9.05
# ratio: 1.00
# alpha,beta: 24.00 ,17.31
# ratio: 1.00
# alpha,beta: 28.00 ,11.84
# ratio: 1.00
# alpha,beta: 5.00 ,7.41
# ratio: 1.00
# alpha,beta: 50.00 ,41.48
# ratio: 1.00
# alpha,beta: 26.00 ,19.18
# ratio: 1.00
# alpha,beta: 8.00 ,9.69
# ratio: 1.00
# alpha,beta: 21.00 ,39.23
# ratio: 1.00
# alpha,beta: 14.00 ,12.54
# ratio: 1.00
# alpha,beta: 7.00 ,3.29
# ratio: 1.00
# alpha,beta: 76.00 ,24.58
# ratio: 1.00
# alpha,beta: 51.00 ,61.14
# ratio: 1.00
# alpha,beta: 30.00 ,58.92
# ratio: 1.00
# alpha,beta: 6.00 ,10.19
# ratio: 1.00
# alpha,beta: 7.00 ,8.97
# ratio: 1.00
# alpha,beta: 9.00 ,4.10
# ratio: 1.00
# alpha,beta: 30.00 ,14.61
# ratio: 1.00
# alpha,beta: 32.00 ,17.02
# ratio: 1.00
# alpha,beta: 53.00 ,51.79
# ratio: 1.00
# alpha,beta: 13.00 ,12.55
# ratio: 1.00
# alpha,beta: 7.00 ,8.12
# ratio: 1.00
# alpha,beta: 52.00 ,31.73
# ratio: 1.00
# alpha,beta: 21.00 ,26.05
# ratio: 1.00
# alpha,beta: 14.00 ,16.65
# ratio: 1.00
# alpha,beta: 14.00 ,5.11
# ratio: 1.00
# alpha,beta: 13.00 ,2.91
# ratio: 1.00
# alpha,beta: 14.00 ,9.61
# ratio: 1.00
# alpha,beta: 107.00 ,105.81
# ratio: 1.00
# alpha,beta: 73.00 ,29.49
# ratio: 1.00
# alpha,beta: 19.00 ,11.60
# ratio: 1.00
# alpha,beta: 18.00 ,10.74
# ratio: 1.00
# alpha,beta: 56.00 ,44.07
# ratio: 1.00
# alpha,beta: 45.00 ,12.32
# ratio: 1.00
# alpha,beta: 36.00 ,9.76
# ratio: 1.00
# alpha,beta: 31.00 ,8.23
# ratio: 1.00
# alpha,beta: 21.00 ,12.10
# ratio: 1.00
# alpha,beta: 28.00 ,7.68
# ratio: 1.00
# alpha,beta: 15.00 ,6.35
# ratio: 1.00
# alpha,beta: 16.00 ,5.69
# ratio: 1.00
# alpha,beta: 51.00 ,17.38
# ratio: 1.00
# alpha,beta: 31.00 ,3.89
# ratio: 1.00
# alpha,beta: 19.00 ,3.25
# ratio: 1.00
# alpha,beta: 11.00 ,4.61
# ratio: 1.00
# alpha,beta: 11.00 ,2.97
# ratio: 1.00
# alpha,beta: 9.00 ,2.65
# ratio: 1.00
# alpha,beta: 11.00 ,4.66
# ratio: 1.00
# alpha,beta: 91.00 ,19.32
# ratio: 1.00
# alpha,beta: 15.00 ,3.30
# ratio: 1.00
# alpha,beta: 28.00 ,11.21
# ratio: 1.00
# alpha,beta: 34.00 ,36.29
# ratio: 1.00
# alpha,beta: 19.00 ,15.88
# ratio: 1.00
# alpha,beta: 17.00 ,11.45
# ratio: 1.00
# alpha,beta: 10.00 ,8.81
# ratio: 1.00
# alpha,beta: 7.00 ,9.71
# ratio: 1.00
# alpha,beta: 39.00 ,36.71
# ratio: 1.00
# alpha,beta: 49.00 ,55.65
# ratio: 1.00
# alpha,beta: 25.00 ,30.41
# ratio: 1.00
# alpha,beta: 53.00 ,34.37
# ratio: 1.00
# alpha,beta: 12.00 ,9.28
# ratio: 1.00
# alpha,beta: 40.00 ,12.19
# ratio: 1.00
# alpha,beta: 18.00 ,12.21
# ratio: 1.00
# alpha,beta: 71.00 ,31.98
# ratio: 1.00
# alpha,beta: 24.00 ,8.98
# ratio: 1.00
# alpha,beta: 22.00 ,10.81
# ratio: 1.00
# alpha,beta: 9.00 ,3.53
# ratio: 1.00
# alpha,beta: 38.00 ,30.35
# ratio: 1.00
# alpha,beta: 20.00 ,9.45
# ratio: 1.00
# alpha,beta: 11.00 ,8.11
# ratio: 1.00
# alpha,beta: 9.00 ,18.42
# ratio: 1.00
# alpha,beta: 8.00 ,2.84
# ratio: 1.00
# alpha,beta: 42.00 ,13.18
# ratio: 1.00
# alpha,beta: 9.00 ,17.55
# ratio: 1.00
# alpha,beta: 14.00 ,5.70
# ratio: 1.00
# alpha,beta: 108.00 ,47.21
# ratio: 1.00
# alpha,beta: 87.00 ,43.91
# ratio: 1.00
# alpha,beta: 22.00 ,11.24
# ratio: 1.00
# alpha,beta: 40.00 ,14.69
# ratio: 1.00
# alpha,beta: 63.00 ,46.41
# ratio: 1.00
# alpha,beta: 51.00 ,51.11
# ratio: 1.00
# alpha,beta: 20.00 ,7.36
# ratio: 1.00
# alpha,beta: 6.00 ,5.43
# ratio: 1.00
# alpha,beta: 53.00 ,36.73
# ratio: 1.00
# alpha,beta: 21.00 ,11.97
# ratio: 1.00
# alpha,beta: 20.00 ,11.83
# ratio: 1.00
# alpha,beta: 14.00 ,4.16
# ratio: 1.00
# alpha,beta: 9.00 ,6.40
# ratio: 1.00
# alpha,beta: 11.00 ,12.70
# ratio: 1.00
# alpha,beta: 13.00 ,8.10
# ratio: 1.00
# alpha,beta: 9.00 ,12.93
# ratio: 1.00
# ...
# ratio: 1.00
# alpha,beta: 60.00 ,88.88
# ratio: 1.00
# alpha,beta: 114.00 ,80.62
# ratio: 1.00
# alpha,beta: 31.00 ,47.62
# ratio: 1.00
# alpha,beta: 17.00 ,29.97
# ratio: 1.00
# alpha,beta: 226.00 ,151.81
# ratio: 1.00
# alpha,beta: 74.00 ,112.67
# ratio: 1.00
# alpha,beta: 65.00 ,171.80
# ratio: 1.00
# alpha,beta: 43.00 ,44.23
# ratio: 1.00
# alpha,beta: 42.00 ,39.47
# ratio: 1.00
# alpha,beta: 17.00 ,60.05
# ratio: 1.00
# alpha,beta: 15.00 ,40.80
# ratio: 1.00
# alpha,beta: 15.00 ,34.60
# ratio: 1.00
# alpha,beta: 17.00 ,21.10
# ratio: 1.00
# alpha,beta: 140.00 ,93.08
# ratio: 1.00
# alpha,beta: 35.00 ,79.76
# ratio: 1.00
# alpha,beta: 38.00 ,126.82
# ratio: 1.00
# alpha,beta: 28.00 ,53.69
# ratio: 1.00
# alpha,beta: 29.00 ,120.73
# ratio: 1.00
# alpha,beta: 18.00 ,51.62
# ratio: 1.00
# alpha,beta: 24.00 ,59.96
# ratio: 1.00
# alpha,beta: 21.00 ,45.23
# ratio: 1.00
# alpha,beta: 17.00 ,31.39
# ratio: 1.00
# alpha,beta: 11.00 ,32.20
# ratio: 1.00
# alpha,beta: 12.00 ,55.17
# ratio: 1.00
# alpha,beta: 5.00 ,38.12
# ratio: 1.00
# alpha,beta: 11.00 ,25.83
# ratio: 1.00
# alpha,beta: 6.00 ,13.06
# ratio: 1.00
# alpha,beta: 36.00 ,95.44
# ratio: 1.00
# alpha,beta: 28.00 ,134.95
# ratio: 1.00
# alpha,beta: 23.00 ,126.61
# ratio: 1.00
# alpha,beta: 28.00 ,59.43
# ratio: 1.00
# alpha,beta: 6.00 ,33.36
# ratio: 1.00
# alpha,beta: 9.00 ,38.13
# ratio: 1.00
# alpha,beta: 11.00 ,30.99
# ratio: 1.00
# alpha,beta: 9.00 ,35.01
# ratio: 1.00
# alpha,beta: 7.00 ,16.25
# ratio: 1.00
# alpha,beta: 16.00 ,41.97
# ratio: 1.00
# alpha,beta: 151.00 ,148.51
# ratio: 1.00
# alpha,beta: 35.00 ,79.54
# ratio: 1.00
# alpha,beta: 44.00 ,83.39
# ratio: 1.00
# alpha,beta: 21.00 ,38.38
# ratio: 1.00
# alpha,beta: 10.00 ,20.73
# ratio: 1.00
# alpha,beta: 20.00 ,51.72
# ratio: 1.00
# alpha,beta: 9.00 ,59.60
# ratio: 1.00
# alpha,beta: 5.00 ,36.99
# ratio: 1.00
# alpha,beta: 15.00 ,43.51
# ratio: 1.00
# alpha,beta: 11.00 ,26.54
# ratio: 1.00
# alpha,beta: 11.00 ,21.92
# ratio: 1.00
# alpha,beta: 6.00 ,17.80
# ratio: 1.00
# alpha,beta: 20.00 ,41.81
# ratio: 1.00
# alpha,beta: 19.00 ,42.29
# ratio: 1.00
# alpha,beta: 5.00 ,37.20
# ratio: 1.00
# alpha,beta: 31.00 ,86.75
# ratio: 1.00
# alpha,beta: 13.00 ,13.43
# ratio: 1.00
# alpha,beta: 12.00 ,17.18
# ratio: 1.00
# alpha,beta: 3.00 ,29.51
# ratio: 1.00
# alpha,beta: 3.00 ,23.91
# ratio: 1.00
# alpha,beta: 20.00 ,13.78
# ratio: 1.00
# alpha,beta: 30.00 ,65.55
# ratio: 1.00
# alpha,beta: 14.00 ,30.78
# ratio: 1.00
# alpha,beta: 15.00 ,9.69
# ratio: 1.00
# alpha,beta: 106.00 ,135.43
# ratio: 1.00
# alpha,beta: 58.00 ,50.65
# ratio: 1.00
# alpha,beta: 35.00 ,15.84
# ratio: 1.00
# alpha,beta: 52.00 ,68.40
# ratio: 1.00
# alpha,beta: 80.00 ,82.19
# ratio: 1.00
# alpha,beta: 40.00 ,42.07
# ratio: 1.00
# alpha,beta: 52.00 ,90.24
# ratio: 1.00
# alpha,beta: 49.00 ,33.85
# ratio: 1.00
# alpha,beta: 17.00 ,31.93
# ratio: 1.00
# alpha,beta: 14.00 ,14.46
# ratio: 1.00
# alpha,beta: 18.00 ,12.04
# ratio: 1.00
# alpha,beta: 18.00 ,23.40
# ratio: 1.00
# alpha,beta: 29.00 ,24.02
# ratio: 1.00
# alpha,beta: 12.00 ,26.15
# ratio: 1.00
# alpha,beta: 13.00 ,30.94
# ratio: 1.00
# alpha,beta: 14.00 ,44.17
# ratio: 1.00
# alpha,beta: 9.00 ,22.32
# ratio: 1.00
# alpha,beta: 22.00 ,15.27
# ratio: 1.00
# alpha,beta: 11.00 ,16.33
# ratio: 1.00
# alpha,beta: 10.00 ,17.34
# ratio: 1.00
# alpha,beta: 13.00 ,8.20
# ratio: 1.00
# alpha,beta: 168.00 ,84.67
# ratio: 1.00
# alpha,beta: 108.00 ,83.56
# ratio: 1.00
# alpha,beta: 97.00 ,168.22
# ratio: 1.00
# alpha,beta: 177.00 ,37.29
# ratio: 1.00
# alpha,beta: 46.00 ,55.06
# ratio: 1.00
# alpha,beta: 18.00 ,21.58
# ratio: 1.00
# alpha,beta: 20.00 ,42.23
# ratio: 1.00
# alpha,beta: 32.00 ,46.73
# ratio: 1.00
# alpha,beta: 5.00 ,12.71
# ratio: 1.00
# alpha,beta: 7.00 ,5.26
# ratio: 1.00
# alpha,beta: 105.00 ,124.74
# ratio: 1.00
# alpha,beta: 39.00 ,63.42
# ratio: 1.00
# alpha,beta: 100.00 ,71.60
# ratio: 1.00
# alpha,beta: 66.00 ,78.69
# ratio: 1.00
# alpha,beta: 53.00 ,55.87
# ratio: 1.00
# alpha,beta: 40.00 ,47.84
# ratio: 1.00
# alpha,beta: 39.00 ,68.35
# ratio: 1.00
# alpha,beta: 14.00 ,23.98
# ratio: 1.00
# alpha,beta: 17.00 ,26.22
# ratio: 1.00
# alpha,beta: 14.00 ,17.73
# ratio: 1.00
# alpha,beta: 35.00 ,82.53
# ratio: 1.00
# alpha,beta: 46.00 ,85.79
# ratio: 1.00
# alpha,beta: 24.00 ,51.06
# ratio: 1.00
# alpha,beta: 7.00 ,18.69
# ratio: 1.00
# alpha,beta: 13.00 ,31.00
# ratio: 1.00
# alpha,beta: 17.00 ,46.81
# ratio: 1.00
# alpha,beta: 12.00 ,21.71
# ratio: 1.00
# alpha,beta: 17.00 ,32.46
# ratio: 1.00
# alpha,beta: 43.00 ,65.56
# ratio: 1.00
# alpha,beta: 28.00 ,47.79
# ratio: 1.00
# alpha,beta: 20.00 ,70.25
# ratio: 1.00
# alpha,beta: 9.00 ,28.92
# ratio: 1.00
# alpha,beta: 43.00 ,56.53
# ratio: 1.00
# alpha,beta: 127.00 ,97.62
# ratio: 1.00
# alpha,beta: 77.00 ,99.58
# ratio: 1.00
# alpha,beta: 26.00 ,21.80
# ratio: 1.00
# alpha,beta: 27.00 ,43.88
# ratio: 1.00
# alpha,beta: 15.00 ,18.21
# ratio: 1.00
# alpha,beta: 13.00 ,33.16
# ratio: 1.00
# alpha,beta: 5.00 ,17.42
# ratio: 1.00
# alpha,beta: 88.00 ,144.97
# ratio: 1.00
# alpha,beta: 67.00 ,102.53
# ratio: 1.00
# alpha,beta: 18.00 ,32.62
# ratio: 1.00
# alpha,beta: 25.00 ,58.32
# ratio: 1.00
# alpha,beta: 12.00 ,45.66
# ratio: 1.00
# alpha,beta: 78.00 ,120.94
# ratio: 1.00
# alpha,beta: 13.00 ,10.48
# ratio: 1.00
# alpha,beta: 74.00 ,51.17
# ratio: 1.00
# alpha,beta: 59.00 ,22.03
# ratio: 1.00
# alpha,beta: 70.00 ,34.11
# ratio: 1.00
# alpha,beta: 43.00 ,20.76
# ratio: 1.00
# alpha,beta: 9.00 ,7.32
# ratio: 1.00
# alpha,beta: 7.00 ,3.29
# ratio: 1.00
# alpha,beta: 172.00 ,46.01
# ratio: 1.00
# alpha,beta: 21.00 ,18.39
# ratio: 1.00
# alpha,beta: 79.00 ,77.75
# ratio: 1.00
# alpha,beta: 15.00 ,18.40
# ratio: 1.00
# alpha,beta: 30.00 ,29.35
# ratio: 1.00
# alpha,beta: 20.00 ,8.32
# ratio: 1.00
# alpha,beta: 110.00 ,80.67
# ratio: 1.00
# alpha,beta: 43.00 ,13.32
# ratio: 1.00
# alpha,beta: 22.00 ,19.98
# ratio: 1.00
# alpha,beta: 78.00 ,29.64
# ratio: 1.00
# alpha,beta: 111.00 ,44.79
# ratio: 1.00
# alpha,beta: 42.00 ,28.02
# ratio: 1.00
# alpha,beta: 33.00 ,13.81
# ratio: 1.00
# alpha,beta: 25.00 ,11.50
# ratio: 1.00
# alpha,beta: 31.00 ,25.28
# ratio: 1.00
# alpha,beta: 5.00 ,4.05
# ratio: 1.00
# alpha,beta: 47.00 ,47.74
# ratio: 1.00
# alpha,beta: 16.00 ,12.37
# ratio: 1.00
# alpha,beta: 22.00 ,14.37
# ratio: 1.00
# alpha,beta: 7.00 ,7.66
# ratio: 1.00
# alpha,beta: 9.00 ,24.99
# ratio: 1.00
# alpha,beta: 16.00 ,13.25
# ratio: 1.00
# alpha,beta: 20.00 ,11.86
# ratio: 1.00
# alpha,beta: 11.00 ,9.60
# ratio: 1.00
# alpha,beta: 21.00 ,31.66
# ratio: 1.00
# alpha,beta: 51.00 ,9.45
# ratio: 1.00
# alpha,beta: 21.00 ,16.35
# ratio: 1.00
# alpha,beta: 16.00 ,4.77
# ratio: 1.00
# alpha,beta: 12.00 ,3.95
# ratio: 1.00
# alpha,beta: 40.00 ,10.37
# ratio: 1.00
# alpha,beta: 26.00 ,5.84
# ratio: 1.00
# alpha,beta: 9.00 ,13.44
# ratio: 1.00
# alpha,beta: 12.00 ,1.78
# ratio: 1.00
# alpha,beta: 28.00 ,13.98
# ratio: 1.00
# alpha,beta: 40.00 ,34.51
# ratio: 1.00
# alpha,beta: 15.00 ,14.50
# ratio: 1.00
# alpha,beta: 54.00 ,9.79
# ratio: 1.00
# alpha,beta: 53.00 ,21.84
# ratio: 1.00
# alpha,beta: 48.00 ,3.64
# ratio: 1.00
# alpha,beta: 9.00 ,6.91
# ratio: 1.00
# alpha,beta: 9.00 ,3.99
# ratio: 1.00
# alpha,beta: 18.00 ,8.78
# ratio: 1.00
# alpha,beta: 16.00 ,2.09
# ratio: 1.00
# alpha,beta: 6.00 ,6.73
# ratio: 1.00
# alpha,beta: 102.00 ,15.32
# ratio: 1.00
# alpha,beta: 17.00 ,16.68
# ratio: 1.00
# alpha,beta: 35.00 ,7.18
# ratio: 1.00
# alpha,beta: 38.00 ,11.99
# ratio: 1.00
# alpha,beta: 41.00 ,17.79
# ratio: 1.00
# alpha,beta: 43.00 ,10.81
# ratio: 1.00
# alpha,beta: 27.00 ,9.94
# ratio: 1.00
# alpha,beta: 20.00 ,6.68
# ratio: 1.00
# alpha,beta: 20.00 ,10.25
# ratio: 1.00
# alpha,beta: 13.00 ,1.97
# ratio: 1.00
# alpha,beta: 11.00 ,5.69
# ratio: 1.00
# alpha,beta: 8.00 ,0.00
# ratio: 1.00
# alpha,beta: 8.00 ,9.73
# ratio: 1.00
# alpha,beta: 25.00 ,18.80
# ratio: 1.00
# alpha,beta: 13.00 ,9.09
# ratio: 1.00
# alpha,beta: 8.00 ,4.72
# ratio: 1.00
# alpha,beta: 19.00 ,4.82
# ratio: 1.00
# alpha,beta: 23.00 ,8.86
# ratio: 1.00
# alpha,beta: 70.00 ,29.76
# ratio: 1.00
# alpha,beta: 40.00 ,29.09
# ratio: 1.00
# alpha,beta: 51.00 ,23.60
# ratio: 1.00
# alpha,beta: 18.00 ,22.87
# ratio: 1.00
# alpha,beta: 11.00 ,1.97
# ratio: 1.00
# alpha,beta: 21.00 ,1.75
# ratio: 1.00
# alpha,beta: 16.00 ,11.59
# ratio: 1.00
# alpha,beta: 11.00 ,2.62
# ratio: 1.00
# alpha,beta: 29.00 ,20.68
# ratio: 1.00
# alpha,beta: 25.00 ,22.84
# ratio: 1.00
# alpha,beta: 5.00 ,2.97
# ratio: 1.00
# alpha,beta: 32.00 ,14.06
# ratio: 1.00
# alpha,beta: 41.00 ,16.85
# ratio: 1.00
# alpha,beta: 26.00 ,15.31
# ratio: 1.00
# alpha,beta: 18.00 ,14.39
# ratio: 1.00
# alpha,beta: 75.00 ,27.97
# ratio: 1.00
# alpha,beta: 18.00 ,11.74
# ratio: 1.00
# alpha,beta: 59.00 ,23.81
# ratio: 1.00
# alpha,beta: 20.00 ,20.05
# ratio: 1.00
# alpha,beta: 15.00 ,9.13
# ratio: 1.00
# alpha,beta: 29.00 ,18.52
# ratio: 1.00
# alpha,beta: 18.00 ,13.84
# ratio: 1.00
# alpha,beta: 12.00 ,9.43
# ratio: 1.00
# alpha,beta: 13.00 ,7.20
# ratio: 1.00
# alpha,beta: 69.00 ,28.92
# ratio: 1.00
# alpha,beta: 18.00 ,17.58
# ratio: 1.00
# alpha,beta: 15.00 ,3.89
# ratio: 1.00
# alpha,beta: 54.00 ,22.08
# ratio: 1.00
# alpha,beta: 41.00 ,27.09
# ratio: 1.00
# alpha,beta: 23.00 ,26.97
# ratio: 1.00
# alpha,beta: 36.00 ,23.72
# ratio: 1.00
# alpha,beta: 36.00 ,52.74
# ratio: 1.00
# alpha,beta: 17.00 ,18.35
# ratio: 1.00
# alpha,beta: 48.00 ,27.56
# ratio: 1.00
# alpha,beta: 33.00 ,19.50
# ratio: 1.00
# alpha,beta: 16.00 ,6.92
# ratio: 1.00
# alpha,beta: 16.00 ,19.13
# ratio: 1.00
# alpha,beta: 43.00 ,25.33
# ratio: 1.00
# alpha,beta: 57.00 ,30.79
# ratio: 1.00
# alpha,beta: 30.00 ,35.06
# ratio: 1.00
# alpha,beta: 47.00 ,64.57
# ratio: 1.00
# alpha,beta: 137.00 ,126.08
# ratio: 1.00
# alpha,beta: 10.00 ,10.07
# ratio: 1.00
# alpha,beta: 49.00 ,57.11
# ratio: 1.00
# alpha,beta: 24.00 ,51.10
# ratio: 1.00
# alpha,beta: 5.00 ,22.34
# ratio: 1.00
# alpha,beta: 56.00 ,105.70
# ratio: 1.00
# alpha,beta: 36.00 ,91.07
# ratio: 1.00
# alpha,beta: 19.00 ,27.05
# ratio: 1.00
# alpha,beta: 25.00 ,44.86
# ratio: 1.00
# alpha,beta: 12.00 ,39.38
# ratio: 1.00
# alpha,beta: 17.00 ,36.77
# ratio: 1.00
# alpha,beta: 87.00 ,105.29
# ratio: 1.00
# alpha,beta: 39.00 ,58.79
# ratio: 1.00
# alpha,beta: 22.00 ,52.20
# ratio: 1.00
# alpha,beta: 48.00 ,61.88
# ratio: 1.00
# alpha,beta: 115.00 ,84.77
# ratio: 1.00
# alpha,beta: 11.00 ,27.05
# ratio: 1.00
# alpha,beta: 26.00 ,66.98
# ratio: 1.00
# alpha,beta: 14.00 ,59.99
# ratio: 1.00
# alpha,beta: 3.00 ,30.01
# ratio: 1.00
# alpha,beta: 22.00 ,48.21
# ratio: 1.00
# alpha,beta: 10.00 ,10.99
# ratio: 1.00
# alpha,beta: 8.00 ,33.67
# ratio: 1.00
# alpha,beta: 16.00 ,16.95
# ratio: 1.00
# alpha,beta: 5.00 ,40.79
# ratio: 1.00
# alpha,beta: 33.00 ,80.15
# ratio: 1.00
# alpha,beta: 19.00 ,41.53
# ratio: 1.00
# alpha,beta: 15.00 ,38.76
# ratio: 1.00
# alpha,beta: 12.00 ,22.42
# ratio: 1.00
# alpha,beta: 97.00 ,81.03
# ratio: 1.00
# alpha,beta: 32.00 ,125.02
# ratio: 1.00
# alpha,beta: 22.00 ,21.59
# ratio: 1.00
# alpha,beta: 12.00 ,23.88
# ratio: 1.00
# alpha,beta: 19.00 ,31.73
# ratio: 1.00
# alpha,beta: 14.00 ,22.90
# ratio: 1.00
# alpha,beta: 10.00 ,21.61
# ratio: 1.00
# alpha,beta: 6.00 ,20.53
# ratio: 1.00
# alpha,beta: 46.00 ,71.28
# ratio: 1.00
# alpha,beta: 18.00 ,31.41
# ratio: 1.00
# alpha,beta: 35.00 ,52.07
# ratio: 1.00
# alpha,beta: 24.00 ,39.18
# ratio: 1.00
# alpha,beta: 11.00 ,22.51
# ratio: 1.00
# alpha,beta: 122.00 ,83.89
# ratio: 1.00
# alpha,beta: 65.00 ,45.69
# ratio: 1.00
# alpha,beta: 17.00 ,33.11
# ratio: 1.00
# alpha,beta: 35.00 ,34.22
# ratio: 1.00
# alpha,beta: 16.00 ,30.27
# ratio: 1.00
# alpha,beta: 12.00 ,13.23
# ratio: 1.00
# alpha,beta: 11.00 ,27.39
# ratio: 1.00
# alpha,beta: 16.00 ,21.69
# ratio: 1.00
# alpha,beta: 14.00 ,13.62
# ratio: 1.00
# alpha,beta: 77.00 ,39.25
# ratio: 1.00
# alpha,beta: 106.00 ,64.32
# ratio: 1.00
# alpha,beta: 40.00 ,44.70
# ratio: 1.00
# alpha,beta: 72.00 ,141.93
# ratio: 1.00
# alpha,beta: 164.00 ,86.66
# ratio: 1.00
# alpha,beta: 51.00 ,46.79
# ratio: 1.00
# alpha,beta: 91.00 ,54.95
# ratio: 1.00
# alpha,beta: 108.00 ,67.61
# ratio: 1.00
# alpha,beta: 55.00 ,28.41
# ratio: 1.00
# alpha,beta: 17.00 ,21.24
# ratio: 1.00
# alpha,beta: 40.00 ,20.97
# ratio: 1.00
# alpha,beta: 38.00 ,59.62
# ratio: 1.00
# alpha,beta: 24.00 ,26.19
# ratio: 1.00
# alpha,beta: 39.00 ,24.20
# ratio: 1.00
# alpha,beta: 27.00 ,22.02
# ratio: 1.00
# alpha,beta: 40.00 ,36.86
# ratio: 1.00
# alpha,beta: 37.00 ,33.61
# ratio: 1.00
# alpha,beta: 16.00 ,26.89
# ratio: 1.00
# alpha,beta: 16.00 ,19.14
# ratio: 1.00
# alpha,beta: 10.00 ,10.66
# ratio: 1.00
# alpha,beta: 5.00 ,11.59
# ratio: 1.00
# alpha,beta: 7.00 ,5.02
# ratio: 1.00
# alpha,beta: 11.00 ,17.10
# ratio: 1.00
# alpha,beta: 96.00 ,68.95
# ratio: 1.00
# alpha,beta: 32.00 ,60.48
# ratio: 1.00
# alpha,beta: 38.00 ,69.34
# ratio: 1.00
# alpha,beta: 42.00 ,49.46
# ratio: 1.00
# alpha,beta: 38.00 ,49.94
# ratio: 1.00
# alpha,beta: 29.00 ,36.95
# ratio: 1.00
# alpha,beta: 44.00 ,105.29
# ratio: 1.00
# alpha,beta: 34.00 ,54.86
# ratio: 1.00
# alpha,beta: 19.00 ,38.87
# ratio: 1.00
# alpha,beta: 8.00 ,33.01
# ratio: 1.00
# alpha,beta: 24.00 ,55.27
# ratio: 1.00
# alpha,beta: 26.00 ,38.22
# ratio: 1.00
# alpha,beta: 15.00 ,31.22
# ratio: 1.00
# alpha,beta: 23.00 ,29.06
# ratio: 1.00
# alpha,beta: 19.00 ,36.96
# ratio: 1.00
# alpha,beta: 5.00 ,18.38
# ratio: 1.00
# alpha,beta: 29.00 ,19.25
# ratio: 1.00
# alpha,beta: 17.00 ,24.63
# ratio: 1.00
# alpha,beta: 16.00 ,38.25
# ratio: 1.00
# alpha,beta: 18.00 ,41.76
# ratio: 1.00
# alpha,beta: 14.00 ,14.05
# ratio: 1.00
# alpha,beta: 17.00 ,16.90
# ratio: 1.00
# alpha,beta: 9.00 ,3.74
# ratio: 1.00
# alpha,beta: 10.00 ,16.99
# ratio: 1.00
# alpha,beta: 14.00 ,29.56
# ratio: 1.00
# alpha,beta: 9.00 ,8.76
# ratio: 1.00
# alpha,beta: 12.00 ,13.92
# ratio: 1.00
# alpha,beta: 69.00 ,173.52
# ratio: 1.00
# alpha,beta: 185.00 ,73.82
# ratio: 1.00
# alpha,beta: 71.00 ,111.34
# ratio: 1.00
# alpha,beta: 44.00 ,51.87
# ratio: 1.00
# alpha,beta: 33.00 ,77.47
# ratio: 1.00
# alpha,beta: 52.00 ,67.95
# ratio: 1.00
# alpha,beta: 23.00 ,38.74
# ratio: 1.00
# alpha,beta: 30.00 ,79.36
# ratio: 1.00
# alpha,beta: 29.00 ,35.64
# ratio: 1.00
# alpha,beta: 26.00 ,74.28
# ratio: 1.00
# alpha,beta: 14.00 ,24.28
# ratio: 1.00
# alpha,beta: 20.00 ,57.35
# ratio: 1.00
# alpha,beta: 27.00 ,35.44
# ratio: 1.00
# alpha,beta: 16.00 ,23.63
# ratio: 1.00
# alpha,beta: 35.00 ,71.18
# ratio: 1.00
# alpha,beta: 25.00 ,70.64
# ratio: 1.00
# alpha,beta: 32.00 ,59.00
# ratio: 1.00
# alpha,beta: 31.00 ,47.11
# ratio: 1.00
# alpha,beta: 55.00 ,66.83
# ratio: 1.00
# alpha,beta: 31.00 ,32.32
# ratio: 1.00
# alpha,beta: 22.00 ,38.41
# ratio: 1.00
# alpha,beta: 11.00 ,29.03
# ratio: 1.00
# alpha,beta: 9.00 ,17.13
# ratio: 1.00
# alpha,beta: 32.00 ,88.33
# ratio: 1.00
# alpha,beta: 25.00 ,49.13
# ratio: 1.00
# alpha,beta: 20.00 ,19.18
# ratio: 1.00
# alpha,beta: 15.00 ,52.55
# ratio: 1.00
# alpha,beta: 10.00 ,19.23
# ratio: 1.00
# alpha,beta: 33.00 ,77.51
# ratio: 1.00
# alpha,beta: 33.00 ,21.24
# ratio: 1.00
# alpha,beta: 12.00 ,15.35
# ratio: 1.00
# alpha,beta: 52.00 ,82.28
# ratio: 1.00
# alpha,beta: 112.00 ,133.34
# ratio: 1.00
# alpha,beta: 58.00 ,108.55
# ratio: 1.00
# alpha,beta: 42.00 ,49.12
# ratio: 1.00
# alpha,beta: 33.00 ,83.58
# ratio: 1.00
# alpha,beta: 13.00 ,11.13
# ratio: 1.00
# alpha,beta: 21.00 ,33.51
# ratio: 1.00
# alpha,beta: 27.00 ,30.52
# ratio: 1.00
# alpha,beta: 13.00 ,12.41
# ratio: 1.00
# alpha,beta: 37.00 ,136.63
# ratio: 1.00
# alpha,beta: 16.00 ,27.84
# ratio: 1.00
# alpha,beta: 21.00 ,36.23
# ratio: 1.00
# alpha,beta: 18.00 ,41.45
# ratio: 1.00
# alpha,beta: 13.00 ,38.08
# ratio: 1.00
# alpha,beta: 25.00 ,38.38
# ratio: 1.00
# alpha,beta: 9.00 ,19.57
# ratio: 1.00
# alpha,beta: 9.00 ,24.25
# ratio: 1.00
# alpha,beta: 84.00 ,48.51
# ratio: 1.00
# alpha,beta: 7.00 ,45.35
# ratio: 1.00
# alpha,beta: 18.00 ,55.28
# ratio: 1.00
# alpha,beta: 15.00 ,35.79
# ratio: 1.00
# alpha,beta: 67.00 ,179.47
# ratio: 1.00
# alpha,beta: 117.00 ,116.72
# ratio: 1.00
# alpha,beta: 6.00 ,19.42
# ratio: 1.00
# alpha,beta: 64.00 ,81.48
# ratio: 1.00
# alpha,beta: 73.00 ,108.08
# ratio: 1.00
# alpha,beta: 50.00 ,72.60
# ratio: 1.00
# alpha,beta: 82.00 ,66.34
# ratio: 1.00
# alpha,beta: 46.00 ,60.11
# ratio: 1.00
# alpha,beta: 54.00 ,94.06
# ratio: 1.00
# alpha,beta: 50.00 ,29.88
# ratio: 1.00
# alpha,beta: 30.00 ,60.40
# ratio: 1.00
# alpha,beta: 18.00 ,39.69
# ratio: 1.00
# alpha,beta: 34.00 ,32.15
# ratio: 1.00
# alpha,beta: 36.00 ,49.31
# ratio: 1.00
# alpha,beta: 31.00 ,45.09
# ratio: 1.00
# alpha,beta: 16.00 ,27.09
# ratio: 1.00
# alpha,beta: 20.00 ,17.38
# ratio: 1.00
# alpha,beta: 10.00 ,28.01
# ratio: 1.00
# alpha,beta: 11.00 ,21.86
# ratio: 1.00
# alpha,beta: 37.00 ,17.84
# ratio: 1.00
# alpha,beta: 16.00 ,5.86
# ratio: 1.00
# alpha,beta: 2.00 ,2.92
# ratio: 1.00
# alpha,beta: 85.00 ,29.12
# ratio: 1.00
# alpha,beta: 29.00 ,33.03
# ratio: 1.00
# alpha,beta: 24.00 ,14.14
# ratio: 1.00
# alpha,beta: 64.00 ,68.28
# ratio: 1.00
# alpha,beta: 82.00 ,36.37
# ratio: 1.00
# alpha,beta: 57.00 ,118.36
# ratio: 1.00
# alpha,beta: 56.00 ,82.21
# ratio: 1.00
# alpha,beta: 54.00 ,77.81
# ratio: 1.00
# alpha,beta: 20.00 ,37.95
# ratio: 1.00
# alpha,beta: 28.00 ,59.19
# ratio: 1.00
# alpha,beta: 42.00 ,64.74
# ratio: 1.00
# alpha,beta: 56.00 ,68.89
# ratio: 1.00
# alpha,beta: 71.00 ,56.96
# ratio: 1.00
# alpha,beta: 6.00 ,13.24
# ratio: 1.00
# alpha,beta: 42.00 ,47.68
# ratio: 1.00
# alpha,beta: 140.00 ,99.56
# ratio: 1.00
# alpha,beta: 55.00 ,96.79
# ratio: 1.00
# alpha,beta: 7.00 ,29.03
# ratio: 1.00
# alpha,beta: 48.00 ,54.27
# ratio: 1.00
# alpha,beta: 47.00 ,30.84
# ratio: 1.00

# %% [markdown]
# ### Comparing The Prior Choices:
#
# Here we compare the difference between the two choices of priors, flat and beta.

# %%
pflat = np.array([res[i]['prior']['flat'] for i in range(ncls)])
pbeta = np.array([res[i]['prior']['beta'] for i in range(ncls)])

plt.scatter(alpha,(pbeta-pflat),c=pflat,cmap='jet')
plt.xscale('log')
plt.ylabel('prior prob: beta - flat',fontsize=16)
plt.xlabel(r'$\alpha = \hat{N}_{c}$',fontsize=16)
plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %% [markdown]
# The prior prob. difference is below 2.5% for $\alpha>10$, for lower values the difference can be up to 15%, which is signficant.

# %%
pflat = np.array([res[i]['prior']['flat'] for i in range(ncls)])
pbeta = np.array([res[i]['prior']['beta'] for i in range(ncls)])

plt.scatter(Nt,(pbeta-pflat),c=pflat,cmap='jet')
plt.xscale('log')
plt.ylabel('prior prob: beta - flat',fontsize=16)
plt.xlabel(r'True richness: $N_{200}$',fontsize=16)
plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %% [markdown]
# The prior choice has its impact on recovering the true richness. The main difference is on the low signal-to-noise ratio cases, i.e. higher number of fields galaxies than cluster galaxies ($P_{flat}<0.5$).

# %% [markdown]
# ## Comparing the richness
#
# Here we compare the richness for the different estimators, old method, flat and beta priors.

# %%
## assign the new probabilities
gal = set_new_columns(gal,columns,val=-99.)
cat = set_new_columns(cat,['Ngals_%s'%c for c in columns],val=-99.)
cat = set_new_columns(cat,['Ngals_z_%s'%c for c in columns],val=-99.)
cat = set_new_columns(cat,[c for c in ['flat','beta']],val=-99.)

for i in range(ncls):
    for col in columns:
        gal[col][keys[i]]  = res[i]['Pmem'][col][:]
        cat['Ngals_%s'%col][i]= res[i]['Ngals'][col]
        cat['Ngals_z_%s'%col][i]= np.nansum(res[i]['Pz'][col][:])

    
    for col in ['flat','beta']:
        cat[col][i]= res[i]['prior'][col]

# %%
def compute_ptaken(g0,label='Pmem'):
	"""
	it computes p_taken
	"""
	print('compute ptaken')
	# g0.sort('Pmem')
	pmem = g0[label]
	ptaken = np.ones_like(pmem,dtype=float)

	## find common galaxies
	gid = np.array(g0['GID'])#.astype(np.int)
	commonGroups = commonValues(gid)

	for indices in commonGroups:
		pm_group = np.array(pmem[indices])
		pt_group = np.array(ptaken[indices])

		idx_sort = np.argsort(-1*pm_group) ## -1* to reverse order

		pm_group_s = pm_group[idx_sort]
		pt_group_s = pt_group[idx_sort]

		new_pm = 0
		toto = 1
		pm = []
		for i in range(indices.size):
			toto *= (1-new_pm)
			new_pm = toto*pm_group_s[i]
			pt_group_s[i] = toto
			pm.append(new_pm)

		pmem[indices[idx_sort]] = np.array(pm)
		ptaken[indices[idx_sort]] = pt_group_s

	g0[label] = pmem
	#g0['Ptaken'] = ptaken

	return g0

def commonValues(values):
	idx_sort = np.argsort(values)
	sorted_values = values[idx_sort]
	vals, idx_start, count = np.unique(sorted_values, return_counts=True,
                                return_index=True)

	# sets of indices
	res = np.split(idx_sort, idx_start[1:])
	#filter them with respect to their size, keeping only items occurring more than once

	vals = vals[count > 1]
	commonValuesIndicies = [ri for ri in res if ri.size>1]
	
	return commonValuesIndicies

# %%
for col in ['flat','beta','old']:
    gal = compute_ptaken(gal,col)
# Out:
# compute ptaken
# compute ptaken
# compute ptaken

# %%
for i in range(ncls):
    for col in ['flat','beta','old']:
        cat['Ngals_%s'] = np.nansum(gal[col][keys[i]])

# %% [markdown]
# ### $N_{200}$ depends on the prior choice?

# %%
def plot_residual(cat,labela,labelb):
    na, nb = cat['Ngals_%s'%labela],cat['Ngals_%s'%labelb]
    w, = np.where((na>0)&(nb>0))
    pflat  = cat['flat'][w]
    
    x = cat['Ngals_true'][w]
    frac_difference = (na[w]-nb[w])#/nb
    
    plt.scatter(x,frac_difference,c=pflat,cmap='jet')
    plt.axhline(0.,color='k',ls='--')
    plt.xlim(.5,300.)
    plt.xscale('log')
    plt.ylabel(r'$N_{200,%s} - N_{200,%s}$'%(labela,labelb),fontsize=16)
    plt.xlabel(r'True richness: $N_{200}$',fontsize=16)
    plt.colorbar().set_label(r'$P_{flat}=N_c/(N_c+N_f)$',fontsize=16)

# %%
plot_residual(cat,'beta','flat')

# %% [markdown]
# The net effect on $N_{200}$ is not significant.

# %%
plot_residual(cat,'flat','old')

# %%
plot_scatter_distribution(cat,'Ngals')
# Out:
# mean: 0.916
# rms : 0.475
# out. frac. : 0.017
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_flat')
# Out:
# mean: 0.811
# rms : 0.138
# out. frac. : 0.027
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_z_flat')
# Out:
# mean: 0.968
# rms : 0.132
# out. frac. : 0.027
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plot_scatter_distribution(cat,'Ngals_flat')
# Out:
# mean: 0.811
# rms : 0.138
# out. frac. : 0.027
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %% [markdown]
# Check if the code old prob. definition is consitenty with the new definition.

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals_z_flat'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals_flat'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
plt.scatter(cat['Ngals_true'],cat['Ngals_beta'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,300.)
plt.ylim(0.5,300.)
plt.xscale('log')
plt.yscale('log')

# %%
plt.scatter(cat['Ngals_flat'],cat['Norm'],alpha=0.3)
plt.plot([0.5,300.],[0.5,300.],'k--')
plt.xlim(0.5,500.)
plt.ylim(0.5,500.)
plt.xscale('log')
plt.yscale('log')

# %%
plot_scatter_distribution(cat,'Ngals_old')
# Out:
# mean: 0.880
# rms : 0.062
# out. frac. : 0.012
# [0.25       0.31896552 0.38793103 0.45689655 0.52586207 0.59482759
#  0.6637931  0.73275862 0.80172414 0.87068966 0.93965517 1.00862069
#  1.07758621 1.14655172 1.21551724 1.28448276 1.35344828 1.42241379
#  1.49137931 1.56034483 1.62931034 1.69827586 1.76724138 1.8362069
#  1.90517241 1.97413793 2.04310345 2.11206897 2.18103448 2.25      ]

# %%
plt.scatter(Nt,(cat['Ngals_beta']+Nf)/Ncf,alpha=0.3)
# plt.plot([0.5,300.],[0.5,300.],'k--')
# plt.xlim(0.5,300.)
# plt.ylim(0.5,300.)
plt.xscale('log')
# plt.yscale('log')

# %%
def get_variable(cat,label):
    nt0= np.array(cat['Ngals_true']).copy()
    ng0= np.array(cat[label]).copy()
    
    w, = np.where(ng0>0.)
    return nt0[w],ng0[w]

def remove_outliers(x,n=1.5):
    q25,q75 = np.nanpercentile(x,[25,75])
    iqr     = q75-q25
    lo, up  = q25-n*iqr, q75+n*iqr
    mask    = (x<up)&(x>lo)
    return mask

def get_scatter(x,xt):
    residual     = x/xt
    log_residual = np.log10(residual)
    
    check    = np.logical_not(np.isnan(log_residual) | np.isinf(log_residual))
    mask     = remove_outliers(log_residual,n=1.5)&(check)
    
    bias            = 10**np.nanmean(log_residual[mask])
    log_scatter     = np.nanstd(log_residual[mask])
    scatter         = 10**(log_scatter)-1
    
    out_fraction    = 1-1.*np.count_nonzero(mask)/len(x)
    out = {'residual':residual,'log_residual':log_residual,'bias': bias, 
           'scatter':scatter, 'log_scatter':log_scatter, 'outlier_fraction': out_fraction,'mask':mask}
    return out

def plot_scatter_distribution(cat,col,label="data",xmin=0.25,xmax=2.25,logx=False):
    ngalst, ngals = get_variable(cat,col)
    
    w = np.where(ngalst>1)[0]
    res  = get_scatter(ngals[w],ngalst[w])
    print(r'mean: %.3f'%(res['bias']))
    print(r'rms : %.3f'%(res['scatter']))
    print(r'out. frac. : %.3f'%(res['outlier_fraction']))
    
    if logx:
        xbins    = np.linspace(np.log10(xmin),np.log10(xmax),30)
        residual = res['log_residual']
        xm       = np.log10(res['bias'])
        xlo,xup  = xm-2*res['log_scatter'],xm+2*res['log_scatter']
        
    else:
        xbins = np.linspace(xmin,xmax,30)
        residual = res['residual']
        xm       = res['bias']
        xlo,xup  = 10**(np.log10(xm)-2*res['log_scatter']),10**(np.log10(xm)+2*res['log_scatter'])
    print(xbins)
    check     = np.logical_not(np.isnan(residual))&np.logical_not(np.isinf(residual))
    _ = plt.hist(residual[check],bins=xbins,label='out. perc = %.2f %%'%(100*res['outlier_fraction']))
    _ = plt.hist(residual[res['mask']],bins=xbins,label=r'precision = %.2f %%'%(100*res['scatter']))
    plt.axvline(xm,color='k',ls='--')
    plt.axvline(xlo,color='r',ls='--')
    plt.axvline(xup,color='r',ls='--')
    plt.title(label)
    # plt.yscale('log')
    plt.xlabel('ratio')
    plt.legend()

# %%
def plot_fraction_pmem(galaxies,lcol='Pmem',color='r',label='_noLabel_',save=False):
    pmem = galaxies[lcol]
    mask = galaxies['True']==True

    pmem_edges = np.arange(0.0,1.1,0.1)
    idx, x_bin = makeBin(pmem, pmem_edges)
    fraction_bin = [len(galaxies[ix][mask[ix]])/(len(galaxies[ix])+1e-9) for ix in idx ]

    # fig = plt.figure(figsize=(6,6))
    plt.scatter(x_bin,fraction_bin,color=color,s=50,label=label)
    plt.plot(np.linspace(0,1.,100),np.linspace(0,1.,100),linestyle='--',color='k')

def makeBin(variable, xedges):
    xbins = (xedges[1:]+xedges[:-1])/2
    indices = [ np.where((variable >= xedges[i]) & (variable <= xedges[i + 1]))[0] for i in range(len(xedges)-1)]
    return indices, xbins

# %%
class BayesianProbability:
    ''' Assign Membership Probabilities For Copacabana Galaxies

    input: alpha, beta, gal
    output: collection('prior','marginal','pdfs','pdfs_field','Pmem','Pr','Pz','Pc')

    alpha: Estimated number of galaxies inside the cluster area
    beta: Estimated number of field galaxies inside the cluster area
    gal: table of galaxies, columns: redshift,pdf,pdfr,pdfz,pdfc and also the field pdfs

    r2: r200, if None use the value from gal
    '''
    def __init__(self, a, b, r2=None):
        self.alpha = np.where(a<=0.,.1,a)
        self.beta  = b
        self.betaDist = scipy.stats.beta(self.alpha, self.beta)
        self.ntotal= a+b
        self.ratio = 1.
        
        self.r2    = r2
        

        self.prob  = defaultdict(dict)
        # ['prior','marginal','pdfs','pdfs_field','Pmem','Pr','Pz','Pc']

        ## init the prior
        self.compute_flat_prior()

    def updatate_ratio(self):
        self.ratio = 1.#*self.ntotal/self.size
        print('ratio: %.2f'%self.ratio)
        
    def load_pdfs(self,gal):
        self.nsize = np.count_nonzero(gal['zmask'])
        self.updatate_ratio()
        
        if self.r2 is None: self.r2 = float(gal['R200'][0])
        #zcls = np.array(gal['redshift'][:]).copy()
        
        self.pdfz = np.array(gal['pdfz'][:]).copy()
        self.pdfr = np.array(gal['pdfr'][:]).copy()
        #self.pdfc = get_color_pdf(zcls,gal['pdfc'][:]).copy()
        
        self.pdfzf= np.array(gal['pdfz_bkg'][:]).copy()
        self.pdfrf= np.array(gal['pdfr_bkg'][:]).copy()
        #self.pdfcf= get_color_pdf(zcls,gal['pdfc_bkg'][:]).copy()        
        
        models       = [self.pdfr*np.sum(self.pdfr),self.pdfz*np.sum(self.pdfz)]
        models_field = [self.pdfrf*np.sum(self.pdfrf),self.pdfzf*np.sum(self.pdfzf)]
        
        models[0]      = np.where(models[1]==0,0,models[0])
        models_field[0]= np.where(models_field[1]==0,0,models_field[0])
            
        self.pdf     = get_full_pdf(models)
        self.pdff    = get_full_pdf(models_field)

#         self.pdf = np.array(gal['pdf'][:]).copy()
#         self.pdff= np.array(gal['pdf_bkg'][:]).copy()
        
    def compute_flat_prior(self):
        pm0 = self.betaDist.mean()
        
        priors = {'flat':pm0,'beta':None}
        self.prob['prior'] = priors

    def compute_marginal(self,name,prior_type):
        pm0 = self.prob['prior'][prior_type]
        pf,pff = self.pick_pdf(name)
        res    = pf*pm0 + pff*(1-pm0)
        self.prob['marginal'][name] = res.copy()
    
    def compute_prob(self,label,name,prior_type,eps=1e-12):
        pm0 = self.prob['prior'][prior_type]
        pdf,pdff = self.pick_pdf(name)
        mar = pdf*pm0 + pdff*(1-pm0)
        res = pdf*pm0/(mar*self.ratio)
        pmem= filter_prob(res.copy())
        self.prob[label][prior_type] = pmem.copy()
    
    def compute_likelihood(self,nbins=40):
        self.pvec = np.linspace(0.,1.,1000)
        pm0   = self.prob['prior']['flat']
        radii = np.linspace(0,self.r2,100)
        pdf   = radial_pdf(radii,self.r2)
        mar   = pdf*pm0+(1-pm0)*(np.pi*self.r2**2)
        p0 = pdf*pm0/(mar+1e-9)
        self.likelihood = get_likelihood(self.pvec,p0,pdf,nbins=nbins)
    
    def compute_beta_prior(self):
        ## assumes a likelihood that only depends on R
        self.compute_likelihood()

        prior = join_pdfs(self.pvec,self.likelihood,self.betaDist.pdf(self.pvec))
        pm0   = mean_pdf(self.pvec,prior)

        self.prob['prior']['beta'] = pm0
        self.prior = prior

    def pick_pdf(self,name):
        if name=='pdfr':
            return [self.pdfr,self.pdfrf]
        
        elif name=='pdfc':
            return [self.pdfc,self.pdfcf]

        elif name=='pdfz':
            return [self.pdfz,self.pdfzf]
        
        elif name=='pdf':
            return [self.pdf,self.pdff]
        else:
            print('error')

    def assign_prob(self,name,label,prior_type):
        self.compute_marginal(name,prior_type)
        self.compute_prob(label,name,prior_type)
    
    def assign_prob_old(self,name,label):
        pdf, pdff = self.pick_pdf(name)
        if name!='Pmem':
            res = doProb(pdf, pdff, self.alpha, self.beta, normed=False)
        else:
            res = doProb(pdf, pdff, self.alpha, self.beta, normed=False)

        self.prob[label]['old'] = res.copy()
    
    def assign_probabilities(self,gal):
        self.names = ['pdf','pdfr','pdfz']
        self.labels= ['Pmem','Pr','Pz']

        ## loading pdfs
        self.load_pdfs(gal)

        ## memb. prob. flat prior
        for label,name in zip(self.labels,self.names):
            self.assign_prob(name,label,'flat')

        ## estimating beta prior
        self.compute_beta_prior()
        
        ## memb. prob. beta prior
        for label,name in zip(self.labels,self.names):
            self.assign_prob(name,label,'beta')

        ## for check purposes
        ## old probabilities definition
        for label,name in zip(self.labels,self.names):
            self.assign_prob_old(name,label)
    
    def compute_ngals(self):
        for col in ['flat','beta','old']:
            self.prob['Ngals'][col] = np.nansum(self.prob['Pmem'][col][:]).copy()

    def plot_prior_distribution(self):
        plt.plot(self.pvec,self.betaDist.pdf(self.pvec),'b',label='Beta')
        plt.plot(self.pvec,self.likelihood,'k',label='P(model|member)')
        plt.plot(self.pvec,self.prior,'r',label='Beta*P(model|member)')
        plt.axvline(self.prob['prior']['flat'],color='b',ls='--')
        plt.axvline(self.prob['prior']['beta'],color='r',ls='--')
        plt.legend()
        plt.xlabel("Prior")
        plt.ylabel('Density')
        pass

def getPDFs(gal,galIndices,vec_list,pdf_list,nbkg,sigma,mag_pdf=False):
    rvec, zvec, cvec, mvec = vec_list
    pdfr, pdfz, pdfc, pdfm = pdf_list

    gal = set_new_columns(gal,['pdf','pdfr','pdfz','pdfm','norm'],val=0.)
    gal = set_new_columns(gal,['pdf_bkg','pdfr_bkg','pdfz_bkg','pdfm_bkg'],val=0.)

    gal['pdfc'] = np.zeros_like(gal['color'])
    gal['pdfc_bkg'] = gal['pdfc']
    
    for i, idx in enumerate(galIndices):
        nb      = nbkg[i]
        zwindow = sigma[i]

        ggal = gal[idx] ## group gal

        ## getting pdfs for a given cluster i
        pdfri, pdfr_cfi  = pdfr[0][i], pdfr[1][i]
        pdfzi, pdfzi_bkg = pdfz[0][i], pdfz[2][i]
        pdfci, pdfci_bkg = pdfc[0][i], pdfc[2][i]
        pdfmi, pdfmi_bkg = pdfm[0][i], pdfm[2][i]

        ## setting galaxies variable columns
        r2    = ggal['R200'] 
        radii = ggal['R']
        zgal  = ggal['z']
        zcls  = ggal['redshift']
        zoff  = ggal['zoffset']*(1+zcls)
        zsig  = ggal['zerr']
        color5= ggal['color']
        mag   = ggal['dmag']
        zmask = ggal['zmask']
        areag = np.pi*r2**2

        radi2 = 0.25*(np.trunc(radii/0.25)+1) ## bins with 0.125 x R200 width
        # areag = np.pi*radi2**2#((radi2+0.25)**2-radi2**2)

        out1 = get_radial_pdf(radii,rvec,pdfri)
        gal['pdfr'][idx]     = out1[0]
        gal['pdfr_bkg'][idx] = out1[1]
        
        out2 = get_photoz_pdf(zgal, zoff, zsig, zvec, pdfzi, pdfzi_bkg, zmask, sigma=zwindow)
        gal['pdfz'][idx]     = out2[0]
        gal['pdfz_bkg'][idx] = out2[1]
        
        for j in range(5):
            gal['pdfc'][idx,j] = get_frequency(interpData(cvec,pdfci[:,j],color5[:,j]))
            gal['pdfc_bkg'][idx,j] = get_frequency(interpData(cvec,pdfci_bkg[:,j],color5[:,j]))

        gal['pdfm'][idx]     = get_frequency(interpData(mvec,pdfmi,mag))
        gal['pdfm_bkg'][idx] = get_frequency(interpData(mvec,pdfmi_bkg,mag))

        ## choose the color filters: g-r for zcls<0.35 and r-i otherwise
        pdfcii     = get_color_pdf(zcls,gal['pdfc'][idx,:])
        pdfcii_bkg = get_color_pdf(zcls,gal['pdfc'][idx,:])

        models       = [gal['pdfr'][idx],gal['pdfz'][idx],pdfcii]
        models_field = [gal['pdfr_bkg'][idx],gal['pdfz_bkg'][idx],pdfcii_bkg]
        
        if mag_pdf:
            models.append(gal['pdfm'][idx])
            models_field.append(gal['pdfm_bkg'][idx])

        gal['pdf'][idx]     = get_full_pdf(models)
        gal['pdf_bkg'][idx] = get_full_pdf(models_field)
                
        ng_profile       = interpData(rvec,pdfr_cfi,radi2)
        gal['norm'][idx] = (ng_profile - nb*areag)#/nb
    return gal

def gaussian(x,mu,sigma):
    return np.exp(-(x-mu)**2/(2*sigma**2))/(sigma*np.sqrt(2*np.pi))

def get_frequency(pdf,eps=1e-12):
    pdfn = np.where(pdf<0.,0.,pdf)
    norm = np.sum(pdfn)
    if norm>0.: pdfn = 1.*pdfn/norm
    return pdfn

def get_radial_pdf(radii,rvec,pdfr):
    pdfr_gal = interpData(rvec,pdfr,radii)
    pdfr_bkg = np.ones_like(radii)
    
    pdfr_gal = np.where(pdfr_gal<0.,0.,pdfr_gal)
    return get_frequency(pdfr_gal), get_frequency(pdfr_bkg)

def get_photoz_pdf(zgal,zoff,zsig,zvec,pdfz,pdfz_field,cut,sigma=0.03):
    ## for a convoluted gaussian: sigma_new^2 = sigma_gal^2+sigma_cls^2
    sigma_eff= sigma#np.sqrt(zsig**2+sigma**2)
    pdfz_gal = gaussian(zoff,0.,sigma_eff)#interpData(rvec,pdfz,zgal)

    ## background distribution
    pdfz_bkg   = interpData(zvec,pdfz_field,zgal)
    pdfz_bkg   = np.where(pdfz_bkg<0.,0.,pdfz_bkg)

    ## only galaxies inside 3*sigma
    #cut = np.abs(zoff)<=2*sigma
    pdfz_gal[np.logical_not(cut)] = 0.
    pdfz_bkg[np.logical_not(cut)] = 0.

    return get_frequency(pdfz_gal), get_frequency(pdfz_bkg)

# pn = np.sum(pdfri),np.sum(pdfzi),np.sum(pdfci)
# pn_bkg = np.sum(pdfr_bkg_i),np.sum(pdfz_bkg_i),np.sum(pdfc_bkg_i)

# Lgals     =  pdfri*pdfzi*pdfci*(np.sum(pn))/np.sum(pdfri*pdfzi*pdfci + eps)#np.product(pn)#
# Lgals_bkg = pdfr_bkg_i*pdfz_bkg_i*pdfc_bkg_i*(np.sum(pn_bkg))/np.sum(pdfr_bkg_i*pdfz_bkg_i*pdfc_bkg_i +eps)#(np.product(pn_bkg))##(np.product(pn_bkg))

def get_full_pdf(params):
    res  = params[0]
    for j in params[1:]:
        res *= j
    return get_frequency(res)

def interpData(x,y,x_new):
    out = interp1d(x, y, kind='linear', fill_value='extrapolate')
    return out(x_new)

def join_pdfs(x,pdf1,pdf2,eps=1e-9):
    prod = pdf1*pdf2
    norm = scipy.integrate.simps(prod,x=x)
    return prod/(norm+eps)

def mean_pdf(x,pdf):
    xmean = scipy.integrate.simps(x*pdf,x=x)
    return xmean

def get_likelihood(xnew,x,pdf,eps=1e-9,nbins=20):
    _,xb,pdfb = bin_data(x,pdf,nbins=nbins)
    like = interpData(xb,pdfb,xnew)
    like = np.where(np.isnan(like),0,like)
    norm = scipy.integrate.simps(like,x=xnew)
    return like/(norm+eps)

def bin_data(x,y,nbins=20):
    xbins = np.linspace(0,1.,nbins+1)#np.percentile(x,np.linspace(0,100,nbins+1))
    xmean = np.zeros_like(xbins[1:])
    ymean = np.zeros_like(xbins[1:])
    
    i=0
    for xl,xh in zip(xbins[:-1],xbins[1:]):
        w, = np.where((x>xl)&(x<=xh))
        if w.size>0:
            xmean[i] = np.nanmean(x[w])
            ymean[i] = np.nanmean(y[w])
        i+=1
    return xbins,xmean,ymean

def filter_prob(x):
    x[np.isnan(x)]=0.
    x = np.where(x<0,0.,x)
    x = np.where(x>1,1.,x)
    return x

def filter_pdf(pdf):
    pdf = np.where(pdf>1e6,1e6,pdf)
    return pdf

def filter_3pdf(x,y,z,norm=True):
    norm = (np.sum(x)+np.sum(y)+np.sum(z))
    norm/= (np.sum(x)*np.sum(y)*np.sum(z))
    
    pdf = x*y*z
    if norm:
        pdf*= norm
        
    pdf = filter_pdf(pdf)
    return pdf

## to do: smooth the color pdfs 
## https://stackoverflow.com/questions/20618804/how-to-smooth-a-curve-in-the-right-way
def get_color_pdf(zcls,pdfc):
    out = np.array(np.where(zcls<0.35,pdfc[:,0],pdfc[:,2]))
    out = np.where(out<0.,0.,out)
    return get_frequency(out)
    
#     return np.ones_like(pdfc[:,0])

def profileNFW(R,R200,c=3):
    #Radial NFW profile implementation. Takes array of radii, value of R200,
    #and NFW concentration parameter (set to 3 by default)
    if R200>0:
        Rs=float(R200)/c
        r=R/Rs
        r=np.where(np.logical_or(r<=1e-5,r==1.),r+0.001,r)
        pre=1./((r**2)-1)
        arctan_coeff=2./(np.sqrt(np.abs(r**2-1)))
        arctan_arg=np.sqrt(np.abs((r-1)/(r+1)))
        sigma=np.where(r>1,pre*(1-arctan_coeff*np.arctan(arctan_arg)),pre*(1-arctan_coeff*np.arctanh(arctan_arg)))
        
        return sigma*2*Rs
    
    else:
        bogusval=-99.*np.ones_like(R)
        return bogusval

def radial_pdf(radii,R200,c=3.5,rc=0.2):
    radii   = np.where(radii<rc/2.,rc/2.,radii)
    density = profileNFW(radii,R200,c=c) ## without norm
    density = np.where(radii<rc,np.mean(density[radii<rc]), density)
    return density

### To Remove
def doProb(Pgals,Pbkg,Ngals,Nbkg, normed=True, eps=1e-12):
    ratio = (Ngals+Nbkg)/( np.sum(Ngals*Pgals) + np.sum(Nbkg*Pbkg) )
    Pgals *= ratio
    Pbkg  *= ratio
    
    if normed:
        Pgals /= (Pgals.sum()+eps)
        Pbkg  /= (Pbkg.sum()+eps)
    
    prob = (Ngals*Pgals)/(Ngals*Pgals+Nbkg*Pbkg+eps)
    # prob[np.isnan(prob)] = 0.

    prob = np.where(prob>1,1.,prob)
    prob = np.where(prob<0.,0.,prob)
    return prob

def chunks(ids1, ids2):
    """Yield successive n-sized chunks from data"""
    for id in ids2:
        w, = np.where( ids1==id )
        yield w

def set_new_columns(table,columns,val=0.):
    for col in columns:
        table[col] = val
    return table

### Assign Probs
def main(cat,gal,norm=0.618):
    ncls    = len(cat)

    r200 = np.array(cat['R200']).copy()
    area = np.array(np.pi*r200**2).copy()

    Nc = cat['Norm']*norm
    Nf = cat['Nbkg']*area

    alpha = np.array(Nc).copy()
    beta  = np.array(Nf).copy()

    cids = np.array(cat['CID'])
    gids = np.array(gal['CID'])
    keys = list(chunks(gids,cids))

    ## compute the new probabilities
    res = []
    for i in range(ncls):
        print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
        b = BayesianProbability(alpha[i],beta[i],r2=r200[i])
        b.assign_probabilities(gal[keys[i]])

        res.append(b.prob)
        del b
    
    ## assign into the table
    ## assign the new probabilities
    gal = set_new_columns(gal,['Pmem','Pr','Pz','Pc'],val=0.)

    for i in range(ncls):
        for col in ['Pmem','Pr','Pz','Pc']:
            gal[col][keys[i]]  = res[i][col]['beta'][:]
            gal[col+'_flat'][keys[i]]  = res[i][col]['flat'][:]
            gal[col+'_old'][keys[i]]  = res[i][col]['old'][:]
    
    return gal

# %%
plot_fraction_pmem(gal,'beta')

# %%
plot_fraction_pmem(gal,'flat')

# %%
plot_fraction_pmem(gal,'old')

# %%
# plt.plot(pvec,b.pr0.pdf(pvec))
# plt.plot(pvec,b.prior)

# plt.axvline(b.pr0.mean())
# plt.axvline(b.pm0,color='r')

# %%
ncls   = len(cat)
columns = ['flat','beta','old']

## compute the new probabilities
res = []
for i in range(ncls):
    print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
    b = bayes_prob(alpha[i],beta[i])
    b.load_likelihood(gal[keys[i]])
    b.get_probabilities()
    b.compute_ngals()
    res.append(b.probabilities)
    del b
    
## assign the new probabilities
gal = set_new_columns(gal,columns,val=-99.)
cat = set_new_columns(cat,['Ngals_%s'%c for c in columns],val=-99.)

for i in range(ncls):
    for col in columns:
        gal[col][keys[i]]  = res[i][col][:]
        cat['Ngals_%s'%col][i]= res[i]['Ngals_%s'%col]
# Out:
# alpha,beta: 34.00 ,29.64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-a1333ca15b1b> in <module>()
#       6 for i in range(ncls):
#       7     print('alpha,beta: %.2f ,%.2f'%(alpha[i],beta[i]))
# ----> 8     b = bayes_prob(alpha[i],beta[i])
#       9     b.load_likelihood(gal[keys[i]])
#      10     b.get_probabilities()
#
# NameError: name 'bayes_prob' is not defined

# %% [markdown]
# ## Testing the Prior Distributions
#
# To understand the differences between the models first, we make a set of fake data. A very simply setup, a grid of 100 points for each variable $N_c$ and $N_f$.

# %%
import numpy as np
from scipy.stats import beta
