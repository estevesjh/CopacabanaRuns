# %% [markdown]
# # Comparing Selections
#
# Here we compare the uniform and redmapper selection.

# %% [markdown]
# ### Importing Packages

# %%
from astropy.table import Table, vstack
from astropy.io.fits import getdata

import pandas as pd

import matplotlib
import numpy as np

from collections import defaultdict
from matplotlib import pylab
import matplotlib.pyplot as plt

from scipy import stats
import sklearn

import scipy.stats as st
import seaborn as sns

# %%
sns.set_style("whitegrid")

# %%
# import sys
# sys.path.append('/home/s1/jesteves/git/buzzardAnalysis/mainAnalysis/')
# from plotLibrary import viewClusters,box_plot, get_dataFrame_residual

# %% [markdown]
# ### Loading Data

# %%
root = '/home/s1/jesteves/git/buzzardAnalysis/mainAnalysis/'
cfg1 = root+'config_buzzard_rm_v2.yaml'
cfg2 = root+'config_buzzard_v2.yaml'

# %%
import sys
sys.path.append("/home/s1/jesteves/git/ccopa/python/")

from main import copacabana

copa1= copacabana(cfg1)
copa2= copacabana(cfg2)
# Out:
# master file:
#  /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00000.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00256.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00257.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00260.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00261.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00263.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00269.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00271.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00272.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00273.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00274.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00275.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00276.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00277.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00278.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00279.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00280.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00281.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00282.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00283.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00284.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00291.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00292.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00293.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00294.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00295.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00296.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00297.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00298.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00299.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00300.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00304.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00320.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00321.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00322.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00323.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00328.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00329.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00330.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00352.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00518.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00519.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00521.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00522.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00523.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00524.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00525.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00526.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00527.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00528.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00529.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00530.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00531.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00532.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00533.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00534.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00535.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00536.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00537.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00538.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00539.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00540.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00541.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00542.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00543.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00544.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00545.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00546.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00547.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00548.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00549.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00550.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00551.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00552.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00553.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00554.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00555.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00556.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00557.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00558.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00559.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00560.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00561.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00562.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00563.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00564.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00565.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00566.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00567.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00568.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00569.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00570.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00571.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00572.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00573.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00574.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00575.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00610.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00616.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00618.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00709.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00710.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00711.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00713.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00715.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00716.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00717.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00718.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00719.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00720.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00721.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00722.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00723.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00724.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00725.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00726.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00728.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00729.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00730.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00731.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00740.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00741.hdf5
# outdir: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/
# tile path: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles
# master file:
#  /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00017.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00018.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00019.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00020.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00022.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00032.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00033.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00034.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00035.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00038.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00044.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00045.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00046.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00047.hdf5
# outdir: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/
# tile path: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles

# %%
def load_data(self,run_name,zmin=0.2,zmax=0.65):
    dat = self.load_copa_out('cluster',run_name)
    cat = dat[(dat['redshift']<=zmax)&(dat['redshift']>=zmin)&(dat['Ngals_true']>0.)].copy()
    return cat

# %%
cat1 = load_data(copa1,'gauss003_rhod_02Lstar')
cat2 = load_data(copa2,'gauss003_rhod_02Lstar_nfw')

print('Catalog 1: %i'%len(cat1))
print('Catalog 2: %i'%len(cat2))
# Out:
# Catalog 1: 9491
# Catalog 2: 1903

# %%
path   = '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/halos/'
rmfile = path+'buzzard-1.9.8_3y3a_run_halos_lambda_chisq.fit'

rmcat  = Table(getdata(rmfile))

# %% [markdown]
# # Lambda Frequency
#
# Create a subsample with a different selection criteria. In particular, lambda>5.

# %%
import healpy as hp
def radec_pix(ra,dec,nside=1024):
    return np.array(hp.ang2pix(nside,np.radians(90-dec),np.radians(ra),nest=True),dtype=np.int64)

# %%
ra = rmcat['RA']
dec= rmcat['DEC']

healpix = radec_pix(ra,dec,nside=8)

# %%
zcut = (rmcat['Z_LAMBDA']>=0.2)&(rmcat['Z_LAMBDA']<=0.65)
lbd_5_20 = (rmcat['LAMBDA_CHISQ']>=5.)&(rmcat['LAMBDA_CHISQ']<=20.)&zcut
sky_cut  = (rmcat['DEC']>-5.)&(rmcat['DEC']<5.)&(rmcat['RA']<30)
hpx_cut = (healpix>=500)&(healpix<=550)

print('# redMaPPer clusters w/ 5<lambda<20')
print('all sky: %i'%np.count_nonzero(lbd_5_20))
print('cut sky: %i'%np.count_nonzero(lbd_5_20&hpx_cut))
# Out:
# # redMaPPer clusters w/ 5<lambda<20
# all sky: 251417
# cut sky: 72387

# %%
a = plt.hist(healpix[lbd_5_20],bins=51)
b = plt.hist(healpix[lbd_5_20&hpx_cut],bins=a[1])
plt.yscale('log')
plt.xlabel('Healpix pixel - Nside=8')
plt.ylabel('Number of Clusters')
plt.title('RM: 5 < lambda < 20')
# Out:
# Text(0.5,1,'RM: 5 < lambda < 20')

# %%
np.unique(healpix[hpx_cut]).size
# Out:
# 32

# %%
np.sum(b[0])
# Out:
# 72387.0

# %%
lbd = np.array(rmcat['LAMBDA_CHISQ'])

# %%
_ = plt.hist(lbd[zcut],bins=np.logspace(0.5,2.2,21))
_ = plt.hist(lbd[zcut&sky_cut],bins=np.logspace(0.5,2.2,21))
plt.axvline(5,ls='--',lw=3,color='k')
plt.axvline(20.,ls='--',lw=3,color='k')
plt.xscale('log')
plt.yscale('log')

# %%
np.count_nonzero(lbd[zcut&hpx_cut]>20.)
# Out:
# 2419

# %% [markdown]
# # Match Selections
#
# Create a subsample with a different selection criteria. In particular, the RM sample will be slipted in an uniform grid of z, M200.

# %% [markdown]
# ### Distributions

# %%
a2= plt.hist(np.log10(cat2['M200_true']),bins=11)
a1= plt.hist(np.log10(cat1['M200_true']),bins=a2[1],histtype='step',lw=3)

# %%
b2= plt.hist(cat2['redshift'],bins=11)
b1= plt.hist(cat1['redshift'],bins=b2[1],histtype='step',lw=3)

# %% [markdown]
# ### Uniform Selection

# %%
from sklearn.model_selection import train_test_split
def get_high_mass_selection(cat2,zbins,mbins,h=0.7,Nsize=2000):
    nbins = len(zbins)-1
    Nsize+= 500
    
    M200 = np.array(np.log10(cat2["M200_true"]))
    z    = np.array(cat2['redshift'])
    df = cat2.to_pandas()

    data = []
    for zl,zh in zip(zbins[:-1],zbins[1:]):
        for ml,mh in zip(mbins[:-1],mbins[1:]):
            w, = np.where((M200>=ml)&(M200<=mh)&(z<=zh)&(z>=zl))
            dfb= df.iloc[w]
            size=int(Nsize/nbins/10)
            if w.size <size: size=len(dfb)-1
            if len(dfb)>0:
                print('bin size:',size)
                if (size>0)&(size< len(dfb)):
                    #try:
                    train_set, test_set = train_test_split(dfb, test_size=size, random_state=42)
                    data.append(Table.from_pandas(test_set))
                    #except:
                    #    print('Error while taking the mass bin %.1e<M200<%.1e'%(ml,mh))
                else:
                    print('Error: no halos within this limits')
    cat_high_mass = vstack(data)
    return cat_high_mass

# %%
cat1_new = get_high_mass_selection(cat1,b2[1],a2[1],h=0.7,Nsize=200*11)
# Out:
# ('bin size:', 9)
# ('bin size:', 14)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 19)
# ('bin size:', 24)
# ('bin size:', 9)
# ('bin size:', 4)
# ('bin size:', 3)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 18)
# ('bin size:', 10)
# ('bin size:', 5)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 16)
# ('bin size:', 5)
# ('bin size:', 0)
# Error: no halos within this limits
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 13)
# ('bin size:', 8)
# ('bin size:', 1)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 3)
# ('bin size:', 0)
# Error: no halos within this limits
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# Error: no halos within this limits
# ('bin size:', 12)
# ('bin size:', 5)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 3)
# ('bin size:', 0)
# Error: no halos within this limits
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 18)
# ('bin size:', 5)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 12)
# ('bin size:', 2)
# ('bin size:', 1)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 10)
# ('bin size:', 2)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 24)
# ('bin size:', 16)
# ('bin size:', 1)

# %%
1.*np.unique(cat1_new['CID']).size/len(cat1_new)
# Out:
# 1.0

# %%
_ = plt.hist(np.log10(cat2['M200_true']),bins=a2[1])
_ = plt.hist(np.log10(cat1_new['M200_true']),bins=a2[1],histtype='step',lw=3)

# %%
_ = plt.hist(cat2['redshift'],bins=b2[1])
_ = plt.hist(cat1_new['redshift'],bins=b2[1],histtype='step',lw=3)

# %% [markdown]
# ### RedMaPPer Selection

# %%
def get_med(x):
    return 0.5*(x[1:]+x[:-1])

# %%
zmed = get_med(b1[1])
mmed = get_med(a1[1])

probz = b1[0]/np.sum(b1[0])
probm = a1[0]/np.sum(a1[0])

prob = lambda z,m: np.interp(z,zmed,probz)*np.interp(m,mmed,probm)

# %%
plt.plot(zmed,probz)
plt.xlabel('redshift',fontsize=16)
plt.ylabel('C. Fraction',fontsize=16)
# Out:
# Text(0,0.5,'C. Fraction')

# %%
plt.plot(mmed,probm)
plt.xlabel('M200',fontsize=16)
plt.ylabel('C. Fraction',fontsize=16)
# Out:
# Text(0,0.5,'C. Fraction')

# %%
p_RM = prob(cat2['redshift'],np.log10(cat2['M200_true']))
p_RM/= np.sum(p_RM)

idx_all = np.linspace(0,len(cat2)-1,len(cat2)).astype(int)
idx_sel = np.random.choice(idx_all,size=1200,p=p_RM,replace=False)

cat2_new= cat2[idx_sel].copy()

# %%
1.*np.unique(cat2_new['CID']).size/len(cat2_new)
# Out:
# 1.0

# %%
_ = plt.hist(np.log10(cat1['M200_true']),bins=a2[1],density=True)
_ = plt.hist(np.log10(cat2_new['M200_true']),bins=a2[1],histtype='step',lw=3,density=True)

# %%
_ = plt.hist(cat1['redshift'],bins=b2[1],density=True)
_ = plt.hist(cat2_new['redshift'],bins=b2[1],histtype='step',lw=3,density=True)

# %% [markdown]
# ### Loading Data

# %%
runs = ['RM','U','RM_Sub_U','U_Sub_RM']
datas= [cat1,cat2,cat1_new,cat2_new]

# %%
vc = viewClusters()
for d,run in zip(datas,runs):
    print('run: %s'%run)
    vc.load_data(d,run)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-9dd2d1c81b83> in <module>()
# ----> 1 vc = viewClusters()
#       2 for d,run in zip(datas,runs):
#       3     print('run: %s'%run)
#       4     vc.load_data(d,run)
#
# NameError: name 'viewClusters' is not defined

# %%
for run in runs:
    vc.compute_residuals(run)
    vc.eval_all_metrics(run)

# %%
heading_properties = [('font-size', '16px')]
cell_properties = [('font-size', '16px')]
dfstyle = [dict(selector="th", props=heading_properties),\
 dict(selector="td", props=cell_properties)]

#df.style.set_table_styles(dfstyle)

# %% [markdown]
# ### Summary Statistics for the whole sample
#
# Here we compute some statiscial properties of the ratio $= x/x_{true}$ where x ={$N_{gals},\mu_{\star},R_{200}$}

# %%
stats_all = vc.show_metrics_table_all(runs[0])
print('Statistics for the whole sample')
stats_all.style.set_table_styles(dfstyle)

# %%
stats_all = pd.concat([vc.show_metrics_table_all(run) for run in runs])
stats_all['run'] = np.repeat(runs,3)
stats_all = stats_all.sort_index()
stats_all['predictor'] = stats_all.index
stats_all = stats_all.set_index('run')

# %%
#stats_all

# %%
stats_all.iloc[np.where(stats_all.predictor=='MU')[0],[0,2,3]].style.set_table_styles(dfstyle)

# %%
stats_all.iloc[np.where(stats_all.predictor=='Ngals')[0],[0,2,3]].style.set_table_styles(dfstyle)

# %%
stats_all.iloc[np.where(stats_all.predictor=='R200')[0],[0,2,3]].style.set_table_styles(dfstyle)

# %%
for run in runs:
    print('run: %s'%run)
    ntrue = vc.models[run]['regressors']['Ngals_true']
    nobjs = np.count_nonzero(ntrue>1.)
    print('Nobj: %i'%nobjs)
    print('Frac: %.2f'%(1.*nobjs/ntrue.size))
    print('\n')

# %% [markdown]
# ### Residuals Distribution

# %% [markdown]
# Residuals

# %%
df = get_dataFrame_residual(vc,runs)

# %%
fig, axs = plt.subplots(1, 2, sharey='all', figsize=(14,5))
fig.subplots_adjust(hspace=0.25,wspace=0.15)

box_plot(df,'Ngals',ax=axs[0],xlims=(0.,2.2))
box_plot(df,'MU',ax=axs[1],xlims=(0.,2.2))

# %%
nruns=3

# %%
fig, axs = plt.subplots(nruns, 3, sharey='all',sharex='all', figsize=(14,(3.5)*nruns))
fig.subplots_adjust(hspace=0.20,wspace=0.05)

axs = axs.T
for j in range(3):
    for i in range(nruns):
        vc.plot_residual_distribution(runs[i],vc.predictors[j],axs=axs[j,i],log_residual=False,xlims=(0.3,3.))
        if i<(nruns-1):
            axs[j,i].set_xlabel('')
        
axs[0,0].set_xlim(0.,2.3)

# %% [markdown]
# Log Residual

# %%
fig, axs = plt.subplots(nruns, 3, sharey='all',sharex='all', figsize=(14,(3.5)*nruns))
fig.subplots_adjust(hspace=0.20,wspace=0.05)

axs = axs.T
for j in range(3):
    for i in range(nruns):
        vc.plot_residual_distribution(runs[i],vc.predictors[j],axs=axs[j,i],log_residual=True,xlims=(-0.4,0.7))
        if i<(nruns-1):
            axs[j,i].set_xlabel('')
        
axs[0,0].set_xlim(-0.4,0.7)

# %% [markdown]
# ### Binned Analysis

# %%
myperc = np.array([1.,15,30,45,60,75,90,95,97.5,100])
# myperc = np.array([1.,15,45,70,90,97.5,100])
mycols = ['Ngals_true','MU_TRUE','R200_true','redshift','M200_true']
mybins = []
for cols in mycols:
    mybins.append(np.nanpercentile(vc.models[runs[0]]['aux_vars'][cols],myperc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-cb819c5369e8> in <module>()
#       4 mybins = []
#       5 for cols in mycols:
# ----> 6     mybins.append(np.nanpercentile(vc.models[runs[0]]['aux_vars'][cols],myperc))
#
# NameError: name 'vc' is not defined

# %%
mybins[-2] = np.linspace(0.1,0.7,9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-f3f030399056> in <module>()
# ----> 1 mybins[-2] = np.linspace(0.1,0.7,9)
#
# IndexError: list assignment index out of range

# %%
vc.make_bins(runs,*mybins)
for run in runs:
    vc.compute_bin_statstics(run)
    vc.eval_all_metrics(run,binned=True)
# Out:
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:293: RuntimeWarning: invalid value encountered in divide
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/ipykernel_launcher.py:308: RuntimeWarning: divide by zero encountered in log10

# %%
x = np.arange(len(runs))
colors = np.array([sns.color_palette()[xx] for xx in x])

# %%
fig, axs = plt.subplots(2, 2, figsize=(14,10),sharex='all',sharey='all')
fig.subplots_adjust(hspace=0.25,wspace=0.3)

axs = axs.flatten(order='F')

for i,co,run in zip(range(len(runs)),colors,runs):
    if i>3:
        break
    vc.plot_scaling_relation(vc.regressors[0],vc.predictors[0],run,points=True,axs=axs[i],color=co)

axs[0].set_xlim(0.7,)
axs[0].set_ylim(0.7,)
# Out:
# (0.7, 356.4)

# %%
fig, axs = plt.subplots(1, 3, figsize=(14,4))
fig.subplots_adjust(hspace=0.30,wspace=0.35)

for co,run in zip(colors,runs):
    vc.plot_scaling_relation(vc.regressors[0],vc.predictors[0],run,points=False,axs=axs[0],color=co)
    vc.plot_scaling_relation(vc.regressors[1],vc.predictors[1],run,points=False,axs=axs[1],color=co)
    vc.plot_scaling_relation(vc.regressors[2],vc.predictors[2],run,points=False,axs=axs[2],color=co,log_scale=False)

axs[0].set_xlim(0.7,)
axs[0].set_ylim(0.7,)
axs[2].set_xlim(0.5,3.)
axs[2].set_ylim(0.5,3.)

axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[2].get_legend().remove()

# %% [markdown]
# ### Binned Residuals
#
# Our results for instance can be dependent on redshift, cluster mass or richness. In order to check, in this section we split the sample in bins of this quantities and we take a look into the residuals.

# %%
ycol='MU'
xcol='M200_true'

# %%
fig, axs = plt.subplots(3, 1, sharey='col', figsize=(10,14))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

for co,run in zip(colors,runs):
    vc.plot_residual(run,'redshift',ycol,ax=axs[0],xlog=False,color=co,points=False)
    # vc.plot_residual(run2,'redshift',ycol,ax=axs[0],xlog=False,color='b',points=False,shift=0.01)
    vc.plot_residual(run,'M200_true',ycol,ax=axs[1],xlog=True,color=co,points=False,units=r'  [$M_{\odot}\, h^{-1}$]')
    vc.plot_residual(run,'Ngals_true',ycol,ax=axs[2],xlog=True,color=co,points=False)

axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[2].get_legend().remove()

axs[0].set_ylim(0.4,1.7)
axs[0].set_xlim(0.08,0.72)
# Out:
# (0.08, 0.72)

# %%
ycol='Ngals'

# %%
fig, axs = plt.subplots(3, 1, sharey='col', figsize=(10,14))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

for co,run in zip(colors,runs):
    vc.plot_residual(run,'redshift',ycol,ax=axs[0],xlog=False,color=co,points=False)
    # vc.plot_residual(run2,'redshift',ycol,ax=axs[0],xlog=False,color='b',points=False,shift=0.01)
    vc.plot_residual(run,'M200_true',ycol,ax=axs[1],xlog=True,color=co,points=False,units=r'  [$M_{\odot}\, h^{-1}$]')
    vc.plot_residual(run,'Ngals_true',ycol,ax=axs[2],xlog=True,color=co,points=False)
    
axs[0].set_ylim(0.6,1.1)
axs[0].set_xlim(0.08,0.72)


axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[2].get_legend().remove()

# %%
ycol='R200'

# %%
fig, axs = plt.subplots(3, 1, sharey='col', figsize=(10,14))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

for co,run in zip(colors,runs):
    vc.plot_residual(run,'redshift',ycol,ax=axs[0],xlog=False,color=co,points=False)
    # vc.plot_residual(run2,'redshift',ycol,ax=axs[0],xlog=False,color='b',points=False,shift=0.01)
    vc.plot_residual(run,'M200_true',ycol,ax=axs[1],xlog=True,color=co,points=False,units=r'  [$M_{\odot}\, h^{-1}$]')
    vc.plot_residual(run,'Ngals_true',ycol,ax=axs[2],xlog=True,color=co,points=False)
    
# axs[0].set_ylim(-0.5,1.5)
# axs[0].set_xlim(0.08,0.72)

axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[2].get_legend().remove()

# %%
def plot_scatter_xvar(vc,xcol,ycol,runs,ax=None,metric='scatter_nmad'):
    if ax is None: ax=plt.axes()
    
    for run in runs:
        xmean,ymean,sigma,of,lower,upper = vc.get_residual_metrics_binned(run,xcol,ycol,metric=metric)
        ymin,ymax = np.mean(ymean-3*sigma),np.mean(ymean+3*sigma)
        xmin,xmax = 0.8*np.min(xmean-lower),1.2*np.max(xmean+upper)
        ylabel = r'$%s/%s_{true}$'%(ycol,ycol)
        ax.plot(xmean,sigma,'--',label=run)
        ax.scatter(xmean,sigma)

    ax.set_xlabel(xcol)
    ax.set_ylabel(metric)
    ax.legend()

# %%
ycol = 'Ngals'

fig, axs = plt.subplots(2, 2, sharex='row',  figsize=(14,8))
fig.subplots_adjust(hspace=0.3,wspace=0.3)

plot_scatter_xvar(vc,'redshift',ycol,runs,ax=axs[0,1],metric='bias')
fig.legend(fontsize=12,bbox_to_anchor=(.5, 1.02), loc='upper center', shadow=True, borderaxespad=0.,ncol=len(runs),borderpad=1)
plot_scatter_xvar(vc,'redshift',ycol,runs,ax=axs[0,0])
axs[0,0].axhline(0.2,ls='--',color='k',lw='2')

plot_scatter_xvar(vc,'Ngals_true',ycol,runs,ax=axs[1,1],metric='bias')
plot_scatter_xvar(vc,'Ngals_true',ycol,runs,ax=axs[1,0])
axs[1,0].axhline(0.2,ls='--',color='k',lw='2')
axs[1,0].set_xscale('log')
axs[1,1].set_xscale('log')

axs[0,0].get_legend().remove()
axs[0,1].get_legend().remove()
axs[1,0].get_legend().remove()
axs[1,1].get_legend().remove()


# axs[0].set_title(ycol,fontsize=22)
fig.tight_layout()

# %%
ycol = 'MU'

fig, axs = plt.subplots(2, 2, sharex='row',  figsize=(14,8))
fig.subplots_adjust(hspace=0.3,wspace=0.3)

plot_scatter_xvar(vc,'redshift',ycol,runs,ax=axs[0,1],metric='bias')
fig.legend(fontsize=12,bbox_to_anchor=(.5, 1.02), loc='upper center', shadow=True, borderaxespad=0.,ncol=len(runs),borderpad=1)
plot_scatter_xvar(vc,'redshift',ycol,runs,ax=axs[0,0])
axs[0,0].axhline(0.2,ls='--',color='k',lw='2')

plot_scatter_xvar(vc,'Ngals_true',ycol,runs,ax=axs[1,1],metric='bias')
plot_scatter_xvar(vc,'Ngals_true',ycol,runs,ax=axs[1,0])
axs[1,0].axhline(0.2,ls='--',color='k',lw='2')
axs[1,0].set_xscale('log')
axs[1,1].set_xscale('log')

axs[0,0].get_legend().remove()
axs[0,1].get_legend().remove()
axs[1,0].get_legend().remove()
axs[1,1].get_legend().remove()


# axs[0].set_title(ycol,fontsize=22)
fig.tight_layout()

# %%
mycols = ['redshift','M200_true','Ngals_true']
ycol = 'Ngals_flat'

fig, axs = plt.subplots(3, 1, sharey='col', figsize=(10,14))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

for i,xcol in enumerate(mycols):
    plot_scatter_xvar(vc,xcol,ycol,runs[:],ax=axs[i])
    if i>0: axs[i].set_xscale('log')
    
axs[0].set_title(ycol,fontsize=22)

axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[2].get_legend().remove()

# %%
mycols = ['redshift','M200_true','Ngals_true']
ycol = 'MU'

fig, axs = plt.subplots(3, 1, sharey='col', figsize=(10,14))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

for i,xcol in enumerate(mycols):
    plot_scatter_xvar(vc,xcol,ycol,runs[:],ax=axs[i])
    if i>0: axs[i].set_xscale('log')
    
axs[0].set_title(ycol,fontsize=22)

axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[2].get_legend().remove()

# %%
mycols = ['redshift','M200_true','Ngals_true']
ycol = 'Ngals_flat'

fig, axs = plt.subplots(3, 1, sharey='col', figsize=(10,14))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

for i,xcol in enumerate(mycols):
    plot_scatter_xvar(vc,xcol,ycol,runs,ax=axs[i],metric='bias')
    if i>0: axs[i].set_xscale('log')

axs[0].set_title(ycol,fontsize=22)
axs[0].legend(fontsize=14)
# axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[2].get_legend().remove()
axs[0].set_ylim(-0.2,0.3)

# %%
mycols = ['redshift','M200_true','Ngals_true']
ycol = 'MU'

fig, axs = plt.subplots(3, 1, sharey='col', figsize=(10,14))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

for i,xcol in enumerate(mycols):
    plot_scatter_xvar(vc,xcol,ycol,runs,ax=axs[i],metric='bias')
    if i>0: axs[i].set_xscale('log')
        
axs[0].set_title(ycol,fontsize=22)
axs[0].legend(fontsize=14)
# axs[0].get_legend().remove()
axs[1].get_legend().remove()
axs[2].get_legend().remove()
axs[0].set_ylim(-0.18,0.07)

# %%
mycols = ['redshift','M200_true','Ngals_true']
ycol = 'MU'

fig, axs = plt.subplots(3, 1, sharey='col', figsize=(10,14))
fig.subplots_adjust(hspace=0.4,wspace=0.4)

axs[0].set_title(ycol,fontsize=22)
for i,xcol in enumerate(mycols):
    plot_scatter_xvar(vc,xcol,ycol,runs[3:],ax=axs[i],metric='outlier_frac')
    if i>0: axs[i].set_xscale('log')

# %%
import sys
sys.path.append("/home/s1/jesteves/git/ccopa/python/")

import sys
sys.path.append('/home/s1/jesteves/git/buzzardAnalysis/mainAnalysis/')
from plotLibrary import viewClusters,box_plot, get_dataFrame_residual

from main import copacabana

class viewClusters:
    def __init__(self,dataset='buzzard_v2'):
        self.models  = defaultdict(dict)
        self.metrics = defaultdict(dict)

        self.predictors = ['Ngals','MU','R200']
        self.regressors = ['Ngals_true','MU_TRUE','R200_true']
        self.aux_vars   = ['Ngals_true','MU_TRUE','R200_true','redshift','M200_true']
        
        self.npredictors = len(self.predictors)
        self.nauxialiars = len(self.aux_vars)
        
        self.metric_funcs = {"bias": bias_log_res,
                             "scatter_stdev": fractional_error_stdev,
                             "scatter_percentile": fractional_error_percentile,
                             "scatter_nmad": get_sigmaNMAD,
                             "outlier_frac": get_outlier_frac}
        pass

    def load_data(self,cat,run_name):
        self.models[run_name]['predictors'] = np.array(cat[self.predictors])
        self.models[run_name]['regressors'] = np.array(cat[self.regressors])
        self.models[run_name]['aux_vars']   = np.array(cat[self.aux_vars])
        self.compute_residuals(run_name)
    
    def compute_resiudal_all(self):
        runs = self.models.keys()
        for run_name in runs:
            self.compute_residuals(run_name)
            
    def compute_residuals(self,run_name):
        self.models[run_name]['residual']     = np.full_like(self.models[run_name]['predictors'],-99.)
        self.models[run_name]['log_residual'] = np.full_like(self.models[run_name]['predictors'],-99.)

        for colx,coly in zip(self.regressors,self.predictors):
            x = self.models[run_name]['regressors'][colx]
            y = self.models[run_name]['predictors'][coly]
            res, log_res = get_frac_residual(x,y)
            self.models[run_name]['residual'][coly] = res
            self.models[run_name]['log_residual'][coly] = log_res

    def make_bins(self, runs, ngals_bins, mu_star_bins, r200_bins, zcls_bins, mass_bins):
        mybins             = [ngals_bins, mu_star_bins, r200_bins, zcls_bins, mass_bins]
        self.metrics['bins']= dict()
        for jj,xbin in zip(self.aux_vars,mybins):
            self.metrics['bins'][jj]  = xbin
            self.metrics['nbins'][jj] = xbin.size - 1
        
        for run_name in runs:
            labels,values = self._make_bins(mybins,run_name)
            self.models[run_name]['bins_idx'] = labels
            self.models[run_name]['bins_val'] = values
        
    def _make_bins(self,bins,run_name):
        labels = np.full_like(self.models[run_name]['aux_vars'],-99.)
        values = np.full_like(self.models[run_name]['aux_vars'],-99.)
        for xbin,col in zip(bins,self.aux_vars):
            x = self.models[run_name]['aux_vars'][col]
            keys,xbins = get_bins(x,xbin)
            labels[col]= keys
            values[col]= xbins
        return labels,values

    ### compute metrics
    def compute_bin_statstics(self,run_name):
        ## out: dict('xbins','xmean','nobjs')
        for jj in self.aux_vars:
            id_bins = self.models[run_name]['bins_idx'][jj].astype(np.int)    
            xs_vals = self.models[run_name]['aux_vars'][jj]
            ys_true = self.models[run_name]['predictors']
            res     = self.models[run_name]['residual']
                
            nbins    = self.metrics['nbins'][jj]
            xbins    = self.metrics['bins'][jj]
            
            indices  = np.arange(nbins,dtype=np.int)
            xmean    = get_binned_mean(xs_vals,xs_vals,xbins)#0.5*(xbins[1:]+xbins[:-1])
            nobjs    = np.histogram(xs_vals,bins=xbins)[0]
            
            ymean       = np.full_like(ys_true,np.nan)[:nbins]
            resmean     = ymean.copy()
            
            for ii in self.predictors:
                ymean[ii]     = get_binned_mean(xs_vals,ys_true[ii],xbins)
                resmean[ii]   = get_binned_mean(xs_vals,res[ii],xbins)
                
            mydict   = {'bins':indices,'xbins':xbins,'xmean':xmean,'ymean':ymean,'res_mean':resmean,
                        'nobjs':nobjs}            
            self.metrics[run_name][jj] = mydict
    
    def eval_metrics(self,run_name,metric):
        ys_predict = self.models[run_name]['predictors']
        ys_true    = self.models[run_name]['regressors']
        
        dtypes      = [(col,'<f8') for col in self.predictors]
        scores      = np.full((1,),-99.,dtype=dtypes)
        for ii,kk in zip(self.predictors,self.regressors):
            scores[ii]  = self.metric_funcs[metric](ys_true[kk],ys_predict[ii])
        self.metrics[run_name][metric] = scores
    
    def eval_all_metrics(self,run_name,binned=False):
        ### func can be: eval_metrics_bin, eval_metrics
        metrics= self.metric_funcs.keys()
        if not binned:
            for metric in metrics:
                self.eval_metrics(run_name, metric)
        else:
            for metric in metrics: 
                self.eval_metrics_bin(run_name, metric)

    def eval_metrics_bin(self, run_name, metric):
        #error_message = f"{run_name} not yet trained"
        #assert run_name in self.models, error_message

        ys_predict = self.models[run_name]['predictors']
        ys_true    = self.models[run_name]['regressors']
        xs_vals    = self.models[run_name]['aux_vars']
        
        for jj in self.aux_vars:
            xbins   = self.metrics[run_name][jj]['xbins']
            dtypes      = [(col,'<f8') for col in self.predictors]
            scores      = np.full_like(xbins[1:],-99.,dtype=dtypes)
            for ii,kk in zip(self.predictors,self.regressors):
                scores[ii]  = self.metrics_bin(metric, ys_true[kk],ys_predict[ii], xs_vals[jj], xbins)
            self.metrics[run_name][jj][metric] = scores

    def metrics_bin(self,metric,ytrue,ypred,xvar,xbins):
        error_message = ('{} not recognized! options are: {}'
                         ''.format(metric, self.metric_funcs.keys()))
        assert metric in self.metric_funcs, error_message
        
        keys     = get_bins_group_indices(xvar,xbins)
        ytrue_bin= group_by(ytrue,keys)#get_bins_group(x,ytrue,xbins)
        ypred_bin= group_by(ypred,keys)#get_bins_group(x,ypred,xbins)#[ypred[idx] for idx in keys]
        
        nbins    = len(xbins)-1
        scores   = np.full_like(xbins[:-1],-99.,dtype=np.float64)
        
        for i,yt,yp in zip(range(nbins),ytrue_bin,ypred_bin):
            scores[i] = self.metric_funcs[metric](yt,yp)
        return scores

    def show_metrics_table_all(self,run):
        metrics= self.metric_funcs.keys()
        mydict = dict.fromkeys(metrics)
        for ycol in self.predictors:
            for col in metrics:
                mydict[col] = np.append(mydict[col],self.metrics[run][col][ycol])
        df = pd.DataFrame(mydict,index=[None]+self.predictors)[1:]
        #df.set_index('index')
        return df
            
    def get_residual_metrics(self,run,ycol,log_residual=False):
        bias = self.metrics[run]['bias'][ycol]+1
        sigma= self.metrics[run]['scatter_percentile'][ycol]
        sigma_nmad = self.metrics[run]['scatter_nmad'][ycol]
        of   = self.metrics[run]['outlier_frac'][ycol]

        if log_residual:
            bias,sigma = np.log10(bias), np.log10(sigma+1)
            sigma_nmad = np.log10(sigma_nmad+1)
        return bias,sigma,sigma_nmad,of
    
    def get_residual_metrics_binned(self,run,xcol,ycol,log_residual=False,metric='scatter_nmad'):
        xbins = self.metrics[run][xcol]['xbins']
        xmean = self.metrics[run][xcol]['xmean']
        bias  = self.metrics[run][xcol]['bias'][ycol]+1
        sigma = self.metrics[run][xcol][metric][ycol]
        of    = self.metrics[run][xcol]['outlier_frac'][ycol]
        
        lower  = xmean-xbins[:-1]
        upper  = xbins[1:]-xmean
        return xmean,bias,sigma,of,lower,upper
        
    def plot_residual_distribution(self,run,ycol,axs=None,xlims=None,log_residual=False):
        if axs is None: axs=plt.axes()
        residual    = filter_nan_inf(self.models[run]['residual'][ycol])
        log_res     = filter_nan_inf(self.models[run]['log_residual'][ycol])
        mask        = get_oulier_mask(log_res)

        xlabel   = r'$%s/%s_{true}$'%(ycol,ycol)
        units    = '\n'
        if log_residual:
            residual = log_res
            xlabel   = r'Log(%s)'%xlabel
            units    = 'dex\n'

        bias,sigma,sigma_nmad,of = self.get_residual_metrics(run,ycol,log_residual=log_residual)
        xmin,xmax   = np.nanpercentile(residual[residual>-99],[0,100])
        xlo,xup     = bias-2*sigma_nmad, bias+2*sigma_nmad

        if xlims is not None:
            xmin,xmax = xlims

        l1 = r'bias  : %.2f %s$\sigma_{NMAD}$: %.2f %s'%(bias,units,sigma_nmad,units)
        l2 = r'outlier: %.2f'%(of)

        xbins = np.linspace(xmin,xmax,50)
        _ = axs.hist(residual,bins=xbins,label=l1,histtype='step',lw=3)
        _ = axs.hist(residual[mask],bins=xbins,label=l2,histtype='step',lw=3)
        axs.axvline(bias,color='k',ls='--')
        axs.axvline(xup,color='r',ls='--')
        axs.axvline(xlo,color='r',ls='--')

        #plt.yscale('log')
        axs.set_xlabel(xlabel,fontsize=20)
        axs.legend(fontsize=12)
        axs.set_title(run,fontsize=14)
        
    def get_binned_variables(self,xcol,ycol,run,metric='scatter_nmad'):
        ## get variables
        x = self.models[run]['regressors'][xcol]
        y = self.models[run]['predictors'][ycol]
        
        xbins = self.metrics[run][xcol]['xbins']
        xb= self.metrics[run][xcol]['xmean']#0.5*(xbins[1:]+xbins[:-1])#self.metrics[run][xcol]['xmean']
        yb= self.metrics[run][xcol]['ymean'][ycol]
        
        lower,upper = xb-xbins[:-1],xbins[1:]-xb
        
        yb_err= self.metrics[run][xcol][metric][ycol]
        xb_err= [lower,upper]
        
        xmin,xmax = 0.8*(np.nanmin(xbins)), 1.2*(np.nanmax(xbins))
        xlims = (xmin,xmax)
        
        mask  = np.logical_not(np.isnan(x)|np.isnan(y))
        x = x[mask]
        y = y[mask]
        return x,y,xb,yb,xb_err,yb_err*xb,xlims
        
    def plot_scaling_relation(self,xcol,ycol,run,color='r',axs=None,xlims=None,points=False,metric='scatter_nmad',fit=False,title='',log_scale=True):
        ## get variables
        x,y,xb,yb,xb_err,yb_err,xlims0 = self.get_binned_variables(xcol,ycol,run,metric=metric)
        if xlims is None: xlims=xlims0
        _plot_scaling_relation(x,y,xb,yb,xb_err,yb_err,xlims,xcol,ycol,li=run,points=points,axs=axs,fit=fit,title=title,log_scale=log_scale,color=color)
    
    def plot_residual(self,run,xcol,ycol,ax=None,xlog=False,color='r',points=True,units='',shift=0.):
        if ax is None: ax = plt.axes()
        xmean,ymean,sigma,of,lower,upper = self.get_residual_metrics_binned(run,xcol,ycol,log_residual=False)
        ymin,ymax = np.nanmean(ymean-3*sigma),np.nanmean(ymean+3*sigma)
        xmin,xmax = 0.8*np.nanmin(xmean-lower),1.2*np.nanmax(xmean+upper)
        ylabel = r'$%s/%s_{true}$'%(ycol,ycol)

        if points:
            x  = self.models[run]['aux_vars'][xcol]
            res= self.models[run]['residual'][ycol]
            ax.scatter(x,res,color=color,alpha=0.3,s=40)

        ax.plot([xmin,xmax],[1.,1.],'k--')
        ax.errorbar(shift+xmean,ymean,xerr=[lower,upper],yerr=sigma,color=color, fmt='o', capsize=4, capthick=2,label=run)
        ax.set_ylim(ymin,ymax)
        ax.set_xlabel(xcol+units,fontsize=20)
        ax.set_ylabel(ylabel,fontsize=20)
        ax.legend()
        if xlog:
            ax.set_xscale('log')

def group_by(x,keys):
    return [x[idx] for idx in keys]

def get_bins_group_indices(x,bins):
    idx  = np.argsort(x)
    ## to avoid the boundary condition of the digitize function as xlow <= x < xup
    mybins = bins.copy()
    mybins[-1] += 0.1
    inds = np.digitize(x,mybins)
    return np.split(idx, np.unique(inds[idx], return_index=True)[1][1:])
    
def get_bins_group(x,y,bins):
    idx  = np.argsort(x)
    ## to avoid the boundary condition of the digitize function as xlow <= x < xup
    mybins = bins.copy()
    mybins[-1] += 0.1
    inds = np.digitize(x,mybins)
    return np.split(y[idx], np.unique(inds[idx], return_index=True)[1][1:])
    
def get_binned_mean(x,y,bins):
    y     = filter_nan_inf(y)
    y     = np.where(y==-99,0.,y)
    x     = filter_nan_inf(x)
    sum_y = np.histogram(x, bins, weights=y)[0]
    nobjs = np.histogram(x, bins)[0]
    return sum_y/nobjs
    
def get_bins(variable,xedges):
    nbins   = len(xedges)-1
    indices = np.full_like(variable,-99,dtype=np.int)
    xbins   = np.full_like(variable,-99,dtype=np.float)

    means = (xedges[1:]+xedges[:-1])/2.
    for i in range(nbins):
        idx = np.where((variable >= xedges[i]) & (variable <= xedges[i + 1]))[0]
        xbins[idx]   = means[i]
        indices[idx] = i
    return indices, xbins

def get_log(x):
    xlog = np.log10(x)
    xlog[np.isinf(xlog)] = -99
    xlog[np.isnan(xlog)] = -99
    return xlog

def get_frac_residual(x,y):
    res = y/(x+1e-6)
    log_res = get_log(res)
    return res,log_res

def mad(data, axis=None):
    return np.median(np.abs(data - np.median(data)))

def median_absolute_dev(x,y):
    res, log_res = get_frac_residual(x,y)
    return 10**mad(log_res[log_res>-99])

def bias_log_res(x,y):
    res, log_res = get_frac_residual(x,y)
    mask = log_res>-99.
    return 10**np.median(log_res[mask])-1.

def fractional_error_stdev(x, y):
    res, log_res = get_frac_residual(x,y)
    score = np.std(log_res[log_res>-99])
    return 10**score-1.

def fractional_error_percentile(x, y):
    res, log_res = get_frac_residual(x,y)
    mask = log_res>-99.
    if np.count_nonzero(mask)>2:
        p16 = np.percentile(log_res[mask], 16)
        p84 = np.percentile(log_res[mask], 84)
        score = 0.5*(p84-p16)
    else:
        score = -99
    return 10**score-1.

def get_sigmaNMAD(x,y):
    sigmaNMAD = 1.4*(median_absolute_dev(x,y)-1.)
    return sigmaNMAD

def get_outlier_frac(x,y):
    res, log_res = get_frac_residual(x,y)
    sigmaNMAD = 1.4*mad(log_res[log_res>-99])
    bias      = np.nanmedian(log_res[log_res>-99])
    out       = np.where(np.abs((log_res-bias)>=3.*sigmaNMAD))[0]
    frac      = 1.*out.size/x.size
    return frac

def get_oulier_mask(log_res):
    sigmaNMAD = 1.4*mad(log_res[log_res>-99])
    bias      = np.nanmedian(log_res[log_res>-99])
    out       = np.where(np.abs((log_res-bias)>=3.*sigmaNMAD))[0]
    return out
    
def r2_score(x,y):
    """ returns non-aggregate version of r2 score.

    based on r2_score() function from sklearn (http://sklearn.org)
    """
    res, log_res = get_frac_residual(x,y)
    mask = log_res>-99.
    return sklearn.metrics.r2_score(x[mask],y[mask]) 

def filter_nan_inf(x):
    mask = np.isinf(x)|np.isnan(x)
    x[mask] = -99.
    return x

# %%
def _plot_scaling_relation(x,y,xb,yb,xb_err,yb_err,xlims,xcol,ycol,li='_',color='b',points=False,axs=None,fit=False,title='',log_scale=True):
    if axs is None: axs = plt.axes()
    
    ## linear fit
    linreg=lin_reg(x,y)
    
    idx = np.argsort(x)
    xt,yh = x[idx],linreg['Yhat'][idx]

    b0 = round(linreg['b0'],3)
    b1 = round(linreg['b1'],3)
    cb_u, cb_l = linreg['cb_u'], linreg['cb_l']
    
    ## Plot
    if fit:
        axs.plot(xt,yh, color="r",label='y=%.2f+%.2fx'%(b0,b1))
        axs.fill_between(xt, cb_l, cb_u, color="gray", alpha=0.25, label='_nolabel_')
        axs.plot(xt,cb_l, color="r", label='_nolabel_')
        axs.plot(xt,cb_u, color="r", label='_nolabel_')

    if points:
        sc = axs.scatter(x,y,s=75, alpha=0.1, color='gray')

    axs.errorbar(xb,yb,xerr=xb_err,yerr=yb_err,color=color,linewidth=2.,fmt='o',label=li)
    axs.plot(np.linspace(xlims[0],xlims[1]),np.linspace(xlims[0],xlims[1]),linestyle='--',color='k')
    
    if log_scale:
        xlims = np.where(xlims<1.,2.,xlims)
        axs.set_xscale('log')
        axs.set_yscale('log')
    
    axs.set_ylim(xlims)
    axs.set_xlim(xlims)
    
    axs.set_xlabel(xcol,fontsize=22)
    axs.set_ylabel(ycol,fontsize=22)
    axs.legend(fontsize=12)
    
    #axs.set_title(run,fontsize=22)
    #fig.tight_layout()
def lin_reg(X,Y):
    barX=np.mean(X); barY=np.mean(Y)
    XminusbarX=X-barX; YminusbarY=Y-barY
    b1=sum(XminusbarX*YminusbarY)/sum(XminusbarX**2)
    b0=barY-b1*barX
    Yhat=b0+b1*X
    e_i=Y-Yhat
    sse=np.sum(e_i**2)
    ssr=np.sum((Yhat-barY )**2)
    n=len(X)
    MSE=sse/np.float(n-2)

    s_of_yh_hat=np.sqrt(MSE*(1.0/n+(X-barX)**2/sum(XminusbarX**2)))
    W=np.sqrt(2.0*st.f.ppf(0.95,2,n-2))

    cb_upper=Yhat+W*s_of_yh_hat
    cb_lower=Yhat-W*s_of_yh_hat
    idx=np.argsort(X)

    return {'Yhat':Yhat,'b0':b0,'b1':b1,'cb_u':cb_upper[idx], 'cb_l': cb_lower[idx]}

# %%
import seaborn as sns

def get_dataFrame_residual(vc,runs):
    out = []
    for run in runs:
        df = pd.DataFrame(columns=['runs']+vc.predictors)
        for col in vc.predictors:
            res = vc.models[run]['residual'][col]
            df[col] = res
        df['runs']     = np.repeat(run,len(res))
        out.append(df)
    odf = pd.concat(out)
    return odf

def box_plot(planets,ycol,ax=None,xlims=(0.,2.6)):
    #f, ax = plt.subplots(figsize=(7, 6))
    
    # Plot the orbital period with horizontal boxes
    sns.boxplot(x=ycol, y="runs", data=planets,
                whis=[4, 96], width=.6, palette="husl",ax=ax)

    # Add in points to show each observation
    # sns.stripplot(x=ycol, y="runs", data=planets,
    #               size=2, color=".3", linewidth=0)

    # Tweak the visual presentation
    ax.xaxis.grid(True)
    ax.set_xlim(xlims)
    ax.set(ylabel="")
    ax.set_xlabel('$%s/%s_{TRUE}$'%(ycol,ycol),fontsize=18)
    #sns.despine(trim=True, left=True,ax=ax)
