# %% [markdown]
# # Get Mag Evolution Model
#
# info: https://cdcvs.fnal.gov/redmine/projects/des-clusters/wiki/ClustDataVecY3 <br>
# path: /data/des81.b/data/mariaeli/y3_buzz/Buzzard-3_v2.0_Y3a_mastercat/

# %%
import matplotlib.pyplot as plt
import numpy as np

from astropy.table import Table, vstack
from astropy.io.fits import getdata

import pandas as pd

import esutil

# %%
import h5py
import glob
# Out:
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## BCG Mag Cut

# %%
root = '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/tiles/'
files= glob.glob(root+'buzzard_*')

# %% [markdown]
# ## Abs. Mag Cut

# %%
out = 'buzzrd_Mi_19.5.txt'
mag_vec = np.genfromtxt(out,delimiter=',')

# %%
data = []
for i in range(5):
    df = pd.read_hdf(files[i],key='members')
    data.append(df)

# %%
df = data[0]
for d in data[1:]:
    df.append(d)

# %%
df.head()
# Out:
#    hpix_16384    haloid  coadd_object_id        ra        dec     rhalo  \
# 0  1074133747   7940756     105000001471  1.977341 -38.080811  1.909971
# 1  1074133749         0     105004153708  1.985661 -38.076233  0.000000
# 2  1074133750  19116953     105013156325  1.978558 -38.076572  4.140540
# 3  1074133750   8283994     105000980423  1.981301 -38.076092  8.039637
# 4  1074133751  18176597     105012060824  1.984393 -38.072361  0.854540
#
#        mag_g      mag_r      mag_i      mag_z  mag_err_g  mag_err_r  \
# 0  19.160030  17.990568  17.563604  17.277460   0.006355   0.004226
# 1  24.548691  24.652481  23.909668  23.242100   0.169862   0.256099
# 2  26.068653  24.417418  23.533007  23.446873   0.684847   0.207507
# 3  22.037966  21.386761  20.998957  20.825924   0.028024   0.023516
# 4  24.847569  24.000124  23.321745  22.631168   0.220685   0.144426
#
#    mag_err_i  mag_err_z         z  z_mean_bpz  z_mean_dnf  z_sigma_dnf  \
# 0   0.004518   0.005430  0.196694    0.391313    0.192429     0.009948
# 1   0.197410   0.176102  1.515478    1.194697    0.000000     0.000000
# 2   0.143369   0.216710  0.792396    0.678668    0.000000     0.000000
# 3   0.025011   0.031882  0.251321    0.488368    0.179934     0.131536
# 4   0.122426   0.106916  0.636770    1.067770    0.000000     0.000000
#
#      index  tile
# 0  6004643    16
# 1  6004653    16
# 2  6004656    16
# 3  6004658    16
# 4  6004660    16

# %%
root = '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/truthSample/amagLimited/input/'
files= glob.glob(root+'buzzard_*')

# %%
files[0]
# Out:
# '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/truthSample/amagLimited/input/buzzard_v2.0.0_00000.hdf5'

# %%
data = []
for i in range(5):
    df = pd.read_hdf(files[i],key='members')
    data.append(df)

# %%
df = data[0]
for d in data[1:]:
    df.append(d)

# %%
centrals = np.array(df['is_central'][:])

# %%
ar = np.array(df['Mag_true_i_des_z01'][centrals])+5*np.log10(0.7)
mr = np.array(df['mag_i_lsst'][centrals])
ztr= np.array(df['redshift'][centrals])

# %%
plt.scatter(ztr, ar,s=5,alpha=0.3)
plt.xlim(0.,1.)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## Load - Get Absolute Mag Cut

# %%
root = '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/truthSample/amagLimited/input/'
files= glob.glob(root+'buzzard_*')

# %%
files[0]
# Out:
# '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/truthSample/amagLimited/input/buzzard_v2.0.0_00000.hdf5'

# %%
data = []
for i in range(5):
    df = pd.read_hdf(files[i],key='members')
    data.append(df)

# %%
df = data[0]
for d in data[1:]:
    df.append(d)

# %%
ar = np.array(df['Mag_true_i_des_z01'][:])+5*np.log10(0.7)
mr = np.array(df['mag_i_lsst'][:])
ztr= np.array(df['redshift'][:])

# %%
z_min, z_max = 0.075, 1.05
w, = np.where((ar<=-19.475)&(ar>=-19.525)&(ztr<=z_max)&(ztr>=z_min))

# %%
w
# Out:
# array([   6877,    7065,    7240, ..., 2786470, 2786492, 2786603])

# %%
def get_bins(xbins,x):
    indices = []
    xmed    = 0.5*(xbins[1:]+xbins[:-1])
    for xl,xh in zip(xbins[:-1],zbins[1:]):
        w, = np.where((x>=xl)&(x<=xh))
        indices.append(w)
    return indices, xmed

# %%
#zbins = np.percentile(ztr[w],np.linspace(0,100,31))
dx = 0.025
zbins = np.arange(z_min,z_max+dx/2,dx)

keys, xmed = get_bins(zbins,ztr[w])

# %%
def get_percentile(x,y,xbins,alpha=10):
    keys, xmed = get_bins(xbins,x)
    xmean = np.array([np.median(y[ix]) for ix in keys])
    xup = np.array([np.percentile(y[ix],100-alpha) for ix in keys])
    xlo = np.array([np.percentile(y[ix],alpha) for ix in keys])
    return xmed, xmean, xup, xlo

# %%
zmed, mr_mean, mr_up, mr_lo = get_percentile(ztr[w],mr[w],zbins,alpha=5)

# %%
plt.scatter(ztr[::10],mr[::10],s=10,alpha=0.2)
plt.scatter(ztr[w],mr[w],s=10,alpha=0.2)
plt.plot(zmed,mr_up,'k--')
plt.plot(zmed,mr_lo,'r--')

plt.xlim(0.,z_max)
# Out:
# (0.0, 1.05)

# %%
from scipy.interpolate import interp1d

# %%
mag_max = interp1d(zmed,mr_up,fill_value='extrapolate')

# %%
mr_95 = mag_max(ztr)
cut,  = np.where((mr<=mr_95)&(ztr>z_min)&(ztr<z_max))

# %%
#plt.scatter(ztr[::10],ar[::10],s=10,alpha=0.2)
zmed, ar_mean,ar_up, ar_lo = get_percentile(ztr[cut],ar[cut],zbins,alpha=5)
plt.scatter(ztr[cut],ar[cut],s=1,alpha=0.2)
plt.plot(zmed,ar_up,'k--',lw=3)
plt.plot([0.05,1.],[-19.5,-19.5],'r--')

# %%
def get_fraction(z,mag,amag,zbins):
    keys, xmed = get_bins(zbins,z)
    mr_max = mag_max(z)
    fraction = np.array([1.*np.count_nonzero(mag[ix]<=mr_max[ix])/ix.size for ix in keys])
    return xmed, fraction

# %%
cut2,  = np.where((ar<=-19.5)&(ztr>z_min)&(ztr<z_max))

_, frac= get_fraction(ztr[cut2],mr[cut2],ar[cut2],zbins)

# %%
plt.plot(xmed,frac)

# %% [markdown]
# ### The selection is complete within 0.5% but not pure.

# %%
mr_up
# Out:
# array([19.48577191, 19.87111425, 20.48065573, 20.79183874, 21.18454939,
#        21.48603595, 21.77517008, 22.07318867, 22.31309859, 22.49145737,
#        22.74812024, 22.90448296, 23.08282876, 23.29731855, 23.45908275,
#        23.60340373, 23.7566778 , 23.88366601, 24.06347026, 24.17650932,
#        24.29529046, 24.42395763, 24.56187675, 24.68268679, 24.84567234,
#        24.94655189, 25.05216395, 25.24356756, 25.33555804, 25.50919799,
#        25.55914974, 25.60802144, 25.81305951, 25.79194327, 25.99862985,
#        26.11568487, 26.22058358, 26.35567348, 26.50870654])

# %%
xmed
# Out:
# array([0.0875, 0.1125, 0.1375, 0.1625, 0.1875, 0.2125, 0.2375, 0.2625,
#        0.2875, 0.3125, 0.3375, 0.3625, 0.3875, 0.4125, 0.4375, 0.4625,
#        0.4875, 0.5125, 0.5375, 0.5625, 0.5875, 0.6125, 0.6375, 0.6625,
#        0.6875, 0.7125, 0.7375, 0.7625, 0.7875, 0.8125, 0.8375, 0.8625,
#        0.8875, 0.9125, 0.9375, 0.9625, 0.9875, 1.0125, 1.0375])

# %%
out = 'buzzrd_Mi_19.5.txt'

f = open(out,'w')
f.write('##buzzard v2.0 truth table, galaxies within Mi<=-19.5 selected\n')
f.write('##atention: the mi is the lsst i-band\n')
f.write('##z,mi\n')
for zi, mi in zip(xmed,mr_up):
    f.write('%.3f, %.3f\n'%(zi,mi))
f.close()

# %%
out = 'buzzrd_Mi_19.5.txt'
mag_vec = np.genfromtxt(out,delimiter=',')
# Out:
# array([[ 0.087, 19.486],
#        [ 0.113, 19.871],
#        [ 0.138, 20.481],
#        [ 0.163, 20.792],
#        [ 0.188, 21.185],
#        [ 0.213, 21.486],
#        [ 0.238, 21.775],
#        [ 0.263, 22.073],
#        [ 0.288, 22.313],
#        [ 0.313, 22.491],
#        [ 0.338, 22.748],
#        [ 0.363, 22.904],
#        [ 0.388, 23.083],
#        [ 0.413, 23.297],
#        [ 0.438, 23.459],
#        [ 0.463, 23.603],
#        [ 0.488, 23.757],
#        [ 0.513, 23.884],
#        [ 0.538, 24.063],
#        [ 0.563, 24.177],
#        [ 0.588, 24.295],
#        [ 0.613, 24.424],
#        [ 0.638, 24.562],
#        [ 0.663, 24.683],
#        [ 0.688, 24.846],
#        [ 0.713, 24.947],
#        [ 0.738, 25.052],
#        [ 0.763, 25.244],
#        [ 0.788, 25.336],
#        [ 0.813, 25.509],
#        [ 0.838, 25.559],
#        [ 0.863, 25.608],
#        [ 0.888, 25.813],
#        [ 0.913, 25.792],
#        [ 0.938, 25.999],
#        [ 0.963, 26.116],
#        [ 0.988, 26.221],
#        [ 1.013, 26.356],
#        [ 1.038, 26.509]])

# %%
# hf = h5py.File(files[0],'r')
# ar = hf['members/main/Mr'][:]#+5*np.log10(0.7)
# mag= hf['members/main/mag'][:]
# ztr= hf['members/main/z_true'][:]
# zcls=hf['members/main/redshift'][:]
# hf.close()

# %%
plt.scatter(ztr,ar,s=10,alpha=0.2)
#plt.axvline(1.,color='k',ls='--')
#plt.axhline(-19.,color='k',ls='--')

# %%
zmin, zmax = 0.5,0.8
ar_min = -19.

# %%
cut, = np.where((zcls>=zmin)&(zcls<=zmax))
_    = plt.hist(ar[cut],bins=np.linspace(-25.,-20.,31))
#plt.yscale('log')
