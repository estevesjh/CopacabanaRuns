# %% [markdown]
# # Copacabana Runs on Buzzard v2.0
#
# This notebook has some of my runs on the Buzzard v2.0 y3 catalog.

# %% [markdown]
# ## Import Packages

# %%
import sys
sys.path.append('/home/s1/jesteves/git/ccopa/python')

from main import copacabana
from make_input_files.make_photoz_pz import generate_photoz_models
# Out:
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# #### Starting Copa

# %%
root = '/home/s1/jesteves/git/buzzardAnalysis/mainAnalysis/'
cfg  = root+'config_buzzard_rm_v2.yaml'

copa = copacabana(cfg,dataset='buzzard_v2')
# Out:
# master file:
#  /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00000.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00256.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00257.hdf5
# /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00260.hdf5
# outdir: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/
# tile path: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles

# %% [markdown]
# ## Run BMA

# %%
##### Atention: this cell takes more than 6 hours to run. It only needs to be run one time.

#copa.run_bma_healpix(nCores=60,overwrite=False)

# %%
import glob

outfiles = glob.glob('/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/temp_file/?????/input_*')

# %%
# import os

# for infile in outfiles:
#     os.remove(infile)

# %%
len(outfiles)
# Out:
# 512

# %% [markdown]
# ## Run Copa

# %% [markdown]
# #### 1. Gaussian, R200, 02Lstar

# %%
## setup 
copa.kwargs['r_aper_model'] = 'r200'
copa.kwargs['mag_selection']= '02Lstar'

# %%
## runs
pz_files = ['gauss001','gauss003','gauss005']
z_widths = [0.01,0.03,0.05]

runs = ['%s_%s_%s'%(pz,'r200','02Lstar') for pz in pz_files]

# %%
runs
# Out:
# ['gauss001_r200_02Lstar', 'gauss003_r200_02Lstar', 'gauss005_r200_02Lstar']

# %%
for run, zfile, zw in zip(runs,pz_files,z_widths):
    print(5*'---')
    print('run     : %s'%run)
    print('zfile   : %s'%zfile)
    print('zwindow : %.2f'%zw)
    
    copa.kwargs['z_window'] = zw
    copa.run_copa_healpix(run,   pz_file=zfile, nCores=60)
    copa.compute_muStar(  run, overwrite=True)
    print(5*'---')
    print('\n')
# Out:
# run     : gauss001_r200_02Lstar
# zfile   : gauss001
# zwindow : 0.01
#
# Starting Copa
# run gauss001_r200_02Lstar
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00000.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2164589
# cut:  1117504
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00000/gauss001_r200_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00256.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2791169
# cut:  1540789
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00256/gauss001_r200_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00257.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3708874
# cut:  2029006
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00257/gauss001_r200_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00260.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3019411
# cut:  1664271
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00260/gauss001_r200_02Lstar_copa_test_gal.fits
# copa parallel process
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# Computing PDFs
#
# -> Radial Distribution
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:485: RuntimeWarning: invalid value encountered in divide
#   return ng/norm
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:512: RuntimeWarning: divide by zero encountered in double_scalars
#   prior = 1 - (nb*area/np.sum(probz))
# Geting Redshift Window
# Computing Galaxy Density
# -> Redshift Distribution
# Computing R200
# -> Radial Distribution
#
# Computing PDFs
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:512: RuntimeWarning: divide by zero encountered in double_scalars
#   prior = 1 - (nb*area/np.sum(probz))
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:485: RuntimeWarning: invalid value encountered in divide
#   return ng/norm
# -> Color Distribution
# -> Redshift Distribution
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# Computing PDFs
#
# -> Radial Distribution
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# Computing PDFs
#
# -> Radial Distribution
# -> Color Distribution
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:485: RuntimeWarning: invalid value encountered in divide
#   return ng/norm
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:512: RuntimeWarning: divide by zero encountered in double_scalars
#   prior = 1 - (nb*area/np.sum(probz))
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:485: RuntimeWarning: invalid value encountered in divide
#   return ng/norm
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:512: RuntimeWarning: divide by zero encountered in double_scalars
#   prior = 1 - (nb*area/np.sum(probz))
# -> Redshift Distribution
# -> Redshift Distribution
# -> Mag Distribution
# --> Getting truth distributions
# -> Color Distribution
# -> Color Distribution
# Compute MaskFraction and Norm
# norm less than zero: -0.33216224955766654
# norm less than zero: -2.0201670335435074
# norm less than zero: -0.12727919355918077
# norm less than zero: -1.87306677406196
# norm less than zero: -1.7641144827875022
# norm less than zero: -1.8213208687271352
# norm less than zero: -0.6060829510279436
# norm less than zero: -0.5274325761443477
# norm less than zero: -0.2685399593630418
# norm less than zero: -0.6594037674448374
# norm less than zero: -0.14735845409205686
# norm less than zero: -0.08924034175685237
# norm less than zero: -0.09832419772870062
# norm less than zero: -0.3000259226980206
# norm less than zero: -0.7544096397835806
# norm less than zero: -1.4242155798501388
# norm less than zero: -0.9158604139659446
# norm less than zero: -1.1113164630034962
# norm less than zero: -0.5971607515011113
# norm less than zero: -0.36857977337410297
# norm less than zero: -0.9791010596686888
# norm less than zero: -0.14496063134467777
#
#  Compute Probabilities
# -> Mag Distribution
# --> Getting truth distributions
# alpha,beta: 7.47 ,0.46
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:265: RuntimeWarning: invalid value encountered in divide
#   return prod/(norm+eps)
# alpha,beta: 8.06 ,0.61
# alpha,beta: 2.28 ,0.44
# alpha,beta: 8.96 ,2.40
# alpha,beta: 4.40 ,0.90
# alpha,beta: 3.78 ,2.32
# alpha,beta: 3.03 ,1.52
# alpha,beta: 3.18 ,2.43
# alpha,beta: 6.52 ,0.79
# alpha,beta: 6.35 ,2.47
# alpha,beta: 12.66 ,2.71
# alpha,beta: 9.44 ,2.04
# alpha,beta: 6.28 ,2.33
# alpha,beta: 11.09 ,2.67
# alpha,beta: 10.49 ,1.80
# alpha,beta: 6.90 ,2.84
# alpha,beta: 5.15 ,1.85
# alpha,beta: 3.18 ,2.13
# alpha,beta: 5.60 ,0.96
# alpha,beta: 4.12 ,2.22
# alpha,beta: 6.70 ,1.49
# alpha,beta: 3.57 ,2.75
# alpha,beta: 11.35 ,3.45
# alpha,beta: 7.24 ,1.73
# alpha,beta: 10.38 ,2.15
# alpha,beta: 4.92 ,1.65
# alpha,beta: 5.25 ,2.16
# alpha,beta: 3.38 ,2.08
# alpha,beta: 3.01 ,1.78
# alpha,beta: 1.67 ,2.30
# alpha,beta: 7.92 ,0.82
# alpha,beta: 2.96 ,2.16
# alpha,beta: 5.59 ,2.27
# alpha,beta: 2.89 ,2.29
# alpha,beta: 4.86 ,2.73
# alpha,beta: 7.02 ,2.34
# alpha,beta: 4.82 ,3.12
# alpha,beta: 1.00 ,1.59
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 5.05 ,1.00
# alpha,beta: 2.82 ,1.50
# alpha,beta: 3.35 ,1.43
# alpha,beta: 1.58 ,1.25
# alpha,beta: 2.33 ,1.26
# alpha,beta: 1.21 ,2.00
# alpha,beta: 2.72 ,1.04
# alpha,beta: 8.34 ,0.83
# alpha,beta: 3.37 ,1.51
# alpha,beta: 7.40 ,2.58
# alpha,beta: 2.38 ,2.19
# alpha,beta: 2.56 ,2.38
# alpha,beta: -0.17 ,1.97
# alpha,beta: 8.42 ,0.28
# alpha,beta: 0.41 ,1.84
# alpha,beta: 3.72 ,0.44
# alpha,beta: 3.41 ,1.33
# alpha,beta: 1.14 ,1.20
# alpha,beta: 1.89 ,2.10
# alpha,beta: 4.22 ,1.68
# alpha,beta: 2.22 ,0.65
# alpha,beta: 2.72 ,1.34
# alpha,beta: -0.66 ,1.88
# alpha,beta: -0.06 ,0.86
# alpha,beta: 0.55 ,1.52
# alpha,beta: 0.78 ,0.38
# alpha,beta: -1.42 ,1.19
# alpha,beta: 6.64 ,1.18
# alpha,beta: 0.10 ,1.77
# alpha,beta: 5.78 ,1.86
# alpha,beta: 7.89 ,1.21
# alpha,beta: 3.11 ,0.89
# alpha,beta: 0.43 ,1.26
# alpha,beta: 1.08 ,0.64
# alpha,beta: 0.67 ,1.25
# alpha,beta: 1.03 ,1.69
# alpha,beta: 9.47 ,1.46
# alpha,beta: -1.04 ,1.45
# alpha,beta: -1.01 ,1.27
# alpha,beta: -0.38 ,1.21
# alpha,beta: 4.55 ,1.12
# alpha,beta: 0.59 ,0.46
# alpha,beta: 1.98 ,1.29
# alpha,beta: 2.64 ,2.15
# alpha,beta: 4.58 ,0.71
# alpha,beta: -0.49 ,1.09
# alpha,beta: 2.18 ,1.42
# alpha,beta: 3.98 ,1.16
# alpha,beta: -0.36 ,1.24
# alpha,beta: -0.59 ,1.26
# alpha,beta: 5.59 ,1.74
# alpha,beta: 0.76 ,0.74
# alpha,beta: 4.55 ,1.21
# alpha,beta: 0.31 ,0.82
# alpha,beta: 0.18 ,1.06
# alpha,beta: 5.86 ,1.83
# alpha,beta: 0.47 ,1.42
# alpha,beta: 3.36 ,1.37
# alpha,beta: -0.13 ,0.87
# alpha,beta: 0.98 ,1.41
# alpha,beta: 0.79 ,2.05
# alpha,beta: -0.09 ,1.65
# alpha,beta: 1.71 ,0.86
# alpha,beta: 1.31 ,0.73
# alpha,beta: 5.40 ,0.83
# alpha,beta: 0.20 ,1.48
# alpha,beta: 2.60 ,1.71
# alpha,beta: 0.96 ,1.39
# alpha,beta: 1.18 ,1.48
# alpha,beta: 2.94 ,1.06
# alpha,beta: 0.96 ,2.10
# alpha,beta: 0.04 ,2.15
# alpha,beta: 5.59 ,1.79
# alpha,beta: 3.32 ,1.28
# alpha,beta: 4.33 ,0.84
# alpha,beta: 9.38 ,1.48
# alpha,beta: 8.09 ,0.52
# alpha,beta: 3.42 ,1.17
# alpha,beta: -0.17 ,1.35
# alpha,beta: 0.16 ,1.61
# alpha,beta: 3.85 ,1.45
# alpha,beta: 4.17 ,0.80
# alpha,beta: 5.96 ,0.90
# alpha,beta: 9.43 ,2.35
# alpha,beta: -0.53 ,0.44
# alpha,beta: 2.97 ,1.12
# alpha,beta: 0.46 ,0.65
# alpha,beta: 2.90 ,0.97
# alpha,beta: 2.18 ,1.28
# alpha,beta: 1.97 ,0.58
# alpha,beta: 3.62 ,1.43
# alpha,beta: -0.34 ,1.22
# alpha,beta: -0.95 ,1.88
# alpha,beta: 0.70 ,0.41
# alpha,beta: -0.58 ,1.08
# alpha,beta: 0.95 ,0.54
# alpha,beta: 3.53 ,1.43
# alpha,beta: 0.04 ,1.01
# alpha,beta: 1.08 ,0.90
# alpha,beta: -1.06 ,0.89
# alpha,beta: 5.94 ,1.07
# alpha,beta: 2.06 ,0.71
# alpha,beta: 0.19 ,1.26
# alpha,beta: 0.68 ,0.98
# alpha,beta: 1.04 ,0.68
# alpha,beta: 2.76 ,0.82
# alpha,beta: 0.22 ,0.91
# alpha,beta: 1.84 ,0.93
# alpha,beta: -0.58 ,1.38
# alpha,beta: 6.16 ,1.10
# alpha,beta: 1.31 ,0.52
# alpha,beta: -0.66 ,0.55
# alpha,beta: 0.58 ,1.20
# alpha,beta: 1.62 ,0.36
# alpha,beta: 3.40 ,0.84
# alpha,beta: 4.56 ,1.20
# alpha,beta: 8.20 ,1.07
# alpha,beta: 1.54 ,0.61
# alpha,beta: 0.12 ,1.11
# alpha,beta: 1.23 ,0.63
# alpha,beta: 2.61 ,1.18
# alpha,beta: 3.98 ,0.94
# alpha,beta: -1.34 ,1.12
# alpha,beta: 4.71 ,1.35
# alpha,beta: 11.01 ,2.41
# alpha,beta: 3.54 ,2.03
# alpha,beta: 1.94 ,2.23
# alpha,beta: 6.55 ,1.34
# alpha,beta: 1.68 ,1.12
# alpha,beta: 2.60 ,2.16
# alpha,beta: 2.02 ,0.90
# alpha,beta: 3.96 ,0.43
# alpha,beta: 4.96 ,1.58
# alpha,beta: 10.42 ,0.89
# alpha,beta: 11.38 ,1.99
# alpha,beta: 3.60 ,1.42
# alpha,beta: 3.68 ,1.05
# alpha,beta: 9.10 ,1.19
# alpha,beta: 11.56 ,1.70
# alpha,beta: -0.23 ,1.21
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# -> Mag Distribution
# --> Getting truth distributions
# Compute MaskFraction and Norm
# norm less than zero: -1.006402141796945
# norm less than zero: -3.370542388744322
# end!
# norm less than zero: -1.1891008539069077
# norm less than zero: -0.9109893267143275
# norm less than zero: -1.5946200293773953
# norm less than zero: -0.5717861726807362
# norm less than zero: -1.62519223748325
# norm less than zero: -2.1251959895626604
# norm less than zero: -0.343285585646986
# norm less than zero: -1.0942078904429295
# norm less than zero: -0.4353491144249964
# norm less than zero: -0.5669780892040415
# norm less than zero: -1.9192945665035877
# norm less than zero: -2.040175638044485
# norm less than zero: -0.1112229110726608
# norm less than zero: -0.5476970166117805
# norm less than zero: -0.32867413089534775
# norm less than zero: -0.9369182928163741
# norm less than zero: -1.2373351982614904
# norm less than zero: -0.9625396428660781
# norm less than zero: -1.8448379282052454
# norm less than zero: -0.5596555361246802
# norm less than zero: -0.05445004563129738
# norm less than zero: -0.5627602875453237
# norm less than zero: -0.004176256859608546
# norm less than zero: -0.6060608840417423
# norm less than zero: -0.5016081449243882
#
#  Compute Probabilities
# alpha,beta: 7.82 ,1.35
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 4.45 ,0.85
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:265: RuntimeWarning: invalid value encountered in divide
#   return prod/(norm+eps)
# alpha,beta: 8.23 ,1.49
# alpha,beta: 5.73 ,0.91
# alpha,beta: 4.36 ,1.30
# alpha,beta: 3.66 ,1.37
# alpha,beta: 4.18 ,1.92
# alpha,beta: 6.26 ,0.90
# alpha,beta: 1.37 ,0.72
# alpha,beta: 9.97 ,0.83
# alpha,beta: 6.33 ,0.58
# alpha,beta: 10.06 ,1.62
# alpha,beta: 14.06 ,1.82
# alpha,beta: 7.95 ,2.36
# alpha,beta: 7.44 ,1.41
# alpha,beta: 4.35 ,1.64
# alpha,beta: 5.81 ,2.25
# alpha,beta: 5.98 ,2.25
# alpha,beta: 4.48 ,0.61
# alpha,beta: 5.54 ,1.87
# alpha,beta: 7.96 ,1.28
# alpha,beta: 6.66 ,2.00
# alpha,beta: 8.32 ,0.88
# alpha,beta: -0.40 ,1.02
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 4.33 ,1.77
# alpha,beta: 16.59 ,1.65
# alpha,beta: 5.69 ,1.89
# alpha,beta: 7.00 ,1.91
# alpha,beta: 7.34 ,2.04
# alpha,beta: 7.79 ,1.79
# alpha,beta: 6.17 ,2.22
# alpha,beta: 8.46 ,2.20
# alpha,beta: 4.72 ,1.68
# alpha,beta: 6.40 ,1.57
# alpha,beta: 1.03 ,1.74
# alpha,beta: 9.30 ,1.56
# alpha,beta: 5.66 ,1.90
# alpha,beta: 5.09 ,2.05
# alpha,beta: 5.92 ,2.47
# alpha,beta: 10.57 ,2.66
# alpha,beta: 7.71 ,1.80
# alpha,beta: 3.45 ,2.41
# alpha,beta: 0.52 ,1.68
# alpha,beta: 6.68 ,2.07
# alpha,beta: 2.53 ,2.06
# alpha,beta: 2.28 ,1.76
# alpha,beta: 12.18 ,2.33
# alpha,beta: 2.72 ,2.27
# alpha,beta: 1.29 ,0.24
# alpha,beta: 11.58 ,0.97
# alpha,beta: 14.16 ,1.36
# alpha,beta: 12.25 ,1.51
# alpha,beta: 6.38 ,1.74
# alpha,beta: 8.53 ,3.77
# alpha,beta: 2.76 ,2.06
# alpha,beta: 7.28 ,3.18
# alpha,beta: -1.06 ,2.40
# alpha,beta: 2.78 ,2.56
# alpha,beta: 3.66 ,1.58
# alpha,beta: 2.16 ,1.91
# alpha,beta: 3.07 ,3.00
# alpha,beta: 3.58 ,1.15
# alpha,beta: -0.79 ,2.59
# alpha,beta: 2.53 ,1.05
# alpha,beta: 6.22 ,2.18
# alpha,beta: 4.46 ,1.32
# alpha,beta: 1.34 ,2.03
# alpha,beta: 4.39 ,1.77
# alpha,beta: 5.63 ,1.85
# alpha,beta: 4.40 ,2.57
# alpha,beta: -1.09 ,0.91
# alpha,beta: 2.38 ,1.45
# alpha,beta: 3.90 ,3.08
# alpha,beta: 0.82 ,2.71
# alpha,beta: 9.95 ,1.68
# alpha,beta: -1.20 ,2.50
# alpha,beta: 5.23 ,3.08
# alpha,beta: -0.37 ,3.48
# alpha,beta: -1.27 ,3.05
# alpha,beta: 2.20 ,2.98
# alpha,beta: 0.31 ,2.39
# alpha,beta: 4.43 ,1.63
# alpha,beta: 7.53 ,1.53
# alpha,beta: 1.93 ,2.25
# alpha,beta: 2.28 ,1.61
# alpha,beta: 5.48 ,1.87
# alpha,beta: 1.83 ,2.61
# alpha,beta: 4.85 ,1.98
# alpha,beta: 11.21 ,2.78
# alpha,beta: 1.73 ,1.74
# alpha,beta: 6.42 ,2.58
# alpha,beta: 0.61 ,2.09
# alpha,beta: 1.02 ,1.59
# alpha,beta: 2.16 ,1.38
# alpha,beta: 2.66 ,2.29
# alpha,beta: 0.56 ,3.04
# alpha,beta: 1.00 ,2.28
# alpha,beta: 2.90 ,1.55
# alpha,beta: -0.79 ,2.50
# alpha,beta: -0.38 ,2.03
# alpha,beta: 4.00 ,1.17
# alpha,beta: 6.44 ,2.32
# alpha,beta: 4.10 ,1.90
# alpha,beta: 10.42 ,1.77
# alpha,beta: 3.12 ,1.83
# alpha,beta: 6.47 ,2.49
# alpha,beta: 5.23 ,1.45
# alpha,beta: 2.24 ,1.57
# alpha,beta: -1.07 ,1.87
# alpha,beta: 7.85 ,1.27
# alpha,beta: 1.22 ,0.77
# alpha,beta: 3.07 ,1.64
# alpha,beta: 7.04 ,2.09
# alpha,beta: 7.56 ,1.93
# alpha,beta: 3.62 ,0.64
# alpha,beta: 8.36 ,1.68
# alpha,beta: 0.91 ,1.96
# alpha,beta: 4.35 ,0.52
# alpha,beta: -0.47 ,0.39
# alpha,beta: 7.35 ,1.94
# alpha,beta: 1.02 ,2.08
# alpha,beta: 1.96 ,0.54
# alpha,beta: 1.66 ,0.49
# alpha,beta: 4.63 ,2.44
# alpha,beta: 8.54 ,1.77
# alpha,beta: -0.90 ,0.75
# alpha,beta: 8.19 ,1.44
# alpha,beta: 3.42 ,1.26
# alpha,beta: 2.29 ,2.65
# alpha,beta: 3.39 ,1.62
# alpha,beta: 3.04 ,1.26
# alpha,beta: 3.52 ,2.16
# alpha,beta: 4.00 ,2.31
# alpha,beta: 2.62 ,1.59
# alpha,beta: 4.67 ,1.80
# alpha,beta: 5.27 ,2.27
# alpha,beta: -1.08 ,2.12
# alpha,beta: 2.85 ,2.19
# alpha,beta: 3.05 ,0.87
# alpha,beta: 1.36 ,1.54
# alpha,beta: 3.44 ,0.91
# alpha,beta: 2.83 ,0.50
# alpha,beta: 0.12 ,0.86
# alpha,beta: 0.86 ,2.29
# alpha,beta: 2.51 ,2.51
# alpha,beta: 2.94 ,0.65
# alpha,beta: 1.83 ,1.25
# alpha,beta: 3.70 ,2.08
# alpha,beta: -2.21 ,2.52
# alpha,beta: 2.46 ,1.19
# alpha,beta: 7.26 ,1.51
# alpha,beta: 4.81 ,1.24
# alpha,beta: 4.22 ,1.61
# alpha,beta: 0.46 ,2.35
# alpha,beta: -0.16 ,1.08
# alpha,beta: 1.75 ,1.22
# alpha,beta: 6.25 ,2.38
# alpha,beta: 0.33 ,0.47
# alpha,beta: 1.88 ,2.18
# alpha,beta: 5.30 ,1.14
# alpha,beta: 1.13 ,2.55
# alpha,beta: -0.52 ,1.26
# alpha,beta: 2.28 ,1.24
# alpha,beta: -0.38 ,1.86
# alpha,beta: 0.14 ,0.55
# alpha,beta: 8.62 ,1.91
# alpha,beta: 8.90 ,2.37
# alpha,beta: 4.14 ,1.07
# alpha,beta: 1.46 ,0.59
# alpha,beta: 2.63 ,1.25
# alpha,beta: 1.81 ,1.64
# alpha,beta: 7.03 ,2.23
# alpha,beta: 3.96 ,1.77
# alpha,beta: 0.11 ,2.43
# alpha,beta: 4.21 ,1.71
# alpha,beta: 1.05 ,1.44
# alpha,beta: 3.47 ,1.09
# alpha,beta: 1.51 ,1.71
# alpha,beta: 1.87 ,1.33
# alpha,beta: -1.51 ,2.17
# alpha,beta: 2.14 ,1.37
# alpha,beta: 3.03 ,1.74
# alpha,beta: 11.63 ,1.87
# alpha,beta: 0.85 ,1.11
# alpha,beta: -1.81 ,1.51
# alpha,beta: 1.85 ,1.35
# alpha,beta: 0.61 ,1.30
# alpha,beta: 2.24 ,1.48
# alpha,beta: 4.05 ,1.00
# alpha,beta: 2.61 ,2.36
# alpha,beta: 5.68 ,2.33
# alpha,beta: 2.73 ,1.32
# alpha,beta: -0.75 ,1.08
# alpha,beta: 5.32 ,1.04
# alpha,beta: 0.83 ,1.24
# alpha,beta: -1.87 ,2.56
# alpha,beta: -0.62 ,0.52
# alpha,beta: 1.56 ,1.08
# alpha,beta: -0.06 ,0.97
# alpha,beta: -0.90 ,0.75
# alpha,beta: 0.75 ,1.41
# alpha,beta: 0.42 ,0.96
# alpha,beta: -0.01 ,1.27
# alpha,beta: 2.04 ,0.89
# alpha,beta: -0.93 ,0.78
# alpha,beta: 8.67 ,0.53
# alpha,beta: 2.00 ,0.61
# alpha,beta: -0.73 ,0.61
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# -> Mag Distribution
# --> Getting truth distributions
# Compute MaskFraction and Norm
# norm less than zero: -1.466295007828424
# norm less than zero: -1.734307240844223
# norm less than zero: -0.17592749544609593
# norm less than zero: -0.5654752999577253
# norm less than zero: -0.6757902155889305
# norm less than zero: -1.1560627562882613
# norm less than zero: -0.3018802973632227
# norm less than zero: -0.3209557226573792
# norm less than zero: -0.5409369912852149
# norm less than zero: -0.42674096960167895
# norm less than zero: -0.8581165147074865
# norm less than zero: -1.6517057327222224
# norm less than zero: -0.09550986648313715
#
#  Compute Probabilities
# alpha,beta: 12.09 ,2.47
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 9.62 ,2.38
# alpha,beta: 6.52 ,2.06
# alpha,beta: 12.61 ,1.63
# alpha,beta: 9.75 ,1.75
# alpha,beta: 12.56 ,1.46
# alpha,beta: 9.48 ,0.70
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:265: RuntimeWarning: invalid value encountered in divide
#   return prod/(norm+eps)
# alpha,beta: 6.77 ,1.70
# alpha,beta: 10.48 ,1.16
# alpha,beta: 2.67 ,1.22
# alpha,beta: 6.99 ,1.15
# alpha,beta: 9.33 ,1.79
# alpha,beta: 9.59 ,1.82
# alpha,beta: 7.91 ,1.31
# alpha,beta: 8.00 ,1.28
# alpha,beta: 6.16 ,1.35
# alpha,beta: 2.28 ,1.13
# alpha,beta: 6.88 ,1.58
# alpha,beta: 5.75 ,1.76
# alpha,beta: 5.70 ,0.62
# alpha,beta: 4.15 ,0.79
# alpha,beta: 9.23 ,2.52
# alpha,beta: 4.18 ,1.63
# alpha,beta: 6.01 ,1.17
# alpha,beta: 2.95 ,1.49
# alpha,beta: 8.68 ,1.75
# alpha,beta: 6.25 ,1.70
# alpha,beta: 4.58 ,2.09
# alpha,beta: 4.68 ,1.63
# alpha,beta: 2.68 ,1.24
# alpha,beta: 6.55 ,1.59
# alpha,beta: 5.74 ,1.18
# alpha,beta: 2.84 ,1.16
# alpha,beta: 11.07 ,1.66
# alpha,beta: 6.74 ,0.85
# alpha,beta: 5.42 ,1.41
# alpha,beta: 8.20 ,2.28
# alpha,beta: 7.28 ,2.20
# alpha,beta: 6.54 ,1.14
# alpha,beta: 7.30 ,2.40
# alpha,beta: 10.17 ,3.02
# alpha,beta: 6.13 ,2.34
# alpha,beta: 7.50 ,2.00
# alpha,beta: 6.32 ,2.27
# alpha,beta: 4.97 ,1.93
# alpha,beta: 7.59 ,1.65
# alpha,beta: 8.71 ,1.68
# alpha,beta: 6.96 ,3.27
# alpha,beta: 4.30 ,1.94
# alpha,beta: 4.01 ,0.93
# alpha,beta: 8.31 ,0.97
# alpha,beta: 6.16 ,1.78
# alpha,beta: 4.78 ,1.81
# alpha,beta: 6.88 ,1.62
# alpha,beta: 7.45 ,2.09
# alpha,beta: 7.51 ,1.89
# alpha,beta: 4.13 ,2.12
# alpha,beta: 3.29 ,2.13
# alpha,beta: 10.09 ,1.83
# alpha,beta: 6.85 ,2.52
# alpha,beta: 7.06 ,1.34
# alpha,beta: 6.44 ,2.06
# alpha,beta: 2.73 ,2.05
# alpha,beta: 5.53 ,2.63
# alpha,beta: 8.83 ,3.13
# alpha,beta: 0.05 ,2.54
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 5.06 ,2.77
# alpha,beta: 0.59 ,1.27
# alpha,beta: 6.20 ,2.47
# alpha,beta: 7.15 ,2.91
# alpha,beta: 3.42 ,2.19
# alpha,beta: 4.25 ,1.50
# alpha,beta: -0.98 ,1.47
# alpha,beta: 7.97 ,2.81
# alpha,beta: 7.58 ,1.69
# alpha,beta: 13.72 ,2.38
# alpha,beta: 4.05 ,1.66
# alpha,beta: 5.76 ,2.08
# alpha,beta: 4.34 ,1.93
# alpha,beta: 6.43 ,4.37
# alpha,beta: 6.87 ,3.77
# alpha,beta: 5.28 ,2.56
# alpha,beta: 5.93 ,4.89
# alpha,beta: 0.87 ,4.07
# alpha,beta: 2.37 ,2.38
# alpha,beta: 8.19 ,2.24
# alpha,beta: 5.53 ,1.62
# alpha,beta: 10.84 ,1.36
# alpha,beta: 0.99 ,2.04
# alpha,beta: 3.89 ,3.38
# alpha,beta: 9.31 ,2.63
# alpha,beta: 1.92 ,1.94
# alpha,beta: 6.09 ,1.76
# alpha,beta: 12.01 ,3.44
# alpha,beta: 1.55 ,1.54
# alpha,beta: 3.86 ,1.86
# alpha,beta: -0.67 ,3.54
# alpha,beta: 6.98 ,2.12
# alpha,beta: 10.25 ,2.26
# alpha,beta: 5.83 ,1.99
# alpha,beta: 2.41 ,2.09
# alpha,beta: 4.63 ,2.40
# alpha,beta: 3.62 ,1.69
# alpha,beta: 2.64 ,2.58
# alpha,beta: 4.78 ,1.36
# alpha,beta: 10.22 ,1.26
# alpha,beta: 8.67 ,1.85
# alpha,beta: 16.13 ,2.39
# alpha,beta: 3.65 ,2.47
# alpha,beta: 4.85 ,2.49
# alpha,beta: 9.67 ,1.92
# alpha,beta: 1.54 ,3.12
# alpha,beta: 2.23 ,2.02
# alpha,beta: 3.03 ,1.45
# alpha,beta: 15.64 ,2.19
# alpha,beta: 4.89 ,1.56
# alpha,beta: -0.20 ,2.81
# alpha,beta: 4.82 ,1.98
# alpha,beta: 5.56 ,1.76
# alpha,beta: 1.47 ,1.16
# alpha,beta: 7.04 ,1.57
# alpha,beta: 0.81 ,3.11
# alpha,beta: 0.26 ,1.52
# alpha,beta: 2.27 ,1.53
# alpha,beta: 0.88 ,2.04
# alpha,beta: -0.47 ,1.55
# alpha,beta: 5.35 ,1.21
# alpha,beta: 2.82 ,1.74
# alpha,beta: 3.27 ,1.77
# alpha,beta: 0.13 ,1.98
# alpha,beta: 0.44 ,2.04
# alpha,beta: 0.73 ,1.40
# alpha,beta: 1.62 ,2.18
# alpha,beta: 0.60 ,2.26
# alpha,beta: 2.96 ,1.52
# alpha,beta: 2.33 ,1.32
# alpha,beta: 8.08 ,1.37
# alpha,beta: 0.57 ,0.72
# alpha,beta: 0.43 ,1.51
# alpha,beta: 5.82 ,1.30
# alpha,beta: 5.35 ,2.70
# alpha,beta: 4.96 ,2.55
# alpha,beta: 4.14 ,1.74
# alpha,beta: 3.08 ,1.32
# alpha,beta: 2.00 ,2.19
# alpha,beta: -0.30 ,1.32
# alpha,beta: 0.66 ,1.74
# alpha,beta: 3.69 ,1.61
# alpha,beta: 0.22 ,1.65
# alpha,beta: 2.41 ,1.33
# alpha,beta: 1.66 ,1.96
# alpha,beta: 3.95 ,1.54
# alpha,beta: 1.24 ,0.66
# alpha,beta: 0.10 ,1.54
# alpha,beta: 4.59 ,1.73
# alpha,beta: 5.32 ,1.26
# alpha,beta: 4.30 ,1.49
# alpha,beta: 5.09 ,1.09
# alpha,beta: 1.91 ,1.51
# alpha,beta: 2.51 ,1.30
# alpha,beta: 2.92 ,1.16
# alpha,beta: -0.89 ,1.39
# alpha,beta: 4.31 ,1.54
# alpha,beta: 1.37 ,2.12
# alpha,beta: -0.18 ,2.09
# alpha,beta: 2.71 ,0.82
# alpha,beta: 3.61 ,1.08
# alpha,beta: 2.75 ,0.73
# alpha,beta: 0.36 ,1.08
# alpha,beta: 0.86 ,1.17
# alpha,beta: 1.13 ,0.96
# alpha,beta: -0.24 ,2.11
# alpha,beta: 1.37 ,1.09
# alpha,beta: 5.07 ,1.26
# alpha,beta: 4.30 ,1.95
# alpha,beta: 8.80 ,1.55
# alpha,beta: 2.12 ,1.18
# alpha,beta: 7.12 ,2.20
# alpha,beta: 0.61 ,0.93
# alpha,beta: 4.52 ,1.42
# alpha,beta: 3.56 ,1.09
# alpha,beta: 0.29 ,2.27
# alpha,beta: 1.08 ,1.59
# alpha,beta: -0.47 ,2.10
# alpha,beta: 0.70 ,2.23
# alpha,beta: 1.68 ,1.10
# alpha,beta: -0.45 ,1.26
# alpha,beta: -1.08 ,0.91
# alpha,beta: 3.49 ,1.67
# alpha,beta: 1.20 ,1.24
# alpha,beta: 2.73 ,1.24
# alpha,beta: -1.83 ,1.53
# alpha,beta: 2.20 ,1.40
# alpha,beta: 1.98 ,1.29
# alpha,beta: 4.96 ,1.28
# alpha,beta: 8.99 ,1.16
# alpha,beta: 3.21 ,1.16
# alpha,beta: 13.45 ,2.19
# alpha,beta: 1.94 ,1.55
# alpha,beta: 1.65 ,1.28
# alpha,beta: 6.30 ,2.62
# alpha,beta: 4.94 ,1.92
# alpha,beta: 1.46 ,1.50
# alpha,beta: 5.70 ,1.54
# alpha,beta: 2.89 ,0.46
# alpha,beta: 2.90 ,2.00
# alpha,beta: 9.99 ,1.02
# alpha,beta: 2.66 ,1.27
# alpha,beta: 0.18 ,1.21
# alpha,beta: 0.85 ,1.92
# alpha,beta: 0.05 ,1.11
# alpha,beta: 1.13 ,1.28
# alpha,beta: 2.92 ,1.70
# alpha,beta: 3.42 ,0.88
# alpha,beta: 0.57 ,1.02
# alpha,beta: 5.43 ,0.87
# alpha,beta: 6.90 ,1.41
# alpha,beta: 1.60 ,2.10
# alpha,beta: 2.12 ,0.83
# alpha,beta: 1.71 ,1.30
# alpha,beta: -0.16 ,1.62
# alpha,beta: 0.96 ,0.62
# end!
# alpha,beta: 1.49 ,1.02
# alpha,beta: 4.35 ,1.40
# alpha,beta: 2.56 ,1.62
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# Compute MaskFraction and Norm
# norm less than zero: -3.115321037163112
# norm less than zero: -1.1019000301419188
# norm less than zero: -1.7329222412993377
# norm less than zero: -1.8586195568256585
# norm less than zero: -10.733472640819782
# norm less than zero: -1.9654139996782627
# norm less than zero: -1.4322647700900724
# norm less than zero: -0.12221150602119735
# norm less than zero: -0.9998675522587824
# norm less than zero: -1.2912438001857254
# norm less than zero: -0.605501932037034
# norm less than zero: -2.305267743617906
# norm less than zero: -0.15979138720251765
# norm less than zero: -1.1735587636312166
# norm less than zero: -0.3278850622667251
# norm less than zero: -0.41601183792097496
# norm less than zero: -0.33936917382903775
# norm less than zero: -0.14214362599018707
# norm less than zero: -1.3052245429382074
# norm less than zero: -0.16391533151316395
# norm less than zero: -0.16871060555048406
# norm less than zero: -0.2708848526709381
# norm less than zero: -0.28489112915561193
#
#  Compute Probabilities
# alpha,beta: 6.12 ,0.58
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:265: RuntimeWarning: invalid value encountered in divide
#   return prod/(norm+eps)
# alpha,beta: 5.08 ,0.41
# alpha,beta: 6.06 ,1.11
# alpha,beta: 5.00 ,1.75
# alpha,beta: 6.36 ,1.98
# alpha,beta: 6.04 ,1.34
# alpha,beta: 4.92 ,0.97
# alpha,beta: 4.85 ,1.83
# alpha,beta: 9.90 ,0.51
# alpha,beta: -0.58 ,1.27
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 6.69 ,1.07
# alpha,beta: 4.41 ,1.36
# end!
# alpha,beta: 9.76 ,0.96
# alpha,beta: 8.01 ,1.81
# alpha,beta: 3.80 ,1.19
# alpha,beta: 8.51 ,1.66
# alpha,beta: 9.80 ,1.40
# alpha,beta: 8.80 ,2.60
# alpha,beta: 7.12 ,2.96
# alpha,beta: 10.84 ,2.15
# alpha,beta: 5.42 ,2.52
# alpha,beta: 8.30 ,1.45
# alpha,beta: 5.98 ,3.22
# alpha,beta: 5.97 ,2.52
# alpha,beta: 6.16 ,1.37
# alpha,beta: 2.50 ,3.88
# alpha,beta: 2.14 ,0.67
# alpha,beta: 6.75 ,1.32
# alpha,beta: 8.43 ,1.64
# alpha,beta: 11.75 ,1.73
# alpha,beta: 8.30 ,2.17
# alpha,beta: 5.76 ,1.61
# alpha,beta: 6.05 ,3.19
# alpha,beta: 6.80 ,1.62
# alpha,beta: 9.29 ,2.20
# alpha,beta: 0.04 ,0.89
# alpha,beta: 6.00 ,1.86
# alpha,beta: 3.62 ,2.34
# alpha,beta: 6.80 ,1.16
# alpha,beta: 6.08 ,1.10
# alpha,beta: 6.17 ,1.73
# alpha,beta: 2.86 ,1.63
# alpha,beta: 2.49 ,2.20
# alpha,beta: 3.37 ,1.28
# alpha,beta: 7.75 ,1.63
# alpha,beta: 7.13 ,1.52
# alpha,beta: 4.27 ,1.57
# alpha,beta: 8.41 ,1.57
# alpha,beta: 2.79 ,0.61
# alpha,beta: 5.74 ,1.14
# alpha,beta: 9.19 ,2.07
# alpha,beta: 10.70 ,1.64
# alpha,beta: 7.87 ,1.83
# alpha,beta: 5.11 ,1.55
# alpha,beta: 3.27 ,1.23
# alpha,beta: 2.03 ,0.40
# alpha,beta: 7.83 ,1.68
# alpha,beta: 7.05 ,2.22
# alpha,beta: 10.50 ,1.15
# alpha,beta: 5.69 ,1.89
# alpha,beta: 7.30 ,2.14
# alpha,beta: 5.68 ,2.95
# alpha,beta: 4.46 ,1.85
# alpha,beta: 13.34 ,2.55
# alpha,beta: 9.12 ,2.39
# alpha,beta: 9.86 ,2.12
# alpha,beta: 2.25 ,1.98
# alpha,beta: 2.59 ,1.85
# alpha,beta: 10.57 ,2.50
# alpha,beta: 2.33 ,2.20
# alpha,beta: 8.26 ,1.56
# alpha,beta: 2.08 ,1.85
# alpha,beta: 10.08 ,2.40
# alpha,beta: 6.69 ,2.01
# alpha,beta: 5.59 ,1.91
# alpha,beta: 5.45 ,2.40
# alpha,beta: 4.03 ,1.63
# alpha,beta: 17.05 ,2.15
# alpha,beta: 7.03 ,2.08
# alpha,beta: 4.85 ,1.42
# alpha,beta: 6.23 ,1.96
# alpha,beta: 2.52 ,1.76
# alpha,beta: 1.55 ,1.96
# alpha,beta: 5.66 ,1.71
# alpha,beta: 3.97 ,2.26
# alpha,beta: 6.78 ,1.93
# alpha,beta: 7.01 ,2.12
# alpha,beta: 2.93 ,2.98
# alpha,beta: 10.88 ,2.96
# alpha,beta: 2.96 ,1.21
# alpha,beta: 2.09 ,1.70
# alpha,beta: 3.13 ,1.48
# alpha,beta: 7.55 ,2.60
# alpha,beta: 3.30 ,2.11
# alpha,beta: 4.49 ,0.96
# alpha,beta: 6.29 ,1.16
# alpha,beta: 0.76 ,1.54
# alpha,beta: 4.54 ,0.86
# alpha,beta: 12.99 ,1.79
# alpha,beta: 5.31 ,2.83
# alpha,beta: 11.19 ,2.58
# alpha,beta: -0.69 ,1.15
# alpha,beta: 2.36 ,0.63
# alpha,beta: 4.81 ,2.27
# alpha,beta: 4.34 ,1.00
# alpha,beta: 5.95 ,2.37
# alpha,beta: 3.27 ,2.85
# alpha,beta: 2.23 ,2.98
# alpha,beta: 13.48 ,3.02
# alpha,beta: 7.82 ,2.61
# alpha,beta: 2.44 ,2.37
# alpha,beta: 8.60 ,1.79
# alpha,beta: -0.59 ,0.68
# alpha,beta: 1.45 ,2.07
# alpha,beta: 2.90 ,1.29
# alpha,beta: 1.50 ,0.74
# alpha,beta: 7.10 ,2.54
# alpha,beta: 5.64 ,2.86
# alpha,beta: 2.96 ,2.36
# alpha,beta: 3.35 ,3.25
# alpha,beta: 1.58 ,3.47
# alpha,beta: 0.84 ,1.92
# alpha,beta: 0.37 ,1.24
# alpha,beta: 13.67 ,3.29
# alpha,beta: 0.59 ,2.03
# alpha,beta: 9.19 ,2.54
# alpha,beta: -1.33 ,2.49
# alpha,beta: 8.08 ,1.88
# alpha,beta: 16.25 ,1.38
# alpha,beta: 8.15 ,2.66
# alpha,beta: 9.81 ,2.44
# alpha,beta: 3.37 ,2.03
# alpha,beta: -1.19 ,1.39
# alpha,beta: 6.86 ,2.54
# alpha,beta: 3.14 ,1.29
# alpha,beta: 6.43 ,2.25
# alpha,beta: 8.03 ,2.46
# alpha,beta: 6.97 ,1.86
# alpha,beta: 4.67 ,2.59
# alpha,beta: 0.55 ,1.33
# alpha,beta: 7.24 ,2.15
# alpha,beta: 0.50 ,1.46
# alpha,beta: 3.99 ,2.27
# alpha,beta: 1.68 ,1.57
# alpha,beta: 10.59 ,1.89
# alpha,beta: 6.72 ,1.82
# alpha,beta: 2.28 ,2.49
# alpha,beta: 6.19 ,2.80
# alpha,beta: 11.02 ,1.92
# alpha,beta: 2.54 ,1.41
# alpha,beta: 2.46 ,1.05
# alpha,beta: 1.36 ,3.13
# alpha,beta: 1.65 ,2.07
# alpha,beta: -1.37 ,2.30
# alpha,beta: 1.13 ,2.01
# alpha,beta: 2.94 ,1.86
# alpha,beta: 9.84 ,2.05
# alpha,beta: -1.83 ,1.53
# alpha,beta: 0.42 ,0.32
# alpha,beta: 5.00 ,1.27
# alpha,beta: 4.03 ,2.18
# alpha,beta: 3.80 ,1.40
# alpha,beta: 0.70 ,1.32
# alpha,beta: 10.87 ,2.14
# alpha,beta: 0.25 ,1.18
# alpha,beta: 3.07 ,0.29
# alpha,beta: -0.16 ,1.33
# alpha,beta: -0.81 ,1.14
# alpha,beta: 1.86 ,0.97
# alpha,beta: 9.68 ,1.26
# alpha,beta: -1.66 ,1.39
# alpha,beta: -0.63 ,1.31
# alpha,beta: 12.19 ,1.45
# alpha,beta: 8.94 ,1.01
# alpha,beta: 0.22 ,1.99
# alpha,beta: 8.50 ,1.91
# alpha,beta: 4.59 ,0.68
# alpha,beta: 2.41 ,1.32
# alpha,beta: 2.98 ,2.13
# alpha,beta: 4.85 ,1.79
# alpha,beta: 5.68 ,0.97
# alpha,beta: 12.68 ,2.07
# alpha,beta: 6.33 ,1.17
# alpha,beta: -0.44 ,1.93
# alpha,beta: 3.89 ,0.77
# alpha,beta: 0.93 ,2.16
# alpha,beta: 6.57 ,1.75
# alpha,beta: 1.40 ,0.85
# alpha,beta: 1.82 ,1.18
# alpha,beta: 3.25 ,1.48
# alpha,beta: 6.39 ,2.34
# alpha,beta: 1.46 ,2.01
# alpha,beta: 3.03 ,2.09
# alpha,beta: 2.24 ,2.30
# alpha,beta: 2.07 ,1.97
# alpha,beta: -0.08 ,1.62
# alpha,beta: 3.88 ,2.35
# alpha,beta: -1.00 ,2.28
# alpha,beta: 5.79 ,1.77
# alpha,beta: 7.62 ,1.53
# alpha,beta: 6.07 ,1.58
# alpha,beta: 2.26 ,2.06
# alpha,beta: 4.17 ,1.84
# alpha,beta: 1.38 ,2.05
# alpha,beta: 4.76 ,1.74
# alpha,beta: 0.11 ,1.39
# alpha,beta: 6.03 ,2.09
# alpha,beta: 3.41 ,1.00
# alpha,beta: 5.10 ,2.40
# alpha,beta: 0.74 ,0.75
# alpha,beta: 10.55 ,2.09
# alpha,beta: 2.90 ,2.80
# alpha,beta: 0.03 ,1.70
# alpha,beta: 3.18 ,2.30
# alpha,beta: 0.23 ,1.42
# alpha,beta: 3.23 ,1.11
# alpha,beta: 2.90 ,1.69
# alpha,beta: 1.40 ,1.56
# alpha,beta: 5.50 ,1.64
# alpha,beta: 6.11 ,0.72
# alpha,beta: 2.59 ,0.90
# alpha,beta: 2.80 ,1.39
# alpha,beta: 5.14 ,1.49
# alpha,beta: 0.26 ,1.58
# alpha,beta: 2.05 ,2.00
# alpha,beta: 4.66 ,0.96
# alpha,beta: 2.47 ,1.13
# alpha,beta: 1.71 ,0.85
# alpha,beta: 8.32 ,2.18
# alpha,beta: 3.22 ,1.61
# alpha,beta: 0.18 ,0.94
# alpha,beta: 8.25 ,1.43
# alpha,beta: 3.04 ,0.89
# alpha,beta: 1.27 ,1.34
# alpha,beta: 0.01 ,0.46
# alpha,beta: 3.37 ,0.90
# alpha,beta: 3.23 ,1.13
# alpha,beta: 2.24 ,1.03
# alpha,beta: 3.19 ,1.85
# alpha,beta: 1.87 ,1.19
# alpha,beta: 2.92 ,1.42
# alpha,beta: -0.17 ,0.65
# alpha,beta: 2.89 ,1.32
# alpha,beta: 0.57 ,1.10
# alpha,beta: 5.15 ,1.20
# alpha,beta: 1.81 ,1.20
# alpha,beta: -0.47 ,1.48
# alpha,beta: 1.10 ,1.25
# alpha,beta: 0.30 ,0.53
# alpha,beta: 1.75 ,0.87
# alpha,beta: 0.50 ,1.04
# alpha,beta: 1.79 ,1.51
# alpha,beta: 1.56 ,1.02
# alpha,beta: 3.03 ,1.05
# alpha,beta: 0.27 ,1.59
# alpha,beta: 3.85 ,0.80
# alpha,beta: -0.24 ,1.08
# alpha,beta: 0.31 ,0.95
# alpha,beta: 1.83 ,0.61
# alpha,beta: 4.41 ,1.10
# alpha,beta: 0.99 ,1.32
# alpha,beta: 3.51 ,0.80
# alpha,beta: 2.58 ,1.34
# alpha,beta: 1.38 ,0.29
# alpha,beta: 0.94 ,1.09
# alpha,beta: -0.21 ,1.57
# alpha,beta: -1.37 ,2.12
# alpha,beta: 5.23 ,1.40
# alpha,beta: -0.22 ,0.88
# alpha,beta: 4.90 ,1.33
# alpha,beta: -0.21 ,1.12
# alpha,beta: 0.67 ,1.03
# alpha,beta: -0.38 ,1.29
# alpha,beta: 7.23 ,0.95
# alpha,beta: 0.77 ,0.63
# alpha,beta: 4.10 ,1.44
# alpha,beta: 1.85 ,1.02
# alpha,beta: 1.18 ,1.31
# alpha,beta: 2.83 ,0.98
# alpha,beta: 6.94 ,1.15
# alpha,beta: 2.52 ,0.80
# alpha,beta: 7.26 ,1.78
# alpha,beta: 4.34 ,1.42
# alpha,beta: 4.01 ,1.35
# alpha,beta: 3.14 ,1.10
# alpha,beta: 0.66 ,1.16
# alpha,beta: 0.51 ,1.03
# alpha,beta: 1.27 ,0.79
# alpha,beta: 1.01 ,1.26
# alpha,beta: 2.56 ,0.67
# alpha,beta: 5.65 ,1.71
# alpha,beta: 7.19 ,0.83
# alpha,beta: 2.68 ,1.08
# alpha,beta: 2.79 ,0.91
# alpha,beta: -0.42 ,1.24
# alpha,beta: 6.01 ,0.72
# alpha,beta: 7.31 ,0.98
# alpha,beta: 4.60 ,0.95
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# end!
# compute ptaken
# Total time: 90.2443521023s
# ---------------
#
#
# run     : gauss003_r200_02Lstar
# zfile   : gauss003
# zwindow : 0.03
#
# Starting Copa
# run gauss003_r200_02Lstar
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00000.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2164589
# cut:  1117449
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00000/gauss003_r200_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00256.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2791169
# cut:  1540729
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00256/gauss003_r200_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00257.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3708874
# cut:  2028915
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00257/gauss003_r200_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00260.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3019411
# cut:  1664190
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00260/gauss003_r200_02Lstar_copa_test_gal.fits
# copa parallel process
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# Computing PDFs
#
# -> Radial Distribution
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# -> Redshift Distribution
# Computing PDFs
#
# -> Radial Distribution
# -> Color Distribution
# -> Redshift Distribution
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# Computing PDFs
#
# -> Radial Distribution
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# Computing PDFs
#
# -> Radial Distribution
# -> Color Distribution
# -> Redshift Distribution
# -> Redshift Distribution
# -> Color Distribution
# -> Color Distribution
# -> Mag Distribution
# --> Getting truth distributions
# Compute MaskFraction and Norm
# norm less than zero: -6.616171507312923
# norm less than zero: -2.3700915143334345
# norm less than zero: -0.5555310121607832
# norm less than zero: -2.749447305936286
# norm less than zero: -0.4394275574296557
# norm less than zero: -0.06449160817658593
# norm less than zero: -0.8998593609481941
# norm less than zero: -3.039240095462957
# norm less than zero: -0.6826252968300441
# norm less than zero: -1.2980596205269967
# norm less than zero: -1.4708697532366737
# norm less than zero: -0.2939205471554141
#
#  Compute Probabilities
# alpha,beta: 9.13 ,1.37
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 15.23 ,2.89
# alpha,beta: 13.71 ,1.67
# alpha,beta: 13.82 ,5.49
# alpha,beta: 7.60 ,3.37
# alpha,beta: 7.33 ,4.12
# alpha,beta: 3.38 ,3.40
# alpha,beta: 9.34 ,5.32
# alpha,beta: 8.11 ,1.68
# alpha,beta: 6.36 ,5.79
# alpha,beta: 13.50 ,5.00
# alpha,beta: 9.86 ,5.26
# alpha,beta: 5.75 ,5.53
# alpha,beta: 10.75 ,5.00
# alpha,beta: 10.10 ,4.94
# alpha,beta: 7.86 ,5.18
# alpha,beta: 7.39 ,4.93
# alpha,beta: 3.76 ,4.47
# alpha,beta: 6.82 ,2.43
# alpha,beta: 2.84 ,4.64
# alpha,beta: 8.38 ,3.40
# alpha,beta: 6.37 ,5.20
# alpha,beta: 12.82 ,5.54
# alpha,beta: 8.32 ,3.67
# alpha,beta: 12.00 ,4.89
# alpha,beta: 3.99 ,3.70
# alpha,beta: 8.15 ,4.70
# alpha,beta: 5.90 ,5.02
# alpha,beta: 7.91 ,4.75
# alpha,beta: 8.07 ,5.33
# alpha,beta: 9.02 ,1.90
# alpha,beta: 3.56 ,5.26
# alpha,beta: 4.66 ,5.96
# alpha,beta: 5.15 ,5.50
# alpha,beta: 3.90 ,5.28
# alpha,beta: 7.66 ,4.56
# alpha,beta: 5.22 ,6.62
# alpha,beta: 0.66 ,3.37
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 9.01 ,2.75
# alpha,beta: 8.67 ,3.99
# alpha,beta: 3.15 ,3.52
# alpha,beta: 3.42 ,4.10
# alpha,beta: 6.10 ,3.76
# alpha,beta: 4.61 ,4.47
# alpha,beta: 5.04 ,3.19
# alpha,beta: 9.85 ,2.00
# alpha,beta: 6.47 ,3.23
# alpha,beta: 7.49 ,5.42
# alpha,beta: 8.60 ,6.29
# alpha,beta: 3.58 ,5.21
# alpha,beta: 3.17 ,5.85
# alpha,beta: 8.75 ,0.85
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:265: RuntimeWarning: invalid value encountered in divide
#   return prod/(norm+eps)
# alpha,beta: 2.88 ,5.30
# alpha,beta: 11.04 ,1.17
# alpha,beta: 3.22 ,3.52
# alpha,beta: 5.18 ,3.33
# alpha,beta: 1.23 ,4.53
# alpha,beta: 3.52 ,4.13
# alpha,beta: 2.24 ,1.59
# alpha,beta: 7.00 ,4.02
# alpha,beta: -2.15 ,3.82
# alpha,beta: 4.57 ,2.96
# alpha,beta: 1.19 ,3.71
# alpha,beta: 1.74 ,0.96
# alpha,beta: -1.80 ,3.07
# alpha,beta: 8.66 ,2.68
# alpha,beta: 1.59 ,4.95
# alpha,beta: 6.60 ,5.61
# alpha,beta: 6.28 ,3.88
# alpha,beta: 6.94 ,2.69
# alpha,beta: 1.19 ,3.48
# alpha,beta: 4.58 ,1.63
# alpha,beta: 0.88 ,3.42
# alpha,beta: 2.27 ,3.55
# alpha,beta: 11.12 ,4.22
# alpha,beta: -0.33 ,5.58
# alpha,beta: 0.99 ,4.61
# alpha,beta: 1.83 ,3.32
# alpha,beta: 3.73 ,2.73
# alpha,beta: 3.34 ,2.57
# alpha,beta: 2.59 ,3.58
# alpha,beta: 2.88 ,4.94
# alpha,beta: 12.91 ,2.63
# alpha,beta: -2.56 ,2.90
# alpha,beta: 5.79 ,3.61
# alpha,beta: 4.07 ,2.90
# alpha,beta: -0.59 ,3.49
# alpha,beta: 3.78 ,4.15
# alpha,beta: 5.81 ,3.86
# alpha,beta: 6.76 ,1.79
# alpha,beta: 3.91 ,3.18
# alpha,beta: 1.82 ,2.40
# alpha,beta: 0.47 ,3.40
# alpha,beta: 5.03 ,3.93
# alpha,beta: 1.13 ,3.38
# alpha,beta: 3.23 ,3.42
# alpha,beta: -0.06 ,3.37
# alpha,beta: 3.23 ,3.77
# alpha,beta: 4.64 ,5.19
# alpha,beta: 3.00 ,4.73
# alpha,beta: 9.10 ,2.30
# alpha,beta: 5.84 ,3.21
# alpha,beta: 7.16 ,2.23
# alpha,beta: 1.22 ,3.50
# alpha,beta: 4.14 ,3.75
# alpha,beta: 1.62 ,3.64
# alpha,beta: 1.76 ,3.69
# alpha,beta: 2.21 ,2.54
# alpha,beta: 0.13 ,4.36
# alpha,beta: 3.32 ,5.07
# alpha,beta: 13.13 ,4.68
# alpha,beta: 0.88 ,3.38
# alpha,beta: 6.26 ,2.34
# alpha,beta: 10.03 ,3.60
# alpha,beta: 10.07 ,1.43
# alpha,beta: 2.19 ,3.20
# alpha,beta: -1.58 ,2.70
# alpha,beta: 0.59 ,4.41
# alpha,beta: 6.70 ,4.08
# alpha,beta: 10.62 ,2.66
# alpha,beta: 5.95 ,3.22
# alpha,beta: 7.88 ,5.22
# alpha,beta: 1.33 ,1.49
# alpha,beta: 2.63 ,2.87
# alpha,beta: 1.64 ,2.33
# alpha,beta: 2.51 ,2.68
# alpha,beta: 3.89 ,3.21
# alpha,beta: 4.40 ,1.55
# alpha,beta: 2.42 ,2.73
# alpha,beta: 2.86 ,3.77
# alpha,beta: -2.02 ,3.94
# alpha,beta: 1.24 ,1.82
# alpha,beta: 0.36 ,3.16
# alpha,beta: 2.03 ,1.56
# alpha,beta: 12.99 ,3.99
# alpha,beta: 0.29 ,2.74
# alpha,beta: 5.06 ,2.17
# alpha,beta: -0.65 ,3.14
# alpha,beta: 4.84 ,2.75
# alpha,beta: 2.25 ,1.72
# alpha,beta: -0.94 ,3.93
# alpha,beta: 2.54 ,3.27
# alpha,beta: 0.92 ,1.42
# alpha,beta: 2.17 ,3.10
# alpha,beta: 1.80 ,2.86
# alpha,beta: 1.78 ,2.18
# alpha,beta: -1.43 ,3.78
# alpha,beta: 6.14 ,3.32
# alpha,beta: 11.75 ,1.61
# alpha,beta: 0.71 ,1.97
# alpha,beta: 6.79 ,3.22
# alpha,beta: 6.06 ,1.18
# alpha,beta: 4.48 ,2.80
# alpha,beta: 13.39 ,3.10
# alpha,beta: 13.31 ,2.10
# alpha,beta: 1.78 ,2.24
# alpha,beta: -0.45 ,3.09
# alpha,beta: 1.28 ,2.32
# alpha,beta: 11.11 ,3.75
# alpha,beta: 5.69 ,2.49
# alpha,beta: 4.03 ,2.85
# alpha,beta: 2.76 ,3.28
# alpha,beta: 10.70 ,5.18
# alpha,beta: 4.30 ,5.62
# alpha,beta: 3.20 ,6.48
# alpha,beta: 6.16 ,3.73
# alpha,beta: 3.11 ,3.30
# alpha,beta: 1.62 ,4.41
# alpha,beta: 6.80 ,3.81
# alpha,beta: 6.34 ,1.41
# alpha,beta: 11.48 ,5.95
# alpha,beta: 13.38 ,2.32
# alpha,beta: 12.04 ,5.00
# alpha,beta: 4.83 ,3.79
# alpha,beta: 5.18 ,2.79
# alpha,beta: 18.32 ,3.20
# alpha,beta: 17.50 ,3.81
# alpha,beta: 1.53 ,3.99
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# -> Mag Distribution
# --> Getting truth distributions
# end!
# -> Mag Distribution
# --> Getting truth distributions
# Compute MaskFraction and Norm
# norm less than zero: -0.9119115461917354
# norm less than zero: -0.22000354604881558
# norm less than zero: -1.8726324659676723
# norm less than zero: -0.483300702731762
# norm less than zero: -0.9375694260063436
# norm less than zero: -0.131120229964403
# norm less than zero: -0.07981304693139574
# norm less than zero: -1.0387910999366166
# norm less than zero: -0.11419760320232009
# norm less than zero: -0.5317369052185612
#
#  Compute Probabilities
# alpha,beta: 8.22 ,2.53
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 4.76 ,1.58
# alpha,beta: 8.04 ,4.07
# alpha,beta: 5.75 ,2.27
# alpha,beta: 5.75 ,2.92
# alpha,beta: 4.24 ,3.43
# alpha,beta: 3.82 ,3.80
# alpha,beta: 6.32 ,3.22
# alpha,beta: 1.23 ,2.10
# alpha,beta: 11.11 ,3.02
# alpha,beta: 8.21 ,1.93
# alpha,beta: 10.46 ,3.84
# alpha,beta: 18.10 ,4.60
# alpha,beta: 8.51 ,4.94
# alpha,beta: 9.22 ,3.50
# alpha,beta: 4.46 ,3.29
# alpha,beta: 6.55 ,4.47
# alpha,beta: 6.82 ,5.12
# alpha,beta: 5.83 ,1.86
# alpha,beta: 6.34 ,3.79
# alpha,beta: 9.50 ,3.35
# alpha,beta: 7.65 ,3.95
# alpha,beta: 10.90 ,2.44
# alpha,beta: 5.27 ,3.24
# alpha,beta: 7.60 ,4.88
# alpha,beta: 17.92 ,3.99
# alpha,beta: 7.61 ,4.35
# alpha,beta: 7.83 ,4.41
# alpha,beta: 7.42 ,5.60
# alpha,beta: 11.01 ,4.46
# alpha,beta: 10.12 ,5.16
# alpha,beta: 10.17 ,5.90
# alpha,beta: 6.24 ,4.64
# alpha,beta: 10.30 ,4.46
# alpha,beta: 2.70 ,4.00
# alpha,beta: 11.10 ,4.51
# alpha,beta: 7.12 ,4.49
# alpha,beta: 9.19 ,4.56
# alpha,beta: 6.34 ,5.63
# alpha,beta: 9.50 ,6.11
# alpha,beta: 9.67 ,5.28
# alpha,beta: 8.70 ,6.81
# alpha,beta: 4.44 ,4.28
# alpha,beta: 10.52 ,5.88
# alpha,beta: 6.32 ,5.66
# alpha,beta: 12.27 ,5.29
# alpha,beta: 9.52 ,6.11
# alpha,beta: 10.35 ,6.32
# alpha,beta: 6.31 ,0.91
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:265: RuntimeWarning: invalid value encountered in divide
#   return prod/(norm+eps)
# alpha,beta: 19.84 ,2.58
# alpha,beta: 23.70 ,5.19
# alpha,beta: 16.25 ,3.12
# alpha,beta: 7.96 ,4.71
# alpha,beta: 8.80 ,7.84
# alpha,beta: 2.89 ,6.01
# alpha,beta: 7.67 ,6.50
# alpha,beta: 2.74 ,7.18
# alpha,beta: 4.82 ,6.52
# alpha,beta: 5.63 ,5.32
# alpha,beta: 7.86 ,5.58
# alpha,beta: 5.46 ,6.87
# alpha,beta: 7.30 ,2.52
# alpha,beta: 5.22 ,6.91
# alpha,beta: 5.05 ,3.26
# alpha,beta: 6.30 ,5.80
# alpha,beta: 6.06 ,4.62
# alpha,beta: 4.35 ,4.72
# alpha,beta: 2.39 ,6.39
# alpha,beta: 8.81 ,5.18
# alpha,beta: 9.65 ,7.26
# alpha,beta: 1.07 ,2.82
# alpha,beta: 6.21 ,4.29
# alpha,beta: 5.06 ,6.95
# alpha,beta: 0.16 ,8.02
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 12.42 ,4.05
# alpha,beta: 1.56 ,5.46
# alpha,beta: 4.13 ,7.35
# alpha,beta: 5.92 ,7.08
# alpha,beta: 0.55 ,8.02
# alpha,beta: 4.18 ,7.21
# alpha,beta: 3.36 ,6.95
# alpha,beta: 11.55 ,5.11
# alpha,beta: 7.36 ,5.99
# alpha,beta: 2.53 ,5.43
# alpha,beta: 2.92 ,3.52
# alpha,beta: 7.24 ,4.78
# alpha,beta: 6.86 ,5.62
# alpha,beta: 5.16 ,5.15
# alpha,beta: 11.19 ,5.79
# alpha,beta: 4.27 ,4.40
# alpha,beta: 4.73 ,6.34
# alpha,beta: 0.23 ,6.40
# alpha,beta: 1.38 ,3.95
# alpha,beta: 3.49 ,3.52
# alpha,beta: 4.04 ,5.07
# alpha,beta: -0.35 ,7.61
# alpha,beta: 3.32 ,5.98
# alpha,beta: 5.21 ,5.22
# alpha,beta: -0.08 ,6.64
# alpha,beta: 1.63 ,5.26
# alpha,beta: 6.92 ,5.68
# alpha,beta: 8.32 ,5.15
# alpha,beta: 8.79 ,5.58
# alpha,beta: 13.66 ,5.20
# alpha,beta: 9.86 ,4.99
# alpha,beta: 12.10 ,5.86
# alpha,beta: 8.27 ,4.79
# alpha,beta: 8.02 ,4.19
# alpha,beta: -1.83 ,5.88
# alpha,beta: 13.23 ,3.55
# alpha,beta: 1.35 ,1.99
# alpha,beta: 3.89 ,4.41
# alpha,beta: 10.65 ,5.87
# alpha,beta: 7.54 ,4.87
# alpha,beta: 8.84 ,1.71
# alpha,beta: 5.89 ,4.63
# alpha,beta: 6.89 ,5.84
# alpha,beta: 6.38 ,1.21
# alpha,beta: 0.39 ,2.26
# alpha,beta: 5.00 ,4.89
# alpha,beta: 1.16 ,4.79
# alpha,beta: 4.10 ,1.65
# alpha,beta: 2.85 ,1.57
# alpha,beta: 3.59 ,5.38
# alpha,beta: 14.90 ,4.79
# alpha,beta: -0.77 ,2.23
# alpha,beta: 9.01 ,3.81
# alpha,beta: 3.91 ,3.63
# alpha,beta: 3.79 ,5.60
# alpha,beta: 3.45 ,3.84
# alpha,beta: 3.45 ,3.62
# alpha,beta: 9.78 ,4.85
# alpha,beta: 3.81 ,6.15
# alpha,beta: 2.65 ,4.22
# alpha,beta: 4.36 ,4.98
# alpha,beta: 5.24 ,4.86
# alpha,beta: 0.85 ,5.64
# alpha,beta: 3.10 ,5.17
# alpha,beta: 2.50 ,3.21
# alpha,beta: 4.02 ,4.82
# alpha,beta: 7.99 ,2.92
# alpha,beta: 8.93 ,1.23
# alpha,beta: 0.70 ,2.81
# alpha,beta: 5.71 ,5.07
# alpha,beta: 4.23 ,5.65
# alpha,beta: 4.53 ,2.18
# alpha,beta: 6.13 ,3.94
# alpha,beta: 6.25 ,4.18
# alpha,beta: 1.52 ,5.50
# alpha,beta: 1.46 ,3.41
# alpha,beta: 8.74 ,4.19
# alpha,beta: 8.91 ,3.68
# alpha,beta: 4.31 ,3.69
# alpha,beta: 5.45 ,5.19
# alpha,beta: 2.20 ,2.59
# alpha,beta: 5.01 ,3.59
# alpha,beta: 9.66 ,5.19
# alpha,beta: 3.12 ,2.01
# alpha,beta: 2.13 ,4.77
# alpha,beta: 3.26 ,3.07
# alpha,beta: 2.18 ,6.48
# alpha,beta: 2.91 ,4.18
# alpha,beta: 0.52 ,4.08
# alpha,beta: 0.26 ,5.33
# alpha,beta: 5.09 ,1.44
# alpha,beta: 8.21 ,4.66
# alpha,beta: 8.25 ,5.11
# alpha,beta: 5.50 ,3.72
# alpha,beta: 1.58 ,1.86
# alpha,beta: 10.18 ,4.99
# alpha,beta: 9.23 ,5.17
# alpha,beta: 13.00 ,5.05
# alpha,beta: 5.67 ,5.53
# alpha,beta: -1.23 ,5.48
# alpha,beta: 2.16 ,4.65
# alpha,beta: 4.56 ,4.29
# alpha,beta: 2.77 ,3.14
# alpha,beta: 6.59 ,4.51
# alpha,beta: 5.41 ,4.33
# alpha,beta: -0.21 ,6.24
# alpha,beta: 6.85 ,5.46
# alpha,beta: 4.39 ,5.08
# alpha,beta: 14.67 ,4.78
# alpha,beta: 1.11 ,3.24
# alpha,beta: 0.23 ,3.47
# alpha,beta: 3.67 ,3.52
# alpha,beta: 1.05 ,3.77
# alpha,beta: 1.34 ,4.34
# alpha,beta: 4.87 ,2.42
# alpha,beta: 7.25 ,6.83
# alpha,beta: 5.57 ,6.30
# alpha,beta: 1.45 ,3.29
# alpha,beta: 0.76 ,3.02
# alpha,beta: 6.94 ,4.32
# alpha,beta: 0.53 ,3.58
# alpha,beta: 4.91 ,5.88
# alpha,beta: 0.67 ,1.25
# alpha,beta: 4.92 ,3.27
# alpha,beta: 5.28 ,2.29
# alpha,beta: -0.13 ,2.37
# alpha,beta: 3.19 ,3.27
# alpha,beta: -1.50 ,2.66
# alpha,beta: -0.18 ,3.50
# alpha,beta: 2.66 ,2.62
# alpha,beta: 2.17 ,2.96
# alpha,beta: 13.69 ,2.50
# alpha,beta: 3.71 ,1.62
# alpha,beta: -0.77 ,2.07
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# Compute MaskFraction and Norm
# norm less than zero: -1.4778017914859847
# norm less than zero: -2.484234675290097
# norm less than zero: -2.3294871817728824
# norm less than zero: -1.6394050240609201
# norm less than zero: -1.2971792602532732
# norm less than zero: -3.3548194298660183
# norm less than zero: -3.298844986394792
# norm less than zero: -0.04843146211056865
#
#  Compute Probabilities
# alpha,beta: 11.37 ,4.12
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 8.95 ,4.03
# alpha,beta: 6.14 ,3.57
# alpha,beta: 12.99 ,3.68
# alpha,beta: 8.82 ,3.91
# alpha,beta: 16.22 ,2.83
# alpha,beta: 9.96 ,2.12
# alpha,beta: 7.07 ,3.68
# alpha,beta: 9.66 ,2.82
# -> Mag Distribution
# --> Getting truth distributions
# alpha,beta: 3.69 ,3.24
# alpha,beta: 6.77 ,3.17
# alpha,beta: 12.69 ,3.89
# alpha,beta: 9.81 ,3.19
# alpha,beta: 9.49 ,3.09
# alpha,beta: 8.33 ,3.95
# alpha,beta: 6.90 ,2.93
# alpha,beta: 8.89 ,3.27
# alpha,beta: 8.46 ,3.67
# alpha,beta: 5.97 ,3.79
# alpha,beta: 6.37 ,1.43
# alpha,beta: 3.91 ,1.88
# alpha,beta: 10.65 ,5.47
# alpha,beta: 6.40 ,4.42
# alpha,beta: 8.26 ,3.37
# alpha,beta: 5.23 ,3.82
# alpha,beta: 8.88 ,3.55
# alpha,beta: 5.43 ,3.97
# alpha,beta: 5.52 ,4.14
# alpha,beta: 4.32 ,3.26
# alpha,beta: 5.08 ,3.02
# alpha,beta: 6.58 ,3.92
# alpha,beta: 7.24 ,3.41
# alpha,beta: 7.75 ,3.22
# alpha,beta: 13.93 ,3.42
# alpha,beta: 8.47 ,1.64
# alpha,beta: 6.30 ,3.55
# alpha,beta: 9.85 ,5.53
# alpha,beta: 10.51 ,4.98
# alpha,beta: 12.43 ,3.58
# alpha,beta: 5.70 ,5.46
# alpha,beta: 11.31 ,5.60
# alpha,beta: 5.12 ,6.31
# alpha,beta: 5.80 ,5.45
# alpha,beta: 7.85 ,6.15
# alpha,beta: 6.00 ,4.54
# alpha,beta: 7.12 ,5.54
# alpha,beta: 9.83 ,4.58
# alpha,beta: 9.02 ,6.40
# alpha,beta: 5.57 ,5.31
# alpha,beta: 6.78 ,3.23
# alpha,beta: 11.61 ,2.13
# alpha,beta: 8.17 ,4.53
# alpha,beta: 5.16 ,5.25
# alpha,beta: 6.47 ,4.65
# alpha,beta: 8.61 ,4.53
# alpha,beta: 8.41 ,4.41
# alpha,beta: 5.16 ,5.22
# alpha,beta: 5.68 ,4.40
# alpha,beta: 10.37 ,3.64
# alpha,beta: 6.31 ,5.26
# alpha,beta: 10.87 ,5.13
# alpha,beta: 8.26 ,4.73
# alpha,beta: 7.97 ,5.39
# alpha,beta: 5.41 ,5.61
# alpha,beta: 10.15 ,6.05
# alpha,beta: -0.55 ,5.81
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 5.82 ,7.23
# alpha,beta: 9.60 ,5.54
# alpha,beta: 5.00 ,5.51
# alpha,beta: 6.35 ,5.85
# alpha,beta: 10.18 ,5.49
# alpha,beta: 7.91 ,3.77
# alpha,beta: 4.51 ,5.41
# alpha,beta: 11.26 ,6.18
# alpha,beta: 8.43 ,4.81
# alpha,beta: 17.53 ,4.81
# alpha,beta: 8.62 ,4.23
# alpha,beta: 10.47 ,4.82
# alpha,beta: 3.71 ,4.54
# ...
# alpha,beta: 2.35 ,5.83
# alpha,beta: 3.48 ,10.05
# alpha,beta: 4.89 ,6.48
# alpha,beta: 0.66 ,6.47
# alpha,beta: 2.05 ,8.43
# alpha,beta: 4.78 ,2.48
# alpha,beta: 10.72 ,7.14
# alpha,beta: 5.94 ,7.47
# alpha,beta: 8.08 ,6.02
# alpha,beta: 9.42 ,3.36
# alpha,beta: 11.15 ,8.21
# alpha,beta: 11.02 ,8.09
# alpha,beta: 14.42 ,7.46
# alpha,beta: 12.11 ,9.17
# alpha,beta: -1.26 ,8.02
# alpha,beta: 3.80 ,7.16
# alpha,beta: 8.69 ,6.51
# alpha,beta: 6.00 ,5.03
# alpha,beta: 4.92 ,6.68
# alpha,beta: 5.04 ,6.64
# alpha,beta: 2.11 ,9.81
# alpha,beta: 7.17 ,8.22
# alpha,beta: 11.49 ,7.87
# alpha,beta: 18.39 ,6.89
# alpha,beta: 2.94 ,5.05
# alpha,beta: -2.73 ,6.27
# alpha,beta: 3.26 ,5.15
# alpha,beta: 0.15 ,6.08
# alpha,beta: -0.83 ,7.15
# alpha,beta: 3.47 ,4.03
# alpha,beta: 8.53 ,9.20
# alpha,beta: 6.18 ,9.44
# alpha,beta: 1.62 ,4.92
# alpha,beta: 2.25 ,4.90
# alpha,beta: 6.95 ,6.78
# alpha,beta: 0.86 ,5.51
# alpha,beta: 8.96 ,9.21
# alpha,beta: 1.26 ,2.08
# alpha,beta: 2.89 ,5.60
# alpha,beta: 10.58 ,3.98
# alpha,beta: -1.43 ,3.91
# alpha,beta: 2.22 ,4.96
# alpha,beta: -1.19 ,4.46
# alpha,beta: 0.41 ,5.74
# alpha,beta: 6.41 ,4.47
# alpha,beta: 8.44 ,5.13
# alpha,beta: 16.18 ,4.21
# alpha,beta: 3.46 ,2.69
# alpha,beta: -2.94 ,3.70
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# Compute MaskFraction and Norm
# norm less than zero: -2.2180856276407312
# norm less than zero: -0.5684594737307598
# norm less than zero: -2.5621831207079273
# norm less than zero: -0.7053851545433302
# norm less than zero: -2.1726886700842925
# norm less than zero: -2.590849335071259
# norm less than zero: -0.028063889961156527
# norm less than zero: -2.029858391016188
# norm less than zero: -1.8672773638269209
# norm less than zero: -0.9481061399990033
# norm less than zero: -0.37898122033053555
# norm less than zero: -0.10942141846296984
# norm less than zero: -2.6913468062718264
# norm less than zero: -0.5475229822105372
# norm less than zero: -0.6628873798185333
#
#  Compute Probabilities
# end!
# alpha,beta: 11.06 ,5.46
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 9.20 ,4.93
# alpha,beta: 5.28 ,4.83
# alpha,beta: 13.03 ,5.18
# alpha,beta: 8.10 ,5.37
# alpha,beta: 16.29 ,4.05
# alpha,beta: 11.78 ,3.15
# alpha,beta: 6.93 ,5.36
# alpha,beta: 8.82 ,4.08
# alpha,beta: 3.99 ,4.32
# alpha,beta: 6.92 ,4.74
# alpha,beta: 13.56 ,5.60
# alpha,beta: 9.29 ,5.12
# alpha,beta: 9.52 ,4.77
# alpha,beta: 8.27 ,6.00
# alpha,beta: 7.98 ,4.61
# alpha,beta: 10.30 ,4.63
# alpha,beta: 9.29 ,5.80
# alpha,beta: 6.62 ,6.12
# alpha,beta: 8.35 ,2.52
# alpha,beta: 4.15 ,3.24
# alpha,beta: 10.35 ,8.21
# alpha,beta: 7.13 ,7.14
# alpha,beta: 7.58 ,5.86
# alpha,beta: 5.28 ,5.46
# alpha,beta: 7.68 ,6.27
# alpha,beta: 5.31 ,6.03
# alpha,beta: 6.58 ,6.13
# alpha,beta: 3.28 ,5.33
# alpha,beta: 6.38 ,4.79
# alpha,beta: 6.46 ,5.94
# alpha,beta: 7.85 ,5.44
# alpha,beta: 8.79 ,4.95
# alpha,beta: 13.59 ,5.08
# alpha,beta: 8.91 ,2.40
# alpha,beta: 8.48 ,4.88
# alpha,beta: 11.21 ,8.04
# alpha,beta: 9.42 ,7.01
# alpha,beta: 12.43 ,6.36
# alpha,beta: 5.48 ,7.87
# alpha,beta: 13.27 ,7.84
# alpha,beta: 5.60 ,10.07
# alpha,beta: 8.02 ,8.22
# alpha,beta: 8.83 ,8.48
# alpha,beta: 6.84 ,7.04
# alpha,beta: 6.33 ,8.57
# alpha,beta: 12.55 ,6.68
# alpha,beta: 12.04 ,8.95
# alpha,beta: 7.13 ,7.88
# alpha,beta: 7.92 ,6.11
# alpha,beta: 12.03 ,3.57
# alpha,beta: 12.55 ,6.81
# alpha,beta: 5.85 ,7.54
# alpha,beta: 6.31 ,7.66
# alpha,beta: 8.75 ,7.08
# alpha,beta: 9.40 ,7.07
# alpha,beta: 3.94 ,7.91
# alpha,beta: 5.24 ,6.46
# alpha,beta: 8.79 ,6.24
# alpha,beta: 5.38 ,7.74
# alpha,beta: 8.83 ,8.36
# alpha,beta: 8.14 ,7.24
# alpha,beta: 10.32 ,8.04
# alpha,beta: 4.75 ,7.66
# alpha,beta: 10.53 ,9.48
# alpha,beta: -0.83 ,8.67
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 7.42 ,10.40
# alpha,beta: 9.96 ,9.19
# alpha,beta: 5.40 ,7.79
# alpha,beta: 7.83 ,9.23
# alpha,beta: 10.08 ,8.44
# alpha,beta: 5.82 ,6.28
# alpha,beta: 5.73 ,9.63
# alpha,beta: 13.20 ,9.06
# alpha,beta: 9.78 ,7.45
# alpha,beta: 19.73 ,7.91
# alpha,beta: 10.32 ,6.54
# alpha,beta: 9.70 ,7.51
# alpha,beta: 3.18 ,7.70
# alpha,beta: 6.50 ,11.62
# alpha,beta: 4.79 ,9.65
# alpha,beta: 8.51 ,9.96
# alpha,beta: 11.54 ,11.74
# alpha,beta: -0.25 ,12.01
# alpha,beta: 6.03 ,9.98
# alpha,beta: 9.77 ,8.82
# alpha,beta: 4.43 ,7.90
# alpha,beta: 12.80 ,6.46
# alpha,beta: 4.08 ,9.49
# alpha,beta: 6.95 ,10.94
# alpha,beta: 17.78 ,11.33
# alpha,beta: 6.11 ,7.85
# alpha,beta: 6.06 ,8.13
# alpha,beta: 14.16 ,9.99
# alpha,beta: 5.81 ,10.75
# alpha,beta: 1.71 ,8.67
# alpha,beta: 1.04 ,12.00
# alpha,beta: 8.56 ,8.66
# alpha,beta: 15.97 ,7.73
# alpha,beta: 8.68 ,6.15
# alpha,beta: 10.74 ,8.38
# alpha,beta: 5.83 ,6.49
# alpha,beta: 6.90 ,6.56
# alpha,beta: 1.34 ,10.83
# alpha,beta: -2.87 ,7.96
# alpha,beta: 23.64 ,8.51
# alpha,beta: 9.40 ,7.84
# alpha,beta: 15.67 ,7.75
# alpha,beta: 2.80 ,9.68
# alpha,beta: 10.97 ,9.35
# alpha,beta: 11.93 ,6.64
# alpha,beta: 1.05 ,9.72
# alpha,beta: 4.94 ,10.08
# alpha,beta: 8.57 ,5.10
# alpha,beta: 19.00 ,10.84
# alpha,beta: 7.19 ,7.69
# alpha,beta: 3.27 ,10.81
# alpha,beta: 9.72 ,7.53
# alpha,beta: 10.45 ,7.17
# alpha,beta: 5.09 ,5.29
# alpha,beta: 5.54 ,5.28
# alpha,beta: 3.05 ,10.68
# alpha,beta: 0.62 ,5.50
# alpha,beta: 7.51 ,7.07
# alpha,beta: 2.14 ,6.31
# alpha,beta: -0.59 ,5.16
# alpha,beta: 6.08 ,4.68
# alpha,beta: 2.32 ,5.42
# alpha,beta: 6.59 ,5.33
# alpha,beta: 6.49 ,6.29
# alpha,beta: 4.01 ,5.56
# alpha,beta: 7.84 ,7.68
# alpha,beta: 6.04 ,8.36
# alpha,beta: 0.93 ,7.67
# alpha,beta: 4.07 ,5.17
# alpha,beta: 16.49 ,6.63
# alpha,beta: 10.08 ,7.13
# alpha,beta: 0.36 ,3.78
# alpha,beta: 1.13 ,5.91
# alpha,beta: 11.75 ,6.60
# alpha,beta: 7.59 ,6.89
# alpha,beta: 7.43 ,6.83
# alpha,beta: 4.74 ,5.24
# alpha,beta: 5.09 ,6.47
# alpha,beta: -1.95 ,8.49
# alpha,beta: -1.17 ,6.01
# alpha,beta: 2.70 ,7.17
# alpha,beta: 2.97 ,4.41
# alpha,beta: 3.91 ,5.52
# alpha,beta: 7.01 ,6.13
# alpha,beta: 0.42 ,7.00
# alpha,beta: 7.15 ,5.63
# alpha,beta: 4.12 ,3.75
# alpha,beta: -0.02 ,6.78
# alpha,beta: 1.72 ,6.13
# alpha,beta: 6.64 ,4.63
# alpha,beta: 7.11 ,5.53
# alpha,beta: 12.10 ,4.93
# alpha,beta: 2.92 ,6.04
# alpha,beta: 5.10 ,5.66
# alpha,beta: 4.57 ,4.37
# alpha,beta: 6.06 ,6.63
# alpha,beta: 11.80 ,5.61
# alpha,beta: 2.64 ,6.57
# alpha,beta: 3.55 ,7.51
# alpha,beta: 5.30 ,4.51
# alpha,beta: 4.26 ,4.42
# alpha,beta: 2.02 ,3.93
# alpha,beta: -2.82 ,4.77
# alpha,beta: 7.23 ,4.91
# alpha,beta: 5.18 ,5.43
# alpha,beta: 6.26 ,7.20
# alpha,beta: 3.35 ,4.53
# alpha,beta: 3.45 ,6.25
# alpha,beta: 5.80 ,6.55
# alpha,beta: 18.22 ,7.31
# alpha,beta: 1.55 ,5.37
# alpha,beta: 6.29 ,6.09
# alpha,beta: 1.30 ,4.66
# alpha,beta: 6.41 ,6.29
# alpha,beta: 0.17 ,4.96
# alpha,beta: -1.53 ,7.51
# alpha,beta: 0.47 ,5.48
# alpha,beta: 3.60 ,7.86
# alpha,beta: 7.07 ,9.58
# alpha,beta: 3.38 ,4.17
# alpha,beta: 5.34 ,6.60
# alpha,beta: 2.01 ,5.59
# alpha,beta: 10.77 ,6.07
# alpha,beta: 3.05 ,5.42
# alpha,beta: 9.12 ,8.27
# alpha,beta: -1.05 ,5.87
# alpha,beta: 3.44 ,5.36
# alpha,beta: 4.41 ,5.60
# alpha,beta: 5.52 ,5.18
# alpha,beta: 6.35 ,5.07
# alpha,beta: 6.48 ,4.90
# alpha,beta: 18.46 ,7.28
# alpha,beta: -0.54 ,5.19
# alpha,beta: 6.93 ,5.50
# alpha,beta: 11.73 ,7.56
# alpha,beta: 4.03 ,10.37
# alpha,beta: 5.46 ,6.10
# alpha,beta: 10.67 ,6.27
# alpha,beta: 8.21 ,3.25
# alpha,beta: 3.37 ,7.28
# alpha,beta: 15.48 ,6.67
# alpha,beta: 3.12 ,5.22
# alpha,beta: -0.03 ,4.78
# alpha,beta: 0.83 ,7.71
# alpha,beta: -1.83 ,5.66
# alpha,beta: -0.28 ,5.56
# alpha,beta: 2.04 ,6.86
# alpha,beta: 2.50 ,5.11
# alpha,beta: -0.99 ,3.75
# alpha,beta: 6.22 ,3.73
# alpha,beta: 7.89 ,6.82
# alpha,beta: 4.62 ,7.30
# alpha,beta: 2.00 ,4.77
# alpha,beta: 2.62 ,5.50
# alpha,beta: 3.34 ,6.63
# alpha,beta: 3.16 ,4.75
# alpha,beta: 8.75 ,4.44
# alpha,beta: 8.29 ,5.10
# alpha,beta: 1.42 ,4.50
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# -> Mag Distribution
# --> Getting truth distributions
# end!
# Compute MaskFraction and Norm
# norm less than zero: -6.813070031854877
# norm less than zero: -9.689991780240403
# norm less than zero: -31.971296630595806
# norm less than zero: -4.4055069088864185
# norm less than zero: -1.566031696711983
# norm less than zero: -1.8432102240638992
# norm less than zero: -0.5757678170859889
# norm less than zero: -2.2349921634961385
# norm less than zero: -0.733506403813839
# norm less than zero: -3.7646779822195335
# norm less than zero: -1.9877477637259178
# norm less than zero: -1.4627313335469192
# norm less than zero: -0.9063556081852687
# norm less than zero: -2.6633206651345045
# norm less than zero: -0.034427741422099443
# norm less than zero: -1.8053645663557527
# norm less than zero: -1.6933977626162533
# norm less than zero: -1.045643440989749
# norm less than zero: -0.4421234614431259
#
#  Compute Probabilities
# alpha,beta: 8.83 ,2.85
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 6.76 ,2.36
# alpha,beta: 7.50 ,4.34
# alpha,beta: 5.79 ,4.22
# alpha,beta: 9.95 ,4.24
# alpha,beta: 8.23 ,4.54
# alpha,beta: 5.96 ,3.97
# alpha,beta: 4.45 ,5.81
# alpha,beta: 12.64 ,2.09
# alpha,beta: 2.91 ,4.95
# alpha,beta: 9.97 ,5.14
# alpha,beta: 8.41 ,5.97
# alpha,beta: 10.11 ,4.74
# alpha,beta: 8.86 ,5.44
# alpha,beta: 3.56 ,4.41
# alpha,beta: 7.77 ,5.26
# alpha,beta: 11.90 ,5.14
# alpha,beta: 11.81 ,6.85
# alpha,beta: 7.68 ,6.55
# alpha,beta: 15.39 ,7.26
# alpha,beta: 6.51 ,5.70
# alpha,beta: 7.19 ,6.51
# alpha,beta: 5.94 ,7.39
# alpha,beta: 6.25 ,6.85
# alpha,beta: 5.49 ,5.77
# alpha,beta: 3.39 ,8.18
# alpha,beta: 4.75 ,5.20
# alpha,beta: 9.51 ,5.78
# alpha,beta: 7.77 ,5.10
# alpha,beta: 15.61 ,5.55
# alpha,beta: 9.17 ,6.45
# alpha,beta: 7.09 ,7.15
# alpha,beta: 8.62 ,6.41
# alpha,beta: 8.72 ,6.13
# alpha,beta: 11.93 ,5.80
# alpha,beta: 1.97 ,5.50
# alpha,beta: 9.53 ,6.68
# alpha,beta: 7.54 ,5.72
# alpha,beta: 14.35 ,5.44
# alpha,beta: 14.91 ,4.46
# alpha,beta: 6.37 ,8.21
# alpha,beta: 5.81 ,6.40
# alpha,beta: 2.94 ,6.48
# alpha,beta: 7.27 ,7.30
# alpha,beta: 9.65 ,5.86
# alpha,beta: 7.32 ,4.87
# alpha,beta: 8.71 ,6.47
# alpha,beta: 8.22 ,6.64
# alpha,beta: 6.28 ,3.47
# alpha,beta: 6.28 ,5.35
# alpha,beta: 7.30 ,8.79
# alpha,beta: 11.04 ,7.65
# alpha,beta: 10.04 ,6.98
# alpha,beta: 6.75 ,7.11
# alpha,beta: 10.73 ,7.56
# alpha,beta: 11.00 ,2.97
# alpha,beta: 11.19 ,7.91
# alpha,beta: 7.76 ,7.04
# alpha,beta: 14.69 ,3.53
# alpha,beta: 5.26 ,7.52
# alpha,beta: 10.15 ,8.02
# alpha,beta: 4.57 ,9.06
# alpha,beta: 7.88 ,6.85
# alpha,beta: 17.64 ,8.32
# alpha,beta: 7.31 ,6.42
# alpha,beta: 8.56 ,8.12
# alpha,beta: 3.25 ,8.26
# alpha,beta: 6.96 ,7.08
# alpha,beta: 13.21 ,8.49
# alpha,beta: 4.47 ,7.31
# alpha,beta: 11.92 ,6.29
# alpha,beta: 8.06 ,8.12
# alpha,beta: 10.36 ,8.60
# alpha,beta: 12.94 ,8.03
# alpha,beta: 12.66 ,6.79
# alpha,beta: 6.27 ,7.79
# alpha,beta: 8.23 ,7.21
# alpha,beta: 17.79 ,7.33
# alpha,beta: 5.70 ,6.77
# alpha,beta: 3.12 ,6.64
# alpha,beta: 4.33 ,7.20
# alpha,beta: 4.70 ,8.58
# alpha,beta: 1.83 ,7.85
# alpha,beta: 7.66 ,8.85
# alpha,beta: 1.91 ,10.01
# alpha,beta: 8.57 ,9.56
# alpha,beta: 9.12 ,7.87
# alpha,beta: 4.06 ,10.45
# alpha,beta: 13.57 ,9.50
# alpha,beta: 9.27 ,7.72
# alpha,beta: 4.20 ,7.18
# alpha,beta: 10.31 ,6.97
# alpha,beta: 12.31 ,8.98
# alpha,beta: 2.72 ,9.30
# alpha,beta: 6.18 ,4.33
# alpha,beta: 6.96 ,5.31
# alpha,beta: 1.02 ,7.21
# alpha,beta: 9.06 ,3.73
# alpha,beta: 14.14 ,6.16
# alpha,beta: 6.28 ,9.69
# alpha,beta: 14.87 ,8.41
# alpha,beta: 7.33 ,10.38
# alpha,beta: 6.64 ,4.30
# alpha,beta: 10.57 ,8.34
# alpha,beta: 21.97 ,4.45
# alpha,beta: 3.42 ,7.46
# alpha,beta: 3.38 ,11.14
# alpha,beta: 10.46 ,10.16
# alpha,beta: 11.83 ,9.76
# alpha,beta: 8.24 ,9.61
# alpha,beta: 3.46 ,6.94
# alpha,beta: 12.63 ,8.08
# alpha,beta: 4.70 ,5.03
# alpha,beta: -3.22 ,9.86
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 6.13 ,7.17
# alpha,beta: 8.44 ,2.52
# alpha,beta: 10.74 ,8.82
# alpha,beta: 5.55 ,7.34
# alpha,beta: 11.75 ,9.38
# alpha,beta: 14.52 ,11.74
# alpha,beta: 3.43 ,10.11
# alpha,beta: 3.41 ,10.08
# alpha,beta: 6.48 ,9.02
# alpha,beta: 12.06 ,10.07
# alpha,beta: 4.05 ,6.54
# alpha,beta: 11.03 ,8.29
# alpha,beta: -6.91 ,8.89
# alpha,beta: 10.16 ,7.98
# alpha,beta: 28.36 ,7.68
# alpha,beta: 6.43 ,8.89
# alpha,beta: 9.68 ,8.95
# alpha,beta: 10.05 ,6.13
# alpha,beta: -3.56 ,10.04
# alpha,beta: 8.00 ,8.23
# alpha,beta: 5.51 ,6.05
# alpha,beta: 7.52 ,6.21
# alpha,beta: 7.62 ,9.19
# alpha,beta: 7.34 ,6.86
# alpha,beta: 3.41 ,9.62
# alpha,beta: 6.91 ,8.08
# alpha,beta: 13.06 ,8.22
# alpha,beta: 4.39 ,6.92
# alpha,beta: 9.33 ,7.44
# alpha,beta: 5.28 ,6.56
# alpha,beta: 16.08 ,7.07
# alpha,beta: 8.40 ,7.34
# alpha,beta: 3.99 ,9.18
# alpha,beta: 7.32 ,8.81
# alpha,beta: 8.77 ,9.37
# alpha,beta: 3.00 ,9.34
# alpha,beta: 7.42 ,5.85
# alpha,beta: 3.79 ,11.22
# alpha,beta: 8.89 ,10.09
# alpha,beta: -3.07 ,7.54
# alpha,beta: 9.99 ,9.70
# alpha,beta: 4.12 ,6.59
# alpha,beta: 9.06 ,9.11
# alpha,beta: 2.56 ,9.44
# alpha,beta: 8.91 ,2.30
# alpha,beta: 9.20 ,7.01
# alpha,beta: 5.07 ,8.78
# alpha,beta: 9.07 ,6.30
# alpha,beta: 3.25 ,6.28
# alpha,beta: 18.59 ,7.33
# alpha,beta: 1.77 ,5.15
# alpha,beta: 3.45 ,1.82
# alpha,beta: 5.03 ,6.51
# alpha,beta: 3.19 ,6.76
# alpha,beta: 4.51 ,4.19
# alpha,beta: 12.81 ,6.24
# alpha,beta: 7.97 ,5.48
# alpha,beta: 1.10 ,8.11
# alpha,beta: 14.66 ,6.13
# alpha,beta: 13.84 ,5.01
# alpha,beta: 6.15 ,7.45
# alpha,beta: 8.61 ,8.07
# alpha,beta: 10.38 ,2.92
# alpha,beta: 14.10 ,4.97
# alpha,beta: 1.58 ,7.18
# alpha,beta: 9.01 ,9.57
# alpha,beta: 11.68 ,4.69
# alpha,beta: 20.02 ,8.62
# alpha,beta: 5.85 ,5.02
# alpha,beta: 0.24 ,9.48
# alpha,beta: 7.02 ,2.93
# alpha,beta: 8.95 ,7.89
# alpha,beta: 5.58 ,6.30
# alpha,beta: 3.31 ,4.39
# alpha,beta: 4.43 ,4.06
# alpha,beta: 2.94 ,4.49
# alpha,beta: 7.33 ,8.95
# alpha,beta: -0.53 ,6.42
# alpha,beta: 8.86 ,8.38
# alpha,beta: 9.27 ,10.05
# alpha,beta: 2.05 ,7.44
# alpha,beta: 1.77 ,7.42
# alpha,beta: 9.01 ,7.22
# alpha,beta: 5.91 ,10.82
# alpha,beta: 2.56 ,5.24
# alpha,beta: 8.73 ,5.09
# alpha,beta: 3.48 ,6.61
# alpha,beta: 7.98 ,7.50
# alpha,beta: 6.02 ,6.35
# alpha,beta: 2.12 ,6.56
# alpha,beta: 7.12 ,6.06
# alpha,beta: 1.69 ,4.23
# alpha,beta: 5.58 ,9.99
# alpha,beta: 8.55 ,4.38
# alpha,beta: 6.62 ,8.66
# alpha,beta: 7.80 ,3.92
# alpha,beta: 17.65 ,8.68
# alpha,beta: 6.26 ,7.87
# alpha,beta: 2.85 ,8.11
# alpha,beta: 5.14 ,7.34
# alpha,beta: 3.01 ,7.07
# alpha,beta: 8.47 ,5.03
# alpha,beta: 10.01 ,9.42
# alpha,beta: 5.17 ,5.69
# alpha,beta: 9.19 ,6.17
# alpha,beta: 10.25 ,4.32
# alpha,beta: 5.88 ,4.97
# alpha,beta: 9.68 ,9.06
# alpha,beta: 3.39 ,6.86
# alpha,beta: 0.66 ,8.79
# alpha,beta: 4.87 ,6.88
# alpha,beta: 6.03 ,4.45
# alpha,beta: 12.83 ,7.81
# alpha,beta: 4.39 ,5.36
# alpha,beta: 4.38 ,8.32
# alpha,beta: 8.65 ,6.29
# alpha,beta: -2.02 ,4.43
# alpha,beta: 13.21 ,5.90
# alpha,beta: 2.13 ,4.90
# alpha,beta: 0.16 ,4.78
# alpha,beta: 1.55 ,2.84
# alpha,beta: 4.71 ,3.68
# alpha,beta: 3.87 ,4.25
# alpha,beta: 3.02 ,4.75
# alpha,beta: 4.97 ,6.02
# alpha,beta: -0.96 ,3.60
# alpha,beta: 0.58 ,4.74
# alpha,beta: -1.13 ,5.45
# alpha,beta: 3.47 ,5.84
# alpha,beta: 1.35 ,4.15
# alpha,beta: 7.98 ,3.84
# alpha,beta: 3.74 ,3.75
# alpha,beta: 0.09 ,5.30
# alpha,beta: -0.40 ,5.36
# alpha,beta: -2.96 ,3.72
# alpha,beta: 6.90 ,5.39
# alpha,beta: 8.81 ,5.67
# alpha,beta: 11.25 ,6.94
# alpha,beta: 5.61 ,5.54
# alpha,beta: 2.68 ,4.70
# alpha,beta: -2.24 ,5.78
# alpha,beta: 9.83 ,4.33
# alpha,beta: 0.00 ,4.61
# alpha,beta: 2.66 ,4.31
# alpha,beta: 0.22 ,3.71
# alpha,beta: 6.95 ,3.82
# alpha,beta: -1.70 ,4.96
# alpha,beta: 2.30 ,4.18
# alpha,beta: 6.08 ,6.54
# alpha,beta: 5.39 ,3.38
# alpha,beta: -0.87 ,4.84
# alpha,beta: 5.91 ,5.04
# alpha,beta: 4.22 ,9.04
# alpha,beta: 6.58 ,5.56
# alpha,beta: -3.58 ,5.15
# alpha,beta: 9.65 ,4.13
# alpha,beta: 1.74 ,3.90
# alpha,beta: -0.06 ,4.25
# alpha,beta: 7.55 ,5.55
# alpha,beta: 9.18 ,4.24
# alpha,beta: 6.85 ,2.71
# alpha,beta: 2.62 ,4.58
# alpha,beta: 3.53 ,4.82
# alpha,beta: 3.67 ,5.30
# alpha,beta: 16.87 ,5.40
# alpha,beta: 7.32 ,4.86
# alpha,beta: -3.14 ,6.19
# alpha,beta: 13.04 ,7.11
# alpha,beta: 6.51 ,5.76
# alpha,beta: 2.76 ,4.67
# alpha,beta: 2.91 ,5.06
# alpha,beta: 10.85 ,5.31
# alpha,beta: -1.24 ,4.63
# alpha,beta: 5.12 ,4.54
# alpha,beta: -1.36 ,7.17
# alpha,beta: 8.61 ,4.33
# alpha,beta: 14.04 ,5.22
# alpha,beta: 9.13 ,4.43
# alpha,beta: 5.22 ,4.80
# alpha,beta: 4.43 ,4.49
# alpha,beta: -0.66 ,4.17
# alpha,beta: 8.98 ,3.11
# alpha,beta: 5.86 ,4.01
# alpha,beta: 3.33 ,3.65
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# end!
# compute ptaken
# Total time: 138.863907814s
# ---------------

# %% [markdown]
# #### 1. Gaussian, Rhod, 02Lstar

# %%
## setup 
copa.kwargs['r_aper_model'] = 'rhod'
copa.kwargs['mag_selection']= '02Lstar'

# %%
## runs
pz_files = ['gauss001','gauss003','gauss005']
z_widths = [0.01,0.03,0.05]

runs = ['%s_%s_%s'%(pz,'rhod','02Lstar') for pz in pz_files]

# %%
runs
# Out:
# ['gauss001_rhod_02Lstar', 'gauss003_rhod_02Lstar', 'gauss005_rhod_02Lstar']

# %%
for run, zfile, zw in zip(runs,pz_files,z_widths):
    print('run     : %s'%run)
    print('zfile   : %s'%zfile)
    print('zwindow : %.2f'%zw)
    
    copa.kwargs['z_window'] = zw
    copa.run_copa_healpix(run,   pz_file=zfile, nCores=60)
    copa.compute_muStar(  run, overwrite=True)
    print(5*'---')
    print('\n')
# Out:
# run     : gauss001_rhod_02Lstar
# zfile   : gauss001
# zwindow : 0.01
#
# Starting Copa
# run gauss001_rhod_02Lstar
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00000.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2164589
# cut:  1117504
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00000/gauss001_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00256.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2791169
# cut:  1540789
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00256/gauss001_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00257.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3708874
# cut:  2029006
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00257/gauss001_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00260.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3019411
# cut:  1664271
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00260/gauss001_rhod_02Lstar_copa_test_gal.fits
# copa parallel process
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# bad cluster: 13884049 ratio min/max: 0.01237456451763766 574.855706320648
# bad cluster: 13884049 ratio min/max: 0.038790222125441955 735.6807265889584
# bad cluster: 23255546 ratio min/max: 4.963157470514799 316.05747051561923
# bad cluster: 24134459 ratio min/max: 0.013091678476849193 287.35021725110323
# bad cluster: 24134459 ratio min/max: 0.02891637181947249 287.35021725110323
# bad cluster: 24134459 ratio min/max: 5.6033901591368345 287.35021725110323
# bad cluster: 24134765 ratio min/max: 0.013456636521541498 339.482903356677
# bad cluster: 24141541 ratio min/max: 3.5206152196257365 651.5184498702699
# bad cluster: 24141541 ratio min/max: 9.977753430174582 4351.45284785168
# bad cluster: 24141541 ratio min/max: 14.039912184306344 4507.285727321646
# bad cluster: 24142653 ratio min/max: 0.4863627838952299 1798.2958094137387
# bad cluster: 24147125 ratio min/max: 1.6451067230002647 922.7112443663434
# bad cluster: 24973287 ratio min/max: 0.009636588679830048 260.18789435541123
# bad cluster: 24973287 ratio min/max: 2.3083687051990687 260.18789435541123
# bad cluster: 24973287 ratio min/max: 5.310337580247782 260.18789435541123
# bad cluster: 24973287 ratio min/max: 7.697399616778094 260.18789435541123
# bad cluster: 24973287 ratio min/max: 9.60140077222356 260.18789435541123
# bad cluster: 24973287 ratio min/max: 11.1219491320315 260.18789435541123
# bad cluster: 24973287 ratio min/max: 12.336316482281294 260.18789435541123
# bad cluster: 24973287 ratio min/max: 13.307145742695262 262.37484418155964
# bad cluster: 24973287 ratio min/max: 14.083809151026433 269.55275090541033
# bad cluster: 24973287 ratio min/max: 14.704645097827147 275.24657815885945
# bad cluster: 24973287 ratio min/max: 15.200530583954016 279.7670030403194
# bad cluster: 24973287 ratio min/max: 15.597238972855516 283.38333952017535
# bad cluster: 24973325 ratio min/max: 0.023400380117326224 517.6514192314493
# bad cluster: 24976625 ratio min/max: 0.5757129979135094 1409.7113189586653
# bad cluster: 24976625 ratio min/max: 2.9335896457299633 2279.7833025981026
# bad cluster: 30253087 ratio min/max: 2.088468893469785 197.84117282805525
# bad cluster: 30253087 ratio min/max: 3.0925756104048685 197.84117282805525
# bad cluster: 30253087 ratio min/max: 5.13214499476312 197.84117282805525
# bad cluster: 30253087 ratio min/max: 8.491418927651527 200.07378169253653
# bad cluster: 30253087 ratio min/max: 9.184305273007906 263.6171908579227
# bad cluster: 30253087 ratio min/max: 9.738596143348541 332.37850857817125
# bad cluster: 30253087 ratio min/max: 10.61821305195398 377.1085308681631
# bad cluster: 30253087 ratio min/max: 11.472077236442184 410.7700699383387
# bad cluster: 30253087 ratio min/max: 12.155165433071971 432.89752210369693
# bad cluster: 30253087 ratio min/max: 13.318699972484273 450.59948383598373
# bad cluster: 30253087 ratio min/max: 14.950296501029545 464.76105322181286
# bad cluster: 30253577 ratio min/max: 0.41567823103265095 396.3420130919702
# bad cluster: 30253577 ratio min/max: 2.600764991937508 2602.0527839726697
# bad cluster: 30253577 ratio min/max: 12.219000529259233 2717.532992832596
# bad cluster: 30253577 ratio min/max: 24.953959163638515 2809.917159920536
# bad cluster: 30253577 ratio min/max: 29.64470097218296 2883.824493590889
# bad cluster: 30253577 ratio min/max: 31.36986470713933 2942.950360527171
# bad cluster: 30253577 ratio min/max: 32.58455219712664 2990.251054076197
# bad cluster: 30253577 ratio min/max: 33.55570190764288 3028.091608915416
# bad cluster: 30253577 ratio min/max: 34.33262167605587 3058.364052786793
# bad cluster: 30253577 ratio min/max: 34.95415749078627 3082.582007883896
# bad cluster: 30253577 ratio min/max: 35.451386142570584 3101.941423277626
# bad cluster: 30253577 ratio min/max: 35.84916906399804 3116.418575603922
# bad cluster: 30253577 ratio min/max: 36.16739540114 3128.000297464961
# bad cluster: 30253577 ratio min/max: 36.42197647085357 3137.265674953791
# bad cluster: 30253865 ratio min/max: 1.8316279604617212 197.19040605024787
# bad cluster: 30253865 ratio min/max: 2.7296903484890502 197.19040605024787
# bad cluster: 30253865 ratio min/max: 3.142147108325317 197.19040605024787
# bad cluster: 30253865 ratio min/max: 3.4631898193971153 197.19040605024787
# bad cluster: 30253865 ratio min/max: 3.7463191353103897 197.19040605024787
# bad cluster: 30253865 ratio min/max: 4.05489259452378 197.19040605024787
# bad cluster: 30253865 ratio min/max: 4.3017513618944925 197.19040605024787
# bad cluster: 30253865 ratio min/max: 4.49951014383352 197.19040605024787
# bad cluster: 30253865 ratio min/max: 4.5994449238253425 197.19040605024787
# bad cluster: 30253865 ratio min/max: 4.599479166384025 197.19040605024787
# bad cluster: 30254185 ratio min/max: 0.7409220101385708 289.07916143809786
# bad cluster: 30254237 ratio min/max: 0.43891552483423557 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.6743986150390566 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.6743986150390566 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8569586334964782 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8570045299164609 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8570586217625217 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8571823822552622 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8582648166813066 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8583815628723828 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8583815628723828 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8583815628723828 185.10120784257458
# bad cluster: 30254237 ratio min/max: 0.8583815628723828 185.10120784257458
# bad cluster: 30254526 ratio min/max: 0.008074473881685248 510.197541400159
# bad cluster: 30254526 ratio min/max: 0.08894985658624083 3458.305777196622
# bad cluster: 30254526 ratio min/max: 4.537932547229297 3592.629510379236
# bad cluster: 30254526 ratio min/max: 8.871297426637634 3700.08849692533
# bad cluster: 30254526 ratio min/max: 11.11079543168751 3786.055686162203
# bad cluster: 30254526 ratio min/max: 12.899192955755357 3853.434624877216
# bad cluster: 30254526 ratio min/max: 14.327945277790747 3904.8245993261653
# bad cluster: 30254526 ratio min/max: 15.470664903336592 3945.936578885325
# bad cluster: 30255259 ratio min/max: 3.544167326013765 219.5008190431271
# bad cluster: 30255264 ratio min/max: 13.47081404213551 177.9174081948444
# bad cluster: 30255269 ratio min/max: 6.528397479881442 2816.872119894153
# bad cluster: 30255483 ratio min/max: 1.2523396621150624 769.9186845242957
# bad cluster: 30255891 ratio min/max: 0.1221079884712966 210.2014667727461
# bad cluster: 30255891 ratio min/max: 0.4983584582018624 210.2014667727461
# bad cluster: 30255891 ratio min/max: 0.6131115518315712 210.2014667727461
# bad cluster: 30255891 ratio min/max: 0.6135036857659077 210.2014667727461
# bad cluster: 30255891 ratio min/max: 0.6428898738587108 210.2014667727461
# bad cluster: 30255891 ratio min/max: 0.8942407251961344 210.2014667727461
# bad cluster: 30255891 ratio min/max: 1.1066767349599413 210.2014667727461
# bad cluster: 30255891 ratio min/max: 1.3667863001588059 210.2014667727461
# bad cluster: 30255891 ratio min/max: 2.5726510458155154 212.65994078124496
# bad cluster: 30255891 ratio min/max: 7.403119373044315 219.27413451939105
# bad cluster: 30255891 ratio min/max: 10.066485231929871 224.4145816194985
# bad cluster: 30255891 ratio min/max: 12.026100960559722 228.52672964388464
# bad cluster: 30255944 ratio min/max: 0.027676685938651857 223.53010244728154
# bad cluster: 30255944 ratio min/max: 0.6524052559504726 223.53010244728154
# bad cluster: 30255944 ratio min/max: 0.6524052559504726 223.53010244728154
# bad cluster: 30255944 ratio min/max: 0.6528599143728905 223.53010244728154
# bad cluster: 30255944 ratio min/max: 0.8278112512186446 223.53010244728154
# bad cluster: 30255944 ratio min/max: 1.0511250204922233 223.53010244728154
# bad cluster: 30255944 ratio min/max: 1.2895196626070509 223.53010244728154
# bad cluster: 30255944 ratio min/max: 1.6565424799744237 223.53010244728154
# bad cluster: 30255944 ratio min/max: 1.7889056504812424 223.53010244728154
# bad cluster: 30255944 ratio min/max: 1.7889056504812424 223.53010244728154
# bad cluster: 30255944 ratio min/max: 1.7889056504812424 223.53010244728154
# bad cluster: 30255944 ratio min/max: 1.7889056504812424 223.53010244728154
# bad cluster: 30255976 ratio min/max: 2.3353933974201504 272.6327589976181
# bad cluster: 30255976 ratio min/max: 14.211035170736146 517.3859749053777
# bad cluster: 30255976 ratio min/max: 21.455093888251366 542.0186022767075
# bad cluster: 30255976 ratio min/max: 22.98985431764875 561.7247041737714
# bad cluster: 30255976 ratio min/max: 24.21766266116665 577.4896602916363
# bad cluster: 30255976 ratio min/max: 25.199750207354615 590.1029104661533
# bad cluster: 30255976 ratio min/max: 25.983702175425055 600.1935106057665
# Geting Redshift Window
# bad cluster: 30255976 ratio min/max: 26.61086374988141 608.2659907174575
# Computing Galaxy Density
# bad cluster: 30256460 ratio min/max: 2.3748740371432606 167.25419124789212
# bad cluster: 30256460 ratio min/max: 4.195219543070755 167.25419124789212
# bad cluster: 30256460 ratio min/max: 4.915071998715694 167.25419124789212
# bad cluster: 30256460 ratio min/max: 5.489634571992014 167.25419124789212
# bad cluster: 30256460 ratio min/max: 5.9492835355375355 167.25419124789212
# bad cluster: 30256460 ratio min/max: 6.209934082406173 167.25419124789212
# bad cluster: 30256460 ratio min/max: 6.209934082406173 167.25419124789212
# Computing R200
# bad cluster: 30257105 ratio min/max: 7.786990237692124 410.0662937182912
# bad cluster: 30257324 ratio min/max: 0.03807775660445501 364.6647211991404
# bad cluster: 30257324 ratio min/max: 0.05067641742624093 2187.0556769705845
# bad cluster: 30257324 ratio min/max: 0.05612358773309802 2258.6666741705194
# bad cluster: 30257324 ratio min/max: 0.14270379470884031 2315.9554719304665
# bad cluster: 30257324 ratio min/max: 1.0990091555389214 2361.7865101384245
# bad cluster: 30257324 ratio min/max: 1.2672883339938679 2396.7035377123307
# bad cluster: 30257324 ratio min/max: 1.4320850507521279 2423.322911771829
# bad cluster: 30257324 ratio min/max: 1.593831885636857 2444.6184110194263
# bad cluster: 30257324 ratio min/max: 1.7627485110008352 2461.654810417506
# bad cluster: 30257324 ratio min/max: 2.0126930787140296 2475.283929935967
# bad cluster: 30257324 ratio min/max: 2.399970045909743 2486.1872255507374
# bad cluster: 8598473 ratio min/max: 0.012324651975196728 332.7656033303116
# bad cluster: 30257874 ratio min/max: 0.21115857887135903 193.0245383029018
# bad cluster: 8598473 ratio min/max: 0.012324651975196728 332.7656033303116
# bad cluster: 30257874 ratio min/max: 0.6437014368875201 193.0245383029018
# bad cluster: 8598473 ratio min/max: 0.012324651975196728 332.7656033303116
# bad cluster: 30257874 ratio min/max: 0.7034793379892457 193.0245383029018
# bad cluster: 8598473 ratio min/max: 0.012324651975196728 332.7656033303116
# bad cluster: 30257874 ratio min/max: 0.8715821292880652 193.0245383029018
# bad cluster: 8598473 ratio min/max: 0.028899354935877558 332.7656033303116
# bad cluster: 30257874 ratio min/max: 1.1289399444931012 193.0245383029018
# bad cluster: 8598473 ratio min/max: 1.2460414225215124 332.7656033303116
# bad cluster: 30257874 ratio min/max: 1.1614449291796791 193.0245383029018
# bad cluster: 8598473 ratio min/max: 2.2440766669860257 332.7656033303116
# bad cluster: 30257874 ratio min/max: 1.1614449291796791 193.0245383029018
# bad cluster: 8598473 ratio min/max: 3.0359175223950445 332.7656033303116
# bad cluster: 8598473 ratio min/max: 3.667292146797152 332.7656033303116
# bad cluster: 30257874 ratio min/max: 1.1614449291796791 193.0245383029018
# bad cluster: 30257874 ratio min/max: 1.1614449291796791 193.0245383029018
# bad cluster: 30257874 ratio min/max: 1.1614449291796791 193.0245383029018
# bad cluster: 30257874 ratio min/max: 1.1614449291796791 193.0245383029018
# bad cluster: 30257874 ratio min/max: 1.1614449291796791 193.0245383029018
# bad cluster: 30258098 ratio min/max: 7.002376329296061 231.7554872344632
# bad cluster: 30258324 ratio min/max: 7.886992288664047 199.0752918984472
# bad cluster: 30258324 ratio min/max: 12.02411492929758 199.0752918984472
# bad cluster: 30258324 ratio min/max: 14.274398201999226 199.0752918984472
# bad cluster: 30258324 ratio min/max: 15.46212023433245 200.33650277785193
# bad cluster: 30258324 ratio min/max: 16.41229786019903 213.8625278298401
# bad cluster: 30258324 ratio min/max: 17.172439960892294 225.47000447829592
# bad cluster: 30258324 ratio min/max: 17.780403395371117 234.23023493416056
# bad cluster: 30258324 ratio min/max: 18.265748041704846 241.23841929885214
# bad cluster: 30258324 ratio min/max: 18.654023758771828 246.84496679060555
# bad cluster: 30258324 ratio min/max: 18.96464433242541 251.33020478400812
# bad cluster: 30258733 ratio min/max: 3.1045265741346433 197.04933151434705
# bad cluster: 17196507 ratio min/max: 0.011387510404251424 3215.2616620990757
# bad cluster: 30258993 ratio min/max: 0.10740438825000982 209.7550649662468
# bad cluster: 17196507 ratio min/max: 0.017495074739445504 8388.709544520332
# bad cluster: 30258993 ratio min/max: 0.12145547148418072 209.7550649662468
# bad cluster: 17196507 ratio min/max: 0.0448321562643041 8486.080412220743
# bad cluster: 30258993 ratio min/max: 0.15759289730603387 209.7550649662468
# bad cluster: 17196507 ratio min/max: 0.04858986820117008 8563.977106381071
# bad cluster: 30258993 ratio min/max: 0.1636030338616071 209.7550649662468
# bad cluster: 17196507 ratio min/max: 0.057371755048743256 8626.294461709333
# bad cluster: 30258993 ratio min/max: 0.28845220461819965 209.7550649662468
# bad cluster: 17196507 ratio min/max: 0.13728245851204202 8674.846435583655
# bad cluster: 30258993 ratio min/max: 1.8144991958880914 209.7550649662468
# bad cluster: 17196507 ratio min/max: 0.35111935672332417 8713.431126192056
# bad cluster: 30258993 ratio min/max: 3.2809758571451555 209.7550649662468
# bad cluster: 17196507 ratio min/max: 2.9353561526456367 8744.298878678785
# bad cluster: 30258993 ratio min/max: 3.2809758571451555 209.7550649662468
# bad cluster: 17196507 ratio min/max: 4.984717467183563 8768.99308066816
# bad cluster: 30258993 ratio min/max: 3.2809758571451555 209.7550649662468
# bad cluster: 17196507 ratio min/max: 6.536726944383506 8788.748442259663
# bad cluster: 30258993 ratio min/max: 3.2809758571451555 209.7550649662468
# bad cluster: 17196507 ratio min/max: 7.378862330060049 8804.552731532865
# bad cluster: 30260348 ratio min/max: 8.754335600606113 438.32898522506224
# bad cluster: 30260348 ratio min/max: 25.942390879340937 777.0748604329967
# bad cluster: 30260751 ratio min/max: 1.8799418224921502 369.53063651028737
# bad cluster: 30260751 ratio min/max: 25.121897881769435 680.188985865576
# bad cluster: 30260751 ratio min/max: 28.049266003893877 889.6087970639325
# bad cluster: 30260751 ratio min/max: 30.311923751041107 1098.0176397873618
# bad cluster: 30260780 ratio min/max: 3.947088403814581 2066.961825582634
# bad cluster: 30260796 ratio min/max: 0.008602166282374986 220.79736947690276
# bad cluster: 30260796 ratio min/max: 0.012566053084814906 220.79736947690276
# bad cluster: 30260796 ratio min/max: 0.01331802454677971 220.79736947690276
# bad cluster: 30260796 ratio min/max: 0.04495829947281439 220.79736947690276
# bad cluster: 30260796 ratio min/max: 0.053933621740592005 220.79736947690276
# bad cluster: 30260796 ratio min/max: 0.05931014478828921 220.79736947690276
# bad cluster: 30260796 ratio min/max: 0.06623139594196908 220.79736947690276
# bad cluster: 30260796 ratio min/max: 0.08982703567054975 220.79736947690276
# bad cluster: 30260796 ratio min/max: 0.1212681809161035 220.79736947690276
# bad cluster: 30261487 ratio min/max: 6.79407104000172 256.06414116265825
# bad cluster: 30261602 ratio min/max: 17.31625394428486 2333.5265329217123
# bad cluster: 18172239 ratio min/max: 6.923070611247959 2931.722268586642
# bad cluster: 18175425 ratio min/max: 0.01055812811533468 2504.8570691869572
# bad cluster: 30265437 ratio min/max: 3.2557418960586904 182.28524661088431
# bad cluster: 18181357 ratio min/max: 0.009266164063703397 6293.9643483392665
# bad cluster: 30265437 ratio min/max: 4.510037008739014 182.28524661088431
# bad cluster: 18181357 ratio min/max: 0.009266164063703397 11119.964947035416
# bad cluster: 30265437 ratio min/max: 5.518793825599299 199.1649094249807
# bad cluster: 18181357 ratio min/max: 0.01956756000016826 11137.57640094091
# bad cluster: 30265437 ratio min/max: 6.993962839169285 230.0778384757936
# bad cluster: 18181357 ratio min/max: 0.496007413803097 11151.66556406531
# bad cluster: 30265437 ratio min/max: 18.966848593952164 254.50299469995147
# bad cluster: 30269123 ratio min/max: 0.20814958894737368 173.33352401931728
# bad cluster: 30269123 ratio min/max: 0.5511687731930848 173.33352401931728
# bad cluster: 30269123 ratio min/max: 1.0429624352379747 173.33352401931728
# bad cluster: 30269123 ratio min/max: 1.0429624352379747 173.33352401931728
# bad cluster: 30269123 ratio min/max: 1.0429624352379747 173.33352401931728
# bad cluster: 30269123 ratio min/max: 1.0429624352379747 173.33352401931728
# bad cluster: 30269123 ratio min/max: 1.0429624352379747 173.33352401931728
# bad cluster: 18227534 ratio min/max: 0.05012990933068436 224.9782198406619
# bad cluster: 18227534 ratio min/max: 0.656036743982215 224.9782198406619
# bad cluster: 18227534 ratio min/max: 0.6566317980954952 224.9782198406619
# bad cluster: 30848009 ratio min/max: 0.9780703720463546 155.8180905974826
# bad cluster: 18227534 ratio min/max: 0.7566216332926048 224.9782198406619
# bad cluster: 30848009 ratio min/max: 3.464547838182353 155.8180905974826
# bad cluster: 18227534 ratio min/max: 1.413136278747869 224.9782198406619
# bad cluster: 30848009 ratio min/max: 4.045837147782658 155.8180905974826
# bad cluster: 18227534 ratio min/max: 1.994446253219319 224.9782198406619
# bad cluster: 30848009 ratio min/max: 5.049214243028704 155.8180905974826
# bad cluster: 18227534 ratio min/max: 2.4855537447926057 224.9782198406619
# bad cluster: 30848009 ratio min/max: 5.7853263002696504 155.8180905974826
# bad cluster: 30848009 ratio min/max: 5.7853263002696504 155.8180905974826
# bad cluster: 18227534 ratio min/max: 3.150908269818438 224.9782198406619
# bad cluster: 18227534 ratio min/max: 8.353153393429253 224.9782198406619
# bad cluster: 30848009 ratio min/max: 5.7853263002696504 155.8180905974826
# bad cluster: 18227534 ratio min/max: 8.353153393429253 224.9782198406619
# bad cluster: 30848009 ratio min/max: 5.7853263002696504 155.8180905974826
# bad cluster: 18227534 ratio min/max: 8.353153393429253 224.9782198406619
# bad cluster: 30848009 ratio min/max: 5.7853263002696504 155.8180905974826
# bad cluster: 18227534 ratio min/max: 8.353153393429253 224.9782198406619
# bad cluster: 18227534 ratio min/max: 8.353153393429253 224.9782198406619
# bad cluster: 18227534 ratio min/max: 8.353153393429253 224.9782198406619
# bad cluster: 18227534 ratio min/max: 8.353153393429253 224.9782198406619
# bad cluster: 18228324 ratio min/max: 0.00907532303500191 232.90664839714537
# bad cluster: 18228324 ratio min/max: 1.8654029812578465 232.90664839714537
# bad cluster: 18228324 ratio min/max: 2.9921791058337903 232.90664839714537
# bad cluster: 18228324 ratio min/max: 5.13148677023954 232.90664839714537
# bad cluster: 30849432 ratio min/max: 0.9899784315294337 338.63967154231364
# bad cluster: 30849432 ratio min/max: 10.966957565972336 1351.4446365062752
# bad cluster: 30849432 ratio min/max: 13.59917939480605 1461.7231990764747
# bad cluster: 30849432 ratio min/max: 15.095134490708334 1536.9814597197292
# bad cluster: 30849432 ratio min/max: 16.289125051386613 1595.3382664129335
# bad cluster: 18228379 ratio min/max: 5.041408181114439 232.94827527184404
# bad cluster: 30849432 ratio min/max: 17.244317499929238 1642.0237117674988
# bad cluster: 30849432 ratio min/max: 18.008471458763335 1679.3720680511499
# bad cluster: 30849432 ratio min/max: 18.619794625830615 1709.2507530780715
# bad cluster: 30849432 ratio min/max: 19.108707394116763 1733.1537010996103
# bad cluster: 30849432 ratio min/max: 19.49903413497483 1752.276059516838
# bad cluster: 30849432 ratio min/max: 19.811295527661283 1767.5739462506226
# bad cluster: 30849432 ratio min/max: 20.06110464181045 1779.8122556376493
# bad cluster: 18230221 ratio min/max: 0.008727293783449675 235.63693215314117
# bad cluster: 18230221 ratio min/max: 0.008727293783449675 235.63693215314117
# bad cluster: 30849442 ratio min/max: 0.1971501316555731 168.90368429328205
# bad cluster: 18230221 ratio min/max: 0.008727293783449675 235.63693215314117
# bad cluster: 30849442 ratio min/max: 0.29790872413595865 168.90368429328205
# bad cluster: 18230221 ratio min/max: 0.010735620743673574 235.63693215314117
# bad cluster: 30849442 ratio min/max: 2.6443297118157703 168.90368429328205
# bad cluster: 30849442 ratio min/max: 3.2362286798058175 168.90368429328205
# bad cluster: 18230221 ratio min/max: 0.1364419719654971 235.63693215314117
# bad cluster: 18230221 ratio min/max: 0.17713969877521699 235.63693215314117
# bad cluster: 30849442 ratio min/max: 3.793745797973229 168.90368429328205
# bad cluster: 18230221 ratio min/max: 0.3719960002111444 235.63693215314117
# bad cluster: 30849442 ratio min/max: 4.22418851774033 168.90368429328205
# bad cluster: 18230221 ratio min/max: 0.46054303351753817 235.63693215314117
# bad cluster: 30849442 ratio min/max: 4.618359176098812 168.90368429328205
# bad cluster: 18230221 ratio min/max: 0.46054303351753817 235.63693215314117
# bad cluster: 30849442 ratio min/max: 5.032099507474896 168.90368429328205
# bad cluster: 18230221 ratio min/max: 0.46054303351753817 235.63693215314117
# bad cluster: 30849442 ratio min/max: 5.363210464492417 189.22699370323636
# bad cluster: 18230221 ratio min/max: 0.4608199125035305 235.63693215314117
# bad cluster: 30849442 ratio min/max: 5.628942360258356 215.48721307332312
# bad cluster: 18230221 ratio min/max: 0.5778621082262891 235.63693215314117
# bad cluster: 30849442 ratio min/max: 6.111402960201365 247.08024718174977
# bad cluster: 18230221 ratio min/max: 0.6670470238673768 235.63693215314117
# bad cluster: 30849442 ratio min/max: 6.519707106196167 272.49608430875384
# bad cluster: 18230221 ratio min/max: 0.7363665351351872 235.63693215314117
# bad cluster: 30849442 ratio min/max: 6.8464842985939125 288.18644806633216
# bad cluster: 18230221 ratio min/max: 0.7983393962784661 235.63693215314117
# bad cluster: 30849442 ratio min/max: 7.109594831679722 300.7054482646769
# bad cluster: 30850464 ratio min/max: 0.9334131339848564 298.5672701005023
# bad cluster: 30850464 ratio min/max: 7.740421397549315 554.5782614912073
# bad cluster: 30850464 ratio min/max: 8.365238459645896 591.8559848756863
# bad cluster: 30850464 ratio min/max: 8.86501585918894 621.6781635832679
# bad cluster: 30850464 ratio min/max: 9.263944760316342 645.5359065493336
# bad cluster: 18233548 ratio min/max: 3.0935873782896306 1847.5122301324066
# bad cluster: 30850464 ratio min/max: 9.58308788121826 664.6221009221877
# bad cluster: 30850464 ratio min/max: 9.838402377939797 687.0397699325421
# bad cluster: 30850754 ratio min/max: 1.015881465722026 169.0903434378505
# bad cluster: 30850754 ratio min/max: 2.0085498122482646 199.34176989402297
# bad cluster: 30850754 ratio min/max: 2.450155672764653 223.20363847535808
# bad cluster: 30850754 ratio min/max: 2.9501705434691377 242.19895179225907
# bad cluster: 30850754 ratio min/max: 4.383019460014598 256.7603307050346
# bad cluster: 18237587 ratio min/max: 0.3798826642450841 2242.37523254256
# bad cluster: 30850754 ratio min/max: 14.353998399777263 268.409433835255
# bad cluster: 30850754 ratio min/max: 19.37458669447459 277.7287163394314
# bad cluster: 30850754 ratio min/max: 20.137399643369836 285.1841423427725
# bad cluster: 30850754 ratio min/max: 20.746470826456335 291.14848314544537
# bad cluster: 18238445 ratio min/max: 0.008583095131855479 231.74356856009788
# bad cluster: 30850754 ratio min/max: 21.23350639243052 295.91995578758355
# bad cluster: 18238445 ratio min/max: 0.008583095131855479 231.74356856009788
# bad cluster: 30850754 ratio min/max: 21.269543182780343 299.7371339012942
# bad cluster: 18238445 ratio min/max: 0.2624219480975026 231.74356856009788
# bad cluster: 18238445 ratio min/max: 0.37776971677973026 231.74356856009788
# bad cluster: 18238445 ratio min/max: 0.43601410821656905 231.74356856009788
# bad cluster: 30850895 ratio min/max: 4.043973468242547 230.2276326477927
# bad cluster: 18238445 ratio min/max: 0.5494317870325257 231.74356856009788
# bad cluster: 18238445 ratio min/max: 0.5494317870325257 231.74356856009788
# bad cluster: 30850895 ratio min/max: 21.014638502961645 610.4213289269132
# bad cluster: 18238445 ratio min/max: 0.5494317870325257 231.74356856009788
# bad cluster: 30850895 ratio min/max: 22.175048463124973 625.5615370002411
# bad cluster: 18238445 ratio min/max: 0.5494317870325257 231.74356856009788
# bad cluster: 30850895 ratio min/max: 22.87657185857637 637.4489950947618
# bad cluster: 18238445 ratio min/max: 0.5494317870325257 231.74356856009788
# bad cluster: 30850895 ratio min/max: 23.437790574937495 646.8235765346523
# bad cluster: 30850895 ratio min/max: 23.88676554802639 654.3231034460329
# bad cluster: 30850895 ratio min/max: 24.245945526497508 660.322641686296
# bad cluster: 30850895 ratio min/max: 24.5332895092744 665.1222722785063
# bad cluster: 18241600 ratio min/max: 9.669295186580252 244.23374967249643
# bad cluster: 30851041 ratio min/max: 3.9380662500600003 424.2573748193133
# bad cluster: 30851041 ratio min/max: 15.903814708063617 3055.950475675962
# bad cluster: 30851041 ratio min/max: 17.40912046584092 3109.4457541059855
# bad cluster: 30851041 ratio min/max: 18.61336130474338 3152.2419768500054
# bad cluster: 30851041 ratio min/max: 19.575942602700845 3186.478955045221
# bad cluster: 30851041 ratio min/max: 20.344846674498843 3213.868537601394
# bad cluster: 30851041 ratio min/max: 20.959969931937252 3235.7802036463313
# bad cluster: 30851041 ratio min/max: 21.45206853788798 3253.309536482282
# bad cluster: 18284374 ratio min/max: 0.007936725040614974 1371.420615593081
# bad cluster: 30851041 ratio min/max: 21.84574742264855 3267.333002751041
# bad cluster: 18284374 ratio min/max: 2.472952593080676 2659.4490824708273
# bad cluster: 30851041 ratio min/max: 22.160690530457018 3278.55177576605
# bad cluster: 18284374 ratio min/max: 7.374518317230753 2764.556531213215
# bad cluster: 30851041 ratio min/max: 22.41264501670378 3287.5267941780567
# bad cluster: 18284374 ratio min/max: 11.267727139868356 2848.6248484301645
# bad cluster: 18284374 ratio min/max: 14.37236161518814 2914.7859514273528
# bad cluster: 30851209 ratio min/max: 9.916601553773468 260.9256995695296
# bad cluster: 30851492 ratio min/max: 0.19879727643551814 174.51057435132438
# bad cluster: 30851492 ratio min/max: 0.9327619345362853 174.51057435132438
# bad cluster: 18285801 ratio min/max: 0.051825475658180874 212.1668882585594
# bad cluster: 30851492 ratio min/max: 1.2405618106088219 174.51057435132438
# bad cluster: 18285801 ratio min/max: 0.10229452505114182 212.1668882585594
# bad cluster: 30851492 ratio min/max: 2.0492648200784345 174.51057435132438
# bad cluster: 18285801 ratio min/max: 1.1336363770650113 212.1668882585594
# bad cluster: 30851492 ratio min/max: 2.2736601717400893 174.51057435132438
# bad cluster: 18285801 ratio min/max: 2.9030202246537513 212.1668882585594
# bad cluster: 30851492 ratio min/max: 2.4815614611040324 174.51057435132438
# bad cluster: 18285801 ratio min/max: 3.379274197013264 212.1668882585594
# bad cluster: 30851492 ratio min/max: 2.683435197944459 174.51057435132438
# bad cluster: 18285801 ratio min/max: 4.498665449958331 212.1668882585594
# bad cluster: 30851492 ratio min/max: 2.7296836972941056 174.51057435132438
# bad cluster: 18285801 ratio min/max: 4.948533722697902 212.1668882585594
# bad cluster: 30851492 ratio min/max: 2.7296836972941056 174.51057435132438
# bad cluster: 18285801 ratio min/max: 4.948614300031178 212.1668882585594
# bad cluster: 30851492 ratio min/max: 2.7296836972941056 174.51057435132438
# bad cluster: 18285801 ratio min/max: 4.948691202260457 212.1668882585594
# bad cluster: 18285801 ratio min/max: 4.948809284552623 212.1668882585594
# bad cluster: 18285801 ratio min/max: 4.9490052400354525 212.1668882585594
# bad cluster: 18285801 ratio min/max: 4.950252472319699 212.1668882585594
# bad cluster: 18285801 ratio min/max: 4.951243722355977 212.1668882585594
# bad cluster: 18285801 ratio min/max: 4.9519057743324 212.1668882585594
# bad cluster: 30851858 ratio min/max: 2.5437323453475233 259.40600678867065
# bad cluster: 18286678 ratio min/max: 0.008164518105096174 220.44198883759663
# bad cluster: 30851858 ratio min/max: 14.066997554324049 467.6079516291474
# bad cluster: 18286678 ratio min/max: 0.013295799853002091 220.44198883759663
# bad cluster: 30851858 ratio min/max: 16.093104163614225 500.0915819129516
# bad cluster: 18286678 ratio min/max: 0.018900194234376794 220.44198883759663
# bad cluster: 30851858 ratio min/max: 17.713360576273537 526.0783028150962
# bad cluster: 18286678 ratio min/max: 0.04908105512315433 220.44198883759663
# bad cluster: 30851858 ratio min/max: 19.00765588311343 546.8668524821857
# bad cluster: 18286678 ratio min/max: 0.11388257221661235 220.44198883759663
# bad cluster: 30851858 ratio min/max: 20.04217663239819 563.4976922158576
# bad cluster: 18286678 ratio min/max: 5.14165661471546 220.44198883759663
# bad cluster: 18286678 ratio min/max: 5.141821977406635 220.44198883759663
# bad cluster: 18286678 ratio min/max: 5.143043072472972 220.44198883759663
# bad cluster: 18286678 ratio min/max: 5.145153752627471 220.44198883759663
# bad cluster: 30852944 ratio min/max: 8.484804176484015 9287.418008047505
# bad cluster: 18286678 ratio min/max: 5.14644099293264 220.44198883759663
# bad cluster: 30852944 ratio min/max: 13.481704113891666 14210.051834565838
# bad cluster: 18286678 ratio min/max: 5.14739939136389 220.44198883759663
# bad cluster: 18286678 ratio min/max: 5.148134108998916 220.44198883759663
# bad cluster: 18286678 ratio min/max: 5.148718340918773 220.44198883759663
# bad cluster: 30853078 ratio min/max: 1.7819306017693668 2087.2204686601694
# bad cluster: 18286678 ratio min/max: 5.149166692305885 220.44198883759663
# bad cluster: 30853078 ratio min/max: 14.691479239621446 4426.675511687971
# bad cluster: 18286678 ratio min/max: 5.149525373415575 220.44198883759663
# bad cluster: 30853078 ratio min/max: 15.646234755202894 4458.5035306356385
# bad cluster: 18286678 ratio min/max: 5.149812318303326 220.44198883759663
# bad cluster: 30853078 ratio min/max: 16.410039167668053 4483.965945793774
# bad cluster: 30853078 ratio min/max: 17.02108269764018 4504.335877920281
# bad cluster: 30853078 ratio min/max: 17.509917521617883 4520.6318236214875
# bad cluster: 30853078 ratio min/max: 17.900330618988693 4533.6685801824515
# bad cluster: 30853078 ratio min/max: 18.212449174181852 4544.0979854312245
# bad cluster: 30853078 ratio min/max: 18.462144018336375 4552.441509630242
# bad cluster: 18288097 ratio min/max: 0.008362891429997745 601.646704031092
# bad cluster: 18288097 ratio min/max: 0.008362891429997745 4515.0633823727985
# bad cluster: 18288097 ratio min/max: 3.259778599095576 4690.754548018625
# bad cluster: 30853615 ratio min/max: 1.049071890176211 1945.831663593613
# bad cluster: 30853615 ratio min/max: 1.4832989160605103 4706.171259333499
# bad cluster: 30853615 ratio min/max: 1.8189188402540668 4750.815848200644
# bad cluster: 30853615 ratio min/max: 2.238266089978321 4786.531519294361
# bad cluster: 30853615 ratio min/max: 4.046921271739205 4815.104056169334
# bad cluster: 30853615 ratio min/max: 11.498515258192741 4837.962085669314
# bad cluster: 30853615 ratio min/max: 14.414170378718596 4856.248509269296
# bad cluster: 30853615 ratio min/max: 14.861478598351727 4870.877648149282
# bad cluster: 30853615 ratio min/max: 15.219324550721145 4882.580959253271
# bad cluster: 30853615 ratio min/max: 15.505241789710869 4891.943608136463
# bad cluster: 30853765 ratio min/max: 6.758648430373484 262.7320460856078
# bad cluster: 30854548 ratio min/max: 2.818790013631398 175.85625185267688
# bad cluster: 30854548 ratio min/max: 4.6610676687788155 1178.6968133196854
# bad cluster: 30856885 ratio min/max: 3.4096626362809204 163.18229523756216
# bad cluster: 30856885 ratio min/max: 16.78386555586878 496.8742207366372
# bad cluster: 30856885 ratio min/max: 17.55667294046801 510.1857641218955
# bad cluster: 30856885 ratio min/max: 18.174918848147403 520.834998830102
# bad cluster: 30856885 ratio min/max: 18.66877406821727 529.3543865966674
# bad cluster: 30856885 ratio min/max: 19.06352094383629 536.1698968099196
# bad cluster: 30856885 ratio min/max: 19.379318444331506 541.6223049805213
# bad cluster: 30856885 ratio min/max: 19.63195644472768 545.9842315170027
# bad cluster: 19047700 ratio min/max: 1.692803484919427 2908.7928558998556
# bad cluster: 19047700 ratio min/max: 3.8497485524838666 4644.975627504823
# bad cluster: 19047700 ratio min/max: 20.347619067833957 4729.559053894907
# bad cluster: 30857258 ratio min/max: 0.6824283203838104 174.34821969448933
# bad cluster: 19047700 ratio min/max: 23.693247685236667 4797.225260996853
# bad cluster: 30857781 ratio min/max: 2.309721427057875 164.8105407843881
# bad cluster: 19047969 ratio min/max: 7.0671656575769335 198.56279322756927
# bad cluster: 30858175 ratio min/max: 7.873060189360693 163.45492438644166
# bad cluster: 30858175 ratio min/max: 10.47208408305084 163.45492438644166
# bad cluster: 30858175 ratio min/max: 10.47208408305084 168.74448545749866
# bad cluster: 30858175 ratio min/max: 10.47208408305084 173.54397765676515
# bad cluster: 30858175 ratio min/max: 10.47208408305084 177.3539468997103
# bad cluster: 30858175 ratio min/max: 10.47208408305084 180.40179140468766
# bad cluster: 19048253 ratio min/max: 4.733003462089015 203.78544848669176
# bad cluster: 19048262 ratio min/max: 3.2593167590825485 553.3119310636218
# bad cluster: 30860254 ratio min/max: 5.878449640576888 2327.0583230952784
# bad cluster: 30860254 ratio min/max: 9.18794418374697 5088.289259295019
# bad cluster: 30860254 ratio min/max: 10.100683937186103 5118.040364492259
# bad cluster: 19048286 ratio min/max: 0.27357168969103407 217.57743866008613
# bad cluster: 30860254 ratio min/max: 10.830158434031 5141.84124865005
# bad cluster: 19048286 ratio min/max: 0.5159226190335277 217.57743866008613
# bad cluster: 19048286 ratio min/max: 0.8719141683639595 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.0642354542037262 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.701142641925325 217.57743866008613
# bad cluster: 30860366 ratio min/max: 3.3280153343547454 413.7965965537408
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 30862591 ratio min/max: 2.600562652539105 180.82884795756777
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 30862591 ratio min/max: 4.976527865658372 180.82884795756777
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 19048286 ratio min/max: 1.7412666355667281 217.57743866008613
# bad cluster: 30904113 ratio min/max: 0.27510297012809837 168.76245285733367
# bad cluster: 19048877 ratio min/max: 0.9300850225919639 200.88804518632946
# bad cluster: 30904113 ratio min/max: 0.40011231652951484 168.76245285733367
# bad cluster: 19048877 ratio min/max: 1.5270936400258954 281.5854028263444
# bad cluster: 30904113 ratio min/max: 0.4286568149756143 168.76245285733367
# bad cluster: 19048877 ratio min/max: 3.819356810883427 321.43429953819395
# bad cluster: 30904113 ratio min/max: 0.6148699179444365 168.76245285733367
# bad cluster: 19048877 ratio min/max: 22.35096653481796 352.9948479280182
# bad cluster: 30904113 ratio min/max: 0.6713418783163413 168.76245285733367
# bad cluster: 19048877 ratio min/max: 24.00503655402373 378.0898574722605
# bad cluster: 30904113 ratio min/max: 0.7813189879773812 168.76245285733367
# bad cluster: 30904113 ratio min/max: 0.7813440951405686 168.76245285733367
# bad cluster: 30904113 ratio min/max: 0.7813666610126722 168.76245285733367
# bad cluster: 30904113 ratio min/max: 0.781390808581979 168.76245285733367
# bad cluster: 30904113 ratio min/max: 0.7814101266374244 168.76245285733367
# bad cluster: 30904113 ratio min/max: 0.7814417687930394 168.76245285733367
# bad cluster: 34056556 ratio min/max: 1.1783530349811269 536.1284689822851
# bad cluster: 34057948 ratio min/max: 0.547733279739107 406.59491284645077
# bad cluster: 34057948 ratio min/max: 3.908415417281974 563.2293098117017
# bad cluster: 19052216 ratio min/max: 2.253616254149618 204.96981818133972
# bad cluster: 34057948 ratio min/max: 5.759445249322208 570.9657674207759
# bad cluster: 19052216 ratio min/max: 2.253616254149618 204.96981818133972
# bad cluster: 34057948 ratio min/max: 7.23577732521537 577.1549335080355
# bad cluster: 19052216 ratio min/max: 2.253616254149618 204.96981818133972
# bad cluster: 34057948 ratio min/max: 8.414609459348192 582.1062663778429
# bad cluster: 19052216 ratio min/max: 2.253616254149618 204.96981818133972
# bad cluster: 34057948 ratio min/max: 9.35647446075659 586.0673326736888
# bad cluster: 19052216 ratio min/max: 2.253616254149618 204.96981818133972
# bad cluster: 34057948 ratio min/max: 10.109545166500016 589.2361857103656
# bad cluster: 19052216 ratio min/max: 2.790319251798074 204.96981818133972
# bad cluster: 34057948 ratio min/max: 10.710900655675395 591.7712681397072
# bad cluster: 19052216 ratio min/max: 3.172810338582943 204.96981818133972
# bad cluster: 34057948 ratio min/max: 11.191985047015693 593.7993340831804
# bad cluster: 34057948 ratio min/max: 11.576852560087934 595.4217868379587
# bad cluster: 19052297 ratio min/max: 4.383549596384964 8342.933292628768
# bad cluster: 19052297 ratio min/max: 7.628707587582749 13056.211174069436
# bad cluster: 19052297 ratio min/max: 8.914749343609696 13095.622443088478
# bad cluster: 19052297 ratio min/max: 9.942163657860949 13127.151458303715
# bad cluster: 19052297 ratio min/max: 10.76366133737366 13152.3746704759
# bad cluster: 19052297 ratio min/max: 11.419646724622575 13172.553240213654
# bad cluster: 34070277 ratio min/max: 0.009025688708995977 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.018150672635448516 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.03209545271771139 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.11481784525965713 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.2796137918556914 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.3588111083502452 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.359134218089876 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.4582713399689994 220.11337329237023
# bad cluster: 19055186 ratio min/max: 2.510784598148201 7410.976299001161
# bad cluster: 34070277 ratio min/max: 0.5469058646149485 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.6215966182822618 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.7054453997458349 220.11337329237023
# bad cluster: 34070277 ratio min/max: 0.7804234644811674 220.11337329237023
# Geting Redshift Window
# Computing Galaxy Density
# bad cluster: 19055517 ratio min/max: 0.2809442160644175 172.28917027881977
# bad cluster: 19055517 ratio min/max: 0.36115548713139434 172.28917027881977
# bad cluster: 19055517 ratio min/max: 0.44545686448512933 172.28917027881977
# bad cluster: 19055517 ratio min/max: 0.5307138604667383 172.28917027881977
# bad cluster: 19055517 ratio min/max: 0.6256681109383725 172.28917027881977
# bad cluster: 19055517 ratio min/max: 0.840175908133807 172.28917027881977
# bad cluster: 19055517 ratio min/max: 2.4686715692132863 172.28917027881977
# bad cluster: 19056873 ratio min/max: 9.376291743506783 424.0400339029362
# Computing PDFs
#
# -> Radial Distribution
# bad cluster: 19058334 ratio min/max: 2.6228471138062943 428.43497853422923
# bad cluster: 19058334 ratio min/max: 4.6816666475073765 2850.920497985207
# Computing R200
# bad cluster: 19062914 ratio min/max: 0.009764142375429332 161.8781332111336
# bad cluster: 19062914 ratio min/max: 0.023603981406473747 161.8781332111336
# Geting Redshift Window
# bad cluster: 19062914 ratio min/max: 0.04257403930967764 161.8781332111336
# Computing Galaxy Density
# bad cluster: 19062914 ratio min/max: 0.07444326274378281 161.8781332111336
# bad cluster: 19062914 ratio min/max: 0.44938843997780265 161.8781332111336
# bad cluster: 19062914 ratio min/max: 1.957317468119725 161.8781332111336
# bad cluster: 19062914 ratio min/max: 2.999648521437694 161.8781332111336
# bad cluster: 19062914 ratio min/max: 3.781885226811178 161.8781332111336
# bad cluster: 19062914 ratio min/max: 3.782132806269681 161.8781332111336
# bad cluster: 19062914 ratio min/max: 3.7823302210361516 161.8781332111336
# Computing R200
# bad cluster: 8880583 ratio min/max: 0.012598091685901959 340.1484755193528
# bad cluster: 8880583 ratio min/max: 0.012598091685901959 340.1484755193528
# bad cluster: 8880583 ratio min/max: 0.030210310325767008 340.1484755193528
# bad cluster: 8880583 ratio min/max: 0.6648066978746758 340.1484755193528
# bad cluster: 8880583 ratio min/max: 0.6650262713858349 340.1484755193528
# bad cluster: 8880583 ratio min/max: 0.845609680745407 340.1484755193528
# bad cluster: 8880583 ratio min/max: 1.0828003236997406 340.1484755193528
# bad cluster: 8880583 ratio min/max: 1.3435134838608216 352.7961180812844
# bad cluster: 8880583 ratio min/max: 1.7853930786329477 364.1735748064473
# bad cluster: 8880583 ratio min/max: 6.66983502912113 373.25652040814936
# bad cluster: 8880583 ratio min/max: 10.148562614926195 380.5226431857084
# bad cluster: 8880583 ratio min/max: 12.614671725844328 386.3355414077554
# bad cluster: 19099983 ratio min/max: 2.571796143141434 189.82090717101943
# bad cluster: 19099983 ratio min/max: 10.505799814734882 189.82090717101943
# bad cluster: 19099983 ratio min/max: 11.929368733709627 189.82090717101943
# bad cluster: 19099983 ratio min/max: 13.64017286226964 201.6813668197064
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:512: RuntimeWarning: divide by zero encountered in double_scalars
#   prior = 1 - (nb*area/np.sum(probz))
# /home/s1/jesteves/git/ccopa/python/copac/probRadial.py:485: RuntimeWarning: invalid value encountered in divide
#   return ng/norm
# bad cluster: 19100756 ratio min/max: 1.772761855061978 175.91435111687883
# bad cluster: 17077018 ratio min/max: 2.5473052040379853 326.7155475449936
# bad cluster: 19101967 ratio min/max: 8.610753901816523 1842.9802695171054
# bad cluster: 19103510 ratio min/max: 0.013409899560674659 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.03115270657810716 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.04389760359097491 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.0531168672973665 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.17039840578691587 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.17053020848754258 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.3330864025735678 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.5754434837738506 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.5754434837738506 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.6340476445692733 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.7687200794939347 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.8694849236034163 197.16110455485708
# bad cluster: 19103510 ratio min/max: 0.9500670396064426 197.16110455485708
# bad cluster: 19103510 ratio min/max: 1.0351690140372685 197.16110455485708
# bad cluster: 19103510 ratio min/max: 1.1126155567285638 197.16110455485708
# bad cluster: 19105131 ratio min/max: 27.313387150593506 523.5753123378398
# bad cluster: 19105134 ratio min/max: 3.8394186954712666 369.86780709270045
# bad cluster: 17135057 ratio min/max: 0.01148325376268061 531.0833842746124
# bad cluster: 19105134 ratio min/max: 7.037149386302592 1617.486127895209
# bad cluster: 19105134 ratio min/max: 7.8373720979862265 1704.4420729084409
# bad cluster: 19105134 ratio min/max: 8.555044354655394 1774.0068289190265
# bad cluster: 19105134 ratio min/max: 9.12918215999073 1829.6586337274937
# bad cluster: 19105134 ratio min/max: 10.222893148510156 1874.1800775742709
# bad cluster: 19105134 ratio min/max: 11.107366673047643 1909.7972326516901
# bad cluster: 19105134 ratio min/max: 12.549878236429134 1938.2909567136257
# bad cluster: 19105134 ratio min/max: 14.89604651473186 1961.085935963174
# bad cluster: 19105134 ratio min/max: 23.587640881701894 1979.3219193628136
# bad cluster: 19105134 ratio min/max: 24.30769661767316 1993.910706082525
#
#
# look here
# bad cluster: 19105442 ratio min/max: 0.8763491505590355 146.73096185654546
#
#
#
#
# bad cluster: 19106072 ratio min/max: 1.834388849111782 175.80220460697572
# bad cluster: 19106072 ratio min/max: 2.693474540021361 175.80220460697572
# bad cluster: 19106072 ratio min/max: 3.2177471116302825 175.80220460697572
# bad cluster: 19106072 ratio min/max: 3.8208890016365675 175.80220460697572
# bad cluster: 19106072 ratio min/max: 4.598257324932067 175.80220460697572
# bad cluster: 19106072 ratio min/max: 6.545533940012419 175.80220460697572
# bad cluster: 19106072 ratio min/max: 11.263138602526354 175.80220460697572
# bad cluster: 19106072 ratio min/max: 11.263138602526354 175.80220460697572
# bad cluster: 19106072 ratio min/max: 11.263138602526354 175.80220460697572
# bad cluster: 19106072 ratio min/max: 11.263138602526354 175.80220460697572
# bad cluster: 19106072 ratio min/max: 11.263138602526354 175.80220460697572
# bad cluster: 19106072 ratio min/max: 11.263138602526354 175.80220460697572
# bad cluster: 19106249 ratio min/max: 2.3521558311900477 325.09047180405327
# bad cluster: 19106249 ratio min/max: 3.6153067884117913 421.7369808040843
# bad cluster: 19106249 ratio min/max: 5.538199491279329 435.31768199160814
# bad cluster: 19106249 ratio min/max: 21.10609830246611 446.18224294162724
# ...
# alpha,beta: -1.53 ,3.53
# alpha,beta: 2.87 ,5.88
# alpha,beta: 1.46 ,5.90
# alpha,beta: 3.50 ,8.17
# alpha,beta: 2.73 ,5.77
# alpha,beta: 3.70 ,5.49
# alpha,beta: 3.38 ,6.81
# alpha,beta: 1.68 ,8.96
# alpha,beta: 1.63 ,6.45
# alpha,beta: 1.47 ,7.46
# alpha,beta: 3.12 ,7.28
# alpha,beta: 2.15 ,8.13
# alpha,beta: 0.86 ,7.73
# alpha,beta: 1.49 ,5.22
# alpha,beta: 1.88 ,7.04
# alpha,beta: 3.71 ,4.96
# alpha,beta: 7.65 ,1.85
# alpha,beta: 3.93 ,4.86
# alpha,beta: 1.02 ,7.46
# alpha,beta: 2.56 ,8.21
# alpha,beta: 2.37 ,3.32
# alpha,beta: 5.83 ,6.13
# alpha,beta: 0.74 ,6.53
# alpha,beta: 1.31 ,8.21
# alpha,beta: 3.03 ,5.36
# alpha,beta: 3.88 ,6.43
# alpha,beta: 1.86 ,6.10
# alpha,beta: 0.69 ,5.38
# alpha,beta: 0.72 ,7.62
# alpha,beta: 3.16 ,4.06
# alpha,beta: 1.80 ,5.66
# alpha,beta: 0.19 ,7.79
# alpha,beta: 1.66 ,3.64
# alpha,beta: 3.68 ,7.18
# alpha,beta: 1.64 ,5.83
# alpha,beta: 0.71 ,10.05
# alpha,beta: 2.73 ,6.48
# alpha,beta: 1.46 ,6.47
# alpha,beta: 3.10 ,8.43
# alpha,beta: 2.79 ,2.48
# alpha,beta: 4.12 ,7.14
# alpha,beta: 3.06 ,7.47
# alpha,beta: -0.24 ,6.02
# alpha,beta: 1.29 ,3.36
# alpha,beta: 3.33 ,8.21
# alpha,beta: 4.85 ,8.09
# alpha,beta: 2.65 ,7.46
# alpha,beta: 2.44 ,9.17
# alpha,beta: -0.20 ,8.02
# alpha,beta: 2.04 ,7.16
# alpha,beta: 1.61 ,6.51
# alpha,beta: 2.03 ,5.03
# alpha,beta: 2.51 ,6.68
# alpha,beta: 1.15 ,6.64
# alpha,beta: 3.17 ,9.81
# alpha,beta: 3.34 ,8.22
# alpha,beta: 2.91 ,7.87
# alpha,beta: 0.91 ,6.89
# alpha,beta: 2.07 ,5.05
# alpha,beta: 0.11 ,6.27
# alpha,beta: 1.84 ,5.15
# alpha,beta: 0.33 ,6.08
# alpha,beta: 2.79 ,7.15
# alpha,beta: 3.40 ,4.03
# alpha,beta: 3.19 ,9.20
# alpha,beta: 0.89 ,9.44
# alpha,beta: 1.12 ,4.92
# alpha,beta: 2.20 ,4.90
# alpha,beta: 1.77 ,6.78
# alpha,beta: 1.67 ,5.51
# alpha,beta: 1.21 ,9.21
# alpha,beta: 1.71 ,2.08
# alpha,beta: -1.19 ,5.60
# alpha,beta: 4.25 ,3.98
# alpha,beta: 2.12 ,3.91
# alpha,beta: 1.17 ,4.96
# alpha,beta: -0.75 ,4.46
# alpha,beta: -2.45 ,5.74
# alpha,beta: 3.75 ,4.47
# alpha,beta: 2.43 ,5.13
# alpha,beta: 3.52 ,4.21
# alpha,beta: 3.11 ,2.69
# alpha,beta: 2.09 ,3.70
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# Compute MaskFraction and Norm
# norm less than zero: -1.3310512231438885
# norm less than zero: -4.810624262542518
# norm less than zero: -0.7947301347475508
# norm less than zero: -5.428993577264488
# norm less than zero: -2.505935123825091
# norm less than zero: -0.4696571626060452
#
#  Compute Probabilities
# alpha,beta: 8.10 ,5.46
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 9.60 ,4.93
# alpha,beta: 5.39 ,4.83
# alpha,beta: 11.44 ,5.18
# alpha,beta: 7.93 ,5.37
# alpha,beta: 7.79 ,4.05
# alpha,beta: 9.32 ,3.15
# alpha,beta: 8.13 ,5.36
# alpha,beta: 7.60 ,4.08
# alpha,beta: 9.05 ,4.32
# alpha,beta: 7.29 ,4.74
# alpha,beta: 10.11 ,5.60
# alpha,beta: 9.05 ,5.12
# alpha,beta: 5.45 ,4.77
# alpha,beta: 6.71 ,6.00
# alpha,beta: 6.95 ,4.61
# alpha,beta: 6.52 ,4.63
# alpha,beta: 5.75 ,5.80
# alpha,beta: 7.87 ,6.12
# alpha,beta: 7.32 ,2.52
# alpha,beta: 4.33 ,3.24
# alpha,beta: 7.67 ,8.21
# alpha,beta: 6.05 ,7.14
# alpha,beta: 8.12 ,5.86
# alpha,beta: 6.76 ,5.46
# alpha,beta: 7.60 ,6.27
# alpha,beta: 4.69 ,6.03
# alpha,beta: 5.86 ,6.13
# alpha,beta: 8.17 ,5.33
# alpha,beta: 5.10 ,4.79
# alpha,beta: 6.55 ,5.94
# alpha,beta: 7.80 ,5.44
# alpha,beta: 6.27 ,4.95
# alpha,beta: 5.07 ,5.08
# alpha,beta: 7.47 ,2.40
# alpha,beta: 8.14 ,4.88
# alpha,beta: 7.19 ,8.04
# alpha,beta: 3.16 ,7.01
# alpha,beta: 6.25 ,6.36
# alpha,beta: 7.43 ,7.87
# alpha,beta: 9.32 ,7.84
# alpha,beta: 5.89 ,10.07
# alpha,beta: 8.11 ,8.22
# alpha,beta: 6.17 ,8.48
# alpha,beta: 6.26 ,7.04
# alpha,beta: 5.40 ,8.57
# alpha,beta: 6.74 ,6.68
# alpha,beta: 8.23 ,8.95
# alpha,beta: 5.93 ,7.88
# alpha,beta: 5.30 ,6.11
# alpha,beta: 4.93 ,3.57
# alpha,beta: 9.52 ,6.81
# alpha,beta: 5.09 ,7.54
# alpha,beta: 6.62 ,7.66
# alpha,beta: 7.61 ,7.08
# alpha,beta: 4.32 ,7.07
# alpha,beta: 6.64 ,7.91
# alpha,beta: 3.52 ,6.46
# alpha,beta: 6.28 ,6.24
# alpha,beta: 4.92 ,7.74
# alpha,beta: 3.78 ,8.36
# alpha,beta: 4.55 ,7.24
# alpha,beta: 3.92 ,8.04
# alpha,beta: 5.94 ,7.66
# alpha,beta: 4.80 ,9.48
# alpha,beta: 1.48 ,8.67
# alpha,beta: 7.62 ,10.40
# alpha,beta: 8.02 ,9.19
# alpha,beta: 5.98 ,7.79
# alpha,beta: 4.91 ,9.23
# alpha,beta: 7.55 ,8.44
# alpha,beta: 6.22 ,6.28
# alpha,beta: 3.74 ,9.63
# alpha,beta: 7.92 ,9.06
# alpha,beta: 5.28 ,7.45
# alpha,beta: 3.01 ,7.91
# alpha,beta: 4.93 ,6.54
# alpha,beta: 4.39 ,7.51
# alpha,beta: 3.21 ,7.70
# alpha,beta: 5.00 ,11.62
# alpha,beta: 3.09 ,9.65
# alpha,beta: 8.52 ,9.96
# alpha,beta: 4.19 ,11.74
# alpha,beta: 2.18 ,12.01
# alpha,beta: 5.19 ,9.98
# alpha,beta: 9.09 ,8.82
# alpha,beta: 3.12 ,7.90
# alpha,beta: 5.44 ,6.46
# alpha,beta: 2.87 ,9.49
# alpha,beta: 5.78 ,10.94
# alpha,beta: 8.16 ,11.33
# alpha,beta: 3.87 ,7.85
# alpha,beta: 4.83 ,8.13
# alpha,beta: 9.14 ,9.99
# alpha,beta: 7.44 ,10.75
# alpha,beta: 2.33 ,8.67
# alpha,beta: 1.71 ,12.00
# alpha,beta: 3.35 ,8.66
# alpha,beta: 7.04 ,7.73
# alpha,beta: 2.99 ,6.15
# alpha,beta: 6.64 ,8.38
# alpha,beta: 2.31 ,6.49
# alpha,beta: 4.71 ,6.56
# alpha,beta: 5.82 ,10.83
# alpha,beta: 0.79 ,7.96
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 7.29 ,8.51
# alpha,beta: 4.29 ,7.84
# alpha,beta: 6.23 ,7.75
# alpha,beta: 5.95 ,9.68
# alpha,beta: 4.41 ,9.35
# alpha,beta: 4.24 ,6.64
# alpha,beta: -0.20 ,9.72
# alpha,beta: 2.07 ,10.08
# alpha,beta: 3.26 ,5.10
# alpha,beta: 9.53 ,10.84
# alpha,beta: 2.77 ,7.69
# alpha,beta: 2.66 ,10.81
# alpha,beta: 2.07 ,7.53
# alpha,beta: 4.66 ,7.17
# alpha,beta: 1.76 ,5.29
# alpha,beta: 2.81 ,5.28
# alpha,beta: 3.39 ,10.68
# alpha,beta: 2.20 ,5.50
# alpha,beta: 1.42 ,7.07
# alpha,beta: 0.71 ,6.31
# alpha,beta: 2.24 ,5.16
# alpha,beta: 1.97 ,4.68
# alpha,beta: 1.97 ,5.42
# alpha,beta: 1.05 ,5.33
# alpha,beta: 3.67 ,6.29
# alpha,beta: 1.93 ,5.56
# alpha,beta: 3.82 ,7.68
# alpha,beta: 3.96 ,8.36
# alpha,beta: 1.63 ,7.67
# alpha,beta: 1.91 ,5.17
# alpha,beta: 4.11 ,6.63
# alpha,beta: 3.01 ,7.13
# alpha,beta: 0.59 ,3.78
# alpha,beta: -1.48 ,5.91
# alpha,beta: 1.58 ,6.60
# alpha,beta: 2.14 ,6.89
# alpha,beta: 2.42 ,6.83
# alpha,beta: 4.07 ,5.24
# alpha,beta: 2.14 ,6.47
# alpha,beta: 0.02 ,8.49
# alpha,beta: 0.97 ,6.01
# alpha,beta: 2.19 ,7.17
# alpha,beta: 3.12 ,4.41
# alpha,beta: 2.29 ,5.52
# alpha,beta: 4.84 ,6.13
# alpha,beta: 0.98 ,7.00
# alpha,beta: 2.69 ,5.63
# alpha,beta: 2.54 ,3.75
# alpha,beta: 2.50 ,6.78
# alpha,beta: 1.40 ,6.13
# alpha,beta: 2.54 ,4.63
# alpha,beta: 2.30 ,5.53
# alpha,beta: 3.88 ,4.93
# alpha,beta: 1.00 ,6.04
# alpha,beta: 4.13 ,5.66
# alpha,beta: 2.30 ,4.37
# alpha,beta: 1.10 ,6.63
# alpha,beta: 2.90 ,5.61
# alpha,beta: -0.34 ,6.57
# alpha,beta: 0.48 ,7.51
# alpha,beta: 2.82 ,4.51
# alpha,beta: 3.04 ,4.42
# alpha,beta: 3.38 ,3.93
# alpha,beta: -1.01 ,4.77
# alpha,beta: 2.92 ,4.91
# alpha,beta: 4.45 ,5.43
# alpha,beta: 3.53 ,7.20
# alpha,beta: 1.96 ,4.53
# alpha,beta: 1.62 ,6.25
# alpha,beta: 1.10 ,6.55
# alpha,beta: 3.70 ,7.31
# alpha,beta: 2.08 ,5.37
# alpha,beta: 2.02 ,6.09
# alpha,beta: 2.81 ,4.66
# alpha,beta: 1.52 ,6.29
# alpha,beta: 2.13 ,4.96
# alpha,beta: 3.57 ,7.51
# alpha,beta: 1.67 ,5.48
# alpha,beta: 3.42 ,7.86
# alpha,beta: 0.25 ,9.58
# alpha,beta: 1.31 ,4.17
# alpha,beta: 0.69 ,6.60
# alpha,beta: 2.11 ,5.59
# alpha,beta: 1.43 ,6.07
# alpha,beta: 2.50 ,5.42
# alpha,beta: 2.67 ,8.27
# alpha,beta: -2.23 ,5.87
# alpha,beta: 2.84 ,5.36
# alpha,beta: 3.50 ,5.60
# alpha,beta: 1.51 ,5.18
# alpha,beta: 1.97 ,5.07
# alpha,beta: 1.41 ,4.90
# alpha,beta: 3.03 ,7.28
# alpha,beta: -0.31 ,5.19
# alpha,beta: 3.41 ,5.50
# alpha,beta: 1.64 ,7.56
# alpha,beta: 1.50 ,10.37
# alpha,beta: 1.47 ,6.10
# alpha,beta: 0.28 ,6.27
# alpha,beta: 4.85 ,3.25
# alpha,beta: 3.58 ,7.28
# alpha,beta: 3.04 ,6.67
# alpha,beta: 2.51 ,5.22
# alpha,beta: 1.07 ,4.78
# alpha,beta: 0.32 ,7.71
# alpha,beta: 0.86 ,5.66
# alpha,beta: 0.56 ,5.56
# alpha,beta: 1.77 ,6.86
# alpha,beta: 0.70 ,5.11
# alpha,beta: 2.16 ,3.75
# alpha,beta: 2.86 ,3.73
# alpha,beta: 3.03 ,6.82
# alpha,beta: 2.48 ,7.30
# alpha,beta: 2.88 ,4.77
# alpha,beta: 0.83 ,5.50
# alpha,beta: 0.68 ,6.63
# alpha,beta: 3.12 ,4.75
# alpha,beta: 3.10 ,4.44
# alpha,beta: 1.10 ,5.10
# alpha,beta: 2.13 ,4.50
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# end!
# -> Mag Distribution
# --> Getting truth distributions
# end!
# Compute MaskFraction and Norm
# norm less than zero: -1.101706623976433
# norm less than zero: -0.6819604692899944
# norm less than zero: -0.20563966129974934
# norm less than zero: -2.8125098322519877
# norm less than zero: -1.5850693030717378
# norm less than zero: -0.05261563245912875
# norm less than zero: -0.25379018395703457
# norm less than zero: -0.8797254708329711
# norm less than zero: -4.497187582009921
# norm less than zero: -7.197857405021941
# norm less than zero: -2.2742407455030103
# norm less than zero: -1.5369325955353939
#
#  Compute Probabilities
# alpha,beta: 8.39 ,2.85
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 7.30 ,2.36
# alpha,beta: 10.29 ,4.34
# alpha,beta: 5.65 ,4.22
# alpha,beta: 7.21 ,4.24
# alpha,beta: 8.67 ,4.54
# alpha,beta: 7.21 ,3.97
# alpha,beta: 4.32 ,5.81
# alpha,beta: 9.05 ,2.09
# alpha,beta: 4.42 ,4.95
# alpha,beta: 8.45 ,5.14
# alpha,beta: 5.58 ,5.97
# alpha,beta: 10.28 ,4.74
# alpha,beta: 8.76 ,5.44
# alpha,beta: 4.87 ,4.41
# alpha,beta: 8.05 ,5.26
# alpha,beta: 7.96 ,5.14
# alpha,beta: 7.35 ,6.85
# alpha,beta: 6.71 ,6.55
# alpha,beta: 8.86 ,7.26
# alpha,beta: 6.72 ,5.70
# alpha,beta: 6.75 ,6.51
# alpha,beta: 6.80 ,7.39
# alpha,beta: 5.60 ,6.85
# alpha,beta: 7.11 ,5.77
# alpha,beta: 3.78 ,8.18
# alpha,beta: 7.01 ,5.20
# alpha,beta: 6.66 ,5.78
# alpha,beta: 7.04 ,5.10
# alpha,beta: 9.42 ,5.55
# alpha,beta: 8.22 ,6.45
# alpha,beta: 6.22 ,7.15
# alpha,beta: 6.07 ,6.41
# alpha,beta: 6.98 ,6.13
# alpha,beta: 8.40 ,5.80
# alpha,beta: 3.41 ,5.50
# alpha,beta: 7.78 ,6.68
# alpha,beta: 9.12 ,5.72
# alpha,beta: 5.51 ,5.44
# alpha,beta: 9.56 ,4.46
# alpha,beta: 6.37 ,8.21
# alpha,beta: 5.41 ,6.40
# alpha,beta: 3.53 ,6.48
# alpha,beta: 7.65 ,7.30
# alpha,beta: 6.45 ,5.86
# alpha,beta: 6.42 ,4.87
# alpha,beta: 8.09 ,6.47
# alpha,beta: 4.81 ,6.64
# alpha,beta: 4.72 ,3.47
# alpha,beta: 7.33 ,5.35
# alpha,beta: 3.87 ,8.79
# alpha,beta: 5.51 ,7.65
# alpha,beta: 8.21 ,6.98
# alpha,beta: 5.32 ,7.11
# alpha,beta: 4.86 ,7.56
# alpha,beta: 8.57 ,2.97
# alpha,beta: 5.23 ,7.91
# alpha,beta: 5.59 ,7.04
# alpha,beta: 10.21 ,3.53
# alpha,beta: 8.14 ,7.52
# alpha,beta: 7.92 ,8.02
# alpha,beta: 3.60 ,9.06
# alpha,beta: 4.97 ,6.85
# alpha,beta: 6.53 ,8.32
# alpha,beta: 7.22 ,6.42
# alpha,beta: 6.81 ,8.12
# alpha,beta: 2.72 ,8.26
# alpha,beta: 6.20 ,7.08
# alpha,beta: 10.24 ,8.49
# alpha,beta: 3.98 ,7.31
# alpha,beta: 8.63 ,6.29
# alpha,beta: 8.70 ,8.12
# alpha,beta: 7.93 ,8.60
# alpha,beta: 8.45 ,8.03
# alpha,beta: 8.10 ,6.79
# alpha,beta: 6.85 ,7.79
# alpha,beta: 7.07 ,7.21
# alpha,beta: 6.35 ,7.33
# alpha,beta: 6.88 ,6.77
# alpha,beta: 3.34 ,6.64
# alpha,beta: 2.31 ,7.20
# alpha,beta: 10.33 ,8.58
# alpha,beta: 3.35 ,7.85
# alpha,beta: 8.00 ,8.85
# alpha,beta: 4.98 ,10.01
# alpha,beta: 8.61 ,9.56
# alpha,beta: 9.21 ,7.87
# alpha,beta: 4.42 ,10.45
# alpha,beta: 9.69 ,9.50
# alpha,beta: 7.89 ,7.72
# alpha,beta: 3.93 ,7.18
# alpha,beta: 10.33 ,6.97
# alpha,beta: 10.56 ,8.98
# alpha,beta: 2.44 ,9.30
# alpha,beta: 2.79 ,4.33
# alpha,beta: 7.21 ,5.31
# alpha,beta: 5.54 ,7.21
# alpha,beta: 7.81 ,3.73
# alpha,beta: 7.13 ,6.16
# alpha,beta: 3.67 ,9.69
# alpha,beta: 4.35 ,8.41
# alpha,beta: 7.21 ,10.38
# alpha,beta: 5.73 ,4.30
# alpha,beta: 3.75 ,8.34
# alpha,beta: 7.77 ,4.45
# alpha,beta: 5.81 ,7.46
# alpha,beta: 7.38 ,11.14
# alpha,beta: 6.06 ,10.16
# alpha,beta: 8.85 ,9.76
# alpha,beta: 5.98 ,9.61
# alpha,beta: 3.88 ,6.94
# alpha,beta: 5.98 ,8.08
# alpha,beta: 6.83 ,5.03
# alpha,beta: -0.92 ,9.86
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 5.43 ,7.17
# alpha,beta: 4.72 ,2.52
# alpha,beta: 5.60 ,8.82
# alpha,beta: 7.49 ,7.34
# alpha,beta: 6.65 ,9.38
# alpha,beta: 9.32 ,11.74
# alpha,beta: 2.66 ,10.11
# alpha,beta: 2.72 ,10.08
# alpha,beta: 3.01 ,9.02
# alpha,beta: 3.33 ,10.07
# alpha,beta: 1.20 ,6.54
# alpha,beta: 3.27 ,8.29
# alpha,beta: 0.25 ,8.89
# alpha,beta: 1.56 ,7.98
# alpha,beta: 8.94 ,7.68
# alpha,beta: 2.00 ,8.89
# alpha,beta: 3.26 ,8.95
# alpha,beta: 2.19 ,6.13
# alpha,beta: -0.16 ,10.04
# alpha,beta: 2.54 ,8.23
# alpha,beta: 3.44 ,6.05
# alpha,beta: 5.34 ,6.21
# alpha,beta: 7.71 ,9.19
# alpha,beta: 3.47 ,6.86
# alpha,beta: 3.11 ,9.62
# alpha,beta: 7.35 ,8.08
# alpha,beta: 5.44 ,8.22
# alpha,beta: 2.50 ,6.92
# alpha,beta: 4.10 ,7.44
# alpha,beta: 4.21 ,6.56
# alpha,beta: 4.62 ,7.07
# alpha,beta: 5.38 ,7.34
# alpha,beta: 3.88 ,9.18
# alpha,beta: 2.82 ,8.81
# alpha,beta: 4.92 ,9.37
# alpha,beta: 0.65 ,9.34
# alpha,beta: 2.71 ,5.85
# alpha,beta: 2.48 ,11.22
# alpha,beta: 3.72 ,10.09
# alpha,beta: 0.37 ,7.54
# alpha,beta: 5.11 ,9.70
# alpha,beta: 1.98 ,6.59
# alpha,beta: 2.01 ,9.11
# alpha,beta: 3.69 ,9.44
# alpha,beta: 3.17 ,2.30
# alpha,beta: 2.98 ,7.01
# alpha,beta: 3.88 ,8.78
# alpha,beta: 4.50 ,6.30
# alpha,beta: 1.73 ,6.28
# alpha,beta: 7.16 ,7.33
# alpha,beta: 0.98 ,5.15
# alpha,beta: 3.92 ,1.82
# alpha,beta: 3.83 ,6.51
# alpha,beta: 1.97 ,6.76
# alpha,beta: 2.13 ,4.19
# alpha,beta: 1.83 ,6.24
# alpha,beta: 4.69 ,5.48
# alpha,beta: -0.17 ,8.11
# alpha,beta: 3.67 ,6.13
# alpha,beta: 4.80 ,5.01
# alpha,beta: 5.51 ,7.45
# alpha,beta: 1.86 ,8.07
# alpha,beta: 3.71 ,2.92
# alpha,beta: 4.98 ,4.97
# alpha,beta: 2.02 ,7.18
# alpha,beta: 2.95 ,9.57
# alpha,beta: 3.79 ,4.69
# alpha,beta: 4.87 ,8.62
# alpha,beta: 2.16 ,5.02
# alpha,beta: 1.05 ,9.48
# alpha,beta: 4.49 ,2.93
# alpha,beta: 1.91 ,7.89
# alpha,beta: 2.77 ,6.30
# alpha,beta: 2.22 ,4.39
# alpha,beta: 3.12 ,4.06
# alpha,beta: 2.23 ,4.49
# alpha,beta: 3.15 ,8.95
# alpha,beta: 1.44 ,6.42
# alpha,beta: 3.87 ,8.38
# alpha,beta: 4.88 ,10.05
# alpha,beta: 2.66 ,7.44
# alpha,beta: 2.10 ,7.42
# alpha,beta: 4.88 ,7.22
# alpha,beta: 3.50 ,10.82
# alpha,beta: 1.67 ,5.24
# alpha,beta: 2.04 ,5.09
# alpha,beta: 1.14 ,6.61
# alpha,beta: 2.97 ,7.50
# alpha,beta: 4.27 ,6.35
# alpha,beta: 2.94 ,6.56
# alpha,beta: 3.54 ,6.06
# alpha,beta: 0.59 ,4.23
# alpha,beta: 2.37 ,9.99
# alpha,beta: 2.73 ,4.38
# alpha,beta: 4.31 ,8.66
# alpha,beta: 2.32 ,3.92
# alpha,beta: 1.99 ,8.68
# alpha,beta: 4.39 ,7.87
# alpha,beta: 3.20 ,8.11
# alpha,beta: 1.87 ,7.34
# alpha,beta: 0.55 ,7.07
# alpha,beta: 3.01 ,5.03
# alpha,beta: 3.98 ,9.42
# alpha,beta: 3.66 ,5.69
# alpha,beta: 3.58 ,6.17
# alpha,beta: 2.08 ,4.32
# alpha,beta: 3.33 ,4.97
# alpha,beta: 5.24 ,9.06
# alpha,beta: 4.87 ,6.86
# alpha,beta: 1.05 ,8.79
# alpha,beta: 1.78 ,6.88
# alpha,beta: 1.12 ,4.45
# alpha,beta: 4.71 ,7.81
# alpha,beta: 2.22 ,5.36
# alpha,beta: -0.99 ,8.32
# alpha,beta: 0.24 ,6.29
# alpha,beta: 0.45 ,4.43
# alpha,beta: 2.77 ,5.90
# alpha,beta: 2.49 ,4.90
# alpha,beta: 2.69 ,4.78
# alpha,beta: 3.15 ,2.84
# alpha,beta: 3.33 ,3.68
# alpha,beta: 2.53 ,4.25
# alpha,beta: 3.10 ,4.75
# alpha,beta: 2.35 ,6.02
# alpha,beta: 1.71 ,3.60
# alpha,beta: 1.16 ,4.74
# alpha,beta: -1.05 ,5.45
# alpha,beta: 2.34 ,5.84
# alpha,beta: 0.42 ,4.15
# alpha,beta: 3.39 ,3.84
# alpha,beta: 1.40 ,3.75
# alpha,beta: 2.31 ,5.30
# alpha,beta: 1.63 ,5.36
# alpha,beta: 0.55 ,3.72
# alpha,beta: 3.08 ,5.39
# alpha,beta: 5.25 ,5.67
# alpha,beta: 2.28 ,6.94
# alpha,beta: 0.68 ,5.54
# alpha,beta: 0.99 ,4.70
# alpha,beta: -0.03 ,5.78
# alpha,beta: 2.70 ,4.33
# alpha,beta: 0.06 ,4.61
# alpha,beta: 1.72 ,4.31
# alpha,beta: -0.14 ,3.71
# alpha,beta: 2.22 ,3.82
# alpha,beta: -0.22 ,4.96
# alpha,beta: 2.44 ,4.18
# alpha,beta: 1.87 ,6.54
# alpha,beta: 2.77 ,3.38
# alpha,beta: 1.70 ,4.84
# alpha,beta: 2.28 ,5.04
# alpha,beta: 1.82 ,9.04
# alpha,beta: 1.23 ,5.56
# alpha,beta: -1.52 ,5.15
# alpha,beta: 3.83 ,4.13
# alpha,beta: 0.28 ,3.90
# alpha,beta: 2.46 ,4.25
# alpha,beta: 1.45 ,5.55
# alpha,beta: 4.75 ,4.24
# alpha,beta: 4.35 ,2.71
# alpha,beta: 0.99 ,4.58
# alpha,beta: 0.44 ,4.82
# alpha,beta: 4.44 ,5.30
# alpha,beta: 3.37 ,5.40
# alpha,beta: 2.27 ,4.86
# alpha,beta: -1.76 ,6.19
# alpha,beta: 2.28 ,7.11
# alpha,beta: 0.45 ,5.76
# alpha,beta: 1.80 ,4.67
# alpha,beta: 2.33 ,5.06
# alpha,beta: 3.08 ,5.31
# alpha,beta: 1.70 ,4.63
# alpha,beta: 4.25 ,4.54
# alpha,beta: -1.74 ,7.17
# alpha,beta: 2.23 ,4.33
# alpha,beta: 4.14 ,5.22
# alpha,beta: 3.14 ,4.43
# alpha,beta: 1.80 ,4.80
# alpha,beta: 3.67 ,4.49
# alpha,beta: -0.64 ,4.17
# alpha,beta: 2.27 ,3.11
# alpha,beta: 3.96 ,4.01
# alpha,beta: 1.54 ,3.65
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# end!
# compute ptaken
# Total time: 156.341619015s
# ---------------

# %%
### 2. DNF model

# %%
## setup 
copa.kwargs['r_aper_model'] = 'rhod'
copa.kwargs['mag_selection']= '02Lstar'

# %%
pz_files = ['dnf_model','dnf']
z_widths = [0.03,0.03]

runs = ['%s_%s_%s'%(pz,'rhod','02Lstar') for pz in pz_files]

# %%
runs
# Out:
# ['dnf_model_rhod_02Lstar', 'dnf_rhod_02Lstar']

# %%
for run, zfile, zw in zip(runs,pz_files,z_widths):
    print('run     : %s'%run)
    print('zfile   : %s'%zfile)
    print('zwindow : %.2f'%zw)

    copa.kwargs['z_window'] = zw
    copa.run_copa_healpix(run,   pz_file=zfile, nCores=60)
    copa.compute_muStar(  run, overwrite=True)
    print(5*'---')
    print('\n')
# Out:
# run     : dnf_model_rhod_02Lstar
# zfile   : dnf_model
# zwindow : 0.03
#
# Starting Copa
# run dnf_model_rhod_02Lstar
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00000.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2164589
# cut:  1117778
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00000/dnf_model_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00256.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2791169
# cut:  1541073
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00256/dnf_model_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00257.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3708874
# cut:  2029154
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00257/dnf_model_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00260.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3019411
# cut:  1664479
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00260/dnf_model_rhod_02Lstar_copa_test_gal.fits
# copa parallel process
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# bad cluster: 30253577 ratio min/max: 0.7799349070180618 9011.188980218934
# bad cluster: 30255944 ratio min/max: 0.02902475990305753 19341.707552912292
# bad cluster: 30257324 ratio min/max: 49.97378130634111 5377.2742745522855
# bad cluster: 30257324 ratio min/max: 0.40552032179381015 1623.8440135744024
# bad cluster: 30257324 ratio min/max: 1.3691528547983203 4764.08939531411
# bad cluster: 30257324 ratio min/max: 1.8201292227610573 5016.15655227635
# bad cluster: 30257324 ratio min/max: 15.723554473144382 5216.777509096314
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# bad cluster: 8598473 ratio min/max: 0.012324651975196728 4455.355196814591
# bad cluster: 34056556 ratio min/max: 0.04787890953745594 856.8022376414973
# bad cluster: 34056556 ratio min/max: 0.5799750938995807 5771.176068494998
# Computing PDFs
#
# -> Radial Distribution
# bad cluster: 18228324 ratio min/max: 0.13810925481206215 562.7686148245124
# bad cluster: 18238445 ratio min/max: 0.008583095131855479 906.4421029734418
# -> Redshift Distribution
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# bad cluster: 19062914 ratio min/max: 1.1052990296932117 1529.9920845139304
# bad cluster: 19062914 ratio min/max: 3.3593679341990357 4504.246289559806
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# bad cluster: 18054432 ratio min/max: 0.00891705915262775 12735.72167524226
# -> Color Distribution
# bad cluster: 19161438 ratio min/max: 6.036975850438406 980.6579171026793
# bad cluster: 19161438 ratio min/max: 6.045243651319074 4175.019097879915
# Computing PDFs
#
# -> Radial Distribution
# bad cluster: 18940831 ratio min/max: 0.026049847928404108 1085.5198989213259
# bad cluster: 18940831 ratio min/max: 0.1730173870856644 3521.5376487250337
# bad cluster: 18945227 ratio min/max: 0.21259376067682584 15633.840075804213
# bad cluster: 18993478 ratio min/max: 0.008354689287716745 2590.999762570264
# bad cluster: 19734539 ratio min/max: 1.0674731653852096 2168.0064267090925
# bad cluster: 18998308 ratio min/max: 1.177685414190388 1302.5070634976648
# bad cluster: 18999174 ratio min/max: 0.011362860347650397 8189.32652459609
# bad cluster: 19773591 ratio min/max: 1.3155486712983357 5457.078354000474
# -> Redshift Distribution
# bad cluster: 19781247 ratio min/max: 0.007898964490891721 1659.412661435713
# Computing PDFs
#
# -> Radial Distribution
# bad cluster: 19832313 ratio min/max: 0.6916584141400532 501.14294050787663
# bad cluster: 19832313 ratio min/max: 1.5192724626834615 4215.725340901623
# bad cluster: 19873052 ratio min/max: 1.3803912881866107 424.4362456078916
# -> Color Distribution
# Computing PDFs
#
# -> Radial Distribution
# -> Redshift Distribution
# -> Redshift Distribution
# -> Color Distribution
# -> Color Distribution
# -> Mag Distribution
# --> Getting truth distributions
# Compute MaskFraction and Norm
# norm less than zero: -3.93472906279081
# norm less than zero: -3.397624077435445
# norm less than zero: -6.932332631136044
# norm less than zero: -0.1182683708821822
# norm less than zero: -3.221520591464281
# norm less than zero: -2.129149293037422
# norm less than zero: -0.489971883035929
# norm less than zero: -1.6214932564338114
# norm less than zero: -2.4980499370619316
# norm less than zero: -0.3109772140019016
# norm less than zero: -0.26275079630416215
#
#  Compute Probabilities
# alpha,beta: 6.85 ,1.16
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 6.73 ,3.42
# alpha,beta: 3.84 ,1.87
# alpha,beta: 9.36 ,8.41
# alpha,beta: 5.18 ,5.38
# alpha,beta: 7.49 ,5.87
# alpha,beta: 3.69 ,5.82
# alpha,beta: 7.86 ,8.96
# alpha,beta: 6.05 ,3.31
# alpha,beta: 7.45 ,9.66
# alpha,beta: 11.18 ,8.93
# alpha,beta: 7.61 ,9.05
# alpha,beta: 5.09 ,8.41
# alpha,beta: 7.07 ,8.59
# alpha,beta: 7.62 ,8.48
# alpha,beta: 8.46 ,8.89
# alpha,beta: 7.45 ,8.18
# alpha,beta: 5.33 ,6.93
# alpha,beta: 7.66 ,5.60
# alpha,beta: 3.51 ,7.83
# alpha,beta: 8.48 ,6.26
# alpha,beta: 4.16 ,8.26
# alpha,beta: 8.99 ,9.37
# alpha,beta: 3.88 ,6.56
# alpha,beta: 7.19 ,8.58
# alpha,beta: 4.70 ,6.19
# alpha,beta: 5.41 ,7.75
# alpha,beta: 4.39 ,8.29
# alpha,beta: 7.44 ,8.85
# alpha,beta: 4.69 ,8.58
# alpha,beta: 6.65 ,3.55
# alpha,beta: 6.13 ,7.96
# alpha,beta: 5.64 ,10.41
# alpha,beta: 4.23 ,8.96
# alpha,beta: 4.84 ,8.79
# alpha,beta: 7.14 ,7.37
# alpha,beta: 4.24 ,10.28
# alpha,beta: 2.41 ,5.82
# alpha,beta: 8.64 ,5.22
# alpha,beta: 4.64 ,7.02
# alpha,beta: 6.37 ,5.79
# alpha,beta: 7.40 ,7.92
# alpha,beta: 8.71 ,8.03
# alpha,beta: 7.13 ,7.93
# alpha,beta: 4.56 ,6.13
# alpha,beta: 8.10 ,3.64
# alpha,beta: 6.35 ,4.97
# alpha,beta: 9.57 ,8.86
# alpha,beta: 4.18 ,11.19
# alpha,beta: 6.02 ,9.24
# alpha,beta: 7.90 ,9.29
# alpha,beta: 8.00 ,1.95
# alpha,beta: 5.79 ,8.97
# alpha,beta: 7.88 ,2.74
# alpha,beta: 0.75 ,7.75
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 4.15 ,6.35
# alpha,beta: -0.58 ,8.27
# alpha,beta: 6.04 ,7.66
# alpha,beta: 4.42 ,3.34
# alpha,beta: 3.16 ,8.21
# alpha,beta: -3.24 ,7.23
# alpha,beta: 5.44 ,6.49
# alpha,beta: 0.77 ,8.32
# alpha,beta: 2.85 ,2.15
# alpha,beta: 1.84 ,6.41
# alpha,beta: 3.96 ,5.75
# alpha,beta: 3.15 ,9.83
# alpha,beta: 2.90 ,11.31
# alpha,beta: 2.08 ,7.90
# alpha,beta: 5.10 ,5.34
# alpha,beta: 5.03 ,7.27
# alpha,beta: 4.78 ,3.87
# alpha,beta: 1.07 ,7.50
# alpha,beta: 2.52 ,6.83
# alpha,beta: 4.48 ,8.72
# alpha,beta: 2.87 ,9.73
# alpha,beta: 7.67 ,9.66
# alpha,beta: 3.56 ,7.43
# alpha,beta: 2.55 ,5.82
# alpha,beta: 2.30 ,6.39
# alpha,beta: 2.20 ,7.98
# alpha,beta: 1.89 ,9.53
# alpha,beta: 7.30 ,5.30
# alpha,beta: -2.73 ,4.88
# alpha,beta: 3.63 ,7.48
# alpha,beta: 5.80 ,5.62
# alpha,beta: 4.69 ,6.91
# alpha,beta: 0.08 ,8.76
# alpha,beta: 0.33 ,7.69
# alpha,beta: 4.95 ,3.44
# alpha,beta: 1.54 ,7.36
# alpha,beta: 1.86 ,4.55
# alpha,beta: 4.39 ,7.31
# alpha,beta: 2.76 ,6.83
# alpha,beta: 1.04 ,7.84
# alpha,beta: 2.06 ,6.94
# alpha,beta: 1.28 ,7.99
# alpha,beta: 2.21 ,7.43
# alpha,beta: 3.40 ,9.19
# alpha,beta: 2.36 ,10.11
# alpha,beta: 5.31 ,4.82
# alpha,beta: 5.26 ,5.94
# alpha,beta: 6.01 ,4.41
# alpha,beta: 1.89 ,7.57
# alpha,beta: -0.02 ,7.60
# alpha,beta: 1.44 ,7.50
# alpha,beta: 1.86 ,7.69
# alpha,beta: 1.40 ,5.84
# alpha,beta: 2.46 ,8.22
# alpha,beta: 0.22 ,9.49
# alpha,beta: 4.03 ,9.01
# alpha,beta: 1.96 ,7.78
# alpha,beta: 4.50 ,5.73
# alpha,beta: 3.10 ,7.57
# alpha,beta: 9.90 ,2.85
# alpha,beta: -1.78 ,7.47
# alpha,beta: 2.74 ,6.57
# alpha,beta: 1.20 ,9.18
# alpha,beta: 2.26 ,8.78
# alpha,beta: 7.50 ,4.42
# alpha,beta: 0.50 ,7.45
# alpha,beta: 0.35 ,9.99
# alpha,beta: 1.43 ,3.29
# alpha,beta: 2.82 ,6.28
# alpha,beta: 2.05 ,5.38
# alpha,beta: 2.50 ,5.66
# alpha,beta: 3.73 ,7.23
# alpha,beta: 6.35 ,3.48
# alpha,beta: 3.68 ,5.95
# alpha,beta: 0.96 ,8.55
# alpha,beta: -0.94 ,6.77
# alpha,beta: 1.10 ,3.65
# alpha,beta: -0.09 ,6.70
# alpha,beta: 4.59 ,3.31
# alpha,beta: 2.67 ,7.61
# alpha,beta: -0.49 ,5.83
# alpha,beta: 2.27 ,5.32
# alpha,beta: 1.89 ,7.24
# alpha,beta: 1.34 ,5.30
# alpha,beta: 2.53 ,3.97
# alpha,beta: -0.35 ,8.71
# alpha,beta: 2.74 ,6.87
# alpha,beta: 1.13 ,3.77
# alpha,beta: 0.37 ,5.87
# alpha,beta: 2.57 ,5.83
# alpha,beta: 0.61 ,5.34
# alpha,beta: -0.15 ,7.22
# alpha,beta: 0.65 ,6.84
# alpha,beta: 5.91 ,3.46
# alpha,beta: 3.45 ,4.45
# alpha,beta: 5.21 ,6.89
# alpha,beta: 4.19 ,2.87
# alpha,beta: -0.08 ,6.44
# alpha,beta: 1.53 ,6.70
# alpha,beta: 2.60 ,4.58
# alpha,beta: 1.55 ,5.15
# alpha,beta: 2.23 ,6.54
# alpha,beta: 0.65 ,4.87
# alpha,beta: 0.65 ,8.06
# alpha,beta: 1.07 ,6.04
# alpha,beta: 3.85 ,6.36
# alpha,beta: 2.08 ,7.42
# alpha,beta: 8.47 ,9.07
# alpha,beta: 4.66 ,11.58
# alpha,beta: 6.01 ,11.00
# alpha,beta: 5.39 ,7.08
# alpha,beta: 4.50 ,6.09
# alpha,beta: 1.59 ,6.91
# alpha,beta: 6.60 ,9.38
# alpha,beta: 6.65 ,3.18
# alpha,beta: 4.20 ,10.85
# alpha,beta: 9.78 ,4.97
# alpha,beta: 4.99 ,7.57
# alpha,beta: 5.16 ,9.61
# alpha,beta: 2.96 ,6.00
# alpha,beta: 9.97 ,5.71
# alpha,beta: 8.43 ,7.94
# alpha,beta: 3.46 ,7.42
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# -> Mag Distribution
# --> Getting truth distributions
# end!
# -> Mag Distribution
# --> Getting truth distributions
# Compute MaskFraction and Norm
# norm less than zero: -1.6799385495871482
# norm less than zero: -4.242204280265463
# norm less than zero: -3.2790023612334496
# norm less than zero: -2.056405278319288
# norm less than zero: -4.95098021894191
# norm less than zero: -2.9145133008690847
# norm less than zero: -4.239817737805043
# norm less than zero: -2.639732001730449
# norm less than zero: -1.0814774036432115
# norm less than zero: -2.7029780868043174
# norm less than zero: -10.12334936268453
# norm less than zero: -3.054220674253876
#
#  Compute Probabilities
# alpha,beta: 9.58 ,2.72
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 4.87 ,1.39
# alpha,beta: 5.30 ,3.94
# alpha,beta: 4.82 ,2.29
# alpha,beta: 5.92 ,2.97
# alpha,beta: 3.08 ,3.52
# alpha,beta: 3.81 ,3.87
# alpha,beta: 5.49 ,3.36
# alpha,beta: 4.82 ,2.68
# alpha,beta: 5.13 ,4.72
# alpha,beta: 3.39 ,3.08
# alpha,beta: 9.11 ,6.29
# alpha,beta: 11.70 ,7.37
# alpha,beta: 9.76 ,7.51
# alpha,beta: 7.83 ,5.58
# alpha,beta: 4.45 ,5.85
# alpha,beta: 5.66 ,7.56
# alpha,beta: 7.96 ,8.09
# alpha,beta: 7.82 ,2.94
# alpha,beta: 6.96 ,6.31
# alpha,beta: 7.34 ,6.50
# alpha,beta: 7.62 ,6.28
# alpha,beta: 7.15 ,5.32
# alpha,beta: 7.61 ,5.56
# alpha,beta: 6.14 ,8.49
# alpha,beta: 12.35 ,7.90
# alpha,beta: 8.37 ,7.95
# alpha,beta: 5.84 ,8.21
# alpha,beta: 5.11 ,10.13
# alpha,beta: 6.56 ,8.09
# alpha,beta: 4.78 ,9.96
# alpha,beta: 10.45 ,10.74
# alpha,beta: 6.90 ,10.28
# alpha,beta: 7.72 ,8.94
# alpha,beta: 5.73 ,6.50
# alpha,beta: 8.23 ,9.14
# alpha,beta: 7.01 ,8.26
# alpha,beta: 4.95 ,8.61
# alpha,beta: 8.57 ,10.39
# alpha,beta: 6.87 ,10.31
# alpha,beta: 6.95 ,9.11
# alpha,beta: 6.81 ,11.83
# alpha,beta: 6.76 ,7.98
# alpha,beta: 8.54 ,9.44
# alpha,beta: 4.97 ,9.58
# alpha,beta: 0.94 ,9.10
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 8.46 ,11.51
# alpha,beta: 8.07 ,11.88
# alpha,beta: 5.56 ,1.53
# alpha,beta: 6.36 ,4.25
# alpha,beta: 7.77 ,9.66
# alpha,beta: 5.24 ,5.62
# alpha,beta: 6.97 ,9.20
# alpha,beta: 7.25 ,13.10
# alpha,beta: 2.84 ,11.78
# alpha,beta: 5.74 ,10.15
# alpha,beta: 6.88 ,12.01
# alpha,beta: 3.96 ,9.76
# alpha,beta: 3.01 ,10.51
# alpha,beta: 5.71 ,9.05
# alpha,beta: 3.99 ,11.39
# alpha,beta: 7.13 ,4.33
# alpha,beta: 7.25 ,10.40
# alpha,beta: 5.69 ,6.50
# alpha,beta: 6.35 ,10.73
# alpha,beta: 1.91 ,8.39
# alpha,beta: 2.26 ,9.87
# alpha,beta: 3.59 ,11.72
# alpha,beta: 5.04 ,9.95
# alpha,beta: 6.81 ,12.70
# alpha,beta: -1.42 ,5.29
# alpha,beta: 2.40 ,9.06
# alpha,beta: 3.87 ,11.63
# alpha,beta: -1.19 ,13.56
# alpha,beta: 4.83 ,7.99
# alpha,beta: 2.93 ,9.57
# alpha,beta: 5.82 ,13.33
# alpha,beta: 6.62 ,11.33
# alpha,beta: 1.83 ,13.15
# alpha,beta: 3.41 ,13.36
# alpha,beta: 4.21 ,12.12
# alpha,beta: 0.30 ,9.59
# alpha,beta: 4.31 ,10.89
# alpha,beta: 5.22 ,9.69
# alpha,beta: 1.87 ,7.48
# alpha,beta: 6.83 ,9.57
# alpha,beta: 6.12 ,10.20
# alpha,beta: 4.12 ,10.98
# alpha,beta: 6.12 ,10.73
# alpha,beta: 4.12 ,7.95
# alpha,beta: 1.31 ,10.92
# alpha,beta: 1.16 ,10.23
# alpha,beta: 3.65 ,7.15
# alpha,beta: 1.18 ,6.87
# alpha,beta: 2.03 ,10.26
# alpha,beta: 0.62 ,12.17
# alpha,beta: 4.65 ,10.86
# alpha,beta: 5.34 ,10.25
# alpha,beta: 4.91 ,11.24
# alpha,beta: 2.12 ,9.28
# alpha,beta: 3.20 ,12.18
# alpha,beta: 0.40 ,10.14
# alpha,beta: 4.67 ,11.30
# alpha,beta: 5.39 ,10.78
# alpha,beta: 4.71 ,9.84
# alpha,beta: 7.27 ,9.97
# alpha,beta: -0.37 ,10.70
# alpha,beta: 2.44 ,8.80
# alpha,beta: 4.19 ,10.94
# alpha,beta: 3.24 ,6.80
# alpha,beta: 0.51 ,4.40
# alpha,beta: 3.61 ,8.60
# alpha,beta: 3.61 ,11.41
# alpha,beta: 3.37 ,9.47
# alpha,beta: 6.36 ,3.03
# alpha,beta: 2.37 ,8.98
# alpha,beta: 3.88 ,11.02
# alpha,beta: 4.61 ,2.95
# alpha,beta: 0.28 ,5.02
# alpha,beta: 4.53 ,8.95
# alpha,beta: -0.31 ,10.16
# alpha,beta: 2.41 ,4.36
# alpha,beta: 0.30 ,3.51
# alpha,beta: 2.72 ,9.42
# alpha,beta: 2.70 ,9.55
# alpha,beta: -2.19 ,4.90
# alpha,beta: 2.07 ,8.10
# alpha,beta: 0.74 ,8.14
# alpha,beta: 3.16 ,10.98
# alpha,beta: 2.07 ,7.82
# alpha,beta: 3.70 ,7.75
# alpha,beta: 3.45 ,8.83
# alpha,beta: 1.46 ,11.50
# alpha,beta: 1.13 ,8.66
# alpha,beta: 1.92 ,9.79
# alpha,beta: 3.47 ,9.89
# alpha,beta: 1.92 ,10.58
# alpha,beta: 2.10 ,10.67
# alpha,beta: 2.04 ,7.26
# alpha,beta: 0.85 ,9.37
# alpha,beta: 3.50 ,6.76
# alpha,beta: 8.32 ,2.13
# alpha,beta: 3.54 ,6.71
# alpha,beta: 0.43 ,9.95
# alpha,beta: 2.20 ,10.86
# alpha,beta: 1.82 ,4.18
# alpha,beta: 6.81 ,7.73
# alpha,beta: 0.94 ,8.76
# alpha,beta: -0.77 ,10.03
# alpha,beta: 2.55 ,7.12
# alpha,beta: 3.90 ,8.62
# alpha,beta: 3.75 ,8.18
# alpha,beta: 0.35 ,6.57
# alpha,beta: 1.49 ,10.26
# alpha,beta: 5.28 ,5.28
# alpha,beta: 0.67 ,7.53
# alpha,beta: 0.99 ,10.12
# alpha,beta: 0.81 ,5.00
# alpha,beta: 3.07 ,9.30
# alpha,beta: 2.37 ,8.04
# alpha,beta: 0.37 ,11.75
# alpha,beta: 2.62 ,8.47
# alpha,beta: 1.29 ,8.85
# alpha,beta: 3.26 ,10.45
# alpha,beta: 3.67 ,3.24
# alpha,beta: 3.46 ,9.48
# alpha,beta: 4.75 ,9.81
# alpha,beta: -1.60 ,8.41
# alpha,beta: 1.50 ,4.60
# alpha,beta: 4.01 ,10.33
# alpha,beta: 4.46 ,9.84
# alpha,beta: 3.17 ,9.70
# alpha,beta: 4.99 ,10.55
# alpha,beta: 0.74 ,10.07
# alpha,beta: 2.71 ,8.82
# alpha,beta: 1.99 ,8.66
# alpha,beta: 1.40 ,7.01
# alpha,beta: 1.91 ,8.28
# alpha,beta: 1.13 ,9.01
# alpha,beta: 4.87 ,11.53
# alpha,beta: 0.58 ,9.99
# alpha,beta: 3.73 ,10.26
# alpha,beta: -0.35 ,9.25
# alpha,beta: 1.36 ,6.77
# alpha,beta: -0.25 ,8.65
# alpha,beta: 1.45 ,6.79
# alpha,beta: 0.24 ,8.18
# alpha,beta: 1.61 ,9.79
# alpha,beta: 2.93 ,5.49
# alpha,beta: 2.24 ,11.48
# alpha,beta: 1.82 ,11.72
# alpha,beta: 2.47 ,6.98
# alpha,beta: 1.87 ,6.81
# alpha,beta: 1.12 ,8.85
# alpha,beta: 1.10 ,7.54
# alpha,beta: 1.07 ,11.03
# alpha,beta: 3.17 ,3.07
# alpha,beta: -0.98 ,7.91
# alpha,beta: 4.04 ,5.09
# alpha,beta: 4.33 ,5.35
# alpha,beta: 2.93 ,6.94
# alpha,beta: -1.73 ,6.23
# alpha,beta: -1.86 ,7.45
# alpha,beta: 3.32 ,6.16
# alpha,beta: 2.90 ,6.83
# alpha,beta: 3.28 ,5.76
# alpha,beta: 3.96 ,3.56
# alpha,beta: 2.14 ,4.88
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# Compute MaskFraction and Norm
# norm less than zero: -2.346291799041254
# norm less than zero: -13.5160862336315
# norm less than zero: -2.8899351688046226
# norm less than zero: -3.9977476210544767
# norm less than zero: -5.140293697388898
# norm less than zero: -2.4377578945482905
# norm less than zero: -2.7475845112154573
# norm less than zero: -0.39053176229221215
# norm less than zero: -2.6985602567387006
#
#  Compute Probabilities
# alpha,beta: 6.77 ,3.49
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 5.84 ,3.20
# alpha,beta: 3.62 ,2.96
# alpha,beta: 8.23 ,3.26
# alpha,beta: 7.25 ,3.47
# alpha,beta: 6.82 ,2.42
# alpha,beta: 4.52 ,1.91
# alpha,beta: 5.42 ,3.97
# alpha,beta: 8.66 ,3.18
# alpha,beta: 5.76 ,3.94
# alpha,beta: 4.82 ,3.63
# alpha,beta: 5.68 ,4.28
# alpha,beta: 7.64 ,3.47
# alpha,beta: 4.41 ,3.71
# alpha,beta: 6.80 ,6.85
# alpha,beta: 8.24 ,5.12
# alpha,beta: 4.90 ,3.99
# alpha,beta: 6.81 ,6.24
# alpha,beta: 7.94 ,7.69
# alpha,beta: 7.11 ,3.09
# alpha,beta: 4.04 ,3.67
# alpha,beta: 8.41 ,9.23
# end!
# alpha,beta: 7.10 ,7.99
# alpha,beta: 8.57 ,6.77
# alpha,beta: 8.98 ,6.40
# alpha,beta: 8.17 ,6.13
# alpha,beta: 5.92 ,6.87
# alpha,beta: 8.93 ,7.22
# alpha,beta: 6.93 ,5.95
# alpha,beta: 6.54 ,5.62
# alpha,beta: 7.18 ,6.91
# alpha,beta: 6.08 ,6.47
# alpha,beta: 6.33 ,5.66
# alpha,beta: 5.29 ,5.98
# alpha,beta: 7.29 ,2.38
# alpha,beta: 8.93 ,5.34
# alpha,beta: 7.74 ,9.09
# alpha,beta: 3.02 ,8.18
# alpha,beta: 7.28 ,8.32
# alpha,beta: 6.61 ,8.82
# alpha,beta: 9.72 ,8.44
# alpha,beta: 6.07 ,11.84
# alpha,beta: 9.81 ,9.49
# alpha,beta: 7.59 ,9.42
# alpha,beta: 5.36 ,7.54
# alpha,beta: 6.35 ,10.10
# alpha,beta: 5.79 ,7.87
# alpha,beta: 9.31 ,10.24
# alpha,beta: 6.25 ,9.14
# alpha,beta: 6.03 ,6.22
# alpha,beta: 6.00 ,3.77
# alpha,beta: 8.49 ,8.14
# alpha,beta: 5.90 ,8.57
# alpha,beta: 6.56 ,7.83
# alpha,beta: 6.85 ,8.17
# alpha,beta: 5.23 ,8.44
# alpha,beta: 7.56 ,9.25
# alpha,beta: 3.55 ,8.44
# alpha,beta: 7.33 ,7.94
# alpha,beta: 6.34 ,9.02
# alpha,beta: 2.82 ,10.35
# alpha,beta: 6.75 ,7.96
# alpha,beta: 3.26 ,9.17
# alpha,beta: 5.92 ,9.32
# alpha,beta: 4.78 ,12.30
# alpha,beta: 0.39 ,11.14
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 7.30 ,11.52
# alpha,beta: 7.38 ,10.96
# alpha,beta: 4.71 ,9.32
# alpha,beta: 4.32 ,11.42
# alpha,beta: 8.15 ,9.47
# alpha,beta: 4.52 ,7.90
# alpha,beta: 4.01 ,10.73
# alpha,beta: 8.72 ,10.29
# alpha,beta: 5.65 ,8.42
# alpha,beta: 3.71 ,10.25
# alpha,beta: 5.76 ,8.36
# alpha,beta: 2.52 ,10.70
# alpha,beta: 2.96 ,10.23
# alpha,beta: 5.98 ,13.45
# alpha,beta: 4.48 ,11.88
# alpha,beta: 9.77 ,10.65
# alpha,beta: 5.90 ,13.55
# alpha,beta: 4.45 ,13.76
# alpha,beta: 5.01 ,12.79
# alpha,beta: 7.89 ,10.77
# alpha,beta: 2.75 ,10.39
# alpha,beta: 7.95 ,8.00
# alpha,beta: 2.75 ,12.40
# alpha,beta: 4.73 ,12.36
# alpha,beta: 9.04 ,13.03
# alpha,beta: 4.19 ,10.14
# alpha,beta: 5.71 ,10.24
# alpha,beta: 8.90 ,11.76
# alpha,beta: 7.78 ,13.41
# alpha,beta: 2.88 ,10.81
# alpha,beta: 1.07 ,14.04
# alpha,beta: 2.68 ,11.19
# alpha,beta: 7.32 ,9.92
# alpha,beta: 3.24 ,7.93
# alpha,beta: 6.37 ,10.09
# alpha,beta: 3.19 ,8.35
# alpha,beta: 6.05 ,8.61
# alpha,beta: 5.18 ,13.64
# alpha,beta: 1.33 ,10.77
# alpha,beta: 7.55 ,10.28
# alpha,beta: 3.84 ,10.11
# alpha,beta: 5.91 ,9.32
# alpha,beta: 5.17 ,11.32
# alpha,beta: 5.08 ,11.75
# alpha,beta: 5.21 ,9.21
# alpha,beta: -0.26 ,12.67
# alpha,beta: 4.54 ,11.54
# alpha,beta: 2.72 ,7.24
# alpha,beta: 8.39 ,10.88
# alpha,beta: 2.16 ,9.78
# alpha,beta: 4.56 ,12.91
# alpha,beta: 1.52 ,9.87
# alpha,beta: 5.11 ,9.77
# alpha,beta: 1.54 ,7.43
# alpha,beta: 3.23 ,7.18
# alpha,beta: 5.02 ,11.90
# alpha,beta: 2.85 ,7.52
# alpha,beta: 0.96 ,9.46
# alpha,beta: 0.08 ,8.35
# alpha,beta: 1.38 ,6.15
# alpha,beta: 1.30 ,5.83
# alpha,beta: 1.53 ,7.32
# alpha,beta: 2.33 ,7.13
# alpha,beta: 3.86 ,8.28
# alpha,beta: 3.32 ,7.28
# alpha,beta: 5.59 ,9.46
# alpha,beta: 5.68 ,10.23
# alpha,beta: 2.18 ,9.75
# alpha,beta: 2.55 ,6.96
# alpha,beta: 4.34 ,8.35
# alpha,beta: 2.81 ,9.42
# alpha,beta: 0.51 ,5.57
# alpha,beta: -2.87 ,7.45
# alpha,beta: 2.25 ,8.54
# alpha,beta: 2.51 ,8.88
# alpha,beta: 1.28 ,9.05
# alpha,beta: 3.58 ,7.11
# alpha,beta: 2.22 ,7.67
# alpha,beta: -0.45 ,10.68
# alpha,beta: 0.20 ,8.08
# alpha,beta: 1.42 ,9.19
# alpha,beta: 1.73 ,6.15
# alpha,beta: 1.01 ,7.44
# alpha,beta: 3.67 ,8.29
# alpha,beta: 0.76 ,9.37
# alpha,beta: 2.09 ,7.44
# alpha,beta: 2.61 ,5.24
# alpha,beta: 2.11 ,8.36
# alpha,beta: 0.55 ,8.60
# alpha,beta: 2.54 ,6.18
# alpha,beta: 2.39 ,7.46
# alpha,beta: 4.84 ,6.81
# alpha,beta: 0.71 ,8.11
# alpha,beta: 4.97 ,7.54
# alpha,beta: 2.19 ,6.07
# alpha,beta: 0.20 ,9.20
# alpha,beta: 2.50 ,7.73
# alpha,beta: 0.82 ,8.59
# alpha,beta: -0.59 ,9.71
# alpha,beta: 2.60 ,5.76
# alpha,beta: 2.58 ,6.13
# alpha,beta: 3.44 ,5.19
# alpha,beta: 0.32 ,6.77
# alpha,beta: 2.32 ,6.23
# alpha,beta: 4.53 ,8.41
# alpha,beta: 4.84 ,8.83
# alpha,beta: 1.64 ,6.39
# alpha,beta: 2.23 ,8.03
# alpha,beta: 2.25 ,8.82
# alpha,beta: 3.95 ,9.20
# alpha,beta: 1.89 ,7.45
# alpha,beta: 1.95 ,8.01
# alpha,beta: 4.14 ,6.65
# alpha,beta: 1.23 ,8.20
# alpha,beta: 2.55 ,6.51
# alpha,beta: 2.56 ,10.53
# alpha,beta: 2.21 ,7.34
# alpha,beta: 3.13 ,9.66
# alpha,beta: -0.74 ,12.17
# alpha,beta: 2.24 ,5.51
# alpha,beta: 1.13 ,8.48
# alpha,beta: 3.32 ,7.20
# alpha,beta: 0.08 ,7.98
# alpha,beta: 2.53 ,7.27
# alpha,beta: 0.80 ,10.20
# alpha,beta: -1.88 ,7.11
# alpha,beta: 3.17 ,7.39
# alpha,beta: 2.45 ,7.82
# alpha,beta: 2.14 ,6.95
# alpha,beta: 1.77 ,7.20
# alpha,beta: 3.10 ,6.52
# alpha,beta: 4.34 ,9.50
# alpha,beta: -1.19 ,7.11
# alpha,beta: 3.04 ,7.74
# alpha,beta: 1.14 ,9.66
# alpha,beta: -0.35 ,12.16
# alpha,beta: 3.74 ,8.11
# alpha,beta: -0.67 ,7.93
# alpha,beta: 5.45 ,4.47
# alpha,beta: 3.30 ,9.60
# alpha,beta: 3.90 ,9.32
# alpha,beta: 3.12 ,7.06
# alpha,beta: 0.96 ,6.52
# alpha,beta: 1.14 ,10.06
# alpha,beta: 1.09 ,7.73
# alpha,beta: 1.82 ,7.20
# alpha,beta: 2.14 ,9.53
# alpha,beta: 1.96 ,7.07
# alpha,beta: 3.27 ,4.91
# alpha,beta: 2.45 ,5.18
# alpha,beta: 2.15 ,9.34
# alpha,beta: 3.61 ,9.31
# alpha,beta: 0.38 ,6.95
# alpha,beta: 1.24 ,7.20
# alpha,beta: 0.94 ,8.43
# alpha,beta: 3.57 ,6.46
# alpha,beta: 2.78 ,6.68
# alpha,beta: 1.23 ,6.84
# alpha,beta: 1.51 ,6.03
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# -> Mag Distribution
# --> Getting truth distributions
# end!
# Compute MaskFraction and Norm
# norm less than zero: -5.733206184067646
# norm less than zero: -5.6872750737930104
# norm less than zero: -4.959966314656141
# norm less than zero: -0.8782770640717934
# norm less than zero: -0.41543634353405773
# norm less than zero: -0.4186082075872016
# norm less than zero: -1.26200613270248
# norm less than zero: -2.7862383532568096
# norm less than zero: -0.2520667664622161
# norm less than zero: -13.763844302440965
# norm less than zero: -3.4493111391739464
# norm less than zero: -20.26144994649664
#
#  Compute Probabilities
# alpha,beta: 7.57 ,1.75
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 7.05 ,1.39
# alpha,beta: 5.67 ,3.02
# alpha,beta: 8.18 ,3.47
# alpha,beta: 7.44 ,3.46
# alpha,beta: 6.30 ,3.28
# alpha,beta: 4.66 ,3.11
# alpha,beta: 4.62 ,5.36
# alpha,beta: 9.74 ,1.79
# alpha,beta: 4.26 ,4.34
# alpha,beta: 5.35 ,3.92
# alpha,beta: 4.91 ,5.70
# alpha,beta: 10.88 ,4.17
# alpha,beta: 9.36 ,5.89
# alpha,beta: 5.61 ,4.03
# alpha,beta: 8.00 ,5.72
# alpha,beta: 9.28 ,5.68
# alpha,beta: 7.58 ,7.87
# alpha,beta: 6.99 ,7.00
# alpha,beta: 8.42 ,8.27
# alpha,beta: 6.06 ,6.08
# alpha,beta: 7.05 ,7.48
# alpha,beta: 7.14 ,7.66
# alpha,beta: 4.95 ,6.65
# alpha,beta: 7.12 ,6.11
# alpha,beta: 6.88 ,8.81
# alpha,beta: 5.78 ,4.86
# alpha,beta: 6.76 ,5.17
# alpha,beta: 7.52 ,5.42
# alpha,beta: 7.59 ,5.45
# alpha,beta: 8.37 ,7.06
# alpha,beta: 5.26 ,8.36
# alpha,beta: 5.32 ,6.63
# alpha,beta: 7.52 ,6.94
# alpha,beta: 7.57 ,5.86
# alpha,beta: 5.31 ,5.12
# alpha,beta: 7.39 ,7.58
# alpha,beta: 6.61 ,6.46
# alpha,beta: 6.47 ,6.65
# alpha,beta: 8.96 ,4.17
# alpha,beta: 7.58 ,9.54
# alpha,beta: 6.93 ,7.39
# alpha,beta: 3.86 ,8.07
# alpha,beta: 6.86 ,8.14
# alpha,beta: 7.07 ,6.90
# alpha,beta: 6.85 ,4.71
# alpha,beta: 6.67 ,8.37
# alpha,beta: 5.61 ,7.70
# alpha,beta: 5.27 ,3.41
# alpha,beta: 7.21 ,6.20
# alpha,beta: 4.63 ,10.51
# alpha,beta: 6.16 ,9.21
# alpha,beta: 7.94 ,8.07
# alpha,beta: 6.52 ,8.67
# alpha,beta: 5.23 ,9.33
# alpha,beta: 9.06 ,2.65
# alpha,beta: 5.11 ,9.05
# alpha,beta: 6.40 ,8.06
# alpha,beta: 11.69 ,3.69
# alpha,beta: 8.57 ,7.72
# alpha,beta: 9.41 ,8.33
# alpha,beta: 7.11 ,10.17
# alpha,beta: 6.36 ,7.90
# alpha,beta: 5.59 ,9.38
# alpha,beta: 9.38 ,7.27
# alpha,beta: 8.32 ,8.86
# alpha,beta: 2.62 ,9.12
# alpha,beta: 5.43 ,8.10
# alpha,beta: 9.60 ,9.50
# alpha,beta: 3.20 ,7.99
# alpha,beta: 8.35 ,6.66
# alpha,beta: 9.49 ,9.17
# alpha,beta: 9.16 ,9.33
# alpha,beta: 8.66 ,9.28
# alpha,beta: 6.94 ,7.64
# alpha,beta: 8.84 ,8.67
# alpha,beta: 7.28 ,8.26
# alpha,beta: 7.13 ,8.20
# alpha,beta: 7.56 ,8.10
# alpha,beta: 4.86 ,6.71
# alpha,beta: 2.25 ,8.56
# alpha,beta: 6.81 ,9.22
# alpha,beta: 1.22 ,9.07
# alpha,beta: 6.06 ,10.10
# alpha,beta: 4.90 ,11.59
# alpha,beta: 8.22 ,10.67
# alpha,beta: 9.06 ,8.67
# alpha,beta: 2.89 ,11.45
# alpha,beta: 9.78 ,10.61
# alpha,beta: 7.80 ,8.28
# alpha,beta: 7.06 ,7.73
# alpha,beta: 10.53 ,8.31
# alpha,beta: 8.57 ,9.90
# alpha,beta: 5.18 ,10.31
# alpha,beta: 3.13 ,5.03
# alpha,beta: 8.58 ,6.34
# alpha,beta: 2.82 ,9.02
# alpha,beta: 6.42 ,4.69
# alpha,beta: 8.81 ,6.81
# alpha,beta: 3.56 ,11.54
# alpha,beta: 6.35 ,9.90
# alpha,beta: 7.54 ,13.27
# alpha,beta: 8.42 ,5.29
# alpha,beta: 3.90 ,9.64
# alpha,beta: 8.94 ,5.62
# alpha,beta: 6.22 ,8.79
# alpha,beta: 5.99 ,13.39
# alpha,beta: 7.26 ,11.79
# alpha,beta: 10.20 ,11.18
# alpha,beta: 8.56 ,12.48
# alpha,beta: 6.04 ,8.15
# alpha,beta: 5.80 ,10.99
# alpha,beta: 6.51 ,5.66
# alpha,beta: -3.43 ,12.42
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 4.75 ,7.50
# alpha,beta: 4.65 ,3.46
# alpha,beta: 5.86 ,11.22
# alpha,beta: 6.05 ,8.67
# alpha,beta: 5.92 ,12.12
# alpha,beta: 5.82 ,12.41
# alpha,beta: 4.18 ,12.95
# alpha,beta: 4.71 ,12.14
# alpha,beta: 4.05 ,10.99
# alpha,beta: 2.79 ,13.14
# alpha,beta: 1.35 ,8.26
# alpha,beta: 3.00 ,10.43
# alpha,beta: 0.30 ,11.58
# alpha,beta: 3.34 ,9.74
# alpha,beta: 9.76 ,9.27
# alpha,beta: 1.44 ,11.31
# alpha,beta: 5.80 ,11.53
# alpha,beta: 0.69 ,7.59
# alpha,beta: 1.06 ,11.11
# alpha,beta: 2.01 ,10.26
# alpha,beta: 2.96 ,8.45
# alpha,beta: 6.18 ,7.87
# alpha,beta: 8.90 ,10.85
# alpha,beta: 2.96 ,8.72
# alpha,beta: 3.21 ,12.57
# alpha,beta: 6.79 ,9.17
# alpha,beta: 5.43 ,10.26
# alpha,beta: 2.17 ,9.94
# alpha,beta: 3.91 ,10.14
# alpha,beta: 5.68 ,8.82
# alpha,beta: 4.20 ,9.14
# alpha,beta: 4.61 ,9.81
# alpha,beta: 5.29 ,11.97
# alpha,beta: 3.54 ,11.47
# alpha,beta: 6.28 ,11.04
# alpha,beta: 1.17 ,11.00
# alpha,beta: 2.70 ,7.94
# alpha,beta: 7.41 ,12.36
# alpha,beta: 3.59 ,12.68
# alpha,beta: 0.48 ,9.57
# alpha,beta: 4.81 ,12.06
# alpha,beta: 2.05 ,7.67
# alpha,beta: 3.56 ,11.42
# alpha,beta: -1.23 ,11.96
# alpha,beta: 2.96 ,2.99
# alpha,beta: 2.34 ,8.74
# alpha,beta: 3.42 ,11.62
# alpha,beta: 5.98 ,7.33
# alpha,beta: 2.70 ,8.66
# alpha,beta: 8.56 ,9.45
# alpha,beta: 2.24 ,7.28
# alpha,beta: 3.97 ,2.45
# alpha,beta: 3.17 ,8.10
# alpha,beta: 2.20 ,9.79
# alpha,beta: 3.04 ,5.03
# alpha,beta: 2.66 ,8.17
# alpha,beta: 4.55 ,8.10
# alpha,beta: 1.28 ,9.82
# alpha,beta: 3.63 ,8.55
# alpha,beta: 4.15 ,6.39
# alpha,beta: 5.14 ,9.55
# alpha,beta: 4.06 ,10.76
# alpha,beta: 5.14 ,3.91
# alpha,beta: 3.85 ,5.70
# alpha,beta: 3.59 ,9.02
# alpha,beta: 0.76 ,11.12
# alpha,beta: 3.69 ,6.45
# alpha,beta: 4.48 ,10.33
# alpha,beta: 1.71 ,7.06
# alpha,beta: 2.24 ,11.12
# alpha,beta: 4.58 ,3.68
# alpha,beta: 2.60 ,10.08
# alpha,beta: 2.73 ,8.17
# alpha,beta: 2.90 ,6.15
# alpha,beta: 2.75 ,5.45
# alpha,beta: 1.39 ,5.55
# alpha,beta: 3.71 ,11.95
# alpha,beta: 2.72 ,8.31
# alpha,beta: 3.16 ,11.11
# alpha,beta: 6.31 ,12.59
# alpha,beta: 2.59 ,9.61
# alpha,beta: 1.36 ,9.86
# alpha,beta: 5.60 ,8.97
# alpha,beta: 6.56 ,13.28
# alpha,beta: 2.17 ,6.59
# alpha,beta: 3.15 ,6.47
# alpha,beta: 0.69 ,8.90
# alpha,beta: 3.02 ,9.87
# alpha,beta: 4.30 ,8.22
# alpha,beta: 2.31 ,8.35
# alpha,beta: 3.47 ,7.44
# alpha,beta: 1.53 ,5.47
# alpha,beta: 3.75 ,11.44
# alpha,beta: 2.34 ,6.26
# alpha,beta: 3.97 ,10.97
# alpha,beta: 1.44 ,4.63
# alpha,beta: 0.81 ,10.57
# alpha,beta: 4.28 ,10.33
# alpha,beta: 4.13 ,10.10
# alpha,beta: 1.31 ,9.58
# alpha,beta: 1.38 ,9.19
# alpha,beta: 1.95 ,6.77
# alpha,beta: 3.34 ,11.48
# alpha,beta: 3.53 ,7.34
# alpha,beta: 3.52 ,8.11
# alpha,beta: 2.53 ,6.44
# alpha,beta: 2.79 ,6.89
# alpha,beta: 4.66 ,10.90
# alpha,beta: 5.81 ,8.93
# alpha,beta: 2.36 ,11.52
# alpha,beta: 1.09 ,8.65
# alpha,beta: 1.49 ,5.83
# alpha,beta: 6.66 ,9.44
# alpha,beta: 1.80 ,6.78
# alpha,beta: 1.52 ,9.21
# alpha,beta: 0.38 ,7.90
# alpha,beta: 2.86 ,5.79
# alpha,beta: 2.82 ,7.14
# alpha,beta: 2.69 ,6.33
# alpha,beta: 2.43 ,6.41
# alpha,beta: 4.21 ,3.57
# alpha,beta: 2.78 ,4.86
# alpha,beta: 2.67 ,5.48
# alpha,beta: 2.18 ,6.56
# alpha,beta: 2.17 ,8.32
# alpha,beta: 1.24 ,4.89
# alpha,beta: 2.39 ,5.91
# alpha,beta: -1.14 ,6.77
# alpha,beta: 2.09 ,7.64
# alpha,beta: 0.44 ,5.66
# alpha,beta: 3.10 ,4.80
# alpha,beta: 2.27 ,4.98
# alpha,beta: 3.02 ,7.23
# alpha,beta: 1.45 ,7.47
# alpha,beta: 0.77 ,5.32
# alpha,beta: 4.86 ,6.89
# alpha,beta: 5.46 ,7.25
# alpha,beta: 3.24 ,9.25
# alpha,beta: -0.14 ,7.45
# alpha,beta: -0.22 ,6.23
# alpha,beta: 0.03 ,7.58
# alpha,beta: 2.66 ,5.78
# alpha,beta: -0.17 ,5.98
# alpha,beta: 1.23 ,6.21
# alpha,beta: -1.02 ,4.96
# alpha,beta: 2.17 ,4.88
# alpha,beta: 1.69 ,6.92
# alpha,beta: 1.53 ,6.09
# alpha,beta: 2.45 ,8.34
# alpha,beta: 3.31 ,4.41
# alpha,beta: 2.04 ,6.36
# alpha,beta: 2.04 ,6.70
# alpha,beta: 3.23 ,10.91
# alpha,beta: 1.80 ,7.42
# alpha,beta: -1.90 ,6.90
# alpha,beta: 3.02 ,5.23
# alpha,beta: -0.20 ,4.86
# alpha,beta: 1.00 ,5.85
# alpha,beta: 2.11 ,6.64
# alpha,beta: 5.04 ,5.91
# alpha,beta: 4.61 ,3.52
# alpha,beta: 0.29 ,6.22
# alpha,beta: 1.25 ,5.70
# alpha,beta: 5.27 ,7.61
# alpha,beta: 3.57 ,7.25
# alpha,beta: 2.52 ,5.84
# alpha,beta: -3.46 ,8.52
# alpha,beta: 3.13 ,9.10
# alpha,beta: -0.70 ,7.52
# alpha,beta: 0.77 ,5.81
# alpha,beta: 2.44 ,6.49
# alpha,beta: 3.66 ,6.94
# alpha,beta: 1.10 ,6.51
# alpha,beta: 3.90 ,6.46
# alpha,beta: -2.81 ,9.34
# alpha,beta: 2.82 ,5.89
# alpha,beta: 3.89 ,7.63
# alpha,beta: 3.19 ,6.22
# alpha,beta: 2.20 ,6.39
# alpha,beta: 2.85 ,5.82
# alpha,beta: 0.34 ,5.31
# alpha,beta: 2.95 ,4.17
# alpha,beta: 4.52 ,5.53
# alpha,beta: 1.39 ,5.10
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# end!
# compute ptaken
# Total time: 162.278414965s
# ---------------
#
#
# run     : dnf_rhod_02Lstar
# zfile   : dnf
# zwindow : 0.03
#
# Starting Copa
# run dnf_rhod_02Lstar
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00000.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2164589
# cut:  1117778
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00000/dnf_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00256.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  2791169
# cut:  1541073
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00256/dnf_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00257.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3708874
# cut:  2029154
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00257/dnf_rhod_02Lstar_copa_test_gal.fits
# master_file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/tiles/buzzard_v2.0.0_rm_lgt20_copa_00260.hdf5
# loading clusters
# apply magnitude selection
# loading full members catalog
# making color columns
# selecting fake photo-z catalog
# making galaxies cut
# galaxy catalog
# all:  3019411
# cut:  1664479
# assigning background galaxies
# computing physical quantities
#
#
# tile file: /data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3_rm/output/temp_file/00260/dnf_rhod_02Lstar_copa_test_gal.fits
# copa parallel process
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# bad cluster: 30253577 ratio min/max: 0.5143857522247857 6742.9593440490235
# bad cluster: 30253577 ratio min/max: 0.6426480244259334 11139.300987452103
# bad cluster: 30253577 ratio min/max: 1.3512912701014939 11383.762029898648
# bad cluster: 30253577 ratio min/max: 28.679768376916567 11579.33086385588
# bad cluster: 30255944 ratio min/max: 13.58293760695075 11440.666622038947
# Geting Redshift Window
# Computing Galaxy Density
# bad cluster: 30257324 ratio min/max: 0.4243807008030016 2161.360285251825
# bad cluster: 30257324 ratio min/max: 1.3699678105408073 5195.58318228526
# bad cluster: 30257324 ratio min/max: 2.4061708403584667 5359.9872491064225
# bad cluster: 30257324 ratio min/max: 18.239487881706253 5491.510502563354
# bad cluster: 30257324 ratio min/max: 40.91394549702288 5596.729105328898
# bad cluster: 30257324 ratio min/max: 44.93945611821228 5680.903987541333
# Computing R200
# bad cluster: 30257324 ratio min/max: 46.94057119087741 5748.243893311282
# bad cluster: 30257324 ratio min/max: 48.54146324900951 5802.115817927239
# bad cluster: 30257324 ratio min/max: 49.820435162108005 5845.213357620007
# bad cluster: 30257324 ratio min/max: 50.84260548052507 5879.69138937422
# bad cluster: 30269123 ratio min/max: 4.1120158795633355 2584.8456583464294
# bad cluster: 30849442 ratio min/max: 4.534447766481515 1487.4604936760436
# bad cluster: 30850464 ratio min/max: 9.03671233973992 4454.132866688529
# bad cluster: 30850754 ratio min/max: 23.740882024688172 1879.9445655707307
# bad cluster: 30851547 ratio min/max: 34.41878092003143 9179.445044105383
# bad cluster: 18228324 ratio min/max: 0.8238637268116717 760.9562363578879
# bad cluster: 30853765 ratio min/max: 5.144976875952564 405.7459666251815
# bad cluster: 30854865 ratio min/max: 38.624914683931074 13376.823164305632
# bad cluster: 18238445 ratio min/max: 0.008583095131855479 1511.6744007604163
# bad cluster: 34056556 ratio min/max: 0.08213748459737857 895.0045730442664
# bad cluster: 34056556 ratio min/max: 4.031925603424021 5546.494075124837
# Computing PDFs
#
# -> Radial Distribution
# bad cluster: 19059672 ratio min/max: 2.7562074535206422 3324.180039481119
# bad cluster: 19062914 ratio min/max: 1.2891509388174986 1375.349175000466
# bad cluster: 19062914 ratio min/max: 3.4345547412346926 4388.656133936871
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# Geting Redshift Window
# Computing Galaxy Density
# Computing R200
# -> Redshift Distribution
# bad cluster: 19156765 ratio min/max: 18.07412404191874 4595.2466136954745
# bad cluster: 19161438 ratio min/max: 0.584037280715775 1472.320636783214
# bad cluster: 19161438 ratio min/max: 6.063296826256401 4452.761251658605
# bad cluster: 19161438 ratio min/max: 7.960086512606864 4686.639077140198
# bad cluster: 19873595 ratio min/max: 3.523915001369089 150.84994816084313
# Computing PDFs
#
# -> Radial Distribution
# bad cluster: 18054432 ratio min/max: 0.00891705915262775 12380.956511407496
# bad cluster: 18111903 ratio min/max: 0.009099545653591421 23006.29566287985
# -> Color Distribution
# bad cluster: 18940831 ratio min/max: 0.018444635197220335 1005.616652404691
# bad cluster: 18940831 ratio min/max: 0.16871344211326575 3064.988874769417
# bad cluster: 18945227 ratio min/max: 0.21259376067682584 18990.252057089307
# bad cluster: 19734539 ratio min/max: 1.125867095119266 2438.73692680985
# -> Redshift Distribution
# bad cluster: 18997887 ratio min/max: 13.422647172426698 573.5446229226629
# bad cluster: 18998308 ratio min/max: 1.1685219377935123 1258.9957146252113
# bad cluster: 19773591 ratio min/max: 1.3155486712983357 2807.904625425707
# bad cluster: 18999174 ratio min/max: 0.009987629402987391 9738.521137171001
# bad cluster: 19781247 ratio min/max: 0.007898964490891721 1426.188945979755
# Computing PDFs
#
# -> Radial Distribution
# bad cluster: 19821779 ratio min/max: 33.32466927708842 1707.87871317509
# -> Color Distribution
# bad cluster: 19824626 ratio min/max: 33.57219167288012 1885.151044312147
# bad cluster: 19832313 ratio min/max: 0.6916584141400532 546.2266606828051
# bad cluster: 19832313 ratio min/max: 1.5192724626834615 4295.034554701637
# bad cluster: 19873052 ratio min/max: 1.5989728447615175 435.74241128582537
# -> Redshift Distribution
# Computing PDFs
#
# -> Radial Distribution
# -> Color Distribution
# -> Redshift Distribution
# -> Color Distribution
# -> Mag Distribution
# --> Getting truth distributions
# Compute MaskFraction and Norm
# norm less than zero: -3.3094871684205507
# norm less than zero: -4.262515588636483
# norm less than zero: -0.5339872308979229
# norm less than zero: -1.9127946462070515
# norm less than zero: -1.4713096798087668
# norm less than zero: -0.17850657090933097
# norm less than zero: -0.19799707703059707
#
#  Compute Probabilities
# alpha,beta: 6.53 ,1.07
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 5.59 ,2.85
# alpha,beta: 3.66 ,1.45
# alpha,beta: 7.72 ,6.74
# alpha,beta: 4.77 ,4.69
# alpha,beta: 6.19 ,4.61
# alpha,beta: 2.78 ,4.58
# alpha,beta: 6.49 ,7.54
# alpha,beta: 5.32 ,2.36
# alpha,beta: 5.69 ,7.74
# alpha,beta: 9.20 ,7.36
# alpha,beta: 6.00 ,6.30
# alpha,beta: 4.11 ,6.05
# alpha,beta: 5.80 ,7.04
# alpha,beta: 5.43 ,5.81
# alpha,beta: 7.12 ,7.37
# alpha,beta: 6.60 ,6.79
# alpha,beta: 4.22 ,5.62
# alpha,beta: 6.46 ,4.46
# alpha,beta: 3.32 ,6.20
# alpha,beta: 6.93 ,4.84
# alpha,beta: 3.50 ,5.63
# alpha,beta: 7.39 ,7.71
# alpha,beta: 3.67 ,5.06
# alpha,beta: 6.05 ,6.97
# alpha,beta: 4.42 ,4.36
# alpha,beta: 4.10 ,5.61
# alpha,beta: 3.41 ,5.93
# alpha,beta: 8.30 ,7.33
# alpha,beta: 4.40 ,6.32
# alpha,beta: 5.28 ,2.35
# alpha,beta: 5.77 ,5.64
# alpha,beta: 4.28 ,7.15
# alpha,beta: 1.81 ,6.05
# alpha,beta: 5.99 ,7.31
# alpha,beta: 6.21 ,5.75
# alpha,beta: 3.69 ,8.55
# alpha,beta: 2.29 ,3.97
# alpha,beta: 5.16 ,3.42
# alpha,beta: 4.78 ,4.87
# alpha,beta: 4.29 ,3.54
# alpha,beta: 5.73 ,6.04
# alpha,beta: 5.97 ,5.10
# alpha,beta: 5.37 ,5.33
# alpha,beta: 2.56 ,3.46
# alpha,beta: 5.16 ,2.29
# alpha,beta: 4.28 ,3.12
# alpha,beta: 6.49 ,5.49
# alpha,beta: 3.74 ,7.83
# alpha,beta: 3.61 ,5.71
# alpha,beta: 6.29 ,6.08
# alpha,beta: 5.35 ,1.18
# alpha,beta: 4.05 ,5.41
# alpha,beta: 4.77 ,1.38
# alpha,beta: 1.36 ,5.41
# alpha,beta: 4.10 ,3.41
# alpha,beta: 0.62 ,5.67
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 4.76 ,5.17
# alpha,beta: 2.39 ,1.80
# alpha,beta: 3.20 ,5.08
# alpha,beta: -3.08 ,4.85
# alpha,beta: 4.78 ,3.94
# alpha,beta: 1.17 ,5.34
# alpha,beta: 2.24 ,1.26
# alpha,beta: 0.95 ,3.87
# alpha,beta: 3.13 ,3.88
# alpha,beta: 1.70 ,5.43
# alpha,beta: 1.95 ,7.93
# alpha,beta: 2.86 ,5.32
# alpha,beta: 3.74 ,2.76
# alpha,beta: 2.36 ,4.35
# alpha,beta: 3.53 ,2.20
# alpha,beta: 0.82 ,4.48
# alpha,beta: 2.41 ,4.45
# alpha,beta: 3.39 ,6.14
# alpha,beta: 1.42 ,6.76
# alpha,beta: 3.12 ,5.46
# alpha,beta: 2.90 ,4.46
# alpha,beta: 1.80 ,3.39
# alpha,beta: 1.72 ,3.64
# alpha,beta: 2.74 ,5.55
# alpha,beta: 1.81 ,5.34
# alpha,beta: 5.32 ,2.85
# alpha,beta: -1.78 ,3.20
# alpha,beta: 2.70 ,4.65
# alpha,beta: 3.88 ,3.01
# alpha,beta: 5.42 ,4.42
# alpha,beta: 0.56 ,5.79
# alpha,beta: 2.30 ,4.16
# alpha,beta: 3.33 ,1.87
# alpha,beta: 1.09 ,4.68
# alpha,beta: 2.00 ,2.77
# alpha,beta: 3.59 ,4.40
# alpha,beta: 2.26 ,4.80
# alpha,beta: 2.75 ,4.32
# alpha,beta: 1.34 ,4.71
# alpha,beta: 1.85 ,5.13
# alpha,beta: 2.17 ,5.30
# alpha,beta: 1.87 ,5.75
# alpha,beta: 1.82 ,7.17
# alpha,beta: 4.50 ,2.82
# alpha,beta: 2.81 ,3.48
# alpha,beta: 4.38 ,2.53
# alpha,beta: 1.29 ,4.66
# alpha,beta: 2.09 ,4.55
# alpha,beta: 2.29 ,4.62
# alpha,beta: 2.07 ,4.45
# alpha,beta: 1.47 ,4.11
# alpha,beta: 2.72 ,5.84
# alpha,beta: 0.82 ,5.23
# alpha,beta: 3.71 ,6.09
# alpha,beta: 1.79 ,5.43
# alpha,beta: 3.99 ,3.35
# alpha,beta: 3.84 ,5.36
# alpha,beta: 6.44 ,1.70
# alpha,beta: -0.42 ,4.65
# alpha,beta: 2.69 ,4.27
# alpha,beta: 1.42 ,6.03
# alpha,beta: 2.66 ,5.62
# alpha,beta: 4.55 ,2.47
# alpha,beta: 1.22 ,4.46
# alpha,beta: 1.46 ,5.60
# alpha,beta: 1.07 ,1.85
# alpha,beta: 1.42 ,3.90
# alpha,beta: 2.01 ,3.77
# alpha,beta: 2.25 ,4.14
# alpha,beta: 2.88 ,4.95
# alpha,beta: 4.17 ,2.17
# alpha,beta: 2.70 ,4.24
# alpha,beta: 0.97 ,6.17
# alpha,beta: -1.19 ,4.46
# alpha,beta: 0.60 ,2.31
# alpha,beta: -0.80 ,4.05
# alpha,beta: 3.76 ,2.02
# alpha,beta: 2.04 ,4.79
# alpha,beta: 0.65 ,3.96
# alpha,beta: 2.30 ,3.18
# alpha,beta: 1.59 ,4.38
# alpha,beta: 1.95 ,3.91
# alpha,beta: 1.48 ,2.50
# alpha,beta: 0.27 ,6.32
# alpha,beta: 3.00 ,4.70
# alpha,beta: 1.52 ,2.16
# alpha,beta: 0.66 ,3.64
# alpha,beta: 3.71 ,3.80
# alpha,beta: 0.34 ,3.37
# alpha,beta: -0.15 ,4.15
# alpha,beta: 0.22 ,4.94
# alpha,beta: 5.46 ,2.35
# alpha,beta: 2.13 ,2.57
# alpha,beta: 4.87 ,4.36
# alpha,beta: 2.56 ,1.78
# alpha,beta: 1.19 ,3.98
# alpha,beta: 2.78 ,4.46
# alpha,beta: 3.03 ,3.24
# alpha,beta: 1.06 ,3.62
# alpha,beta: 1.82 ,3.99
# alpha,beta: -0.14 ,3.02
# alpha,beta: 1.87 ,5.58
# alpha,beta: 2.13 ,3.94
# alpha,beta: 3.69 ,4.17
# alpha,beta: 1.21 ,4.83
# alpha,beta: 5.11 ,5.35
# alpha,beta: 2.55 ,7.05
# alpha,beta: 3.58 ,6.84
# alpha,beta: 3.47 ,4.02
# alpha,beta: 2.09 ,3.65
# alpha,beta: 0.08 ,4.15
# alpha,beta: 3.30 ,5.11
# alpha,beta: 5.38 ,1.78
# alpha,beta: 3.20 ,7.00
# alpha,beta: 6.18 ,2.92
# alpha,beta: 4.07 ,4.53
# alpha,beta: 3.41 ,5.17
# alpha,beta: 1.95 ,3.27
# alpha,beta: 6.30 ,3.15
# alpha,beta: 6.20 ,5.02
# alpha,beta: 3.37 ,4.22
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# -> Mag Distribution
# --> Getting truth distributions
# end!
# Compute MaskFraction and Norm
# norm less than zero: -2.3056925868900353
# norm less than zero: -5.455582297274446
# norm less than zero: -0.8398762139994317
# norm less than zero: -2.4473380082100307
# norm less than zero: -2.137916503111634
# -> Mag Distribution
# --> Getting truth distributions
# norm less than zero: -4.706988026225541
# norm less than zero: -0.3475206807444166
# norm less than zero: -0.8817495103270571
# norm less than zero: -0.18425476103656285
# norm less than zero: -1.9446037402336067
# norm less than zero: -0.8222757078373405
#
#  Compute Probabilities
# alpha,beta: 9.96 ,2.95
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 4.51 ,1.36
# alpha,beta: 5.33 ,4.08
# alpha,beta: 4.51 ,2.35
# alpha,beta: 5.86 ,2.91
# alpha,beta: 3.14 ,3.36
# alpha,beta: 3.61 ,3.81
# alpha,beta: 5.05 ,3.13
# alpha,beta: 2.26 ,3.03
# alpha,beta: 3.91 ,4.38
# alpha,beta: 3.88 ,2.73
# alpha,beta: 8.41 ,5.77
# alpha,beta: 10.67 ,6.89
# alpha,beta: 8.62 ,6.97
# alpha,beta: 6.89 ,5.14
# alpha,beta: 4.43 ,5.13
# alpha,beta: 4.92 ,6.84
# alpha,beta: 7.32 ,7.29
# alpha,beta: 8.70 ,3.22
# alpha,beta: 6.26 ,5.60
# alpha,beta: 6.50 ,5.47
# alpha,beta: 5.83 ,5.54
# alpha,beta: 7.06 ,4.50
# alpha,beta: 7.49 ,4.94
# alpha,beta: 6.16 ,7.58
# alpha,beta: 10.38 ,6.50
# alpha,beta: 6.78 ,6.76
# alpha,beta: 5.57 ,7.19
# alpha,beta: 4.32 ,8.83
# alpha,beta: 5.77 ,7.13
# alpha,beta: 4.18 ,8.41
# alpha,beta: 8.52 ,8.31
# alpha,beta: 5.28 ,8.36
# alpha,beta: 8.56 ,10.24
# alpha,beta: 6.73 ,6.97
# alpha,beta: 5.81 ,7.12
# alpha,beta: 5.08 ,6.07
# alpha,beta: 4.76 ,6.38
# alpha,beta: 5.71 ,7.79
# alpha,beta: 5.09 ,7.67
# alpha,beta: 5.29 ,7.11
# alpha,beta: 5.08 ,8.71
# alpha,beta: 6.28 ,6.46
# alpha,beta: 6.25 ,6.93
# alpha,beta: 3.12 ,7.14
# alpha,beta: 2.24 ,7.49
# alpha,beta: 6.37 ,8.68
# alpha,beta: 4.69 ,8.41
# alpha,beta: 6.46 ,1.76
# alpha,beta: 5.50 ,3.08
# alpha,beta: 6.17 ,6.87
# alpha,beta: 3.72 ,3.51
# alpha,beta: 5.81 ,6.88
# alpha,beta: 5.69 ,9.69
# alpha,beta: 3.19 ,8.53
# alpha,beta: 4.61 ,7.53
# alpha,beta: 5.48 ,9.00
# alpha,beta: 2.04 ,7.27
# alpha,beta: 1.64 ,7.91
# alpha,beta: 3.31 ,6.73
# alpha,beta: 4.65 ,8.59
# alpha,beta: 5.42 ,2.82
# alpha,beta: 3.85 ,8.02
# alpha,beta: 4.63 ,4.70
# alpha,beta: 5.07 ,7.77
# alpha,beta: 2.57 ,5.53
# alpha,beta: 2.79 ,6.84
# alpha,beta: 1.71 ,8.57
# alpha,beta: 3.22 ,7.69
# alpha,beta: 4.66 ,9.37
# alpha,beta: -1.96 ,6.09
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 2.82 ,6.79
# alpha,beta: 2.83 ,8.64
# alpha,beta: -2.15 ,10.34
# alpha,beta: 4.04 ,5.74
# alpha,beta: 1.82 ,6.85
# alpha,beta: 5.23 ,10.00
# alpha,beta: 5.41 ,8.16
# alpha,beta: 0.83 ,9.70
# alpha,beta: 2.50 ,10.11
# alpha,beta: 2.81 ,8.86
# alpha,beta: 1.19 ,7.03
# alpha,beta: 4.40 ,8.00
# alpha,beta: 3.79 ,6.89
# alpha,beta: 1.08 ,5.86
# alpha,beta: 6.65 ,6.96
# alpha,beta: 5.33 ,7.69
# alpha,beta: 3.72 ,8.17
# alpha,beta: 5.28 ,7.79
# alpha,beta: 4.89 ,7.81
# alpha,beta: 1.26 ,8.17
# alpha,beta: -0.46 ,7.64
# alpha,beta: 3.84 ,7.91
# alpha,beta: 0.87 ,7.53
# alpha,beta: 2.50 ,7.62
# alpha,beta: 3.76 ,9.26
# alpha,beta: 3.23 ,8.26
# alpha,beta: 3.56 ,7.59
# alpha,beta: 2.33 ,8.02
# alpha,beta: 0.88 ,7.22
# alpha,beta: 3.17 ,8.92
# alpha,beta: 0.46 ,7.42
# alpha,beta: 4.91 ,8.40
# alpha,beta: 4.84 ,7.72
# alpha,beta: 3.76 ,7.22
# alpha,beta: 4.59 ,7.75
# alpha,beta: -0.35 ,8.24
# alpha,beta: 1.92 ,6.46
# alpha,beta: 3.36 ,7.99
# alpha,beta: 2.79 ,7.57
# alpha,beta: 0.45 ,4.91
# alpha,beta: 2.71 ,6.41
# alpha,beta: 2.89 ,8.83
# alpha,beta: 3.97 ,6.82
# alpha,beta: 4.03 ,1.82
# alpha,beta: 2.61 ,6.85
# alpha,beta: 3.88 ,8.37
# alpha,beta: 4.30 ,3.35
# alpha,beta: 1.72 ,5.60
# alpha,beta: 2.88 ,6.54
# alpha,beta: 1.01 ,7.71
# alpha,beta: 2.98 ,3.73
# alpha,beta: 1.02 ,3.97
# alpha,beta: -0.49 ,7.24
# alpha,beta: 2.54 ,7.05
# alpha,beta: -2.04 ,5.34
# alpha,beta: 2.68 ,6.11
# alpha,beta: 1.84 ,6.17
# alpha,beta: 3.49 ,8.35
# alpha,beta: 2.87 ,5.72
# alpha,beta: 3.19 ,5.57
# alpha,beta: 2.86 ,6.30
# alpha,beta: 2.37 ,9.01
# alpha,beta: 1.70 ,6.53
# alpha,beta: 2.11 ,7.46
# alpha,beta: 2.92 ,7.52
# alpha,beta: 1.91 ,8.01
# alpha,beta: 0.49 ,8.18
# alpha,beta: 0.89 ,5.49
# alpha,beta: 0.77 ,7.07
# alpha,beta: 3.22 ,5.26
# alpha,beta: 6.42 ,1.25
# alpha,beta: 3.84 ,4.60
# alpha,beta: 0.36 ,7.40
# alpha,beta: 2.81 ,8.40
# alpha,beta: 1.63 ,4.55
# alpha,beta: 5.77 ,6.01
# alpha,beta: 1.42 ,6.69
# alpha,beta: -0.21 ,7.43
# alpha,beta: 1.13 ,5.04
# alpha,beta: 3.77 ,6.24
# alpha,beta: 3.44 ,6.28
# alpha,beta: 0.93 ,4.54
# alpha,beta: 0.50 ,7.96
# alpha,beta: 4.61 ,4.05
# alpha,beta: 2.02 ,5.75
# alpha,beta: 0.68 ,7.60
# alpha,beta: 1.09 ,3.87
# alpha,beta: 3.25 ,6.85
# alpha,beta: 1.44 ,5.99
# alpha,beta: 0.75 ,8.85
# alpha,beta: 3.21 ,6.44
# alpha,beta: 0.91 ,6.62
# alpha,beta: 2.14 ,7.92
# alpha,beta: 3.28 ,2.13
# alpha,beta: 3.79 ,7.02
# alpha,beta: 3.74 ,7.50
# alpha,beta: -0.40 ,5.89
# alpha,beta: 1.18 ,5.16
# alpha,beta: 2.77 ,7.94
# alpha,beta: 2.34 ,7.11
# alpha,beta: 3.02 ,7.55
# alpha,beta: 4.33 ,7.91
# alpha,beta: 0.33 ,7.10
# alpha,beta: 2.70 ,6.44
# alpha,beta: 1.07 ,6.46
# alpha,beta: 2.06 ,4.81
# alpha,beta: 0.49 ,6.08
# alpha,beta: 1.05 ,6.96
# alpha,beta: 4.19 ,8.75
# alpha,beta: 1.22 ,7.33
# alpha,beta: 3.08 ,7.58
# alpha,beta: 0.63 ,6.85
# alpha,beta: 1.32 ,5.01
# alpha,beta: 0.05 ,6.64
# alpha,beta: 0.03 ,5.21
# alpha,beta: 1.36 ,6.18
# alpha,beta: 1.68 ,7.23
# alpha,beta: 3.29 ,4.19
# alpha,beta: 2.04 ,8.49
# alpha,beta: 1.72 ,9.13
# alpha,beta: 2.61 ,5.46
# alpha,beta: 2.20 ,5.45
# alpha,beta: 0.96 ,6.16
# alpha,beta: 1.28 ,5.70
# alpha,beta: 1.19 ,8.60
# alpha,beta: 2.44 ,2.00
# alpha,beta: -0.07 ,6.08
# alpha,beta: 4.03 ,3.91
# alpha,beta: 3.01 ,3.46
# alpha,beta: 3.16 ,5.27
# alpha,beta: -1.82 ,4.70
# alpha,beta: -0.67 ,5.78
# alpha,beta: 3.30 ,4.57
# alpha,beta: 1.91 ,5.22
# alpha,beta: 3.18 ,4.59
# alpha,beta: 4.50 ,3.93
# alpha,beta: 1.68 ,3.70
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# Compute MaskFraction and Norm
# norm less than zero: -0.8951981931399325
# norm less than zero: -0.6924588059261684
# norm less than zero: -6.033444836498007
# norm less than zero: -5.619328656897545
# norm less than zero: -5.378805367231514
# norm less than zero: -0.0004937432864763595
# norm less than zero: -0.4680314002263716
# norm less than zero: -2.993589594172951
# norm less than zero: -1.5373209236741845
#
#  Compute Probabilities
# end!
# alpha,beta: 7.05 ,3.71
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 5.91 ,3.44
# alpha,beta: 3.69 ,3.16
# alpha,beta: 8.21 ,3.30
# alpha,beta: 7.27 ,3.53
# alpha,beta: 7.06 ,2.50
# alpha,beta: 4.48 ,1.92
# alpha,beta: 5.54 ,4.03
# alpha,beta: 8.71 ,3.62
# alpha,beta: 5.94 ,4.48
# alpha,beta: 4.68 ,3.54
# alpha,beta: 5.94 ,4.03
# alpha,beta: 7.27 ,3.40
# alpha,beta: 4.63 ,4.03
# alpha,beta: 6.12 ,6.27
# alpha,beta: 7.76 ,4.69
# alpha,beta: 4.27 ,3.66
# alpha,beta: 6.82 ,5.80
# alpha,beta: 7.01 ,6.57
# alpha,beta: 5.75 ,2.50
# alpha,beta: 3.10 ,2.99
# alpha,beta: 7.92 ,8.19
# alpha,beta: 6.39 ,7.12
# alpha,beta: 8.10 ,5.91
# alpha,beta: 8.46 ,5.78
# alpha,beta: 8.70 ,6.42
# alpha,beta: 5.03 ,6.34
# alpha,beta: 8.72 ,6.16
# alpha,beta: 5.80 ,5.22
# alpha,beta: 6.10 ,5.00
# alpha,beta: 6.95 ,6.04
# alpha,beta: 5.89 ,5.65
# alpha,beta: 5.52 ,5.09
# alpha,beta: 4.92 ,5.34
# alpha,beta: 7.89 ,2.65
# alpha,beta: 9.81 ,5.38
# alpha,beta: 6.64 ,7.98
# alpha,beta: 2.68 ,7.06
# alpha,beta: 6.60 ,6.94
# alpha,beta: 4.85 ,6.91
# alpha,beta: 8.19 ,6.57
# alpha,beta: 5.38 ,13.50
# alpha,beta: 6.53 ,7.55
# alpha,beta: 6.66 ,7.36
# alpha,beta: 5.27 ,8.65
# alpha,beta: 5.26 ,8.45
# alpha,beta: 4.74 ,6.44
# alpha,beta: 7.26 ,8.18
# alpha,beta: 4.41 ,6.88
# alpha,beta: 5.44 ,4.80
# alpha,beta: 5.16 ,2.65
# alpha,beta: 6.99 ,6.84
# alpha,beta: 7.46 ,8.99
# alpha,beta: 5.12 ,6.02
# alpha,beta: 4.94 ,6.20
# alpha,beta: 4.62 ,7.12
# alpha,beta: 7.19 ,7.35
# alpha,beta: 3.47 ,6.95
# alpha,beta: 6.23 ,6.46
# alpha,beta: 4.89 ,6.84
# alpha,beta: 2.72 ,8.77
# alpha,beta: 7.06 ,6.23
# alpha,beta: 2.40 ,7.46
# alpha,beta: 5.67 ,6.88
# alpha,beta: 4.29 ,9.43
# alpha,beta: -0.24 ,8.36
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 5.02 ,8.28
# alpha,beta: 5.22 ,8.22
# alpha,beta: 3.18 ,6.77
# alpha,beta: 2.69 ,8.65
# alpha,beta: 8.95 ,10.71
# alpha,beta: 2.99 ,5.23
# alpha,beta: 2.12 ,7.72
# alpha,beta: 6.16 ,7.57
# alpha,beta: 4.34 ,5.91
# alpha,beta: 2.85 ,7.60
# alpha,beta: 4.55 ,6.20
# alpha,beta: 2.41 ,7.98
# alpha,beta: 2.53 ,7.47
# alpha,beta: 3.34 ,9.48
# alpha,beta: 3.69 ,8.51
# alpha,beta: 7.81 ,8.01
# alpha,beta: 3.92 ,9.62
# alpha,beta: 2.44 ,9.71
# alpha,beta: 5.35 ,13.95
# alpha,beta: 5.85 ,7.75
# alpha,beta: 3.42 ,7.46
# alpha,beta: 6.20 ,5.75
# alpha,beta: 3.05 ,13.79
# alpha,beta: 2.74 ,8.63
# alpha,beta: 6.31 ,9.82
# alpha,beta: 3.54 ,11.21
# alpha,beta: 3.60 ,7.45
# alpha,beta: 6.44 ,8.20
# alpha,beta: 8.72 ,14.97
# alpha,beta: 2.41 ,7.79
# alpha,beta: 0.18 ,10.08
# alpha,beta: 3.74 ,10.84
# alpha,beta: 7.28 ,11.10
# alpha,beta: 3.32 ,8.82
# alpha,beta: 4.89 ,7.11
# alpha,beta: 3.10 ,5.70
# alpha,beta: 6.16 ,9.54
# alpha,beta: 3.46 ,9.98
# alpha,beta: 0.57 ,7.62
# alpha,beta: 6.09 ,7.31
# alpha,beta: 3.95 ,11.46
# alpha,beta: 4.47 ,6.67
# alpha,beta: 4.36 ,8.39
# alpha,beta: 4.46 ,8.65
# alpha,beta: 4.51 ,6.97
# alpha,beta: -0.05 ,13.73
# alpha,beta: 2.66 ,8.73
# alpha,beta: 3.20 ,5.52
# alpha,beta: 6.58 ,8.02
# alpha,beta: 1.56 ,7.35
# alpha,beta: 3.73 ,9.66
# alpha,beta: 2.10 ,7.31
# alpha,beta: 4.72 ,7.42
# alpha,beta: 1.48 ,5.60
# alpha,beta: 2.42 ,5.36
# alpha,beta: 4.25 ,8.59
# alpha,beta: 2.10 ,5.65
# alpha,beta: 1.45 ,7.10
# alpha,beta: 1.19 ,6.23
# alpha,beta: 0.43 ,4.13
# alpha,beta: 1.88 ,3.98
# alpha,beta: 2.21 ,5.61
# alpha,beta: 0.44 ,5.52
# alpha,beta: 3.99 ,6.11
# alpha,beta: 1.94 ,5.42
# alpha,beta: 4.54 ,6.90
# alpha,beta: 3.83 ,7.44
# alpha,beta: 1.85 ,7.42
# alpha,beta: 1.94 ,5.00
# alpha,beta: 3.86 ,5.71
# alpha,beta: 3.23 ,7.13
# alpha,beta: 0.39 ,4.04
# alpha,beta: -1.96 ,5.49
# alpha,beta: 0.83 ,6.34
# alpha,beta: 2.68 ,6.74
# alpha,beta: 2.01 ,6.83
# alpha,beta: 2.82 ,5.28
# alpha,beta: 2.70 ,7.39
# alpha,beta: -0.86 ,11.45
# alpha,beta: 0.52 ,5.89
# alpha,beta: 1.75 ,10.08
# alpha,beta: 1.51 ,4.63
# alpha,beta: 2.17 ,5.38
# alpha,beta: 3.52 ,6.25
# alpha,beta: 1.43 ,7.10
# alpha,beta: 2.58 ,5.71
# alpha,beta: 2.40 ,3.71
# alpha,beta: 2.14 ,8.92
# alpha,beta: 1.54 ,6.19
# alpha,beta: 2.79 ,4.59
# alpha,beta: 2.38 ,5.83
# alpha,beta: 4.42 ,4.85
# alpha,beta: 0.30 ,8.76
# alpha,beta: 3.90 ,5.72
# alpha,beta: 1.62 ,4.86
# alpha,beta: 0.70 ,6.71
# alpha,beta: 2.48 ,8.39
# alpha,beta: 0.69 ,6.63
# alpha,beta: -0.77 ,10.41
# alpha,beta: 3.25 ,4.36
# alpha,beta: 2.28 ,4.46
# alpha,beta: 2.85 ,3.92
# alpha,beta: 0.07 ,5.09
# alpha,beta: 2.12 ,4.21
# alpha,beta: 3.61 ,6.09
# alpha,beta: 4.65 ,9.44
# alpha,beta: 2.27 ,4.89
# alpha,beta: 1.46 ,6.14
# alpha,beta: 1.60 ,6.65
# alpha,beta: 3.83 ,10.01
# alpha,beta: 2.71 ,5.48
# alpha,beta: 2.33 ,6.11
# alpha,beta: 4.32 ,7.36
# alpha,beta: 1.48 ,6.23
# alpha,beta: 2.79 ,7.26
# alpha,beta: 2.85 ,8.24
# alpha,beta: 1.70 ,5.58
# alpha,beta: 3.16 ,7.26
# alpha,beta: 0.37 ,9.25
# alpha,beta: 2.32 ,4.16
# alpha,beta: 0.27 ,9.57
# alpha,beta: 2.50 ,5.29
# alpha,beta: 1.07 ,6.19
# alpha,beta: 2.81 ,5.57
# alpha,beta: 2.08 ,7.16
# alpha,beta: -0.00 ,4.78
# alpha,beta: 2.47 ,5.79
# alpha,beta: 1.41 ,5.64
# alpha,beta: 2.83 ,4.97
# alpha,beta: 2.09 ,5.55
# alpha,beta: 2.03 ,4.71
# alpha,beta: 4.60 ,10.02
# alpha,beta: -0.27 ,5.46
# alpha,beta: 2.87 ,5.89
# alpha,beta: 1.72 ,7.28
# alpha,beta: -2.49 ,13.46
# alpha,beta: 1.71 ,6.03
# alpha,beta: 0.73 ,5.73
# alpha,beta: 5.02 ,2.99
# alpha,beta: 3.26 ,10.25
# alpha,beta: 3.54 ,6.84
# alpha,beta: 3.05 ,5.59
# alpha,beta: 1.01 ,4.88
# alpha,beta: 0.08 ,7.59
# alpha,beta: 1.68 ,5.96
# alpha,beta: 1.55 ,5.54
# alpha,beta: 1.95 ,7.18
# alpha,beta: 2.43 ,5.30
# alpha,beta: 2.52 ,3.89
# alpha,beta: 2.31 ,4.11
# alpha,beta: 1.70 ,7.20
# alpha,beta: 3.01 ,7.06
# alpha,beta: 2.29 ,5.25
# alpha,beta: 1.56 ,5.45
# alpha,beta: -0.44 ,6.22
# alpha,beta: 3.57 ,5.03
# alpha,beta: 2.87 ,4.77
# alpha,beta: 1.51 ,5.44
# alpha,beta: 2.42 ,4.73
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# -> Mag Distribution
# --> Getting truth distributions
# end!
# Compute MaskFraction and Norm
# norm less than zero: -2.0675489804562157
# norm less than zero: -6.089873328619167
# norm less than zero: -1.5523717801869623
# norm less than zero: -1.8125147738515355
# norm less than zero: -0.652646934599373
# norm less than zero: -0.9720095022272648
# norm less than zero: -2.372966261793642
# norm less than zero: -1.1641841853503547
# norm less than zero: -3.96383770317906
# norm less than zero: -0.687198326696767
# norm less than zero: -11.240484530194806
# norm less than zero: -9.667187209729246
#
#  Compute Probabilities
# alpha,beta: 7.87 ,2.02
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/des18a/lib/python2.7/site-packages/scipy/interpolate/interpolate.py:595: RuntimeWarning: invalid value encountered in true_divide
#   slope = (y_hi - y_lo) / (x_hi - x_lo)[:, None]
# alpha,beta: 7.24 ,1.59
# alpha,beta: 5.56 ,3.06
# alpha,beta: 8.66 ,3.74
# alpha,beta: 7.24 ,3.69
# alpha,beta: 6.27 ,3.06
# alpha,beta: 4.56 ,2.94
# alpha,beta: 4.74 ,5.84
# alpha,beta: 9.89 ,2.01
# alpha,beta: 5.30 ,4.84
# alpha,beta: 5.13 ,3.71
# alpha,beta: 4.22 ,5.36
# alpha,beta: 10.73 ,4.92
# alpha,beta: 8.32 ,5.42
# alpha,beta: 5.68 ,4.18
# alpha,beta: 7.39 ,5.29
# alpha,beta: 8.29 ,5.03
# alpha,beta: 7.30 ,7.18
# alpha,beta: 6.73 ,6.50
# alpha,beta: 7.85 ,7.47
# alpha,beta: 5.24 ,5.71
# alpha,beta: 6.88 ,6.66
# alpha,beta: 6.09 ,7.25
# alpha,beta: 4.78 ,6.22
# alpha,beta: 6.41 ,5.64
# alpha,beta: 6.23 ,8.14
# alpha,beta: 6.21 ,5.86
# alpha,beta: 6.80 ,5.66
# alpha,beta: 6.58 ,4.98
# alpha,beta: 7.24 ,5.13
# alpha,beta: 7.10 ,6.43
# alpha,beta: 5.90 ,7.53
# alpha,beta: 4.62 ,6.22
# alpha,beta: 7.14 ,6.36
# alpha,beta: 7.13 ,5.48
# alpha,beta: 5.76 ,6.16
# alpha,beta: 6.47 ,6.61
# alpha,beta: 6.55 ,5.95
# alpha,beta: 5.43 ,5.82
# alpha,beta: 9.29 ,4.69
# alpha,beta: 9.64 ,9.14
# alpha,beta: 5.59 ,6.26
# alpha,beta: 4.13 ,7.08
# alpha,beta: 6.31 ,7.16
# alpha,beta: 7.04 ,6.02
# alpha,beta: 6.94 ,5.21
# alpha,beta: 5.91 ,7.29
# alpha,beta: 4.97 ,6.58
# alpha,beta: 5.24 ,3.89
# alpha,beta: 6.64 ,5.48
# alpha,beta: 3.22 ,9.10
# alpha,beta: 5.72 ,7.84
# alpha,beta: 6.70 ,7.17
# alpha,beta: 5.44 ,7.37
# alpha,beta: 3.90 ,7.88
# alpha,beta: 9.85 ,3.15
# alpha,beta: 5.40 ,7.88
# alpha,beta: 4.78 ,6.91
# alpha,beta: 12.03 ,4.25
# alpha,beta: 8.24 ,8.73
# alpha,beta: 9.61 ,9.25
# alpha,beta: 4.89 ,8.87
# alpha,beta: 5.67 ,6.59
# alpha,beta: 5.19 ,7.59
# alpha,beta: 6.89 ,6.28
# alpha,beta: 8.41 ,10.10
# alpha,beta: 1.92 ,10.18
# alpha,beta: 4.62 ,6.22
# alpha,beta: 10.27 ,10.68
# alpha,beta: 2.74 ,9.07
# alpha,beta: 8.31 ,7.42
# alpha,beta: 7.72 ,7.93
# alpha,beta: 9.12 ,10.21
# alpha,beta: 8.87 ,10.65
# alpha,beta: 5.19 ,6.29
# alpha,beta: 5.70 ,7.00
# alpha,beta: 6.41 ,6.94
# alpha,beta: 6.36 ,6.63
# alpha,beta: 5.55 ,6.76
# alpha,beta: 4.76 ,7.93
# alpha,beta: 3.17 ,6.96
# alpha,beta: 7.80 ,9.34
# alpha,beta: -0.85 ,10.16
# /home/s1/jesteves/git/ccopa/python/copac/assignProb.py:263: RuntimeWarning: invalid value encountered in multiply
#   prod = pdf1*pdf2
# alpha,beta: 5.39 ,7.88
# alpha,beta: 4.98 ,13.11
# alpha,beta: 8.72 ,12.49
# alpha,beta: 11.37 ,8.77
# alpha,beta: 2.54 ,8.68
# alpha,beta: 7.37 ,8.34
# alpha,beta: 5.37 ,6.97
# alpha,beta: 8.62 ,8.92
# alpha,beta: 9.91 ,9.50
# alpha,beta: 7.10 ,7.80
# alpha,beta: 5.46 ,11.72
# alpha,beta: 2.45 ,5.66
# alpha,beta: 8.78 ,6.94
# alpha,beta: 3.33 ,10.09
# alpha,beta: 6.86 ,5.59
# alpha,beta: 9.51 ,7.90
# alpha,beta: 3.23 ,8.52
# alpha,beta: 5.33 ,8.12
# alpha,beta: 3.40 ,11.26
# alpha,beta: 10.36 ,5.80
# alpha,beta: 3.38 ,10.87
# alpha,beta: 9.79 ,6.39
# alpha,beta: 4.71 ,6.54
# alpha,beta: 4.26 ,9.87
# alpha,beta: 4.03 ,8.67
# alpha,beta: 7.74 ,8.26
# alpha,beta: 8.12 ,14.07
# alpha,beta: 4.43 ,5.63
# alpha,beta: 5.80 ,12.20
# alpha,beta: 7.27 ,6.36
# alpha,beta: -4.66 ,13.55
# alpha,beta: 4.17 ,5.42
# alpha,beta: 4.63 ,3.93
# alpha,beta: 6.24 ,12.60
# alpha,beta: 3.81 ,6.37
# alpha,beta: 3.72 ,10.59
# alpha,beta: 5.29 ,9.54
# alpha,beta: 4.05 ,14.48
# alpha,beta: 4.54 ,13.42
# alpha,beta: 4.56 ,12.33
# alpha,beta: 2.57 ,14.86
# alpha,beta: 0.65 ,9.16
# alpha,beta: 2.55 ,11.58
# alpha,beta: 0.59 ,12.67
# alpha,beta: 2.79 ,7.15
# alpha,beta: 9.99 ,10.57
# alpha,beta: 1.35 ,11.98
# alpha,beta: 6.03 ,12.72
# alpha,beta: 0.43 ,8.38
# alpha,beta: 4.11 ,10.89
# alpha,beta: 3.45 ,9.99
# alpha,beta: 3.25 ,9.58
# alpha,beta: 6.09 ,5.85
# alpha,beta: 5.58 ,8.12
# alpha,beta: 2.63 ,9.72
# alpha,beta: 2.87 ,14.03
# alpha,beta: 7.87 ,10.20
# alpha,beta: 5.14 ,11.30
# alpha,beta: 1.93 ,7.36
# alpha,beta: 3.66 ,7.39
# alpha,beta: 4.84 ,6.71
# alpha,beta: 4.55 ,6.98
# alpha,beta: 4.68 ,10.84
# alpha,beta: 3.64 ,9.68
# alpha,beta: 3.60 ,12.54
# alpha,beta: 5.35 ,8.33
# alpha,beta: 0.29 ,8.10
# alpha,beta: 3.56 ,8.66
# alpha,beta: 4.91 ,9.21
# alpha,beta: 4.06 ,14.10
# alpha,beta: 0.25 ,10.56
# alpha,beta: 2.81 ,8.74
# alpha,beta: 1.59 ,8.25
# alpha,beta: 2.56 ,8.66
# alpha,beta: -0.60 ,13.18
# alpha,beta: 2.99 ,3.41
# alpha,beta: 1.75 ,9.70
# alpha,beta: 3.29 ,8.92
# alpha,beta: 6.55 ,8.06
# alpha,beta: 2.74 ,6.48
# alpha,beta: 8.93 ,10.43
# alpha,beta: 2.53 ,5.38
# alpha,beta: 4.47 ,2.72
# alpha,beta: 3.70 ,9.08
# alpha,beta: 1.66 ,7.64
# alpha,beta: 2.89 ,5.71
# alpha,beta: 3.29 ,8.14
# alpha,beta: 4.09 ,6.08
# alpha,beta: 0.73 ,11.16
# alpha,beta: 3.46 ,6.10
# alpha,beta: 4.16 ,6.96
# alpha,beta: 4.70 ,6.79
# alpha,beta: 4.04 ,12.20
# alpha,beta: 5.30 ,4.41
# alpha,beta: 4.61 ,6.29
# alpha,beta: 1.74 ,6.35
# alpha,beta: 2.91 ,8.36
# alpha,beta: 3.90 ,7.30
# alpha,beta: 2.88 ,7.59
# alpha,beta: 1.88 ,5.27
# alpha,beta: 2.51 ,8.26
# alpha,beta: 4.56 ,4.08
# alpha,beta: 1.95 ,7.65
# alpha,beta: 2.84 ,6.24
# alpha,beta: 2.42 ,6.90
# alpha,beta: 2.35 ,6.00
# alpha,beta: 1.01 ,6.14
# alpha,beta: 2.86 ,8.94
# alpha,beta: 2.03 ,6.35
# alpha,beta: 3.11 ,8.35
# alpha,beta: 3.96 ,9.37
# alpha,beta: 3.24 ,7.22
# alpha,beta: 0.68 ,7.43
# alpha,beta: 5.00 ,6.56
# alpha,beta: 5.08 ,9.79
# alpha,beta: 2.32 ,7.20
# alpha,beta: 2.50 ,4.99
# alpha,beta: 1.19 ,6.78
# alpha,beta: 3.46 ,7.45
# alpha,beta: 4.81 ,6.29
# alpha,beta: 1.86 ,6.34
# alpha,beta: 3.20 ,8.19
# alpha,beta: 0.94 ,6.09
# alpha,beta: 3.85 ,8.56
# alpha,beta: 2.45 ,5.16
# alpha,beta: 4.77 ,8.03
# alpha,beta: 1.38 ,5.12
# alpha,beta: 0.58 ,11.93
# alpha,beta: 4.52 ,7.72
# alpha,beta: 3.57 ,7.76
# alpha,beta: 2.28 ,7.05
# alpha,beta: 0.49 ,6.90
# alpha,beta: 2.35 ,5.17
# alpha,beta: 2.94 ,8.71
# alpha,beta: 3.54 ,5.69
# alpha,beta: 3.76 ,5.85
# alpha,beta: 2.65 ,4.89
# alpha,beta: 2.99 ,5.16
# alpha,beta: 5.16 ,11.95
# alpha,beta: 5.50 ,9.54
# alpha,beta: 2.33 ,12.70
# alpha,beta: 0.86 ,9.13
# alpha,beta: 1.55 ,6.55
# alpha,beta: 6.73 ,10.59
# alpha,beta: 1.69 ,7.35
# alpha,beta: 0.59 ,10.47
# alpha,beta: 0.19 ,8.66
# alpha,beta: 4.44 ,6.23
# alpha,beta: 2.26 ,7.94
# alpha,beta: 2.38 ,6.98
# alpha,beta: 2.26 ,4.85
# alpha,beta: 5.74 ,3.89
# alpha,beta: 2.72 ,5.23
# alpha,beta: 2.38 ,5.96
# alpha,beta: 2.83 ,5.10
# alpha,beta: 2.04 ,6.14
# alpha,beta: 0.96 ,3.73
# alpha,beta: 2.09 ,6.54
# alpha,beta: -0.33 ,4.93
# alpha,beta: 2.29 ,5.85
# alpha,beta: 0.94 ,4.26
# alpha,beta: 2.89 ,5.21
# alpha,beta: 2.95 ,5.58
# alpha,beta: 1.83 ,5.25
# alpha,beta: 1.35 ,5.62
# alpha,beta: 0.71 ,4.08
# alpha,beta: 5.27 ,7.74
# alpha,beta: 5.83 ,8.13
# alpha,beta: 2.03 ,6.95
# alpha,beta: -0.10 ,8.43
# alpha,beta: -0.54 ,6.88
# alpha,beta: -0.48 ,8.33
# alpha,beta: 2.84 ,4.27
# alpha,beta: 0.67 ,4.41
# alpha,beta: 0.59 ,5.16
# alpha,beta: -0.58 ,3.77
# alpha,beta: 1.99 ,5.29
# alpha,beta: 1.63 ,5.35
# alpha,beta: 2.07 ,4.65
# alpha,beta: 2.28 ,6.16
# alpha,beta: 2.98 ,5.09
# alpha,beta: 2.28 ,4.63
# alpha,beta: 2.88 ,5.22
# alpha,beta: 3.13 ,11.89
# alpha,beta: 1.99 ,8.12
# alpha,beta: -0.91 ,6.59
# alpha,beta: 3.41 ,5.78
# alpha,beta: -0.54 ,5.42
# alpha,beta: 0.28 ,4.21
# alpha,beta: 1.86 ,7.30
# alpha,beta: 4.47 ,4.64
# alpha,beta: 4.42 ,3.93
# alpha,beta: 0.50 ,4.64
# alpha,beta: 0.87 ,6.29
# alpha,beta: 4.56 ,5.57
# alpha,beta: 3.61 ,8.12
# alpha,beta: 2.39 ,6.35
# alpha,beta: -2.93 ,6.49
# alpha,beta: 2.85 ,9.72
# alpha,beta: 0.06 ,8.27
# alpha,beta: 0.80 ,6.20
# alpha,beta: 3.06 ,4.95
# alpha,beta: 4.05 ,7.53
# alpha,beta: 1.19 ,6.59
# alpha,beta: 3.56 ,5.01
# alpha,beta: -2.35 ,7.12
# alpha,beta: 2.21 ,4.52
# alpha,beta: 2.20 ,6.51
# alpha,beta: 2.98 ,4.72
# alpha,beta: 1.42 ,4.92
# alpha,beta: 2.54 ,6.34
# alpha,beta: 0.32 ,6.01
# alpha,beta: 4.45 ,4.15
# alpha,beta: 2.86 ,4.02
# alpha,beta: 1.72 ,3.86
# Writing Output: Catalogs
#
# Writing Galaxy Output
# Writing Cluster Output
#
# Writing cluster PDFs
#
# end!
# compute ptaken
# Total time: 159.989161968s
# ---------------

# %%
# import os

# os.remove(infile)

# %%
# os.rename(outfile,infile)

# %%
infile = '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00017.hdf5'

# %%
outfile= '/data/des61.a/data/johnny/Buzzard/Buzzard_v2.0.0/y3/output/tiles/buzzard_v2.0.0_copa_00017_new.hdf5'

# %%
def allkeys(obj):
    "Recursively find all keys in an h5py.Group."
    keys = (obj.name,)
    if isinstance(obj, h5py.Group):
        for key, value in obj.items():
            if isinstance(value, h5py.Group):
                keys = keys + allkeys(value)
            else:
                keys = keys + (value.name,)
    return keys

# %%
hf = h5py.File(infile,'r')
allkeys(hf)
# Out:
# (u'/',
#  u'/clusters',
#  u'/clusters/copa',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Area',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Area_bkg',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/CID',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/DA',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/DEC',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/M200_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/MASKFRAC',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/MU',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/MU_ERR_JK',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/MU_TRUE',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/MU_TRUE_ERR_JK',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Nbkg',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Nbkg_Counts',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Nbkg_Counts_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Nbkg_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Ngals',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Ngals_flat',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Ngals_old',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Ngals_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/Norm',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/R200',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/R200_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/RA',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/RAPER',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/magLim_i',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/redshift',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw/tile',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Area',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Area_bkg',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/CID',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/DA',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/DEC',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/M200_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/MASKFRAC',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/MU',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/MU_ERR_JK',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/MU_TRUE',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/MU_TRUE_ERR_JK',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Nbkg',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Nbkg_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Ngals',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Ngals_flat',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Ngals_old',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Ngals_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Norm',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/R200',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/R200_true',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/RA',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/RAPER',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/magLim_i',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/redshift',
#  u'/clusters/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/tile',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Area',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Area_bkg',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/CID',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/DA',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/DEC',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/M200_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/MASKFRAC',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/MU',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/MU_ERR_JK',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/MU_TRUE',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/MU_TRUE_ERR_JK',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Nbkg',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Nbkg_Counts',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Nbkg_Counts_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Nbkg_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Ngals',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Ngals_flat',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Ngals_old',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Ngals_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/Norm',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/R200',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/R200_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/RA',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/RAPER',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/magLim_i',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/redshift',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw/tile',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Area',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Area_bkg',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/CID',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/DA',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/DEC',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/M200_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/MASKFRAC',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/MU',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/MU_ERR_JK',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/MU_TRUE',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/MU_TRUE_ERR_JK',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Nbkg',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Nbkg_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Ngals',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Ngals_flat',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Ngals_old',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Ngals_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/Norm',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/R200',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/R200_true',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/RA',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/RAPER',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/magLim_i',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/redshift',
#  u'/clusters/copa/dnf_r200_02Lstar_nfw_nbkg_true/tile',
#  u'/clusters/copa/gauss001_r200_02Lstar',
#  u'/clusters/copa/gauss001_r200_02Lstar/Area',
#  u'/clusters/copa/gauss001_r200_02Lstar/Area_bkg',
#  u'/clusters/copa/gauss001_r200_02Lstar/CID',
#  u'/clusters/copa/gauss001_r200_02Lstar/DA',
#  u'/clusters/copa/gauss001_r200_02Lstar/DEC',
#  u'/clusters/copa/gauss001_r200_02Lstar/M200_true',
#  u'/clusters/copa/gauss001_r200_02Lstar/MASKFRAC',
#  u'/clusters/copa/gauss001_r200_02Lstar/MU',
#  u'/clusters/copa/gauss001_r200_02Lstar/MU_ERR_JK',
#  u'/clusters/copa/gauss001_r200_02Lstar/MU_TRUE',
#  u'/clusters/copa/gauss001_r200_02Lstar/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss001_r200_02Lstar/Nbkg',
#  u'/clusters/copa/gauss001_r200_02Lstar/Nbkg_Counts',
#  u'/clusters/copa/gauss001_r200_02Lstar/Nbkg_Counts_true',
#  u'/clusters/copa/gauss001_r200_02Lstar/Nbkg_true',
#  u'/clusters/copa/gauss001_r200_02Lstar/Ngals',
#  u'/clusters/copa/gauss001_r200_02Lstar/Ngals_flat',
#  u'/clusters/copa/gauss001_r200_02Lstar/Ngals_old',
#  u'/clusters/copa/gauss001_r200_02Lstar/Ngals_true',
#  u'/clusters/copa/gauss001_r200_02Lstar/Norm',
#  u'/clusters/copa/gauss001_r200_02Lstar/R200',
#  u'/clusters/copa/gauss001_r200_02Lstar/R200_true',
#  u'/clusters/copa/gauss001_r200_02Lstar/RA',
#  u'/clusters/copa/gauss001_r200_02Lstar/RAPER',
#  u'/clusters/copa/gauss001_r200_02Lstar/magLim_i',
#  u'/clusters/copa/gauss001_r200_02Lstar/redshift',
#  u'/clusters/copa/gauss001_r200_02Lstar/tile',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Area',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Area_bkg',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/CID',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/DA',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/DEC',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/M200_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/MASKFRAC',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/MU',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/MU_ERR_JK',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/MU_TRUE',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Nbkg',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Nbkg_Counts',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Nbkg_Counts_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Nbkg_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Ngals',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Ngals_flat',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Ngals_old',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Ngals_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/Norm',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/R200',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/R200_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/RA',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/RAPER',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/magLim_i',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/redshift',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw/tile',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Area',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Area_bkg',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/CID',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/DA',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/DEC',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/M200_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/MASKFRAC',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/MU',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/MU_ERR_JK',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/MU_TRUE',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Nbkg',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Nbkg_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Ngals',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Ngals_flat',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Ngals_old',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Ngals_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Norm',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/R200',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/R200_true',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/RA',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/RAPER',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/magLim_i',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/redshift',
#  u'/clusters/copa/gauss001_r200_02Lstar_nfw_nbkg_true/tile',
#  u'/clusters/copa/gauss001_rhod_02Lstar',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Area',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Area_bkg',
#  u'/clusters/copa/gauss001_rhod_02Lstar/CID',
#  u'/clusters/copa/gauss001_rhod_02Lstar/DA',
#  u'/clusters/copa/gauss001_rhod_02Lstar/DEC',
#  u'/clusters/copa/gauss001_rhod_02Lstar/M200_true',
#  u'/clusters/copa/gauss001_rhod_02Lstar/MASKFRAC',
#  u'/clusters/copa/gauss001_rhod_02Lstar/MU',
#  u'/clusters/copa/gauss001_rhod_02Lstar/MU_ERR_JK',
#  u'/clusters/copa/gauss001_rhod_02Lstar/MU_TRUE',
#  u'/clusters/copa/gauss001_rhod_02Lstar/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Nbkg',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Nbkg_Counts',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Nbkg_Counts_true',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Nbkg_true',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Ngals',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Ngals_flat',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Ngals_old',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Ngals_true',
#  u'/clusters/copa/gauss001_rhod_02Lstar/Norm',
#  u'/clusters/copa/gauss001_rhod_02Lstar/R200',
#  u'/clusters/copa/gauss001_rhod_02Lstar/R200_true',
#  u'/clusters/copa/gauss001_rhod_02Lstar/RA',
#  u'/clusters/copa/gauss001_rhod_02Lstar/RAPER',
#  u'/clusters/copa/gauss001_rhod_02Lstar/magLim_i',
#  u'/clusters/copa/gauss001_rhod_02Lstar/redshift',
#  u'/clusters/copa/gauss001_rhod_02Lstar/tile',
#  u'/clusters/copa/gauss003_r200_02Lstar',
#  u'/clusters/copa/gauss003_r200_02Lstar/Area',
#  u'/clusters/copa/gauss003_r200_02Lstar/Area_bkg',
#  u'/clusters/copa/gauss003_r200_02Lstar/CID',
#  u'/clusters/copa/gauss003_r200_02Lstar/DA',
#  u'/clusters/copa/gauss003_r200_02Lstar/DEC',
#  u'/clusters/copa/gauss003_r200_02Lstar/M200_true',
#  u'/clusters/copa/gauss003_r200_02Lstar/MASKFRAC',
#  u'/clusters/copa/gauss003_r200_02Lstar/MU',
#  u'/clusters/copa/gauss003_r200_02Lstar/MU_ERR_JK',
#  u'/clusters/copa/gauss003_r200_02Lstar/MU_TRUE',
#  u'/clusters/copa/gauss003_r200_02Lstar/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss003_r200_02Lstar/Nbkg',
#  u'/clusters/copa/gauss003_r200_02Lstar/Nbkg_Counts',
#  u'/clusters/copa/gauss003_r200_02Lstar/Nbkg_Counts_true',
#  u'/clusters/copa/gauss003_r200_02Lstar/Nbkg_true',
#  u'/clusters/copa/gauss003_r200_02Lstar/Ngals',
#  u'/clusters/copa/gauss003_r200_02Lstar/Ngals_flat',
#  u'/clusters/copa/gauss003_r200_02Lstar/Ngals_old',
#  u'/clusters/copa/gauss003_r200_02Lstar/Ngals_true',
#  u'/clusters/copa/gauss003_r200_02Lstar/Norm',
#  u'/clusters/copa/gauss003_r200_02Lstar/R200',
#  u'/clusters/copa/gauss003_r200_02Lstar/R200_true',
#  u'/clusters/copa/gauss003_r200_02Lstar/RA',
#  u'/clusters/copa/gauss003_r200_02Lstar/RAPER',
#  u'/clusters/copa/gauss003_r200_02Lstar/magLim_i',
#  u'/clusters/copa/gauss003_r200_02Lstar/redshift',
#  u'/clusters/copa/gauss003_r200_02Lstar/tile',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Area',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Area_bkg',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/CID',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/DA',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/DEC',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/M200_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/MASKFRAC',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/MU',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/MU_ERR_JK',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/MU_TRUE',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Nbkg',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Nbkg_Counts',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Nbkg_Counts_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Nbkg_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Ngals',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Ngals_flat',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Ngals_old',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Ngals_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/Norm',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/R200',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/R200_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/RA',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/RAPER',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/magLim_i',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/redshift',
#  u'/clusters/copa/gauss003_r200_02Lstar_dk14_nbkg_true/tile',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Area',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Area_bkg',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/CID',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/DA',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/DEC',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/M200_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/MASKFRAC',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/MU',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/MU_ERR_JK',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/MU_TRUE',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Nbkg',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Nbkg_Counts',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Nbkg_Counts_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Nbkg_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Ngals',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Ngals_flat',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Ngals_old',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Ngals_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/Norm',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/R200',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/R200_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/RA',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/RAPER',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/magLim_i',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/redshift',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw/tile',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Area',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Area_bkg',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/CID',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/DA',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/DEC',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/M200_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/MASKFRAC',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/MU',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/MU_ERR_JK',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/MU_TRUE',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Nbkg',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Nbkg_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Ngals',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Ngals_flat',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Ngals_old',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Ngals_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/Norm',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/R200',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/R200_true',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/RA',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/RAPER',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/magLim_i',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/redshift',
#  u'/clusters/copa/gauss003_r200_02Lstar_nfw_nbkg_true/tile',
#  u'/clusters/copa/gauss003_rhod_02Lstar',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Area',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Area_bkg',
#  u'/clusters/copa/gauss003_rhod_02Lstar/CID',
#  u'/clusters/copa/gauss003_rhod_02Lstar/DA',
#  u'/clusters/copa/gauss003_rhod_02Lstar/DEC',
#  u'/clusters/copa/gauss003_rhod_02Lstar/M200_true',
#  u'/clusters/copa/gauss003_rhod_02Lstar/MASKFRAC',
#  u'/clusters/copa/gauss003_rhod_02Lstar/MU',
#  u'/clusters/copa/gauss003_rhod_02Lstar/MU_ERR_JK',
#  u'/clusters/copa/gauss003_rhod_02Lstar/MU_TRUE',
#  u'/clusters/copa/gauss003_rhod_02Lstar/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Nbkg',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Nbkg_Counts',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Nbkg_Counts_true',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Nbkg_true',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Ngals',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Ngals_flat',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Ngals_old',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Ngals_true',
#  u'/clusters/copa/gauss003_rhod_02Lstar/Norm',
#  u'/clusters/copa/gauss003_rhod_02Lstar/R200',
#  u'/clusters/copa/gauss003_rhod_02Lstar/R200_true',
#  u'/clusters/copa/gauss003_rhod_02Lstar/RA',
#  u'/clusters/copa/gauss003_rhod_02Lstar/RAPER',
#  u'/clusters/copa/gauss003_rhod_02Lstar/magLim_i',
#  u'/clusters/copa/gauss003_rhod_02Lstar/redshift',
#  u'/clusters/copa/gauss003_rhod_02Lstar/tile',
#  u'/clusters/copa/gauss005_r200_02Lstar',
#  u'/clusters/copa/gauss005_r200_02Lstar/Area',
#  u'/clusters/copa/gauss005_r200_02Lstar/Area_bkg',
#  u'/clusters/copa/gauss005_r200_02Lstar/CID',
#  u'/clusters/copa/gauss005_r200_02Lstar/DA',
#  u'/clusters/copa/gauss005_r200_02Lstar/DEC',
#  u'/clusters/copa/gauss005_r200_02Lstar/M200_true',
#  u'/clusters/copa/gauss005_r200_02Lstar/MASKFRAC',
#  u'/clusters/copa/gauss005_r200_02Lstar/MU',
#  u'/clusters/copa/gauss005_r200_02Lstar/MU_ERR_JK',
#  u'/clusters/copa/gauss005_r200_02Lstar/MU_TRUE',
#  u'/clusters/copa/gauss005_r200_02Lstar/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss005_r200_02Lstar/Nbkg',
#  u'/clusters/copa/gauss005_r200_02Lstar/Nbkg_Counts',
#  u'/clusters/copa/gauss005_r200_02Lstar/Nbkg_Counts_true',
#  u'/clusters/copa/gauss005_r200_02Lstar/Nbkg_true',
#  u'/clusters/copa/gauss005_r200_02Lstar/Ngals',
#  u'/clusters/copa/gauss005_r200_02Lstar/Ngals_flat',
#  u'/clusters/copa/gauss005_r200_02Lstar/Ngals_old',
#  u'/clusters/copa/gauss005_r200_02Lstar/Ngals_true',
#  u'/clusters/copa/gauss005_r200_02Lstar/Norm',
#  u'/clusters/copa/gauss005_r200_02Lstar/R200',
#  u'/clusters/copa/gauss005_r200_02Lstar/R200_true',
#  u'/clusters/copa/gauss005_r200_02Lstar/RA',
#  u'/clusters/copa/gauss005_r200_02Lstar/RAPER',
#  u'/clusters/copa/gauss005_r200_02Lstar/magLim_i',
#  u'/clusters/copa/gauss005_r200_02Lstar/redshift',
#  u'/clusters/copa/gauss005_r200_02Lstar/tile',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Area',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Area_bkg',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/CID',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/DA',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/DEC',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/M200_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/MASKFRAC',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/MU',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/MU_ERR_JK',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/MU_TRUE',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Nbkg',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Nbkg_Counts',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Nbkg_Counts_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Nbkg_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Ngals',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Ngals_flat',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Ngals_old',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Ngals_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/Norm',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/R200',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/R200_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/RA',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/RAPER',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/magLim_i',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/redshift',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw/tile',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Area',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Area_bkg',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/CID',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/DA',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/DEC',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/M200_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/MASKFRAC',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/MU',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/MU_ERR_JK',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/MU_TRUE',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Nbkg',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Nbkg_Counts_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Nbkg_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Ngals',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Ngals_flat',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Ngals_old',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Ngals_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/Norm',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/R200',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/R200_true',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/RA',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/RAPER',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/magLim_i',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/redshift',
#  u'/clusters/copa/gauss005_r200_02Lstar_nfw_nbkg_true/tile',
#  u'/clusters/copa/gauss005_rhod_02Lstar',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Area',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Area_bkg',
#  u'/clusters/copa/gauss005_rhod_02Lstar/CID',
#  u'/clusters/copa/gauss005_rhod_02Lstar/DA',
#  u'/clusters/copa/gauss005_rhod_02Lstar/DEC',
#  u'/clusters/copa/gauss005_rhod_02Lstar/M200_true',
#  u'/clusters/copa/gauss005_rhod_02Lstar/MASKFRAC',
#  u'/clusters/copa/gauss005_rhod_02Lstar/MU',
#  u'/clusters/copa/gauss005_rhod_02Lstar/MU_ERR_JK',
#  u'/clusters/copa/gauss005_rhod_02Lstar/MU_TRUE',
#  u'/clusters/copa/gauss005_rhod_02Lstar/MU_TRUE_ERR_JK',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Nbkg',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Nbkg_Counts',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Nbkg_Counts_true',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Nbkg_true',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Ngals',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Ngals_flat',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Ngals_old',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Ngals_true',
#  u'/clusters/copa/gauss005_rhod_02Lstar/Norm',
#  u'/clusters/copa/gauss005_rhod_02Lstar/R200',
#  u'/clusters/copa/gauss005_rhod_02Lstar/R200_true',
#  u'/clusters/copa/gauss005_rhod_02Lstar/RA',
#  u'/clusters/copa/gauss005_rhod_02Lstar/RAPER',
#  u'/clusters/copa/gauss005_rhod_02Lstar/magLim_i',
#  u'/clusters/copa/gauss005_rhod_02Lstar/redshift',
#  u'/clusters/copa/gauss005_rhod_02Lstar/tile',
#  u'/clusters/main',
#  u'/clusters/main/CID',
#  u'/clusters/main/DA',
#  u'/clusters/main/DEC',
#  u'/clusters/main/M200_true',
#  u'/clusters/main/R200_true',
#  u'/clusters/main/RA',
#  u'/clusters/main/magLim',
#  u'/clusters/main/redshift',
#  u'/members',
#  u'/members/bma',
#  u'/members/bma/CID',
#  u'/members/bma/best_chisq',
#  u'/members/bma/best_model',
#  u'/members/bma/best_zmet',
#  u'/members/bma/distmod',
#  u'/members/bma/gi_o',
#  u'/members/bma/gi_o_err',
#  u'/members/bma/gr_o',
#  u'/members/bma/gr_o_err',
#  u'/members/bma/iabs',
#  u'/members/bma/index',
#  u'/members/bma/iobs',
#  u'/members/bma/kii',
#  u'/members/bma/kii_err',
#  u'/members/bma/kri',
#  u'/members/bma/kri_err',
#  u'/members/bma/mass',
#  u'/members/bma/mass_err',
#  u'/members/bma/mass_weight_age',
#  u'/members/bma/mass_weight_age_err',
#  u'/members/bma/mcMass',
#  u'/members/bma/mid',
#  u'/members/bma/mid_cut',
#  u'/members/bma/rabs',
#  u'/members/bma/ssfr',
#  u'/members/bma/ssfr_std',
#  u'/members/bma/taMass',
#  u'/members/bma/zmet',
#  u'/members/copa',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/CID',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/DEC',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/GID',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Gal',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/HALOID',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Mr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pc',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pc_flat',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pc_old',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pmem',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pmem_flat',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pmem_old',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pr_flat',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pr_old',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Ptaken',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pz',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pz_flat',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Pz_old',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/R',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/R200',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/RA',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/Rn',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/True',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/color',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/dmag',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/dx',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/dy',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/mag',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/magerr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/mid',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/norm',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdf',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdf_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdfc',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdfc_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdfm',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdfm_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdfr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdfr_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdfz',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pdfz_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/pz0',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/r_aper',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/redshift',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/theta',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/tile',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/z',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/z_true',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/zerr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/zmask',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/zoffset',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw/zwindow',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/CID',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/DEC',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/GID',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Gal',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/HALOID',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Mr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pc',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pc_flat',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pc_old',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pmem',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pmem_flat',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pmem_old',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pr_flat',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pr_old',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Ptaken',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pz',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pz_flat',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Pz_old',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/R',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/R200',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/RA',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/Rn',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/True',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/color',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/dmag',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/dx',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/dy',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/mag',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/magerr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/mid',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/norm',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdf',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdf_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdfc',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdfc_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdfm',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdfm_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdfr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdfr_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdfz',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pdfz_bkg',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/pz0',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/r_aper',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/redshift',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/theta',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/tile',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/z',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/z_true',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/zerr',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/zmask',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/zoffset',
#  u'/members/copa/dnf_model_r200_02Lstar_nfw_nbkg_true/zwindow',
#  u'/members/copa/dnf_r200_02Lstar_nfw',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw/CID',
#  u'/members/copa/dnf_r200_02Lstar_nfw/DEC',
#  u'/members/copa/dnf_r200_02Lstar_nfw/GID',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Gal',
#  u'/members/copa/dnf_r200_02Lstar_nfw/HALOID',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Mr',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pc',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pc_flat',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pc_old',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pmem',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pmem_flat',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pmem_old',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pr',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pr_flat',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pr_old',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Ptaken',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pz',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pz_flat',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Pz_old',
#  u'/members/copa/dnf_r200_02Lstar_nfw/R',
#  u'/members/copa/dnf_r200_02Lstar_nfw/R200',
#  u'/members/copa/dnf_r200_02Lstar_nfw/RA',
#  u'/members/copa/dnf_r200_02Lstar_nfw/Rn',
#  u'/members/copa/dnf_r200_02Lstar_nfw/True',
#  u'/members/copa/dnf_r200_02Lstar_nfw/color',
#  u'/members/copa/dnf_r200_02Lstar_nfw/dmag',
#  u'/members/copa/dnf_r200_02Lstar_nfw/dx',
#  u'/members/copa/dnf_r200_02Lstar_nfw/dy',
#  u'/members/copa/dnf_r200_02Lstar_nfw/mag',
#  u'/members/copa/dnf_r200_02Lstar_nfw/magerr',
#  u'/members/copa/dnf_r200_02Lstar_nfw/mid',
#  u'/members/copa/dnf_r200_02Lstar_nfw/norm',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdf',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdf_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdfc',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdfc_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdfm',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdfm_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdfr',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdfr_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdfz',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pdfz_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw/pz0',
#  u'/members/copa/dnf_r200_02Lstar_nfw/r_aper',
#  u'/members/copa/dnf_r200_02Lstar_nfw/redshift',
#  u'/members/copa/dnf_r200_02Lstar_nfw/theta',
#  u'/members/copa/dnf_r200_02Lstar_nfw/tile',
#  u'/members/copa/dnf_r200_02Lstar_nfw/z',
#  u'/members/copa/dnf_r200_02Lstar_nfw/z_true',
#  u'/members/copa/dnf_r200_02Lstar_nfw/zerr',
#  u'/members/copa/dnf_r200_02Lstar_nfw/zmask',
#  u'/members/copa/dnf_r200_02Lstar_nfw/zoffset',
#  u'/members/copa/dnf_r200_02Lstar_nfw/zwindow',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/CID',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/DEC',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/GID',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Gal',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/HALOID',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Mr',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pc',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pc_flat',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pc_old',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pmem',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pmem_flat',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pmem_old',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pr',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pr_flat',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pr_old',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Ptaken',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pz',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pz_flat',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Pz_old',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/R',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/R200',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/RA',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/Rn',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/True',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/color',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/dmag',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/dx',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/dy',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/mag',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/magerr',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/mid',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/norm',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdf',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdf_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdfc',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdfc_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdfm',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdfm_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdfr',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdfr_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdfz',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pdfz_bkg',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/pz0',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/r_aper',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/redshift',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/theta',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/tile',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/z',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/z_true',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/zerr',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/zmask',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/zoffset',
#  u'/members/copa/dnf_r200_02Lstar_nfw_nbkg_true/zwindow',
#  u'/members/copa/gauss001_r200_02Lstar',
#  u'/members/copa/gauss001_r200_02Lstar/Bkg',
#  u'/members/copa/gauss001_r200_02Lstar/CID',
#  u'/members/copa/gauss001_r200_02Lstar/DEC',
#  u'/members/copa/gauss001_r200_02Lstar/GID',
#  u'/members/copa/gauss001_r200_02Lstar/Gal',
#  u'/members/copa/gauss001_r200_02Lstar/HALOID',
#  u'/members/copa/gauss001_r200_02Lstar/Mr',
#  u'/members/copa/gauss001_r200_02Lstar/Pc',
#  u'/members/copa/gauss001_r200_02Lstar/Pc_flat',
#  u'/members/copa/gauss001_r200_02Lstar/Pc_old',
#  u'/members/copa/gauss001_r200_02Lstar/Pmem',
#  u'/members/copa/gauss001_r200_02Lstar/Pmem_flat',
#  u'/members/copa/gauss001_r200_02Lstar/Pmem_old',
#  u'/members/copa/gauss001_r200_02Lstar/Pr',
#  u'/members/copa/gauss001_r200_02Lstar/Pr_flat',
#  u'/members/copa/gauss001_r200_02Lstar/Pr_old',
#  u'/members/copa/gauss001_r200_02Lstar/Ptaken',
#  u'/members/copa/gauss001_r200_02Lstar/Pz',
#  u'/members/copa/gauss001_r200_02Lstar/Pz_flat',
#  u'/members/copa/gauss001_r200_02Lstar/Pz_old',
#  u'/members/copa/gauss001_r200_02Lstar/R',
#  u'/members/copa/gauss001_r200_02Lstar/R200',
#  u'/members/copa/gauss001_r200_02Lstar/RA',
#  u'/members/copa/gauss001_r200_02Lstar/Rn',
#  u'/members/copa/gauss001_r200_02Lstar/True',
#  u'/members/copa/gauss001_r200_02Lstar/color',
#  u'/members/copa/gauss001_r200_02Lstar/dmag',
#  u'/members/copa/gauss001_r200_02Lstar/dx',
#  u'/members/copa/gauss001_r200_02Lstar/dy',
#  u'/members/copa/gauss001_r200_02Lstar/mag',
#  u'/members/copa/gauss001_r200_02Lstar/magerr',
#  u'/members/copa/gauss001_r200_02Lstar/mid',
#  u'/members/copa/gauss001_r200_02Lstar/norm',
#  u'/members/copa/gauss001_r200_02Lstar/pdf',
#  u'/members/copa/gauss001_r200_02Lstar/pdf_bkg',
#  u'/members/copa/gauss001_r200_02Lstar/pdfc',
#  u'/members/copa/gauss001_r200_02Lstar/pdfc_bkg',
#  u'/members/copa/gauss001_r200_02Lstar/pdfm',
#  u'/members/copa/gauss001_r200_02Lstar/pdfm_bkg',
#  u'/members/copa/gauss001_r200_02Lstar/pdfr',
#  u'/members/copa/gauss001_r200_02Lstar/pdfr_bkg',
#  u'/members/copa/gauss001_r200_02Lstar/pdfz',
#  u'/members/copa/gauss001_r200_02Lstar/pdfz_bkg',
#  u'/members/copa/gauss001_r200_02Lstar/pz0',
#  u'/members/copa/gauss001_r200_02Lstar/r_aper',
#  u'/members/copa/gauss001_r200_02Lstar/redshift',
#  u'/members/copa/gauss001_r200_02Lstar/theta',
#  u'/members/copa/gauss001_r200_02Lstar/tile',
#  u'/members/copa/gauss001_r200_02Lstar/z',
#  u'/members/copa/gauss001_r200_02Lstar/z_true',
#  u'/members/copa/gauss001_r200_02Lstar/zerr',
#  u'/members/copa/gauss001_r200_02Lstar/zmask',
#  u'/members/copa/gauss001_r200_02Lstar/zoffset',
#  u'/members/copa/gauss001_r200_02Lstar/zwindow',
#  u'/members/copa/gauss001_r200_02Lstar_nfw',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/CID',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/DEC',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/GID',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Gal',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/HALOID',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Mr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pc',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pc_flat',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pc_old',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pmem',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pmem_flat',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pmem_old',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pr_flat',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pr_old',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Ptaken',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pz',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pz_flat',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Pz_old',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/R',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/R200',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/RA',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/Rn',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/True',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/color',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/dmag',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/dx',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/dy',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/mag',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/magerr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/mid',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/norm',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdf',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdf_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdfc',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdfc_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdfm',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdfm_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdfr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdfr_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdfz',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pdfz_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/pz0',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/r_aper',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/redshift',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/theta',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/tile',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/z',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/z_true',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/zerr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/zmask',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/zoffset',
#  u'/members/copa/gauss001_r200_02Lstar_nfw/zwindow',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/CID',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/DEC',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/GID',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Gal',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/HALOID',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Mr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pc',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pc_flat',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pc_old',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pmem',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pmem_flat',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pmem_old',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pr_flat',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pr_old',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Ptaken',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pz',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pz_flat',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Pz_old',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/R',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/R200',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/RA',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/Rn',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/True',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/color',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/dmag',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/dx',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/dy',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/mag',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/magerr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/mid',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/norm',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdf',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdf_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdfc',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdfc_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdfm',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdfm_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdfr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdfr_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdfz',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pdfz_bkg',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/pz0',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/r_aper',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/redshift',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/theta',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/tile',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/z',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/z_true',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/zerr',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/zmask',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/zoffset',
#  u'/members/copa/gauss001_r200_02Lstar_nfw_nbkg_true/zwindow',
#  u'/members/copa/gauss001_rhod_02Lstar',
#  u'/members/copa/gauss001_rhod_02Lstar/Bkg',
#  u'/members/copa/gauss001_rhod_02Lstar/CID',
#  u'/members/copa/gauss001_rhod_02Lstar/DEC',
#  u'/members/copa/gauss001_rhod_02Lstar/GID',
#  u'/members/copa/gauss001_rhod_02Lstar/Gal',
#  u'/members/copa/gauss001_rhod_02Lstar/HALOID',
#  u'/members/copa/gauss001_rhod_02Lstar/Mr',
#  u'/members/copa/gauss001_rhod_02Lstar/Pc',
#  u'/members/copa/gauss001_rhod_02Lstar/Pc_flat',
#  u'/members/copa/gauss001_rhod_02Lstar/Pc_old',
#  u'/members/copa/gauss001_rhod_02Lstar/Pmem',
#  u'/members/copa/gauss001_rhod_02Lstar/Pmem_flat',
#  u'/members/copa/gauss001_rhod_02Lstar/Pmem_old',
#  u'/members/copa/gauss001_rhod_02Lstar/Pr',
#  u'/members/copa/gauss001_rhod_02Lstar/Pr_flat',
#  u'/members/copa/gauss001_rhod_02Lstar/Pr_old',
#  u'/members/copa/gauss001_rhod_02Lstar/Ptaken',
#  u'/members/copa/gauss001_rhod_02Lstar/Pz',
#  u'/members/copa/gauss001_rhod_02Lstar/Pz_flat',
#  u'/members/copa/gauss001_rhod_02Lstar/Pz_old',
#  u'/members/copa/gauss001_rhod_02Lstar/R',
#  u'/members/copa/gauss001_rhod_02Lstar/R200',
#  u'/members/copa/gauss001_rhod_02Lstar/RA',
#  u'/members/copa/gauss001_rhod_02Lstar/Rn',
#  u'/members/copa/gauss001_rhod_02Lstar/True',
#  u'/members/copa/gauss001_rhod_02Lstar/color',
#  u'/members/copa/gauss001_rhod_02Lstar/dmag',
#  u'/members/copa/gauss001_rhod_02Lstar/dx',
#  u'/members/copa/gauss001_rhod_02Lstar/dy',
#  u'/members/copa/gauss001_rhod_02Lstar/mag',
#  u'/members/copa/gauss001_rhod_02Lstar/magerr',
#  u'/members/copa/gauss001_rhod_02Lstar/mid',
#  u'/members/copa/gauss001_rhod_02Lstar/norm',
#  u'/members/copa/gauss001_rhod_02Lstar/pdf',
#  u'/members/copa/gauss001_rhod_02Lstar/pdf_bkg',
#  u'/members/copa/gauss001_rhod_02Lstar/pdfc',
#  u'/members/copa/gauss001_rhod_02Lstar/pdfc_bkg',
#  u'/members/copa/gauss001_rhod_02Lstar/pdfm',
#  u'/members/copa/gauss001_rhod_02Lstar/pdfm_bkg',
#  u'/members/copa/gauss001_rhod_02Lstar/pdfr',
#  u'/members/copa/gauss001_rhod_02Lstar/pdfr_bkg',
#  u'/members/copa/gauss001_rhod_02Lstar/pdfz',
#  u'/members/copa/gauss001_rhod_02Lstar/pdfz_bkg',
#  u'/members/copa/gauss001_rhod_02Lstar/pz0',
#  u'/members/copa/gauss001_rhod_02Lstar/r_aper',
#  u'/members/copa/gauss001_rhod_02Lstar/redshift',
#  u'/members/copa/gauss001_rhod_02Lstar/theta',
#  u'/members/copa/gauss001_rhod_02Lstar/tile',
#  u'/members/copa/gauss001_rhod_02Lstar/z',
#  u'/members/copa/gauss001_rhod_02Lstar/z_true',
#  u'/members/copa/gauss001_rhod_02Lstar/zerr',
#  u'/members/copa/gauss001_rhod_02Lstar/zmask',
#  u'/members/copa/gauss001_rhod_02Lstar/zoffset',
#  u'/members/copa/gauss001_rhod_02Lstar/zwindow',
#  u'/members/copa/gauss003_r200_02Lstar',
#  u'/members/copa/gauss003_r200_02Lstar/Bkg',
#  u'/members/copa/gauss003_r200_02Lstar/CID',
#  u'/members/copa/gauss003_r200_02Lstar/DEC',
#  u'/members/copa/gauss003_r200_02Lstar/GID',
#  u'/members/copa/gauss003_r200_02Lstar/Gal',
#  u'/members/copa/gauss003_r200_02Lstar/HALOID',
#  u'/members/copa/gauss003_r200_02Lstar/Mr',
#  u'/members/copa/gauss003_r200_02Lstar/Pc',
#  u'/members/copa/gauss003_r200_02Lstar/Pc_flat',
#  u'/members/copa/gauss003_r200_02Lstar/Pc_old',
#  u'/members/copa/gauss003_r200_02Lstar/Pmem',
#  u'/members/copa/gauss003_r200_02Lstar/Pmem_flat',
#  u'/members/copa/gauss003_r200_02Lstar/Pmem_old',
#  u'/members/copa/gauss003_r200_02Lstar/Pr',
#  u'/members/copa/gauss003_r200_02Lstar/Pr_flat',
#  u'/members/copa/gauss003_r200_02Lstar/Pr_old',
#  u'/members/copa/gauss003_r200_02Lstar/Ptaken',
#  u'/members/copa/gauss003_r200_02Lstar/Pz',
#  u'/members/copa/gauss003_r200_02Lstar/Pz_flat',
#  u'/members/copa/gauss003_r200_02Lstar/Pz_old',
#  u'/members/copa/gauss003_r200_02Lstar/R',
#  u'/members/copa/gauss003_r200_02Lstar/R200',
#  u'/members/copa/gauss003_r200_02Lstar/RA',
#  u'/members/copa/gauss003_r200_02Lstar/Rn',
#  u'/members/copa/gauss003_r200_02Lstar/True',
#  u'/members/copa/gauss003_r200_02Lstar/color',
#  u'/members/copa/gauss003_r200_02Lstar/dmag',
#  u'/members/copa/gauss003_r200_02Lstar/dx',
#  u'/members/copa/gauss003_r200_02Lstar/dy',
#  u'/members/copa/gauss003_r200_02Lstar/mag',
#  u'/members/copa/gauss003_r200_02Lstar/magerr',
#  u'/members/copa/gauss003_r200_02Lstar/mid',
#  u'/members/copa/gauss003_r200_02Lstar/norm',
#  u'/members/copa/gauss003_r200_02Lstar/pdf',
#  u'/members/copa/gauss003_r200_02Lstar/pdf_bkg',
#  u'/members/copa/gauss003_r200_02Lstar/pdfc',
#  u'/members/copa/gauss003_r200_02Lstar/pdfc_bkg',
#  u'/members/copa/gauss003_r200_02Lstar/pdfm',
#  u'/members/copa/gauss003_r200_02Lstar/pdfm_bkg',
#  u'/members/copa/gauss003_r200_02Lstar/pdfr',
#  ...)

# %%
hf.close()

# %%
df = h5py.File(infile,'r')
df.visit(all_h5_objs.append)
all_groups   = [ obj for obj in all_h5_objs if isinstance(df[obj],h5py.Group) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-be57362dca18> in <module>()
#       1 df = h5py.File(infile,'r')
# ----> 2 df.visit(all_h5_objs.append)
#       3 all_groups   = [ obj for obj in all_h5_objs if isinstance(df[obj],h5py.Group) ]
#
# NameError: name 'all_h5_objs' is not defined

# %%
def check_group(fname,path):
    hf = h5py.File(fname,'r')

    all_items = list(allkeys(hf))
    hf.close()
    return path in all_items

# %%
check_group(infile,'/clusters')
# Out:
# True

# %%
hf = h5py.File(infile,'r')

all_items = [allkeys(hf)]
hf.close()

# %%
u'/clusters' in list(all_items[0])
# Out:
# True

# %%
def store_structure(name,node):
    if isinstance(node, h5py.Group):
        groups.append(node.name)
    
    if isinstance(node, h5py.Dataset):
        datasets.append(node.name)
        
    return None

# %%
def copy_h5_file(infile,outfile):
    hf = h5py.File(infile,'r')
    hf2 = h5py.File(outfile,'w')

    groups = []
    datasets = []
    hf.visititems(store_structure)
    
    for g in groups:
        hf2.create_group(g)

    for d in datasets:
        hf2.create_dataset(d,data=hf[d])

    hf.close()
    hf2.close()

    os.rename(outfile,infile)
