# %% [markdown]
# ## Get Halos
#
# Check the golden and silver sample
#
# This code creates a golden and a silver cluster selection of Buzzard Clusters
#
# Apr 24th 2021

# %%
import numpy as np
from astropy.table import Table, vstack
import fitsio
import healpy as hp

from astropy.io.fits import getdata
from astropy.io import fits as pyfits

from astropy.cosmology import FlatLambdaCDM
from astropy import units as u
import esutil

import dask
from joblib import Parallel, delayed

import os
from time import sleep
from time import time
import glob
import matplotlib 
import matplotlib.pyplot as plt

# %%
root   = '/global/project/projectdirs/des/jesteves/buzzardSelection/v2.0.0/'
infile = root+'buzzard_v2.0.0_halos_hod.fits'

cat = Table(getdata(infile))

# %%
cat
# Out:
# <Table length=36456>
#  HALOID          RA                DEC         ...  bad  hpx8_radec
#  int64        float64            float64       ...  bool   int64
# -------- ------------------ ------------------ ... ----- ----------
#       65  176.2527591565059  4.059806104511715 ... False        432
#      855 177.46176505602398  2.559815540078757 ... False        432
#    37542   176.109278798764  9.275820056186591 ... False        434
#    47899  176.3793939308375  5.265792379738031 ... False        432
#    48243  172.9685156710036  6.491493073793363 ... False        434
#    76242 170.97229136828201 20.231445962053737 ... False        441
#    76312 179.38533899527621 18.894736810436548 ... False        435
#    76312 179.38533899527621 18.894736810436548 ...  True        435
#    95755  177.8178181767138  9.127989931872374 ... False        434
#    96574 177.60470056304592   8.88364597999642 ... False        434
#      ...                ...                ... ...   ...        ...
# 40591433   18.8367867879294 14.472410978156606 ... False        287
# 40592192 18.232462117027808 13.962919696628113 ... False        287
# 40593618  22.57778881631025 14.341212938992355 ... False        287
# 40602633  20.97269227383482 15.269522606498544 ... False        287
# 40602653 19.154079590330316 13.392762399691312 ... False        287
# 40634276 20.652021342326805 17.712211119498154 ... False        287
# 40646399 18.820496070898457 20.993902401005545 ... False        309
# 41100905 28.226830082495663   5.93917063399368 ... False        285
# 41144859  27.73721190452072  8.967923804046025 ... False        285
# 41151583 26.454114383527187  8.871983036974125 ... False        285

# %%
sns.set_style('whitegrid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7c1890868f3b> in <module>
# ----> 1 sns.set_style('whitegrid')
#
# NameError: name 'sns' is not defined

# %%
w = np.logical_not(cat['bad'])
plt.plot([5e12,3e15],[5e12,3e15],'k--')
plt.scatter(cat['M200_old'],cat['M200B'],alpha=0.2)
plt.scatter(cat['M200_old'][w],cat['M200B'][w],alpha=0.2,label='My Selection')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('M200m [centrals]',fontsize=16)
plt.ylabel('M200m [truth halos]',fontsize=16)
plt.legend()
plt.savefig('check_halo_mass.png')

# %%
files_truth   = glob.glob(indir+'halos/Chinchilla-3_halos*')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8bcf725cbd11> in <module>
# ----> 1 files_truth   = glob.glob(indir+'halos/Chinchilla-3_halos*')
#
# NameError: name 'indir' is not defined

# %%
files_truth[0]

# %%
cat= loadfiles(files_truth)

# %%
hid = cat['HALOID']

# %%
hbins = np.logspace(2,9.2,21)
plt.hist(hid,bins=hbins)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('HALOID')
plt.title('v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.{}.fits')
# Out:
# Text(0.5, 1.0, 'v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.{}.fits')

# %%
hidu = np.unique(hid)

# %%
hidu.size/hid.size
# Out:
# 0.9498847926267281

# %%
hid_cls = hidu
hid_gal = g['HALOID'][:]

# %%
import esutil

# %%
# %%timeit
match = esutil.numpy_util.match_multi(hid_cls,hid_gal)
# Out:
# 2.55 s ± 74.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
match[0]
# Out:
# array([ 6714,  6714,  6714, ..., 33367, 33301,  8616])

# %%
# %%timeit
match[1].size
# Out:
# 74.9 ns ± 3.59 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
len(hid_gal)
# Out:
# 91026

# %%
data[match[1]]
# Out:
# array([ 6714,  6714,  6714, ..., 33367, 33301,  8616])

# %%
esutil.numpy_util.where1(g['HALOID']==hid_cls[match[0]][0])
# Out:
# array([      16,      146,      600, ...,   745523,   745547, 10628085])

# %%
######### Setting the Code #########

####### Input Variables
Nhalos = 3000        ## choose the output sample size
nbins  = 25          ## choose how much bins you divide your whole sample
nprocess = 4

#######
rmax = 4               ## maximum radius in Mpc
zmin, zmax = 0.1, 1.0  ## for GC
MassCut = 1e12         ## the low Mass cut
Nside=1024
h=0.7
#######

# %%
####### Output Files
outdir = '/global/project/projectdirs/des/jesteves/buzzardSelection/v2.0.0/'

fileprefix      = 'buzzard_v2.0.0_{}.fits' 
file_cls_out_all= outdir+fileprefix.format('hod_halos')
file_cls_out    = outdir+fileprefix.format('%iHalos_cluster'%(Nhalos))
file_gal_out    = outdir+fileprefix.format('%iHalos_members'%(Nhalos))

hpx_file = outdir+'hpxmap_%i_buzzard_v2.0.0.fits'%Nside
#######


####### Input Files
indir         ='/global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/'
files         = glob.glob(indir+'truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam*')
files_truth   = glob.glob(indir+'halos/Chinchilla-3_halos*')

print('\n'.join(files[:5]))
# Out:
# /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.351.fits
# /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.34.fits
# /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.446.fits
# /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.8.fits
# /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.118.fits

# %%
def split(infile):
    return int(infile.split('.')[-2])

healpix = np.array([split(infile) for infile in files])
w, = np.where(healpix<60)

# files = [files[i] for i in w]

files.sort()

# %%
healpix
# Out:
# array([351,  34, 446,   8, 118,  40, 370,  36,  30, 282,  35, 122,  86,
#        342, 125,  15,  65, 348,  12, 278, 421,  13,  74, 110,  45,   6,
#         72,  51, 426, 378, 358, 380, 443,  82,  56,  71, 379,  69, 429,
#          2,   0,   4, 444,  50,  94, 374, 366,   3, 431,  27,  24,  60,
#        373, 279,  11,  17,  78,  25,  58, 382,  38,  62, 277,  22,  91,
#          5,  81,  68, 311, 283,  26,  59,  83,  97,  63,  55, 361,  20,
#        430,  16,  49, 349, 123, 116,  75,  31, 350, 117, 113, 364,  98,
#         47,  96,  52, 309,  37, 316,  80, 103,  76,  32, 346, 341, 121,
#        359,  39,  41, 112,   7, 305, 363, 435,  19, 377,  61,  70, 432,
#        362,  92, 371, 124, 114,   1,  90, 422, 102, 111, 101,  84,  79,
#         54,  18,  44, 423, 383,  64, 120, 109, 317,  29,  10,  95,  21,
#        365, 281,  42, 343, 428, 126,  66, 310,  67, 107,  57, 105,  28,
#        115,  14, 369, 368, 304, 442, 100, 375, 367, 308, 285, 104, 447,
#        425, 434, 376, 357,  77,  33,  89, 119,  87, 319,  23, 347, 307,
#        127,  88,  85, 372, 345,   9,  46, 108,  73,  99, 440, 286, 427,
#         93, 381, 106, 287,  53,  48, 284,  43, 441])

# %%
NSIDE= 8
NPIX = hp.nside2npix(NSIDE)
print(NPIX)
# Out:
# 768

# %%
m = np.zeros(NPIX)
m[healpix] = 1
hp.mollview(m, nest=True, title="Mollview image NESTED")
# Out:
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:920: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_over(newcm(1.0))
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:921: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_under(bgcolor)
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:922: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_bad(badcolor)
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(

# %%
cluster_mask = 'CENTRAL == 0  && M200 >= %.2e &&  Z>= %.2f && Z<= %.2f'%(MassCut,zmin,zmax)

# %%
def get_mask(f,mask):
    fits = fitsio.FITS(f)
    if mask is not None: w = fits[1].where(mask)
    else: w = np.arange(fits[1].get_nrows(),dtype=np.int64)
    fits.close()
    return w

# %%
def loadfiles(filenames, columns=None, mask=None):
    '''
    Read a set of filenames with fitsio.read and return a concatenated array
    '''
    out = []
    i = 1
    print()
    for f in filenames:
        print('File {i}: {f}'.format(i=i, f=f))
        if not os.path.isfile(f):
            print('file not found: %s'%f)
        else:
            w = get_mask(f,mask) ## if mask None returns all the rows
            ## loading subset
            g0= Table(fitsio.read(f,rows=w,columns=columns))
            g0['hpx8'] = split(f)
            out.append(g0)
        i += 1
    mygals  = [data for data in out if data is not None]
    data       = vstack(mygals)
    return data

# %%
# %timeit
print('a')
# Out:
# a

# %%
# %timeit for _ in range(1000): True
# Out:
# 18.7 µs ± 304 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
files = files[:3]

# %%
g = loadfiles(files,mask='AMAG[1]>-19',columns=colnames)
# Out:
# File 1: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.0.fits
# File 2: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.1.fits
# File 3: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.10.fits

# %%
# %timeit

colnames = ['HALOID','RA','DEC','Z','M200','R200','MAG_R']
data = loadfiles(files,columns=colnames,mask=cluster_mask)
# Out:
# File 1: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.0.fits
# File 2: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.1.fits
# File 3: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/truth/Chinchilla-3_lensed_rs_shift_rs_scat_cam.10.fits

# %%
def chunks(ids1, ids2):
    """Yield successive n-sized chunks from data"""
    for id in ids2:
        w, = np.where( ids1==id )
        yield w

def rhoc(z):
    try:
        rho_c = float(cosmo.critical_density(z)/(u.g/u.cm**3)) # in g/cm**3
    except:
        rho_c = [float(cosmo.critical_density(zi)/(u.g/u.cm**3)) for zi in z]
        rho_c = np.array(rho_c)
    
    rho_c = rho_c*(Mpc2cm**3)/Msol # in Msol/Mpc**3
    return rho_c

def convertM200toR200(M200,z):
    ## M200 in solar masses
    ## R200 in Mpc
    rho = rhoc(z)
    R200 = np.power( M200/(200*4*np.pi*rho/3) , 1/3.  )
    return R200

def AngularDistance(z):
    DA = ( (cosmo.luminosity_distance(z)/(1+z)**2)/u.Mpc ) # em Mpc
    return DA
AngularDistance = np.vectorize(AngularDistance)

rad2deg = 180/np.pi
## functions
def get_healpix_radec(center_ra,center_dec,radius=1.,nside=32):
    center_ra_rad = np.radians(center_ra)
    center_dec_rad = np.radians(center_dec)

    center_vec = np.array([np.cos(center_dec_rad)*np.cos(center_ra_rad),
                        np.cos(center_dec_rad)*np.sin(center_ra_rad),
                        np.sin(center_dec_rad)])

    healpix_list = hp.query_disc(nside, center_vec, np.radians(radius), nest=True, inclusive=True)
    healpix_list = np.append(healpix_list,radec_pix(center_ra,center_dec,nside=nside))
    
    return healpix_list

def get_healpix_map(ra,dec,nside=1024):
    # Set the number of sources and the coordinates for the input
    nsources = len(ra)
    npix = hp.nside2npix(nside)

    thetas,phis = np.radians(90-dec),np.radians(ra)

    # Go from HEALPix coordinates to indices
    indices = hp.ang2pix(nside, thetas, phis,nest=True)

    hpxmap = np.zeros(npix, dtype=np.float)
    w, values = np.unique(indices,return_counts=True)
    hpxmap[w] = values

    return hpxmap

def compute_area_fraction(cat,hpxmap,rmax=1,nside=1024):
    ncls=len(cat)
    out = []
    for i in range(ncls):
        ra,dec = cat['RA'][i], cat['DEC'][i]
        zcls = cat['Z'][i]

        DA = float(AngularDistance(zcls))
        radius = (float(rmax)/DA)*rad2deg ## degrees

        hps_rad = get_healpix_radec(ra,dec,radius=radius,nside=nside)
        hpx_circle  = np.unique(hps_rad)
        
        ## matched healpix table
        ncommon = np.count_nonzero(hpxmap[hpx_circle]) #np.unique(hpx_gals[(np.in1d(hpx_gals,hpx_circle))])

        ## area fraction: number of matched healpix / number of healpix in the cluster circle
        area_fraction = 1.*ncommon/len(hpx_circle)
        out.append(area_fraction)
    
    return np.array(out)

def get_healpix_list(cat,nside=1024):
    healpix_list = np.empty((0),dtype=int)

    for ra,dec,rmax in zip(cat["RA"],cat["DEC"],cat['rmax']):
        hps_rad = get_healpix_radec(ra,dec,radius=rmax/60,nside=nside)
        healpix_list = np.append(healpix_list,hps_rad)
    
    # cat["healpix_list"] = healpix_list

    return np.unique(healpix_list) ## get unique healpix number

def hpix2ang(pix,nside=1024):
    lon,lat = hp.pix2ang(nside,pix,nest=True)
    dec,ra=(90-(lon)*(180/np.pi)),(lat*(180/np.pi))
    return ra,dec

def radec_pix(ra,dec,nside=1024):
    return np.array(hp.ang2pix(nside,np.radians(90-dec),np.radians(ra),nest=True),dtype=np.int64)

def make_hpx_map(ra,dec,Nside,hpx_file,save=True):
    hpx_map = get_healpix_map(ra,dec,nside=Nside)
    hpx_indices = np.arange(1,len(hpx_map)+1,1,dtype=np.int)

    
    data = [hpx_indices,hpx_map]
    cols = ['hpx_pixel','hpx_value']
    if save:
        data = Table(data,names=cols)
        data.write(hpx_file,format='fits',overwrite=True)
        print('healpix map, nside %i'%Nside)
        print('-> %s'%hpx_file)
    return data

def get_critical_mass(cat2,files_truth):
    ### Truth table
    print('Load the halos files')
    cat= loadfiles(files_truth,columns=['HALOID','RA','DEC','Z','M200c','M200b','RVIR','Z_COS'])
    #cat.rename_column('HOST_HALOID','HALOID')
    cat.rename_column('M200C','M200')

    print('\n Making cuts')
    print('clusters with M200<%.2E and z<%.2f'%(MassCut,zmax))
    cat = cat[(cat['Z']>=zmin)&(cat['Z']<=zmax)]
    cat = cat[cat['M200B']>=MassCut]

    ## get unique idx
    _, idx = np.unique(cat['HALOID'],return_index=True)
    cat = cat[idx]
    catb= cat

    print('matching halos truth files')
    cidx = cat2['HALOID']
    indices, = np.where(np.in1d(catb['HALOID'],cidx))#list(chunks(catb['HALOID'],cidx))
    #indices = np.array([int(ix[0]) for ix in indices if ix.size>0])
    
    cat = catb[indices]

    cat['sample'] = False
    for i,cid in enumerate(cidx):
        w, = np.where(cat['HALOID']==cid)
        if w.size>0:
            cat['RA'][w] = cat2['RA'][i]
            cat['DEC'][w] = cat2['DEC'][i]
            cat['sample'][w] = cat2['sample'][i]

    Z = cat['Z']
    M200c = cat['M200'][:]     ## [Msun/h] in physical units
    M200b = cat['M200B'][:]     ## [Msun/h] in physical units

    r200c = convertM200toR200(M200c*h,Z)/h  ## [Mpc/h] in physical units
    r200b = convertM200toR200(M200b*h,Z)/h  ## [Mpc/h] in physical units

    print('switching M200b and R200b to M200c and R200c')
    cat['R200B'] = r200b      ## [Mpc/h] mean, in comoving units 
    cat['R200'] = r200c

    return cat,catb

def get_random_selection(cat2,Nsize=3000):
    df = cat2.to_pandas()
    train_set, test_set = train_test_split(df, test_size=Nsize, random_state=42)

    cat3 = Table.from_pandas(test_set)
    return cat3

def get_high_mass_selection(cat2,Nsize=1000,nbins=25):
    Nsize+= 1200

    M200 = cat2["M200"]
    Mh = M200[cat2["M200"]>=5e13]
    z  = cat2['Z']
    df = cat2.to_pandas()

    data = []
    mbins = np.logspace(np.log10(np.min(Mh)),np.log10(np.max(Mh)),nbins)
    zbins = np.linspace(0.1,1.,11)
    for zl,zh in zip(zbins[:-1],zbins[1:]):
        for ml,mh in zip(mbins[:-1],mbins[1:]):
            w, = np.where((M200>=ml)&(M200<=mh)&(z<=zh)&(z>=zl))
            dfb= df.iloc[w]
            size=int(Nsize/nbins/10)
            if w.size <size: size=len(dfb)-1
            if len(dfb)>0:
                print('bin size:',size)
                if (size>0)&(size<=len(dfb)):
                    train_set, test_set = train_test_split(dfb, test_size=size, random_state=42)
                    data.append(Table.from_pandas(test_set))
                else:
                    print('Error: no halos within this limits')
    cat_high_mass = vstack(data)
    return cat_high_mass

# %%
c = data['HALOID','RA','DEC','Z','M200','R200','MAG_R','hpx8']

# %%
ncls = len(c)
print('# clusters:', ncls)
# Out:
# # clusters: 91026

# %%
Nhalos=3000

# %%
## random selection of halos with mass less than 5 x E13 Msun
print('Selecting Silver Sample')
mask = c['M200']<5e13
cat_silver = get_random_selection(c[mask],Nsize=31000)

## uniform selection of halos with mass greater than 5 x E13 Msun
print('Selecting Golden Sample')
cat_golden = get_high_mass_selection(c,Nsize=Nhalos*1.2,nbins=20)

print('Mathching Sample')
## flag
cat_silver['sample'] = False
cat_golden['sample'] = True

catf = vstack([cat_golden,cat_silver])
keys, idx = np.unique(catf['HALOID'],return_index=True) ## unique keys
catf = catf[idx]
# Out:
# Selecting Silver Sample
# Selecting Golden Sample
# bin size: 12
# bin size: 11
# bin size: 21
# bin size: 9
# bin size: 5
# bin size: 7
# bin size: 6
# bin size: 6
# bin size: 5
# bin size: 3
# bin size: 0
# Error: no halos within this limits
# bin size: 1
# bin size: 0
# Error: no halos within this limits
# bin size: 1
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 19
# bin size: 16
# bin size: 13
# bin size: 6
# bin size: 6
# bin size: 5
# bin size: 3
# bin size: 0
# Error: no halos within this limits
# bin size: 2
# bin size: 0
# Error: no halos within this limits
# bin size: 1
# bin size: 2
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 22
# bin size: 11
# bin size: 7
# bin size: 4
# bin size: 2
# bin size: 3
# bin size: 4
# bin size: 0
# Error: no halos within this limits
# bin size: 0
# Error: no halos within this limits
# bin size: 0
# Error: no halos within this limits
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 10
# bin size: 15
# bin size: 10
# bin size: 4
# bin size: 2
# bin size: 1
# bin size: 0
# Error: no halos within this limits
# bin size: 1
# bin size: 0
# Error: no halos within this limits
# bin size: 0
# Error: no halos within this limits
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 14
# bin size: 16
# bin size: 13
# bin size: 11
# bin size: 5
# bin size: 4
# bin size: 3
# bin size: 2
# bin size: 2
# bin size: 3
# bin size: 1
# bin size: 0
# Error: no halos within this limits
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 19
# bin size: 9
# bin size: 5
# bin size: 10
# bin size: 5
# bin size: 2
# bin size: 0
# Error: no halos within this limits
# bin size: 1
# bin size: 0
# Error: no halos within this limits
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 13
# bin size: 15
# bin size: 5
# bin size: 3
# bin size: 2
# bin size: 2
# bin size: 0
# Error: no halos within this limits
# bin size: 1
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 7
# bin size: 4
# bin size: 6
# bin size: 4
# bin size: 2
# bin size: 0
# Error: no halos within this limits
# bin size: 1
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 13
# bin size: 11
# bin size: 3
# bin size: 1
# bin size: 5
# bin size: 1
# bin size: 0
# Error: no halos within this limits
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 24
# bin size: 17
# bin size: 6
# bin size: 4
# bin size: 2
# bin size: 1
# bin size: 1
# bin size: 0
# Error: no halos within this limits
# Mathching Sample

# %%
    print('Load the halos files')
    cat= loadfiles(files_truth,columns=['HALOID','Z','M200c','M200b','RVIR','Z_COS'])
    #cat.rename_column('HOST_HALOID','HALOID')
    cat.rename_column('M200C','M200')

    print('\n Making cuts')
    print('clusters with M200<%.2E and z<%.2f'%(MassCut,zmax))
    cat = cat[(cat['Z']>=zmin)&(cat['Z']<=zmax)]
    cat = cat[cat['M200B']>=MassCut]
    cat.remove_columns('hpx8')
    
    print('matching halos truth files')
    new_cat = join(catf['HALOID','RA','DEC','sample','hpx8'],cat,keys=['HALOID'])
    
    Z = new_cat['Z']
    M200c = new_cat['M200'][:]     ## [Msun/h] in physical units
    M200b = new_cat['M200B'][:]     ## [Msun/h] in physical units

    r200c = convertM200toR200(M200c*h,Z)/h  ## [Mpc/h] in physical units
    r200b = convertM200toR200(M200b*h,Z)/h  ## [Mpc/h] in physical units

    print('switching M200b and R200b to M200c and R200c')
    new_cat['R200B'] = r200b      ## [Mpc/h] mean, in comoving units 
    new_cat['R200'] = r200c
    

#     cidx = cat2['HALOID']
#     indices, = np.where(np.in1d(catb['HALOID'],cidx))#list(chunks(catb['HALOID'],cidx))
#     #indices = np.array([int(ix[0]) for ix in indices if ix.size>0])
    
#     cat = catb[indices]

#     cat['sample'] = False
#     for i,cid in enumerate(cidx):
#         w, = np.where(cat['HALOID']==cid)
#         if w.size>0:
#             cat['RA'][w] = cat2['RA'][i]
#             cat['DEC'][w] = cat2['DEC'][i]
#             cat['sample'][w] = cat2['sample'][i]
# Out:
# Load the halos files
#
# File 1: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.4.fits
# File 2: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.2.fits
# File 3: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.21.fits
# File 4: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.19.fits
# File 5: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.17.fits
# File 6: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.23.fits
# File 7: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.0.fits
# File 8: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.3.fits
# File 9: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.26.fits
# File 10: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.7.fits
# File 11: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.22.fits
# File 12: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.5.fits
# File 13: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.1.fits
# File 14: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.6.fits
# File 15: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.27.fits
#
#  Making cuts
# clusters with M200<1.00E+12 and z<1.00
# matching halos truth files
# switching M200b and R200b to M200c and R200c

# %%
new_cat
# Out:
# <Table length=34144>
#  HALOID          RA         ...        R200B                R200
#  int64        float64       ...       float64             float64
# -------- ------------------ ... ------------------- -------------------
#  8947021  25.43873009418812 ...  0.5645368329094338  0.5490600629041518
#  8947636 24.594680640986187 ...  0.8111600465044521  0.7998910197193378
#  8947743   27.2635412872239 ...  0.7262241904910967  0.7238867631009172
#  8949135  23.87957784134395 ...  0.8752012215878816  0.8638964682314648
#  8950467 25.825613849297646 ...  0.6381821594195395  0.6095668642644199
#  8950856 25.060783486226242 ...  0.6611347390149097  0.6554342701897559
#  8950979 24.338993794361595 ...   0.569404371877703  0.5456547173298423
#  8951430 27.032056953966208 ...  0.6572396623569737   0.633642605120387
#  8951854 24.682401885870412 ...  0.6210055035488358  0.6146674503537425
#  8953837  25.92751985497763 ...  0.6036934750137672  0.5970214413526784
#      ...                ... ...                 ...                 ...
# 37744958  50.53580732671521 ...  0.3676112195827191  0.3512511442763416
# 37745144 51.812190917697286 ...  0.3577763357767834  0.3465897147982667
# 37745343  50.79557906900565 ...  0.3631940463222251  0.3492109714976254
# 37745344  50.08294584973264 ...  0.3566364202417937   0.345215662155187
# 37745546 51.810019278958386 ... 0.37263230001848696 0.36241768789995293
# 37745797 50.177261225681505 ... 0.34787958264657404 0.33895487750760833
# 37746753 50.974924975973465 ...  0.3609170654664548  0.3581621767243248
# 37747009  52.17462928372303 ...  0.3404654526348801  0.3146687948894174
# 37748135  49.23166357022049 ...  0.3418202703296269 0.32611770783284827
# 37748147  50.74620002438286 ...  0.3603679984590542  0.3517855312780312

# %%
cat.remove_columns('hpx8')

# %%
new_cat

# %%
print('Geting Critical Mass')
## catf is whole sample with M200 added
## catb is the halos data
catf2,catb = get_critical_mass(catf,files_truth)

print('Computing Area Fraction')
catf['area_frac'] = compute_area_fraction(catf,hpx_values,rmax=8,nside=Nside)
# Out:
# Geting Critical Mass
# Load the halos files
#
# File 1: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.4.fits
# File 2: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.2.fits
# File 3: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.21.fits
# File 4: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.19.fits
# File 5: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.17.fits
# File 6: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.23.fits
# File 7: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.0.fits
# File 8: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.3.fits
# File 9: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.26.fits
# File 10: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.7.fits
# File 11: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.22.fits
# File 12: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.5.fits
# File 13: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.1.fits
# File 14: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.6.fits
# File 15: /global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.9/addgalspostprocess/halos/Chinchilla-3_halos.27.fits
#
#  Making cuts
# clusters with M200<1.00E+12 and z<1.00
# matching halos truth files
# switching M200b and R200b to M200c and R200c
# Computing Area Fraction

# %%
x1=catf['M200']
x2=catf2['M200']

fresidual = np.log10(x1/(x2+1e-3))

w = remove_outlier(fresidual)

# %%
plt.hist(fresidual,bins=100)
plt.yscale('log')

# %%
def remove_outlier(x):
    p16,p84 = np.percentile(x,[16,84])
    iqr = p84-p16
    nh = p84+2.5*iqr
    nl = p16-2.5*iqr
    w, = np.where((x>=nl)&(x<=nh))
    return w

# %%
plt.plot([5e12,3e15],[5e12,3e15],'k--')
plt.scatter(catf['M200'],catf2['M200'],alpha=0.2)
plt.scatter(catf['M200'][w],catf2['M200'][w],alpha=0.2,label='My Selection')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('M200m')
plt.ylabel('M200c')
plt.legend()

# %%
catf = catf2[w]

catf['hpx8'] = radec_pix(catf['RA'],catf['DEC'],nside=8)

# %%
## spliting sample
mask = catf['sample']
cat_g = catf[mask]
cat_s = catf[np.logical_not(mask)]

print('Saving preliminar cluster samples')
catf = vstack([cat_g,cat_s])

print('->',file_cls_out)
print('->',file_cls_out_all)

cat_g.write(file_cls_out,format='fits',overwrite=True)
catf.write(file_cls_out_all,format='fits',overwrite=True)
# Out:
# Saving preliminar cluster samples
# -> /global/project/projectdirs/des/jesteves/buzzardSelection/v2.0.0/buzzard_v2.0.0_3000Halos_cluster.fits
# -> /global/project/projectdirs/des/jesteves/buzzardSelection/v2.0.0/buzzard_v2.0.0_hod_halos.fits

# %%
mbins = np.logspace(np.log10(5e13),np.log10(3e15),20)
plt.hist(catf['M200'],bins=mbins)
plt.xscale('log')

# %%
plt.plot([5e12,3e15],[5e12,3e15],'k--')
plt.scatter(catf['M200B'],catf['M200'],alpha=0.2)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('M200m')
plt.ylabel('M200c')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot([0.3,3.],[0.3,3.],'k--')
plt.scatter(catf['RVIR']/1000,catf['R200'],alpha=0.2)
# plt.xscale('log')
# plt.yscale('log')
plt.xlabel('R200m')
plt.ylabel('R200c')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
print('getting healpix map')
# if not os.path.isfile(hpx_file):
ra,dec = cat_g['RA'], cat_g['DEC']
hpx_map = get_healpix_map(ra,dec,Nside)

# else:
#     hpx_map = Table(getdata(hpx_file))

#hpx_values = np.array(hpx_map['hpx_value'])
# Out:
# getting healpix map
# <ipython-input-425-e9b7c282f703>:54: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hpxmap = np.zeros(npix, dtype=np.float)

# %%
hpx_map8 = get_healpix_map(ra,dec,8)
# Out:
# <ipython-input-425-e9b7c282f703>:54: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hpxmap = np.zeros(npix, dtype=np.float)

# %%
hp.mollview(hpx_map8, nest=True, title="NSIDE = 8 ")
# Out:
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:920: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("rocket").copy()
#   newcm.set_over(newcm(1.0))
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:921: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("rocket").copy()
#   newcm.set_under(bgcolor)
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:922: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("rocket").copy()
#   newcm.set_bad(badcolor)
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:202: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   aximg = self.imshow(

# %%
hp.mollview(hpx_map, nest=True, title='Cluster Footprint')

# %%
cat_g
# Out:
# <Table length=3487>
#        Z_COS              M200B       ...       R200B               R200
#       float64            float64      ...      float64            float64
# ------------------- ----------------- ... ------------------ ------------------
#  0.8690741973375709 619950000000000.0 ...  1.629345110236703 1.5866955713037396
#  0.9235167638496333 115970000000000.0 ... 0.9131447749119128  0.876753289325702
# 0.30971057808535885 960610000000000.0 ... 2.3340518200817018 2.2677661273211793
#  0.9251532680095578 273190000000000.0 ... 1.2136443406865538 1.1915964870018332
#  0.9191490524573727 194900000000000.0 ... 1.0872746534529822 1.0647767558952608
#  0.3177403356526445 161980000000000.0 ...  1.284962452022134  1.119890105989918
# 0.30038031877170845 204450000000000.0 ... 1.3991050064330197 1.3390337001661505
#  0.9178493054934147 114990000000000.0 ... 0.9119899932927873 0.8813638207225548
#  0.9217152047771822  96802000000000.0 ... 0.8595479481741412 0.8498218714494965
#  0.8677534043725919 301610000000000.0 ...   1.28219824398181 1.2326680187025798
#                 ...               ... ...                ...                ...
#  0.8497268778846852 212440000000000.0 ... 1.1489631732935737 1.0965441635433135
#  0.8670218804210936 360250000000000.0 ... 1.3608048766663974  1.338338265152761
#   0.878197663287211 179470000000000.0 ... 1.0745320640298472 1.0295686138845292
#  0.8988963851249312 177850000000000.0 ... 1.0626373732010725 1.0361092749718597
#   0.886714983987581  70328000000000.0 ... 0.7837441416491477 0.7689842711646717
#  0.8352066844007258 282770000000000.0 ... 1.2706125564504018  1.211464138576303
#  0.8708175752646987 234700000000000.0 ...  1.177423294656631  1.093643558527242
#  0.8868363506431707  51000000000000.0 ... 0.7036897605804557 0.6716191475803466
#   0.865305901723916  81047000000000.0 ... 0.8281047342171364 0.7964884481256018
#  0.9321889652026045  77636000000000.0 ...  0.795536124322497 0.7738699121756776

# %%
import seaborn as sns
sns.set_style('darkgrid')

def plot_scatter_hist(x,y,xlabel=r'$z$',ylabel=r'$\log(M_{200,c})\,\,[M_{\odot}\; h^{-1}]$',save='./img/bla.png'):
    fig = plt.figure(figsize=(10,8))

    # definitions for the axes
    left, width = 0.1, 0.65
    bottom, height = 0.1, 0.65
    spacing = 0.01
    scale = 70
    
    rect_scatter = [left, bottom, width, height]
    rect_histx = [left, bottom + height + spacing, width, 0.2]
    rect_histy = [left + width + spacing, bottom, 0.175, height]

    scatter_axes = plt.axes(rect_scatter)
    scatter_axes.tick_params(direction='in', top=True, right=True)
    x_hist_axes = plt.axes(rect_histx,sharex=scatter_axes)
    x_hist_axes.tick_params(direction='in')
    y_hist_axes = plt.axes(rect_histy,sharey=scatter_axes)
    y_hist_axes.tick_params(direction='in')
    
    xmax = np.nanmax(x)
    ymin, ymax = np.nanmin(y), np.nanmax(y)
    
    binx = np.linspace(0.1, xmax, num=15)
    biny = np.linspace(ymin, ymax, num=15)  # 1500/100.

    pal = sns.dark_palette("#3498db", as_cmap=True)
    # sns.kdeplot(x, y, ax=scatter_axes, cmap=pal, zorder=3)  # n_levels=10

    scatter_axes.set_xlabel(xlabel, fontsize=25)
    scatter_axes.set_ylabel(ylabel, fontsize=25)

    scatter_axes.scatter(x, y, s=scale, color='b', marker='o', alpha=0.3, zorder=0)
#     scatter_axes.axhline(np.mean(y),linestyle='--',color='b')

    x_hist_axes.hist(x, bins=binx, density=False, alpha=0.3, color='b')
    y_hist_axes.hist(y, bins=biny, density=False, orientation='horizontal', alpha=0.3, color='b')
#     y_hist_axes.axhline(np.mean(y),linestyle='--', color='b')
    
    x_hist_axes.set_yticklabels([])
    y_hist_axes.set_xticklabels([])

    if ymax<0:
        ymin,ymax=13.5,15.3

        scatter_axes.set_ylim(ymin, ymax)
        y_hist_axes.set_ylim(ymin, ymax)

    scatter_axes.xaxis.set_tick_params(labelsize=15)
    scatter_axes.yaxis.set_tick_params(labelsize=15)
    x_hist_axes.xaxis.set_tick_params(labelsize=0.05, labelcolor='white')
    y_hist_axes.yaxis.set_tick_params(labelsize=0.05, labelcolor='white')

    fig.subplots_adjust(hspace=.01, wspace=0.01)

# %%
zcls = catf['Z']
m200 = catf['M200B']

plot_scatter_hist(zcls,np.log10(m200),ylabel=r'$\log(M_{halo})$')
plt.savefig('halo_mass_redshift_distribution.png')

# %%
gg = get_galaxy(hpx,cat)

## find the healpix files around the cluster centers
gg.get_healpix_neighbours()

## load files within Mr<=-18
d = gg.load_files(base,amagMax=-18.)

## get only true members for the silver cluster sample
ds= gg.get_silver_sample(g)

## get the galaxies within 8Mpc from the golden cluster centers
dg= gg.get_golden_sample(g)

## compute cluster richness for all the sample ; updates ngals on the cluster sample
gg.compute_cluster_richness(ds)

## save output
save_copacabana_output(dg,gg.cat)
save

# %%
gal = rename_buzzard_columns(gal)

df  = gal.to_pandas()
df.save_hdf5()

# %%
import numpy as np

# %%
a = []
for i in range(3):
    a.append(np.arange(3))

# %%
np.hstack(a)
# Out:
# array([0, 1, 2, 0, 1, 2, 0, 1, 2])
