# %% [markdown]
# # Cluster Subsample:
#
# info: https://cdcvs.fnal.gov/redmine/projects/des-clusters/wiki/ClustDataVecY3 <br>

# %%
import matplotlib.pyplot as plt
import numpy as np

from astropy.table import Table, vstack

# %% [markdown]
# # Load

# %% [markdown]
# ### Show DataStructure

# %%
ls /data/des81.b/data/mariaeli/y3_cats/subsampled
# Out:
# Y3_GOLD_2_2.1_BPZ_subsampled.h5
# Y3_GOLD_2_2.1_DNF_subsampled.h5
# Y3_GOLD_2_2_1_maps.h5
# Y3_GOLD_2_2.1_subsampled.h5
# y3_gold_2.2.1_wide_sofcol_run_redmapper_v6.4.22_wv1.2_subsampled.h5
# Y3_mastercat_6_15_19_subsampled.h5
# y3v02-mcal-003-v1_subsampled.h5

# %%
import h5py

path   = '/data/des81.b/data/mariaeli/y3_cats/subsampled/'
fname  = path+'y3_gold_2.2.1_wide_sofcol_run_redmapper_v6.4.22_wv1.2_subsampled.h5'

master = h5py.File(fname,'r')

# %%
def show_h5_group(name,node):
    ''' show all the h5 groups
    Example:
    fmaster = h5py.File(copa.master_fname,'r')
    fmaster.visititems(show_h5_group)

    ## https://stackoverflow.com/questions/45562169/traverse-hdf5-file-tree-and-continue-after-return
    '''
    if isinstance(node, h5py.Group):
        print(name,node)
    return None

def show_h5_dataset(name,node):
    if isinstance(node, h5py.Dataset):
        print(name,node)
    return None

# %%
master.visititems(show_h5_dataset)
# Out:
# (u'catalog/redmagic/combined_sample_fid/chisq', <HDF5 dataset "chisq": shape (357967,), type ">f4">)
# (u'catalog/redmagic/combined_sample_fid/coadd_object_id', <HDF5 dataset "coadd_object_id": shape (357967,), type "<i8">)
# (u'catalog/redmagic/combined_sample_fid/dec', <HDF5 dataset "dec": shape (357967,), type ">f8">)
# (u'catalog/redmagic/combined_sample_fid/mabs', <HDF5 dataset "mabs": shape (357967, 4), type ">f4">)
# (u'catalog/redmagic/combined_sample_fid/mabs_err', <HDF5 dataset "mabs_err": shape (357967, 4), type ">f4">)
# (u'catalog/redmagic/combined_sample_fid/model_mag', <HDF5 dataset "model_mag": shape (357967, 4), type ">f4">)
# (u'catalog/redmagic/combined_sample_fid/model_magerr', <HDF5 dataset "model_magerr": shape (357967, 4), type ">f4">)
# (u'catalog/redmagic/combined_sample_fid/ra', <HDF5 dataset "ra": shape (357967,), type ">f8">)
# (u'catalog/redmagic/combined_sample_fid/redmagicflag', <HDF5 dataset "redmagicflag": shape (357967,), type "|u1">)
# ...

# %%
master['catalog/redmapper/lgt20/'].visititems(show_h5_dataset)
# Out:
# (u'bcg_ilum', <HDF5 dataset "bcg_ilum": shape (2289,), type ">f4">)
# (u'bcg_spec_z', <HDF5 dataset "bcg_spec_z": shape (2289,), type ">f4">)
# (u'c_lambda', <HDF5 dataset "c_lambda": shape (2289, 3), type ">f4">)
# (u'c_lambda_err', <HDF5 dataset "c_lambda_err": shape (2289, 3), type ">f4">)
# (u'chisq', <HDF5 dataset "chisq": shape (2289,), type ">f4">)
# (u'dec', <HDF5 dataset "dec": shape (2289,), type ">f8">)
# (u'dec_cent', <HDF5 dataset "dec_cent": shape (2289, 5), type ">f8">)
# (u'dec_orig', <HDF5 dataset "dec_orig": shape (2289,), type ">f8">)
# (u'dlambda_dz', <HDF5 dataset "dlambda_dz": shape (2289,), type ">f4">)
# (u'dlambda_dz2', <HDF5 dataset "dlambda_dz2": shape (2289,), type ">f4">)
# (u'dlambdavar_dz', <HDF5 dataset "dlambdavar_dz": shape (2289,), type ">f4">)
# (u'dlambdavar_dz2', <HDF5 dataset "dlambdavar_dz2": shape (2289,), type ">f4">)
# (u'ebv_mean', <HDF5 dataset "ebv_mean": shape (2289,), type ">f4">)
# ...

# %% [markdown]
# ### Load Variables

# %%
clusters = master['catalog/redmapper/lgt5/']

# %%
cols = ['ra','dec','z_lambda','lambda_chisq','lim_limmag']

ra   = clusters['ra'][:]
dec  = clusters['dec'][:]
zcls = clusters['z_lambda'][:]

lbd     = clusters['lambda_chisq'][:]
lim_mag = clusters['lim_limmag'][:]

# %%
_ = plt.hist(zcls,bins=np.arange(0.1,0.8,0.05),histtype='step',lw=4)
plt.axvline(0.6,ls='--',lw=3,color='gray')
plt.xlabel('redshift',fontsize=18)
plt.title('redMaPPer Y3: lgt5',fontsize=14)
plt.ylabel('N',fontsize=16)
# Out:
# Text(0,0.5,'N')

# %%
plt.hist(lbd,bins=np.logspace(np.log10(5),np.log10(200),21))
plt.yscale('log')
plt.xscale('log')
plt.xlabel(r'$\lambda$',fontsize=18)
# Out:
# Text(0.5,0,'$\\lambda$')

# %%
plt.scatter(ra,dec,s=10)
plt.xlabel('RA')
plt.ylabel('DEC')
# Out:
# Text(0,0.5,'DEC')

# %%
def sky_plot(RA,DEC,ax=None,title=''):
    if ax is None:
        fig = plt.figure(figsize=(8,6))
        ax = fig.add_subplot(111, projection="aitoff")

    ############################
    #Codigo para plotar coordenadas de objetos na esfera celeste
    #############################
    import astropy.coordinates as coord
    from astropy import units as u
    
    ra = coord.Angle(RA*u.degree)
    ra = ra.wrap_at(180*u.degree)
    dec = coord.Angle(DEC*u.degree)

    ##############
    #Plotando os objetos
    #import astropy.coordinates as coord
    ax.set_xticklabels(['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h'])
    ax.grid(True)
    ax.scatter(ra.radian, dec.radian, s=10, alpha=0.5)
    ax.set_title(title,fontsize=20)
    
    plt.subplots_adjust(top=0.9,bottom=0.0)
    # ax.set_xticklabels(['10h','8h','6h','4h','2h','0h','20h','18h','16h','14h','12h'])
    
    #fig.savefig(savefig, bbox_inches = "tight")
    #plt.clf()
    #plt.close()

# %%
dec_min,dec_max = -75, +15

cut = (cat['DEC']>=dec_min)&(cat['DEC']<=dec_max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c1e069a455b1> in <module>
#       1 dec_min,dec_max = -75, +15
#       2
# ----> 3 cut = (cat['DEC']>=dec_min)&(cat['DEC']<=dec_max)
#
# NameError: name 'cat' is not defined

# %%
sky_plot(cat['RA'][::10],cat['DEC'][::10],title='All')
# sky_plot(cat['RA'][cut][::10],cat['DEC'][cut][::10],title='Selection')

# %% [markdown]
# ### Select an uniform distribution on mass and redshift

# %%
import sys
# sys.path.append('/home/s1/jesteves/git/buzzardAnalysis/buzzardSelection/scripts/')
sys.path.append('/global/u2/j/jesteves/codes/buzzardAnalysis/buzzardSelection/scripts/')
from helper import get_high_mass_selection,plot_scatter_hist,getMagLimModel,make_hpx_map,radec_pix,AngularDistance

# %%
mag_file = '../scripts/files/annis_mags_04_Lcut.txt'

# %%
h = 0.7
Nhalos = 3000
zmax   = 0.7

# %%
cat_golden = get_high_mass_selection(cat[cut],zmin=0.1,zmax=zmax,Nsize=Nhalos,nbins=20,h=h)
# Out:
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 9
# bin size: 5
# bin size: 3
# bin size: 0
# Error: no halos within this limits
# bin size: 3
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 6
# bin size: 7
# bin size: 2
# bin size: 3
# bin size: 0
# Error: no halos within this limits
# bin size: 0
# Error: no halos within this limits
# bin size: 0
# Error: no halos within this limits
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 11
# bin size: 11
# bin size: 3
# bin size: 3
# bin size: 1
# bin size: 20
# bin size: 20
# bin size: 20
# bin size: 20
# ...

# %%
zcls = cat_golden['redshift']
m200 = cat_golden['M200']

# %%
plot_scatter_hist(zcls,np.log10(m200*h),ylabel=r'$\log(M_{halo})$')

# %%
xbins = np.logspace(13.5,15.1,30)
_     = plt.hist(m200*h,bins=xbins)
plt.xscale('log')
plt.yscale('log')

# %%
#### Get Magnitude Model

# %%
z = cat_golden['redshift']
magLim3 = getMagLimModel(mag_file,z,dm=1)
cat_golden['magLim'] = magLim3[:,1]                ##i-band

# %%
plt.figure(figsize=(8,6))
plt.scatter(z,magLim3[:,1],label='All galaxies')
plt.scatter(cat['redshift'][::300],cat['MAG_I'][::300],s=20,alpha=0.5,label='Centrals')

plt.axhline(23.5,color='k',ls='--')
plt.xlim(0.08,0.73)

_ = plt.xticks(np.arange(0.1,0.715,0.15))
_ = plt.yticks(np.arange(14,24,3))
plt.legend(fontsize=12)
plt.ylabel(r'$mag_{i,max}$')
plt.xlabel('redshift')
# Out:
# Text(0.5, 0, 'redshift')

# %% [markdown]
# ### Make Healpix Map

# %%
rad2deg  = 180/np.pi
rmax     = 8 #Mpc around each cluster
Nside    = 2
outdir   = '/global/project/projectdirs/des/jesteves/buzzardSelection/y3_v2.0.0/'
hpx_file = outdir+'healpix8/hpxmap_nside%i_buzzard_y3_v2.0.0.fits'%Nside

# %%
ra,dec = cat_golden['RA'], cat_golden['DEC']
cat_golden['hpx2'] = radec_pix(ra,dec,nside=Nside)

# %%
# r200   = cat['R200'][:]*0.7 ## Mpc
# DA     = AngularDistance(np.array(cat['redshift']))
# cat['rmax']  = 60*(float(rmax)/DA)*rad2deg ## arcmin

# %%
print('getting healpix map')

hpx_map = make_hpx_map(ra,dec,Nside,hpx_file)
hpx_values = np.array(hpx_map['hpx_value'])
# Out:
# getting healpix map
# healpix map, nside 2
# -> /global/project/projectdirs/des/jesteves/buzzardSelection/y3_v2.0.0/healpix8/hpxmap_nside2_buzzard_y3_v2.0.0.fits

# %%
import healpy as hp
hp.mollview(hpx_values, nest=True, title="NSIDE = 2")

# %%
print('# Tiles: ',np.count_nonzero(hpx_values>1))
# Out:
# # Tiles:  14

# %%
hpx_map[hpx_values>1]
# Out:
# <Table length=14>
# hpx_pixel hpx_value
#   int64    float64
# --------- ---------
#         1       3.0
#        17     109.0
#        18     282.0
#        19     100.0
#        20       2.0
#        21     145.0
#        33     189.0
#        34     424.0
#        35     494.0
#        36     448.0
#        39      47.0
#        45     199.0
#        46     282.0
#        47      22.0

# %% [markdown]
# ### Save Output

# %%
outdir = '/global/project/projectdirs/des/jesteves/buzzardSelection/y3_v2.0.0/'
name   = outdir+'halos/buzzard_y3_v2.0.0_golden_halos.fits'

# %%
cat_golden.write(name,format='fits',overwrite=True)

# %%
len(cat_golden)
# Out:
# 2748

# %%
sky_plot(cat_golden['RA'],cat_golden['DEC'],title='All')
# sky_plot(cat['RA'][cut][::10],cat['DEC'][cut][::10],title='Selection')

# %%
outdir= '/global/project/projectdirs/des/jesteves/buzzardSelection/y3_v2.0.0/tiles/'
infile = outdir+'buzzard_y3_v2.0.0_golden_16.hdf'

# %%
infile = '/global/project/projectdirs/des/jesteves/buzzardSelection/y3_v2.0.0/tiles/buzzard_y3_v2.0.0_golden_34.hdf'

# %%
print(infile)
# Out:
# /global/project/projectdirs/des/jesteves/buzzardSelection/y3_v2.0.0/tiles/buzzard_y3_v2.0.0_golden_34.hdf

# %%
def upload_dataFrame(infile,keys='members'):
    hdf = pd.HDFStore(infile, mode='r')
    df1 = hdf.get(keys)
    hdf.close()
    data = Table.from_pandas(df1)
    return data

# %%
import pandas as pd

# %%
gi = upload_dataFrame(infile,keys='members')
ci = upload_dataFrame(infile,keys='cluster')

# %%
sky_plot(gi['ra'][::100],gi['dec'][::100])
#sky_plot(ci['RA'],ci['DEC'])

# %%
plt.scatter(gi['ra'][::1000],gi['dec'][::1000])
#plt.scatter(ci['RA'][:10],ci['DEC'][:10])
#plt.xlim(-1.,11)

# %%
#gi=ci=0

# %%
gi.write(outdir+'test_members.fits',format='fits',overwrite=True)

# %%
ci.write(outdir+'test_cluster.fits',format='fits',overwrite=True)

# %%
len(gi)*1e-5
# Out:
# 216.94363

# %%
'/global/project/projectdirs/des/jesteves/buzzardSelection/y3_v2.0.0/tiles/buzzard_y3_v2.0.0_golden_0.hdf
'

# %%
cols = ['mag_%s'%(fi) for fi in ['g','r','i','z']]

# %%
gc = gi[:10000].copy()

# %%
mag = np.vstack([gc[mi] for mi in cols]).T

# %%
mag
# Out:
# array([[25.213903, 24.250378, 23.531538, 23.780712],
#        [23.413706, 22.747944, 22.182749, 22.098326],
#        [23.876905, 23.76076 , 23.541327, 23.71996 ],
#        ...,
#        [24.345   , 23.41777 , 23.071198, 23.573027],
#        [24.909733, 24.485285, 23.95149 , 24.01866 ],
#        [24.372717, 23.45334 , 22.686693, 22.042736]], dtype=float32)

# %%
path   = '/global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.8/sampleselection/Y3a/mastercat/'
fname  = path+'Buzzard_v1.9.8_Y3a_gold.h5'
fname_aux  = path+'Buzzard-3_v1.9.8_Y3a_mastercat.h5'

# %%
import h5py

#path   = '/data/des81.b/data/mariaeli/y3_buzz/Buzzard-3_v2.0_Y3a_mastercat/'
path   = '/global/project/projectdirs/des/jderose/Chinchilla/Herd/Chinchilla-3/v1.9.8/sampleselection/Y3a/mastercat/'
fname  = path+'Buzzard_v1.9.8_Y3a_gold.h5'
fname_aux  = path+'Buzzard-3_v1.9.8_Y3a_mastercat.h5'

# %%
master = h5py.File(fname,'r')
#indexes= h5py.File(fname_aux,'r')

values = master['masks/gold/hpix'][:]

master.close()

# %%
nside  = 4096
npix   = hp.nside2npix(nside)
hpxmap = np.zeros(npix, dtype=np.float)
hpxmap[values] = 1
# Out:
# <ipython-input-48-c751821a80c4>:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hpxmap = np.zeros(npix, dtype=np.float)

# %%
import healpy as hp

# %%
hp.mollview(hpxmap,nest=True)

# %%
fname = path+'Y3_GOLD_2_2_1_maps_copy.h5'
master = h5py.File(fname,'r')

# %%
def show_h5_dataset(name,node):
    if isinstance(node, h5py.Dataset):
        print(name,node)
    return None

# %%
master.visititems(show_h5_dataset)
# Out:
# maps/det_frac <HDF5 dataset "det_frac": shape (25169981,), type "<f8">
# maps/ebv_planck13 <HDF5 dataset "ebv_planck13": shape (25169981,), type "<f8">
# maps/g/airmass <HDF5 dataset "airmass": shape (25169981,), type "<f8">
# maps/g/fwhm <HDF5 dataset "fwhm": shape (25169981,), type "<f8">
# maps/g/mof_depth <HDF5 dataset "mof_depth": shape (25169981,), type "<f8">
# maps/g/sigma_zp <HDF5 dataset "sigma_zp": shape (25169981,), type "<f8">
# maps/g/sky_var <HDF5 dataset "sky_var": shape (25169981,), type "<f8">
# maps/g/teff_mean <HDF5 dataset "teff_mean": shape (25169981,), type "<f8">
# maps/g/teff_sum <HDF5 dataset "teff_sum": shape (25169981,), type "<f8">
# maps/hpix <HDF5 dataset "hpix": shape (25169981,), type "<i8">
# maps/i/airmass <HDF5 dataset "airmass": shape (25169981,), type "<f8">
# maps/i/fwhm <HDF5 dataset "fwhm": shape (25169981,), type "<f8">
# maps/i/mof_depth <HDF5 dataset "mof_depth": shape (25169981,), type "<f8">
# ...

# %%
y3_map = master['maps/hpix'][:]

master.close()

# %%
nside  = 4096
npix   = hp.nside2npix(nside)
hpxmap = np.zeros(npix, dtype=np.float)
hpxmap[y3_map] = 1
# Out:
# <ipython-input-56-7096dc871541>:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hpxmap = np.zeros(npix, dtype=np.float)

# %%
hp.mollview(hpxmap,nest=True)
# Out:
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:920: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_over(newcm(1.0))
# /usr/local/py/envs/desc/lib/python3.8/site-packages/healpy/projaxes.py:921: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("viridis").copy()
#   newcm.set_under(bgcolor)
# ...
